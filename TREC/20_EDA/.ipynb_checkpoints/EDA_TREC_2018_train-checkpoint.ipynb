# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Vishaal\\Documents\\GitHub\\TREC_Distributed_Machine_Learning\\TREC'

# %%
os.chdir('10_Data/30_Extracted Tweets by Disaster/2018 Train/Ul')

# %%
df = pd.read_csv('Ultimate Dataframe.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-12e1acc9e6d8> in <module>
# ----> 1 df = pd.read_csv('Ultimate Dataframe.csv')
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Ultimate Dataframe.csv' does not exist: b'Ultimate Dataframe.csv'

# %%
df.sample(5)
# Out:
#        Unnamed: 0                  ID  \
# 16556       16556  541460406829473793
# 1028         1028  391798149104549888
# 2934         2934  964349326490251264
# 1960         1960  451304386728177664
# 15964       15964  541401445098991616
#
#                                                    Tweet  \
# 16556  "The Lord will keep you from all harm; He will...
# 1028   #Ø³ÙˆØ±ÙŠØ§ #Ø­Ù…Øµ #Ø­Ù„Ø¨ Australia bush fir...
# 2934   @ChadPergram Fixed it for them"WH: The Trump R...
# 1960   NORTHERN Chile waking up after an 8,2 shake. C...
# 15964  Typhoon Hagupit â€“ in pictures: Preparations ...
#
#                        Event  Retweet_Count  Follower_Count  \
# 16556     typhoonHagupit2014              1             214
# 1028   australiaBushfire2013              0             882
# 2934    flSchoolShooting2018              1              65
# 1960     chileEarthquake2014              1             524
# 15964     typhoonHagupit2014              0            1241
#
#                                                   Source  \
# 16556  <a href="http://twitter.com/download/iphone" r...
# 1028   <a href="http://www.hootsuite.com" rel="nofoll...
# 2934   <a href="http://twitter.com/download/android" ...
# 1960   <a href="http://www.linkedin.com/" rel="nofoll...
# 15964  <a href="http://twitterfeed.com" rel="nofollow...
#
#                       User_Created_at                Tweet_Created_at  \
# 16556  Sat Sep 15 16:36:33 +0000 2012  Sun Dec 07 05:13:15 +0000 2014
# 1028   Wed Jun 06 13:24:29 +0000 2012  Sun Oct 20 05:28:52 +0000 2013
# 2934   Sun Jan 08 19:41:05 +0000 2012  Fri Feb 16 04:02:50 +0000 2018
# 1960   Wed Mar 03 00:19:50 +0000 2010  Wed Apr 02 10:25:25 +0000 2014
# 15964  Tue Apr 19 14:49:42 +0000 2011  Sun Dec 07 01:18:57 +0000 2014
#
#       User_Language User_Screen_Name        User_Location  \
# 16556            en      USTSandigan                  NaN
# 1028             en        awsyrian1                SYRIA
# 2934             en     Liberalmom71  North Carolina, USA
# 1960             en           imaonl             Colombia
# 15964            en        ASAPwaley      Ibadan, Nigeria
#
#                                          Event_Decrption  \
# 16556  Typhoon Hagupit, known in the Philippines as T...
# 1028   The 2013 New South Wales bushfires were a seri...
# 2934   On February 14, 2018, a gunman opened fire at ...
# 1960   The 2014 Iquique earthquake struck off the coa...
# 15964  Typhoon Hagupit, known in the Philippines as T...
#
#                                          Categories Priority
# 16556                                 ['Sentiment']      Low
# 1028              ['ThirdPartyObservation', 'News']      Low
# 2934        ['Discussion', 'ContextualInformation']      Low
# 1960                                 ['Irrelevant']      Low
# 15964  ['ThirdPartyObservation', 'MultimediaShare']      Low

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# ID                   int64
# Tweet               object
# Event               object
# Retweet_Count        int64
# Follower_Count       int64
# Source              object
# User_Created_at     object
# Tweet_Created_at    object
# User_Language       object
# User_Screen_Name    object
# User_Location       object
# Event_Decrption     object
# Categories          object
# Priority            object
# dtype: object

# %%
df.shape
# Out:
# (19840, 15)

# %%
'''
    Converting cols to datetime data type
'''
df['User_Created_at'] = df['User_Created_at'].astype('datetime64')
df['Tweet_Created_at'] = df['Tweet_Created_at'].astype('datetime64')

# %%
'''
    Converting cols to str data type
'''
df['Source'] = df['Source'].astype('str')
df['Event'] = df['Event'].astype('str')

# %%
'''
    Source (device iphone, andorid etc) and user_location have Nans
'''
df.isna().any()
# Out:
# Unnamed: 0          False
# ID                  False
# Tweet               False
# Event               False
# Retweet_Count       False
# Follower_Count      False
# Source              False
# User_Created_at     False
# Tweet_Created_at    False
# User_Language       False
# User_Screen_Name    False
# User_Location        True
# Event_Decrption     False
# Categories          False
# Priority            False
# dtype: bool

# %%
'''
    We seem to have tweets from 2011, 12, 13, 14, 15 and 18
'''
df['Tweet_Created_at'].dt.year.unique()
# Out:
# array([2013, 2014, 2018, 2012, 2011, 2015], dtype=int64)

# %%
df['Tweet_Created_at'].dt.month_name().apply(lambda x:x).value_counts()
# Out:
# April       8500
# December    4247
# November    2732
# February    1158
# August       848
# June         690
# October      675
# January      673
# May          239
# July          78
# Name: Tweet_Created_at, dtype: int64

# %%
'''
    Both March and Sep have no emergency tweets according to our data
'''
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
month_ct = [673, 1158, 0, 8500, 239, 690, 78, 848, 0, 675, 2732, 4247]

# %%
plt.figure(figsize=(12,8))
plt.plot(month, month_ct, 'r')
plt.ylabel('Number of Tweets')
plt.title('Tweets by Month of the Year')
# Out:
# Text(0.5, 1.0, 'Tweets by Month of the Year')

# %%
df['Tweet_Created_at'].dt.weekday_name.apply(lambda x:x).value_counts()
# Out:
# Monday       6447
# Sunday       4413
# Saturday     3995
# Tuesday      1769
# Friday       1213
# Thursday     1043
# Wednesday     960
# Name: Tweet_Created_at, dtype: int64

# %%
'''
    Most tweets from weekend and monday
'''
day = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
day_ct = [6447, 1768, 960, 1043, 1213, 3995, 4413]

# %%
plt.figure(figsize=(12,8))
plt.plot(day, day_ct, 'r')
plt.ylabel('Number of Tweets')
plt.title('Tweets by Day of the Week')
# Out:
# Text(0.5, 1.0, 'Tweets by Day of the Week')

# %%
s_dayct = df['Tweet_Created_at'].dt.day.apply(lambda x:x).value_counts()
s_dayct = s_dayct.sort_index()

# %%
'''
    Not much of an insight from this data but we can see three distinct peaks
'''
plt.figure(figsize=(12,8))
plt.plot(s_dayct.index, s_dayct, 'r')
plt.ylabel('Number of Tweets')
plt.title('Tweets by Day of the Month')
plt.xlabel('Day of the Month')
# Out:
# Text(0.5, 0, 'Day of the Month')

# %%
s_hourct = df['Tweet_Created_at'].dt.hour.apply(lambda x:x).value_counts()
s_hourct = s_hourct.sort_index()

# %%
'''
    Huge average influx of tweets at 7 AM
'''
plt.figure(figsize=(12,8))
plt.plot(s_hourct.index, s_hourct, 'r')
plt.ylabel('Number of Tweets')
plt.xticks(np.arange(0,24))
plt.title('Tweets by Hour of the Day')
plt.xlabel('Hour of the Day')
# Out:
# Text(0.5, 0, 'Hour of the Day')

# %%
s_priority = df['Priority'].apply(lambda x:x).value_counts()
s_priority
# Out:
# Low         13837
# Medium       3153
# High         2697
# Critical      153
# Name: Priority, dtype: int64

# %%
'''
    As predicted most tweets are of low prioity. Critical tweets are far and few. Unbalanced.
'''
plt.figure(figsize=(10,8))
plt.bar(s_priority.index, s_priority, color = 'g')
plt.xlabel('Priority')
plt.ylabel('Number of Tweets')
plt.title('Count of Tweets by Priority')
# Out:
# Text(0.5, 1.0, 'Count of Tweets by Priority')

# %%
'''
    We try to get the count of each type of decvice used to tweet. Not sure how it will be useful yet but
    I guess good to know.
    
    By far, the webclient, iphones and androids are the most popular. It also has to be noted that we have some
    tweets from non-twitter sources like Facebook and some other random websites.
    
    Tweet Deck is dashboard application by twitter to manage multiple twitter accounts.
'''
s_twc = df['Source'].str.contains('Twitter Web Client').apply(lambda x:x).value_counts()
s_tweetdeck = df['Source'].str.contains('TweetDeck').apply(lambda x:x).value_counts()
s_tw = df['Source'].str.contains('Twitter for Websites').apply(lambda x:x).value_counts()
s_tf = df['Source'].str.contains('twitterfeed').apply(lambda x:x).value_counts()
s_iphone = df['Source'].str.contains('Twitter for iPhone').apply(lambda x:x).value_counts()
s_android = df['Source'].str.contains('Twitter for Android').apply(lambda x:x).value_counts()
s_ipad = df['Source'].str.contains('Twitter for iPad').apply(lambda x:x).value_counts()
s_bb = df['Source'].str.contains('Twitter for BlackBerry').apply(lambda x:x).value_counts()
s_f = df['Source'].str.contains('Facebook').apply(lambda x:x).value_counts()

s_tw
# Out:
# False    19561
# True       279
# Name: Source, dtype: int64

# %%
source_type = ['Web Client', 'iPhone', 'Android', 'Twitter Feed', 'Facebook', 'Tweet Deck','iPad', 'BlackBerry', 'Websites']
source_count = [s_twc[1], s_iphone[1], s_android[1], s_tf[1], s_f[1], s_tweetdeck[1], s_ipad[1], s_bb[1], s_tw[1]]

# %%
plt.figure(figsize=(10,8))
plt.bar(source_type, source_count, color = 'blue')
plt.title('Tweets Collected by Source')
# Out:
# Text(0.5, 1.0, 'Tweets Collected by Source')

# %%
'''
    We shall now look at the tweet counts by type of disaster. Attacks, bombings and school shootings are considered 
    separately despite having some commonalities in the nature of the disaster. 
    
    Most of the tweets are from earthquakes and the least are from tornadoes.
'''

event_type = ['Floods', 'Earthquake', 'Bushfire', 'Bombings', 'Tornado', 'Attack', 'SchoolShooting', 'typhoon' ]
event_count = {}
for element in event_type:
    counts = df['Event'].str.contains(element).apply(lambda x:x).value_counts()
    event_count[element] = counts[1]

event_count = sorted(event_count.items(), key=lambda kv: kv[1], reverse = True)
keys = []
val = []
for element in event_count:
    keys.append(element[0])
    val.append(element[1])

# %%
plt.figure(figsize=(10,8))
plt.bar(keys, val, color = 'orange')
plt.title('Tweets Collected by Disaster Type')
# Out:
# Text(0.5, 1.0, 'Tweets Collected by Disaster Type')

# %%
new_df = df[df['Event'].str.contains('Earthquake')]

# %%
'''
    Writing each type of disaster as a new csv file for feature extraction
'''
for element in event_type:
    new_df = df[df['Event'].str.contains(element)]
    new_df.to_csv(element+'_TREC_2018_train.csv')

# %%
a = np.array(df['Tweet'][df['Priority'] == 'Critical'])
len(a)
# Out:
# 153

# %%
event_type = ['Floods', 'Earthquake', 'Bushfire', 'Bombings', 'Tornado', 'Attack', 'SchoolShooting', 'typhoon' ]
l = {}
for element in event_type:
    df_1 = df[(df['Priority'] == 'Critical' or df['Priority'] == 'High') & (df['Event'].str.contains(element))]
    l[element] = df_1.shape[0]
    
l = sorted(l.items(), key=lambda kv: kv[1], reverse = True)
key = []
values = []
for element in l:
    key.append(element[0])
    values.append(element[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6d2f76fcd2c> in <module>
#       2 l = {}
#       3 for element in event_type:
# ----> 4     df_1 = df[(df['Priority'] == 'Critical' or df['Priority'] == 'High') & (df['Event'].str.contains(element))]
#       5     l[element] = df_1.shape[0]
#       6
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(10,8))
plt.bar(key, values, color = 'red')
plt.title('Critical Tweets by Disaster Type')
# Out:
# Text(0.5, 1.0, 'Critical Tweets by Disaster Type')

# %%
df['Event'].unique()
# Out:
# array(['albertaFloods2013', 'australiaBushfire2013', 'bostonBombings2013',
#        'chileEarthquake2014', 'flSchoolShooting2018',
#        'guatemalaEarthquake2012', 'italyEarthquakes2012',
#        'joplinTornado2011', 'manilaFloods2013', 'nepalEarthquake2015',
#        'parisAttacks2015', 'philipinnesFloods2012',
#        'queenslandFloods2013', 'typhoonHagupit2014', 'typhoonYolanda2013'],
#       dtype=object)
