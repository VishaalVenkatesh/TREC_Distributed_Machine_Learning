# %%
'''
    Importing Modules
'''
import csv, os, collections, json
import numpy as np
import pandas as pd
import collections
import preprocessor as p
import itertools
import json
from pprint import pprint

# %%
'''
    Set working directory
'''
filen = 'trecis2018-train/'
files = os.listdir(filen)

# %%
'''
    Function to get event details from json file
'''
def getevents(filename):
    with open(filename, 'r', encoding = 'utf-8' ) as fp:
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
        
    allevents = []
    for eachevent in range(len(data)):
        allevents.append(data[i]['topic'])
    return allevents

# %%
'''
    Function to open each json file about a specific event and obtian info on the tweets
'''

def gettweets(filename):
                
    with open(filename, 'r' ,encoding = 'utf-8' ) as fp:     
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
    
    #print(data[0].keys())
    #print(data[0]['allProperties'].keys())
    #print(data[0])
    #print(data[1]['allProperties']['source'])
    #print(data[1]['allProperties']['text'])
    alltwts = []
    allid = []
    alltopics = []
    retweet = []
    follower_count = []
    source = []
    user_created_at = []
    tweet_created_at = []
    user_lang = []
    user_screen_name = []
    user_location = []
    for i in range (len(data)):
        
        alltwts.append(data[i]['allProperties']['text'])
        allid.append(data[i]['allProperties']['id'])
        alltopics.append(data[i]['topic'])
        retweet.append(data[i]['allProperties']['retweet_count'])
        follower_count.append(data[i]['allProperties']['user.followers_count'])
        source.append(data[i]['allProperties']['source'])
        user_created_at.append(data[i]['allProperties']['user.created_at'])
        tweet_created_at.append(data[i]['allProperties']['created_at'])
        user_lang.append(data[i]['allProperties']['user.lang'])
        user_screen_name.append(data[i]['allProperties']['user.screen_name'])
        user_location.append(data[i]['allProperties']['user.location'])
    return (allid, alltwts, alltopics, retweet, follower_count, source, user_created_at, tweet_created_at, user_lang, user_screen_name, user_location)

# %%
'''
    Appending returned info about the tweets into lists to later create pandas df
'''
ids = []
tweet = []
topic = []
retweet = []
follower_count = []
source = []
user_created_at = []
tweet_created_at = []
user_lang = []
user_screen_name = []
user_location = []
for each in files:
    a, b, c, d, e, f, g, h, i, j, k = gettweets(filen+each)
    ids.extend(a)
    tweet.extend(b)
    topic.extend(c)
    retweet.extend(d)
    follower_count.extend(e)
    source.extend(f)
    user_created_at.extend(g)
    tweet_created_at.extend(h)
    user_lang.extend(i)
    user_screen_name.extend(j)
    user_location.extend(k)

# %%
tweetdf = pd.DataFrame([ids, tweet, topic, retweet, follower_count, source, user_created_at, tweet_created_at, user_lang, user_screen_name, user_location]).T

# %%
tweetdf.columns = ['ID', 'Tweet', 'Event', 'Retweet_Count', 'Follower_Count', 'Source', 'User_Created_at', 'Tweet_Created_at', 'User_Language', 'User_Screen_Name', 'User_Location']

# %%
tweetdf.head(100)
# Out:
#                     ID                                              Tweet  \
# 0   351734622884855808  #yycflood be sure when you are ready for re bu...
# 1   351741648327294977  RT @CansForCalgary: Happy Canada Day everyone!...
# 2   351776825967513600  RT @redcrosscanada: Unloading a truck filled w...
# 3   352043285876977664  Unofficial â€œanthemâ€� of #Alberta floods by ...
# 4   352054501466849280  RT @paulbrandt: Get the Alberta Strong (Flood ...
# 5   352132125450973185  Cheers for the follow @redcrosscanada. Donated...
# 14            en  stephiestylings                   Vancouver, BC
# 15            en    lissaholbrook
# 16            en         NHMS2013                       Hebron KY
# 17            en  platform_design                         Calgary
# 18            id       asrikandis  Nusa Tenggara Barat-Yogyakarta
# 19            en  SteelSlayerMatt
# 20            en        Past_Prez                 New Sarepta, AB
# 21            en     CBDCAtlantic                 Atlantic Canada
# 22            en         CCSD_edu                Calgary, Alberta
# 23            en  brkcanadiannews
# 24            en  manmeetsbhullar
# 25            en         jmcoupal                         Calgary
# 26            en           cfibAB                 Alberta, Canada
# 27            en      foreverjaay
# 28            en         HWesleyE                         Calgary
# 29            en       featherlou
# ..           ...              ...                             ...
# 70            en          Cadrieu                 Bois du GrÃ©zel
# 71            en       CHWorldCup
# 72            en         yychelps                         Calgary
# 73            en         valkyrs_
# 74            en    TeamTaylorYYC                Calgary, Alberta
# 75            en     MoneyMentors                    Alberta-wide
# 76            en     kathy_holder          Central Alberta Canada
# 77            en      graciestyle                         Canada
# 78            en        CanadaKaz                         SFO/YYZ
# 79            da  Radio_Solutions
# 80            en        APinkNewt                Calgary, Alberta
# 81            en       calgarysun      ÃœT: 50.953278,-113.978785
# 82            en           tocyyc                         Calgary
# 83            en        cfcalgary                         Calgary
# 84            en       ralphiecat               Calgary, Alberta
# 85            en     thenickynash              Crossfield/Calgary
# 86            en           MizNVM             North Vancouver, BC
# 87            en          kerdunk                         Canada
# 88            en      benrowley78              Lethbridge Alberta
# 89            en  HuffPostAlberta                         Alberta
# 90            en  FrancainCalgary                         Calgary
# 91            en   TimmermanClark                         Calgary
# 92            en         IanGFoss                      Sidney, BC
# 93            en     daynavettese                 Ontario, Canada
# 94            en    ChanelleBlair
# 95            en       kuvintillo                   Vancouver, BC
# 96            en       jody_blood                         Calgary
# 97            en   CBCHomestretch      ÃœT: 51.054086,-114.083504
# 98            en   lusciousluchia                          Canada
# 99            en         ydfished       edmonton, alberta, canada
#
# [100 rows x 11 columns]

# %%
'''
    Opening a json contianing descriptions about the events on which the tweets are about
'''
with open('TRECIS_2018_2019-labels/TRECIS_2018_2019-labels.json', 'r', encoding = 'utf-8' ) as fp:
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
        tweetid = []
        event_desc = []
        cat = []
        priority = []
        
        for i in range (len(data[0])):
            tweetid.append(data[0][i]['postID'])
            event_desc.append(data[0][i]['eventDescription'])
            cat.append(data[0][i]['postCategories'])
            priority.append(data[0][i]['postPriority'])

# %%
len(tweetid), len(event_desc), len(cat), len(priority)
# Out:
# (38478, 38478, 38478, 38478)

# %%
labeldf = pd.DataFrame([tweetid, event_desc, cat, priority]).T

# %%
labeldf.columns = ['ID', 'Event_Decrption', 'Categories', 'Priority']

# %%
labeldf.tail(10)
# Out:
#                         ID                                    Event_Decrption  \
# 38468  1135532790601068546  The 2019 Alberta wildfires were described by N...
# 38469  1135535392818679808  The 2019 Alberta wildfires were described by N...
# 38470  1135535540051353602  The 2019 Alberta wildfires were described by N...
# 38471  1135551329705873409  The 2019 Alberta wildfires were described by N...
# 38472  1135552993254920194  The 2019 Alberta wildfires were described by N...
# 38473  1135557504484687872  The 2019 Alberta wildfires were described by N...
# 38474  1135560375074603008  The 2019 Alberta wildfires were described by N...
# 38475  1135560828298510336  The 2019 Alberta wildfires were described by N...
# 38476  1135561309573902336  The 2019 Alberta wildfires were described by N...
# 38477  1135561310513451008  The 2019 Alberta wildfires were described by N...
#
#                                               Categories Priority
# 38468  [FirstPartyObservation, Location, MultimediaSh...      Low
# 38469  [Location, MultimediaShare, Factoid, Hashtags,...      Low
# 38470                  [Location, MultimediaShare, News]      Low
# 38471                                         [Location]   Medium
# 38472  [Location, MultimediaShare, Official, Hashtags...      Low
# 38473  [Weather, Location, MultimediaShare, Hashtags,...      Low
# 38474  [Location, MultimediaShare, Official, Hashtags...      Low
# 38475         [Location, Factoid, ContextualInformation]      Low
# 38476        [Location, MultimediaShare, Hashtags, News]      Low
# 38477                [Location, Factoid, Hashtags, News]   Medium

# %%
'''
    Inner join on the tweets and label df to arrive at a comprehensive df
'''

joindf = pd.merge(tweetdf,labeldf,on='ID')

# %%
joindf.head()
# Out:
#                    ID                                              Tweet  \
# 0  351734622884855808  #yycflood be sure when you are ready for re bu...
# 1  351741648327294977  RT @CansForCalgary: Happy Canada Day everyone!...
# 2  351776825967513600  RT @redcrosscanada: Unloading a truck filled w...
# 3  352043285876977664  Unofficial â€œanthemâ€� of #Alberta floods by ...
# 4  352054501466849280  RT @paulbrandt: Get the Alberta Strong (Flood ...
#
#                Event Retweet_Count Follower_Count  \
# 0  albertaFloods2013             0             27
# 1  albertaFloods2013             3            122
# 2  albertaFloods2013            22          11311
# 3  albertaFloods2013             3           4867
# 4  albertaFloods2013            26             94
#
#                                               Source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com" rel="nofollow">Tw...
# 3  <a href="https://about.twitter.com/products/tw...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                   User_Created_at                Tweet_Created_at  \
# 0  Thu Oct 11 13:25:17 +0000 2012  Mon Jul 01 16:10:43 +0000 2013
# 1  Thu Sep 06 04:11:51 +0000 2012  Mon Jul 01 16:38:38 +0000 2013
# 2  Tue Sep 13 19:53:02 +0000 2011  Mon Jul 01 18:58:25 +0000 2013
# 3  Mon Jun 27 19:19:07 +0000 2011  Tue Jul 02 12:37:14 +0000 2013
# 4  Thu Apr 19 19:45:25 +0000 2012  Tue Jul 02 13:21:48 +0000 2013
#
#   User_Language User_Screen_Name         User_Location  \
# 0            en         hstreetz               Calgary
# 1            en      makeitbrain  Edmonton, AB, Canada
# 2            en  Chris_Bentley77      Toronto, Ontario
# 3            en    1310Alexblack                Ottawa
# 4            en     Flames4Life1
#
#                                      Event_Decrption  \
# 0  The 2013 Alberta floods was a case of catastro...
# 1  The 2013 Alberta floods was a case of catastro...
# 2  The 2013 Alberta floods was a case of catastro...
# 3  The 2013 Alberta floods was a case of catastro...
# 4  The 2013 Alberta floods was a case of catastro...
#
#                                  Categories Priority
# 0           [ThirdPartyObservation, Advice]      Low
# 1           [FirstPartyObservation, Advice]      Low
# 2  [ThirdPartyObservation, Sentiment, News]      Low
# 3           [FirstPartyObservation, Advice]      Low
# 4           [ThirdPartyObservation, Advice]      Low

# %%
joindf.to_csv('Ultimate_Dataframe_TREC_2018_train.csv')
