# %%
'''
    Importing Modules
'''
import csv, os, collections, json
import numpy as np
import pandas as pd
import collections
import preprocessor as p
import itertools
import json
from pprint import pprint

# %%
'''
    Set working directory
'''
filen = 'trecis2019-B-test/'
files = os.listdir(filen)

# %%
'''
    Function to get event details from json file
'''
def getevents(filename):
    with open(filename, 'r', encoding = 'utf-8' ) as fp:
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
        
    allevents = []
    for eachevent in range(len(data)):
        allevents.append(data[i]['topic'])
    return allevents

# %%
'''
    Function to open each json file about a specific event and obtian info on the tweets
'''

def gettweets(filename):
                
    with open(filename, 'r' ,encoding = 'utf-8' ) as fp:     
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
    
    #print(data[0].keys())
    #print(data[0]['allProperties'].keys())
    #print(data[0])
    #print(data[1]['allProperties']['source'])
    #print(data[1]['allProperties']['text'])
    alltwts = []
    allid = []
    alltopics = []
    source = []
    user_lang = []
    for i in range (len(data)):
        
        alltwts.append(data[i]['allProperties']['text'])
        allid.append(data[i]['allProperties']['id'])
        alltopics.append(data[i]['topic'])
        source.append(data[i]['allProperties']['source'])
        user_lang.append(data[i]['allProperties']['user.lang'])
    return (allid, alltwts, alltopics,  source , user_lang)

# %%
'''
    Appending returned info about the tweets into lists to later create pandas df
'''
ids = []
tweet = []
topic = []
source = []
user_lang = []
for each in files:
    a, b, c, f,  i = gettweets(filen+each)
    ids.extend(a)
    tweet.extend(b)
    topic.extend(c)
    source.extend(f)
    user_lang.extend(i)

# %%
tweetdf = pd.DataFrame([ids, tweet, topic, source, user_lang]).T

# %%
tweetdf.columns = ['ID', 'Tweet', 'Event', 'Source', 'User_Language']

# %%
tweetdf.head(100)
# Out:
#                      ID                                              Tweet  \
# 0   1134239576111771648  Tolkoâ€™s Athabasca division in Slave Lake, Al...
# 1   1131161667398774784  'Heartbroken' Alberta woman describes wildfire...
# 2   1134148540719017984  There is so much smoke from the high level fir...
# 3   1133705772246786049  Waking to smoky sunrise in Calgary today - eer...
# 4   1134018172309295104  BREAKING: Hundreds of evacuees in Calling Lake...
# 5   1131561862343086081  High Level wildfire crews fight fire with fire...
# 6   1131953405025562625  Stay Safe #HighLevel. We encourage everyone im...
# 7   1135344861106778112  @jkenney wants to support dirty oil, fossil fu...
# 8   1134590404563574784  1/2 Interactive map for Canada wildland fires....
# 9   1134942616414351360  In a Q&amp;A with @EdmontonJournal, Mike Flann...
# 10  1131266442177855488  Update: For those impacted by the wildfires in...
# 11  1130822548252315649  Norbord Reports Fire Near High Level, Alberta ...
# 12  1130859806326218753  Winds helping in battle against fire threateni...
# 13  1130159530342526976  Alberta Wildfire reported seven new wildfires ...
# 14  1133691490880954371  The #Tyne, Swing and High Level Bridges and #G...
# 15  1135234381440643072  High Level wildfires out of control at over 30...
# 16  1130656053710839808  @SPhillipsAB @TheGentYYC Reminder @jkenney May...
# 79  albertaWildfires2019  <a href="http://twitter.com/download/android" ...
# 80  albertaWildfires2019  <a href="http://twitter.com/download/iphone" r...
# 81  albertaWildfires2019  <a href="http://twitter.com/download/android" ...
# 82  albertaWildfires2019  <a href="http://www.facebook.com/twitter" rel=...
# 83  albertaWildfires2019  <a href="https://about.twitter.com/products/tw...
# 84  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
# 85  albertaWildfires2019  <a href="http://twitter.com/download/android" ...
# 86  albertaWildfires2019  <a href="http://twitter.com/download/iphone" r...
# 87  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
# 88  albertaWildfires2019  <a href="http://www.facebook.com/twitter" rel=...
# 89  albertaWildfires2019  <a href="https://mobile.twitter.com" rel="nofo...
# 90  albertaWildfires2019  <a href="http://twitter.com/download/iphone" r...
# 91  albertaWildfires2019  <a href="https://mobile.twitter.com" rel="nofo...
# 92  albertaWildfires2019  <a href="http://twitter.com/download/iphone" r...
# 93  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
# 94  albertaWildfires2019  <a href="http://twitter.com/download/android" ...
# 95  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
# 96  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
# 97  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
# 98  albertaWildfires2019  <a href="http://twitter.com/download/iphone" r...
# 99  albertaWildfires2019  <a href="http://twitter.com" rel="nofollow">Tw...
#
#    User_Language
# 0           null
# 1           null
# 2           null
# 3           null
# 4           null
# 5           null
# 6           null
# 7           null
# 8           null
# 9           null
# 10          null
# 11          null
# 12          null
# 13          null
# 14          null
# 15          null
# 16          null
# 17          null
# 18          null
# 19          null
# 20          null
# 21          null
# 22          null
# 23          null
# 24          null
# 25          null
# 26          null
# 27          null
# 28          null
# 29          null
# ..           ...
# 70          null
# 71          null
# 72          null
# 73          null
# 74          null
# 75          null
# 76          null
# 77          null
# 78          null
# 79          null
# 80          null
# 81          null
# 82          null
# 83          null
# 84          null
# 85          null
# 86          null
# 87          null
# 88          null
# 89          null
# 90          null
# 91          null
# 92          null
# 93          null
# 94          null
# 95          null
# 96          null
# 97          null
# 98          null
# 99          null
#
# [100 rows x 5 columns]

# %%
'''
    Opening a json contianing descriptions about the events on which the tweets are about
'''
with open('TRECIS_2018_2019-labels/TRECIS_2018_2019-labels.json', 'r', encoding = 'utf-8' ) as fp:
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
        tweetid = []
        event_desc = []
        cat = []
        priority = []
        
        for i in range (len(data[0])):
            tweetid.append(data[0][i]['postID'])
            event_desc.append(data[0][i]['eventDescription'])
            cat.append(data[0][i]['postCategories'])
            priority.append(data[0][i]['postPriority'])

# %%
len(tweetid), len(event_desc), len(cat), len(priority)
# Out:
# (38478, 38478, 38478, 38478)

# %%
labeldf = pd.DataFrame([tweetid, event_desc, cat, priority]).T

# %%
labeldf.columns = ['ID', 'Event_Decrption', 'Categories', 'Priority']

# %%
labeldf.tail(10)
# Out:
#                         ID                                    Event_Decrption  \
# 38468  1135532790601068546  The 2019 Alberta wildfires were described by N...
# 38469  1135535392818679808  The 2019 Alberta wildfires were described by N...
# 38470  1135535540051353602  The 2019 Alberta wildfires were described by N...
# 38471  1135551329705873409  The 2019 Alberta wildfires were described by N...
# 38472  1135552993254920194  The 2019 Alberta wildfires were described by N...
# 38473  1135557504484687872  The 2019 Alberta wildfires were described by N...
# 38474  1135560375074603008  The 2019 Alberta wildfires were described by N...
# 38475  1135560828298510336  The 2019 Alberta wildfires were described by N...
# 38476  1135561309573902336  The 2019 Alberta wildfires were described by N...
# 38477  1135561310513451008  The 2019 Alberta wildfires were described by N...
#
#                                               Categories Priority
# 38468  [FirstPartyObservation, Location, MultimediaSh...      Low
# 38469  [Location, MultimediaShare, Factoid, Hashtags,...      Low
# 38470                  [Location, MultimediaShare, News]      Low
# 38471                                         [Location]   Medium
# 38472  [Location, MultimediaShare, Official, Hashtags...      Low
# 38473  [Weather, Location, MultimediaShare, Hashtags,...      Low
# 38474  [Location, MultimediaShare, Official, Hashtags...      Low
# 38475         [Location, Factoid, ContextualInformation]      Low
# 38476        [Location, MultimediaShare, Hashtags, News]      Low
# 38477                [Location, Factoid, Hashtags, News]   Medium

# %%
'''
    Inner join on the tweets and label df to arrive at a comprehensive df
'''

joindf = pd.merge(tweetdf,labeldf,on='ID')

# %%
joindf.head()
# Out:
#                     ID                                              Tweet  \
# 0  1134239576111771648  Tolkoâ€™s Athabasca division in Slave Lake, Al...
# 1  1131161667398774784  'Heartbroken' Alberta woman describes wildfire...
# 2  1134148540719017984  There is so much smoke from the high level fir...
# 3  1133705772246786049  Waking to smoky sunrise in Calgary today - eer...
# 4  1134018172309295104  BREAKING: Hundreds of evacuees in Calling Lake...
#
#                   Event                                             Source  \
# 0  albertaWildfires2019  <a href="https://dlvrit.com/" rel="nofollow">d...
# 1  albertaWildfires2019  <a href="https://www.awayshare.com/" rel="nofo...
# 2  albertaWildfires2019  <a href="http://twitter.com/download/iphone" r...
# 3  albertaWildfires2019  <a href="http://twitter.com/download/android" ...
# 4  albertaWildfires2019  <a href="https://about.twitter.com/products/tw...
#
#   User_Language                                    Event_Decrption  \
# 0          null  The 2019 Alberta wildfires were described by N...
# 1          null  The 2019 Alberta wildfires were described by N...
# 2          null  The 2019 Alberta wildfires were described by N...
# 3          null  The 2019 Alberta wildfires were described by N...
# 4          null  The 2019 Alberta wildfires were described by N...
#
#                             Categories  Priority
# 0                     [Location, News]      High
# 1                         [Irrelevant]       Low
# 2                         [Irrelevant]       Low
# 3                         [Irrelevant]       Low
# 4  [Location, Factoid, Hashtags, News]  Critical

# %%
joindf.to_csv('Ultimate_Dataframe_TREC_2019_B-test.csv')
