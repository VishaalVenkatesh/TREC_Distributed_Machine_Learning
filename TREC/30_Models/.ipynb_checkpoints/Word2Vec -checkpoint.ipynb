# %%
import os
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import string
import re
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
import logging
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
from nltk import bigrams

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Vishaal\\Documents\\GitHub\\TREC_Distributed_Machine_Learning\\TREC\\30_Models'

# %% [markdown]
# ## Reading in the Data:
#
# We have used all the tweets from 2018 (train and test) to create the embeddings. However, balanced datasets have been used to train and test the model. The following code reads in all the data. Note, we are only considering earthquakes and floods in the following sections and we will build separate models for each earthquakes and floods.

# %%
os.chdir('../10_Data/30_Balanced Tweets (Crit = High = Medium = Low)/10_2018 Train')

# %%
df_e1 = pd.read_csv('earthquake_TREC_2018_train_BALANCED.csv')
df_f1 = pd.read_csv('flood_TREC_2018_train_BALANCED.csv')

# %%
os.chdir('../15_2018 Test')

# %%
df_e2 = pd.read_csv('earthquake_TREC_2018_test_BALANCED.csv')
df_f2 = pd.read_csv('flood_TREC_2018_test_BALANCED.csv')

# %%
os.chdir('../../20_Extracted Tweets/10_2018 Train')

# %%
df_e1_embed = pd.read_csv('Earthquake_TREC_2018_train.csv')
df_f1_embed = pd.read_csv('flood_TREC_2018_train.csv')

# %%
os.chdir('../15_2018 Test')

# %%
df_e2_embed = pd.read_csv('Earthquake_TREC_2018_test.csv')
df_f2_embed = pd.read_csv('Floods_TREC_2018_test.csv')

# %% [markdown]
# ## Combining dataframes
# We are now combine earthquake tweets into one df and flood tweets into another df. We have subsetting on the tweets and priority columns. We do this for both the embedding dataframes and our balanced datasets, although we will not use the balanced datasets until later.

# %%
df_quake_e = pd.DataFrame()
df_quake_e['Tweet'] = pd.concat([df_e1_embed['Tweet'] , df_e2_embed['Tweet']])
df_quake_e['Priority'] = pd.concat([df_e1_embed['Priority'] , df_e2_embed['Priority']])

# %%
df_flood_e = pd.DataFrame()
df_flood_e['Tweet'] = pd.concat([df_f1_embed['Tweet'] , df_f2_embed['Tweet']])
df_flood_e['Priority'] = pd.concat([df_f1_embed['Priority'] , df_f2_embed['Priority']])

# %%
df_quake = pd.DataFrame()
df_quake['Tweet'] = pd.concat([df_e1['Tweet'] , df_e2['Tweet']])
df_quake['Priority'] = pd.concat([df_e1['Priority'] , df_e2['Priority']])

# %%
df_flood = pd.DataFrame()
df_flood['Tweet'] = pd.concat([df_f1['Tweet'] , df_f2['Tweet']])
df_flood['Priority'] = pd.concat([df_f1['Priority'] , df_f2['Priority']])

# %% [markdown]
# Cross checking the shapes to make sure they match. **They do match**

# %%
df_quake_e.shape, df_flood_e.shape, df_quake.shape, df_flood.shape
# Out:
# ((5140, 2), (2518, 2), (100, 2), (120, 2))

# %% [markdown]
# ## Converting to categorical (0 & 1)
#
# We will now define a function to convert the priority to a categorical 0 & 1. This will be necessary when we train a model.

# %%
'''
Creating a categorical variable to keep label critical tweets as 1 and 0 otherwise
'''
def to_categorical(df_c):
    t = []
    for element in df_c['Priority']:
        if element =='Critical':
            t.append(1)
        else:
            t.append(0)
        
    t = np.array(t)
    df_c['Target'] = t

    df_c['Target'] = df_c['Target'].astype('category')
    t = df_c['Target']
    del df_c['Target']
    return (t)

t_quake_e = to_categorical(df_quake_e)
t_flood_e = to_categorical(df_flood_e)
t_quake = to_categorical(df_quake)
t_flood = to_categorical(df_flood)

# %% [markdown]
# ## Pre-Processing
#
# We shall now perform a series of pre processing to our tweets. This includes tokenizing them, removing stop words and lemmatising them.
#
# **I also wrote a line of code to remove the links in the tweets as it was throwing in a lot of gibberish into the emebddings.** The link is almost always at the end of the tweet so its relatively easy to remove.
#
# I left the punctuation marks in. We have to take a call on this later.

# %%
def preProcess(df):
    df['Tweet'] = df['Tweet'].astype('str')
    
    df['Tweet'] = df['Tweet'].apply(lambda x: re.split('http?s *: *\/\/.*', str(x))[0])
    
    token_array = []
    #for tweet in df['Tweet']:
    #    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    #    tweet = tweet.translate(translator)
    #    token_tweet = word_tokenize(tweet)
    #    token_array.append(token_tweet)
    
    for tweet in df['Tweet']:
        token_tweet = word_tokenize(tweet)
        token_array.append(token_tweet)
        
    stop_words=set(stopwords.words("english"))
    filtered_token_array=[]
    for tweet in token_array:
        filtered_tweet = []
        for word in tweet:
                if word not in stop_words:
                    filtered_tweet.append(word)
        filtered_token_array.append(filtered_tweet)
        
    lem = WordNetLemmatizer()

    lemmatized_array=[]
    for tweet in filtered_token_array:
        lemmatized_tweet = []
        for word in tweet:
            lemmatized_tweet.append(lem.lemmatize(word,'v'))
        lemmatized_array.append(lemmatized_tweet)
    
    lemmatized_array_join = []
    for element in lemmatized_array:
        lemmatized_array_join.append(' '.join(element))
        
    return (lemmatized_array_join)

# %% [markdown]
# The tweets have been pre processed and we now have a collection of tweets. Word2Vec takes in a list of words together contained in a bigger list (Corpus -> List of Tweet -> List of Words).

# %%
l_quake_e = preProcess(df_quake_e)
l_flood_e = preProcess(df_flood_e)

list_of_words_quake = []
list_of_words_flood = []

for tweet in l_quake_e:
        token_tweet = word_tokenize(tweet)
        list_of_words_quake.append(token_tweet)
        
for tweet in l_flood_e:
        token_tweet = word_tokenize(tweet)
        list_of_words_flood.append(token_tweet)

# %% [markdown]
# ## Creating a Word2Vec model
#
# We will now initialise a word2vec model. This takes in a paramter 'min_count' which is the number of minimum occurences of a word required for it be included in the embeddings. **For now we set min_count = 1**. I did this because we are creating our own embeddings (not picking from wikipedia embeddings etc) and our data is not that huge.

# %%
'''
min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)

window = int - The maximum distance between the current and predicted word within a sentence. 
        E.g. window words on the left and window words on the left of our target - (2, 10)

size = int - Dimensionality of the feature vectors. - (50, 300)

sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. 
        Highly influencial. - (0, 1e-5)

alpha = float - The initial learning rate - (0.01, 0.05)

min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. 
        To set it: alpha - (min_alpha * epochs) ~ 0.00

negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" 
        should be drown. If set to 0, no negative sampling is used. - (5, 20)
        
workers = int - Use these many worker threads to train the model (=faster training with multicore machines)
'''
w2v_quake = Word2Vec(min_count=1,
                     window=4,
                     size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20)
w2v_flood = Word2Vec(min_count=1,
                     window=4,
                     size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20)

# %% [markdown]
# We will now build our vocabulary. Do not run the following code multiple times before initialising the w2v instance again from above.

# %%
w2v_quake.build_vocab(list_of_words_quake)
w2v_flood.build_vocab(list_of_words_flood)
# Out:
# INFO - 11:02:00: collecting all words and their counts
# INFO - 11:02:00: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 11:02:00: collected 11096 word types from a corpus of 61156 raw words and 5140 sentences
# INFO - 11:02:00: Loading a fresh vocabulary
# INFO - 11:02:00: effective_min_count=1 retains 11096 unique words (100% of original 11096, drops 0)
# INFO - 11:02:00: effective_min_count=1 leaves 61156 word corpus (100% of original 61156, drops 0)
# INFO - 11:02:00: deleting the raw counts dictionary of 11096 items
# INFO - 11:02:00: sample=6e-05 downsamples 771 most-common words
# INFO - 11:02:00: downsampling leaves estimated 29229 word corpus (47.8% of prior 61156)
# INFO - 11:02:00: estimated required memory for 11096 words and 100 dimensions: 14424800 bytes
# INFO - 11:02:00: resetting layer weights
# INFO - 11:02:02: collecting all words and their counts
# INFO - 11:02:02: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 11:02:02: collected 8277 word types from a corpus of 43000 raw words and 2518 sentences
# INFO - 11:02:02: Loading a fresh vocabulary
# INFO - 11:02:02: effective_min_count=1 retains 8277 unique words (100% of original 8277, drops 0)
# INFO - 11:02:02: effective_min_count=1 leaves 43000 word corpus (100% of original 43000, drops 0)
# INFO - 11:02:02: deleting the raw counts dictionary of 8277 items
# INFO - 11:02:02: sample=6e-05 downsamples 816 most-common words
# INFO - 11:02:02: downsampling leaves estimated 19950 word corpus (46.4% of prior 43000)
# INFO - 11:02:02: estimated required memory for 8277 words and 100 dimensions: 10760100 bytes
# INFO - 11:02:02: resetting layer weights

# %% [markdown]
# The following code is to view the vocabulary that we created

# %%
vocabulary_quake = w2v_quake.wv.vocab
vocabulary_flood = w2v_flood.wv.vocab
vocabulary_quake
# Out:
# {'ã€�': <gensim.models.keyedvectors.Vocab at 0x228e98ebfd0>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x228ee6189b0>,
#  'USGS': <gensim.models.keyedvectors.Vocab at 0x228ee618c50>,
#  'Breakingã€': <gensim.models.keyedvectors.Vocab at 0x228ee615b00>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x228ee615748>,
#  'M': <gensim.models.keyedvectors.Vocab at 0x228ee6156a0>,
#  '1.1': <gensim.models.keyedvectors.Vocab at 0x228ee615c18>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x228ee615860>,
#  '28km': <gensim.models.keyedvectors.Vocab at 0x228ee615eb8>,
#  'SSW': <gensim.models.keyedvectors.Vocab at 0x228ee615048>,
#  'Fairbanks': <gensim.models.keyedvectors.Vocab at 0x228ee6154e0>,
#  'Alaska': <gensim.models.keyedvectors.Vocab at 0x228ee6154a8>,
#  'Earthquake': <gensim.models.keyedvectors.Vocab at 0x228ee6158d0>,
#  '4.8': <gensim.models.keyedvectors.Vocab at 0x228ee615d30>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x228ee615c88>,
#  'Bali': <gensim.models.keyedvectors.Vocab at 0x228ee615d68>,
#  'Indonesia': <gensim.models.keyedvectors.Vocab at 0x228eebb1908>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x228eebb1940>,
#  'September': <gensim.models.keyedvectors.Vocab at 0x228eebb1978>,
#  '04': <gensim.models.keyedvectors.Vocab at 0x228eebb19b0>,
#  '2012': <gensim.models.keyedvectors.Vocab at 0x228eebb19e8>,
#  '21:19:30': <gensim.models.keyedvectors.Vocab at 0x228eebb1be0>,
#  'GMT': <gensim.models.keyedvectors.Vocab at 0x228eebb1ba8>,
#  'earthquake': <gensim.models.keyedvectors.Vocab at 0x228eebb1a20>,
#  '4.5': <gensim.models.keyedvectors.Vocab at 0x228eebb1c88>,
#  'Taiwan': <gensim.models.keyedvectors.Vocab at 0x228eebb1cc0>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x228eebb1cf8>,
#  '2.6': <gensim.models.keyedvectors.Vocab at 0x228eebb1d30>,
#  'Hawaii': <gensim.models.keyedvectors.Vocab at 0x228eebb1d68>,
#  'Magnitude': <gensim.models.keyedvectors.Vocab at 0x228eebb1da0>,
#  '7.9': <gensim.models.keyedvectors.Vocab at 0x228eebb1dd8>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x228eebb1e10>,
#  'coast': <gensim.models.keyedvectors.Vocab at 0x228eebb1e48>,
#  'Costa': <gensim.models.keyedvectors.Vocab at 0x228eebb1e80>,
#  'Rica': <gensim.models.keyedvectors.Vocab at 0x228eebb1eb8>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x228eebb1ef0>,
#  'RT': <gensim.models.keyedvectors.Vocab at 0x228eebb1f28>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x228eebb1f60>,
#  'Reuters': <gensim.models.keyedvectors.Vocab at 0x228eebb1f98>,
#  'Live': <gensim.models.keyedvectors.Vocab at 0x228eebb1fd0>,
#  'coverage': <gensim.models.keyedvectors.Vocab at 0x228eebb7048>,
#  '7.9-magnitude': <gensim.models.keyedvectors.Vocab at 0x228eebb7080>,
#  'rattle': <gensim.models.keyedvectors.Vocab at 0x228eebb70b8>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x228eebb70f0>,
#  'tsunami': <gensim.models.keyedvectors.Vocab at 0x228eebb7128>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x228eebb7160>,
#  'Caribbean': <gensim.models.keyedvectors.Vocab at 0x228eebb7198>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x228eebb71d0>,
#  'ãƒ‡ã‚': <gensim.models.keyedvectors.Vocab at 0x228eebb7208>,
#  '«': <gensim.models.keyedvectors.Vocab at 0x228eebb7240>,
#  'ã‚¤ã�ªã€‚ã�§ã�‹ã�™ã�Žã‚‹ã�œã€�ãƒ™ã‚¯ãƒ†ãƒ': <gensim.models.keyedvectors.Vocab at 0x228eebb7278>,
#  'ï¼�': <gensim.models.keyedvectors.Vocab at 0x228eebb72b0>,
#  'BreakingNews': <gensim.models.keyedvectors.Vocab at 0x228eebb72e8>,
#  'Caribbean-wide': <gensim.models.keyedvectors.Vocab at 0x228eebb7320>,
#  'Rican': <gensim.models.keyedvectors.Vocab at 0x228eebb7358>,
#  'quake': <gensim.models.keyedvectors.Vocab at 0x228eebb7390>,
#  'Pacific': <gensim.models.keyedvectors.Vocab at 0x228eebb73c8>,
#  'Tsunami': <gensim.models.keyedvectors.Vocab at 0x228eebb7400>,
#  'Warning': <gensim.models.keyedvectors.Vocab at 0x228eebb7438>,
#  'Center': <gensim.models.keyedvectors.Vocab at 0x228eebb7470>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x228eebb74a8>,
#  'lgf': <gensim.models.keyedvectors.Vocab at 0x228eebb74e0>,
#  'p2': <gensim.models.keyedvectors.Vocab at 0x228eebb7518>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x228eebb7550>,
#  'magnitude-5.8': <gensim.models.keyedvectors.Vocab at 0x228eebb7588>,
#  'More': <gensim.models.keyedvectors.Vocab at 0x228eebb75c0>,
#  'coastline': <gensim.models.keyedvectors.Vocab at 0x228eebb75f8>,
#  'AlertNet': <gensim.models.keyedvectors.Vocab at 0x228eebb7630>,
#  'Strong': <gensim.models.keyedvectors.Vocab at 0x228eebb7668>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x228eebb76a0>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x228eebb76d8>,
#  'RobertaCBS5': <gensim.models.keyedvectors.Vocab at 0x228eebb7710>,
#  'Breaking': <gensim.models.keyedvectors.Vocab at 0x228eebb7748>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x228eebb7780>,
#  'Tsunmai': <gensim.models.keyedvectors.Vocab at 0x228eebb77b8>,
#  'WARNING': <gensim.models.keyedvectors.Vocab at 0x228eebb77f0>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x228eebb7828>,
#  'Central': <gensim.models.keyedvectors.Vocab at 0x228eebb7860>,
#  'America': <gensim.models.keyedvectors.Vocab at 0x228eebb7898>,
#  'magnitude': <gensim.models.keyedvectors.Vocab at 0x228eebb78d0>,
#  'Birth': <gensim.models.keyedvectors.Vocab at 0x228eebb7908>,
#  'pangs': <gensim.models.keyedvectors.Vocab at 0x228eebb7940>,
#  'NewEarthquake': <gensim.models.keyedvectors.Vocab at 0x228eebb7978>,
#  'Sep': <gensim.models.keyedvectors.Vocab at 0x228eebb79b0>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x228eebb79e8>,
#  '8:42am': <gensim.models.keyedvectors.Vocab at 0x228eebb7a20>,
#  'epicenter': <gensim.models.keyedvectors.Vocab at 0x228eebb7a58>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x228eebb7a90>,
#  '6m': <gensim.models.keyedvectors.Vocab at 0x228eebb7ac8>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x228eebb7b00>,
#  '83km': <gensim.models.keyedvectors.Vocab at 0x228eebb7b38>,
#  'S': <gensim.models.keyedvectors.Vocab at 0x228eebb7b70>,
#  'Liberia': <gensim.models.keyedvectors.Vocab at 0x228eebb7ba8>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x228eebb7be0>,
#  '46km': <gensim.models.keyedvectors.Vocab at 0x228eebb7c18>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x228eebb7c50>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x228eebb7c88>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x228eebb7cc0>,
#  'Oh': <gensim.models.keyedvectors.Vocab at 0x228eebb7cf8>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x228eebb7d30>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x228eebb7d68>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x228eebb7da0>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x228eebb7dd8>,
#  'Nids_ShriKant': <gensim.models.keyedvectors.Vocab at 0x228eebb7e10>,
#  'Rica..': <gensim.models.keyedvectors.Vocab at 0x228eebb7e48>,
#  'Now': <gensim.models.keyedvectors.Vocab at 0x228eebb7e80>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x228eebb7eb8>,
#  'KeepSafe': <gensim.models.keyedvectors.Vocab at 0x228eebb7ef0>,
#  'GodBless': <gensim.models.keyedvectors.Vocab at 0x228eebb7f28>,
#  'costa': <gensim.models.keyedvectors.Vocab at 0x228eebb7f60>,
#  'rica': <gensim.models.keyedvectors.Vocab at 0x228eebb7f98>,
#  '7,9SR': <gensim.models.keyedvectors.Vocab at 0x228eebb7fd0>,
#  'CHILE': <gensim.models.keyedvectors.Vocab at 0x228eebb9048>,
#  "'S": <gensim.models.keyedvectors.Vocab at 0x228eebb9080>,
#  'NAVY': <gensim.models.keyedvectors.Vocab at 0x228eebb90b8>,
#  'SAYS': <gensim.models.keyedvectors.Vocab at 0x228eebb90f0>,
#  'DECLARES': <gensim.models.keyedvectors.Vocab at 0x228eebb9128>,
#  'TSUNAMI': <gensim.models.keyedvectors.Vocab at 0x228eebb9160>,
#  'ALERT': <gensim.models.keyedvectors.Vocab at 0x228eebb9198>,
#  'FOR': <gensim.models.keyedvectors.Vocab at 0x228eebb91d0>,
#  'CHILEAN': <gensim.models.keyedvectors.Vocab at 0x228eebb9208>,
#  'COAST': <gensim.models.keyedvectors.Vocab at 0x228eebb9240>,
#  'FOLLOWING': <gensim.models.keyedvectors.Vocab at 0x228eebb9278>,
#  'COSTA': <gensim.models.keyedvectors.Vocab at 0x228eebb92b0>,
#  'RICA': <gensim.models.keyedvectors.Vocab at 0x228eebb92e8>,
#  'QUAKE': <gensim.models.keyedvectors.Vocab at 0x228eebb9320>,
#  'CP24': <gensim.models.keyedvectors.Vocab at 0x228eebb9358>,
#  'BREAKING': <gensim.models.keyedvectors.Vocab at 0x228eebb9390>,
#  'Coast': <gensim.models.keyedvectors.Vocab at 0x228eebb93c8>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x228eebb9400>,
#  'No': <gensim.models.keyedvectors.Vocab at 0x228eebb9438>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x228eebb9470>,
#  'damage/injuries': <gensim.models.keyedvectors.Vocab at 0x228eebb94a8>,
#  'TWCBreaking': <gensim.models.keyedvectors.Vocab at 0x228eebb94e0>,
#  'Mag': <gensim.models.keyedvectors.Vocab at 0x228eebb9518>,
#  'Mexico': <gensim.models.keyedvectors.Vocab at 0x228eebb9550>,
#  'C.': <gensim.models.keyedvectors.Vocab at 0x228eebb9588>,
#  'S.': <gensim.models.keyedvectors.Vocab at 0x228eebb95c0>,
#  'â€œ': <gensim.models.keyedvectors.Vocab at 0x228eebb95f8>,
#  'USGSâ€�': <gensim.models.keyedvectors.Vocab at 0x228eebb9630>,
#  'YahooNews': <gensim.models.keyedvectors.Vocab at 0x228eebb9668>,
#  'Please': <gensim.models.keyedvectors.Vocab at 0x228eebb96a0>,
#  'pray': <gensim.models.keyedvectors.Vocab at 0x228eebb96d8>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x228eebb9710>,
#  'magnitude-7.9': <gensim.models.keyedvectors.Vocab at 0x228eebb9748>,
#  'CostaRica': <gensim.models.keyedvectors.Vocab at 0x228eebb9780>,
#  'accord': <gensim.models.keyedvectors.Vocab at 0x228eebb97b8>,
#  'BBCWorld': <gensim.models.keyedvectors.Vocab at 0x228eebb97f0>,
#  'Details': <gensim.models.keyedvectors.Vocab at 0x228eebb9828>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x228eebb9860>,
#  'QuakeReports': <gensim.models.keyedvectors.Vocab at 0x228eebb9898>,
#  'MEXICO': <gensim.models.keyedvectors.Vocab at 0x228eebb98d0>,
#  'CITY': <gensim.models.keyedvectors.Vocab at 0x228eebb9908>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x228eebb9940>,
#  'miles': <gensim.models.keyedvectors.Vocab at 0x228eebb9978>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x228eebb99b0>,
#  'northwestern': <gensim.models.keyedvectors.Vocab at 0x228eebb99e8>,
#  'Wednesday..': <gensim.models.keyedvectors.Vocab at 0x228eebb9a20>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x228eebb9a58>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x228eebb9a90>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x228eebb9ac8>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x228eebb9b00>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x228eebb9b38>,
#  'fieldproducer': <gensim.models.keyedvectors.Vocab at 0x228eebb9b70>,
#  'revise': <gensim.models.keyedvectors.Vocab at 0x228eebb9ba8>,
#  '7.6': <gensim.models.keyedvectors.Vocab at 0x228eebb9be0>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x228eebb9c18>,
#  'My': <gensim.models.keyedvectors.Vocab at 0x228eebb9c50>,
#  'prayers': <gensim.models.keyedvectors.Vocab at 0x228eebb9c88>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x228eebb9cc0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x228eebb9cf8>,
#  'They': <gensim.models.keyedvectors.Vocab at 0x228eebb9d30>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x228eebb9d68>,
#  'Powerful': <gensim.models.keyedvectors.Vocab at 0x228eebb9da0>,
#  'CNBC': <gensim.models.keyedvectors.Vocab at 0x228eebb9dd8>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x228eebb9e10>,
#  '98': <gensim.models.keyedvectors.Vocab at 0x228eebb9e48>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x228eebb9e80>,
#  'Jose': <gensim.models.keyedvectors.Vocab at 0x228eebb9eb8>,
#  'Chile': <gensim.models.keyedvectors.Vocab at 0x228eebb9ef0>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x228eebb9f28>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x228eebb9f60>,
#  'declare': <gensim.models.keyedvectors.Vocab at 0x228eebb9f98>,
#  'alert': <gensim.models.keyedvectors.Vocab at 0x228eebb9fd0>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x228eebbb048>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x228eebbb080>,
#  'Revised': <gensim.models.keyedvectors.Vocab at 0x228eebbb0b8>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x228eebbb0f0>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x228eebbb128>,
#  '24m': <gensim.models.keyedvectors.Vocab at 0x228eebbb160>,
#  '60km': <gensim.models.keyedvectors.Vocab at 0x228eebbb198>,
#  'SSE': <gensim.models.keyedvectors.Vocab at 0x228eebbb1d0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x228eebbb208>,
#  'irasuwindro': <gensim.models.keyedvectors.Vocab at 0x228eebbb240>,
#  'RT_com': <gensim.models.keyedvectors.Vocab at 0x228eebbb278>,
#  'Quake': <gensim.models.keyedvectors.Vocab at 0x228eebbb2b0>,
#  'Hits': <gensim.models.keyedvectors.Vocab at 0x228eebbb2e8>,
#  'Damn': <gensim.models.keyedvectors.Vocab at 0x228eebbb320>,
#  'Poor': <gensim.models.keyedvectors.Vocab at 0x228eebbb358>,
#  'cnnbrk': <gensim.models.keyedvectors.Vocab at 0x228eebbb390>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x228eebbb3c8>,
#  'ccbp': <gensim.models.keyedvectors.Vocab at 0x228eebbb400>,
#  'Big': <gensim.models.keyedvectors.Vocab at 0x228eebbb438>,
#  'M7.9': <gensim.models.keyedvectors.Vocab at 0x228eebbb470>,
#  'occurrred': <gensim.models.keyedvectors.Vocab at 0x228eebbb4a8>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x228eebbb4e0>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x228eebbb518>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x228eebbb550>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x228eebbb588>,
#  '7.6-magnitude': <gensim.models.keyedvectors.Vocab at 0x228eebbb5c0>,
#  'weathernetwork': <gensim.models.keyedvectors.Vocab at 0x228eebbb5f8>,
#  'Reports': <gensim.models.keyedvectors.Vocab at 0x228eebbb630>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x228eebbb668>,
#  'collapse': <gensim.models.keyedvectors.Vocab at 0x228eebbb6a0>,
#  'church': <gensim.models.keyedvectors.Vocab at 0x228eebbb6d8>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x228eebbb710>,
#  'Nicoya': <gensim.models.keyedvectors.Vocab at 0x228eebbb748>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x228eebbb780>,
#  'epicentre': <gensim.models.keyedvectors.Vocab at 0x228eebbb7b8>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x228eebbb7f0>,
#  '7.6-mag': <gensim.models.keyedvectors.Vocab at 0x228eebbb828>,
#  'For': <gensim.models.keyedvectors.Vocab at 0x228eebbb860>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x228eebbb898>,
#  'Hawaii..': <gensim.models.keyedvectors.Vocab at 0x228eebbb8d0>,
#  'case..': <gensim.models.keyedvectors.Vocab at 0x228eebbb908>,
#  'mag': <gensim.models.keyedvectors.Vocab at 0x228eebbb940>,
#  'prompt': <gensim.models.keyedvectors.Vocab at 0x228eebbb978>,
#  'karmonan': <gensim.models.keyedvectors.Vocab at 0x228eebbb9b0>,
#  'Radio_Riquelme': <gensim.models.keyedvectors.Vocab at 0x228eebbb9e8>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x228eebbba20>,
#  'coastal': <gensim.models.keyedvectors.Vocab at 0x228eebbba58>,
#  'htt': <gensim.models.keyedvectors.Vocab at 0x228eebbba90>,
#  'CNN': <gensim.models.keyedvectors.Vocab at 0x228eebbbac8>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x228eebbbb00>,
#  'CBSNews': <gensim.models.keyedvectors.Vocab at 0x228eebbbb38>,
#  'LATEST': <gensim.models.keyedvectors.Vocab at 0x228eebbbb70>,
#  'DETAILS': <gensim.models.keyedvectors.Vocab at 0x228eebbbba8>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x228eebbbbe0>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x228eebbbc18>,
#  'JamaicaGleaner': <gensim.models.keyedvectors.Vocab at 0x228eebbbc50>,
#  'Yahoo/Space-': <gensim.models.keyedvectors.Vocab at 0x228eebbbc88>,
#  'WASHINGTON': <gensim.models.keyedvectors.Vocab at 0x228eebbbcc0>,
#  'magnit': <gensim.models.keyedvectors.Vocab at 0x228eebbbcf8>,
#  'Yahoo': <gensim.models.keyedvectors.Vocab at 0x228eebbbd30>,
#  'News': <gensim.models.keyedvectors.Vocab at 0x228eebbbd68>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x228eebbbda0>,
#  'preliminary': <gensim.models.keyedvectors.Vocab at 0x228eebbbdd8>,
#  'Pura': <gensim.models.keyedvectors.Vocab at 0x228eebbbe10>,
#  'Vida': <gensim.models.keyedvectors.Vocab at 0x228eebbbe48>,
#  'EliteDaily': <gensim.models.keyedvectors.Vocab at 0x228eebbbe80>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x228eebbbeb8>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x228eebbbef0>,
#  'warning-': <gensim.models.keyedvectors.Vocab at 0x228eebbbf28>,
#  'there-just': <gensim.models.keyedvectors.Vocab at 0x228eebbbf60>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x228eebbbf98>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x228eebbbfd0>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x228eebbd048>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x228eebbd080>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x228eebbd0b8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x228eebbd0f0>,
#  'abc7newsBayArea': <gensim.models.keyedvectors.Vocab at 0x228eebbd128>,
#  'abcnews': <gensim.models.keyedvectors.Vocab at 0x228eebbd160>,
#  'Magnitude-7.6': <gensim.models.keyedvectors.Vocab at 0x228eebbd198>,
#  '_mannymeister': <gensim.models.keyedvectors.Vocab at 0x228eebbd1d0>,
#  'thankyou': <gensim.models.keyedvectors.Vocab at 0x228eebbd208>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x228eebbd240>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x228eebbd278>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x228eebbd2b0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x228eebbd2e8>,
#  "'m": <gensim.models.keyedvectors.Vocab at 0x228eebbd320>,
#  'md': <gensim.models.keyedvectors.Vocab at 0x228eebbd358>,
#  'SonOfAKing3': <gensim.models.keyedvectors.Vocab at 0x228eebbd390>,
#  'UnivisionNews': <gensim.models.keyedvectors.Vocab at 0x228eebbd3c8>,
#  'Northwestern': <gensim.models.keyedvectors.Vocab at 0x228eebbd400>,
#  'Ricaâ€�': <gensim.models.keyedvectors.Vocab at 0x228eebbd438>,
#  '100prayingwomen': <gensim.models.keyedvectors.Vocab at 0x228eebbd470>,
#  'Interior': <gensim.models.keyedvectors.Vocab at 0x228eebbd4a8>,
#  'Minister': <gensim.models.keyedvectors.Vocab at 0x228eebbd4e0>,
#  'Hinzpeter': <gensim.models.keyedvectors.Vocab at 0x228eebbd518>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x228eebbd550>,
#  'evacuation': <gensim.models.keyedvectors.Vocab at 0x228eebbd588>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x228eebbd5c0>,
#  'LisaDCNN': <gensim.models.keyedvectors.Vocab at 0x228eebbd5f8>,
#  'UPDATE': <gensim.models.keyedvectors.Vocab at 0x228eebbd630>,
#  'CNNweather': <gensim.models.keyedvectors.Vocab at 0x228eebbd668>,
#  'Warnings': <gensim.models.keyedvectors.Vocab at 0x228eebbd6a0>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x228eebbd6d8>,
#  'Panama': <gensim.models.keyedvectors.Vocab at 0x228eebbd710>,
#  'Nicaragua': <gensim.models.keyedvectors.Vocab at 0x228eebbd748>,
#  '7.6M': <gensim.models.keyedvectors.Vocab at 0x228eebbd780>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x228eebbd7b8>,
#  'COSTARICA': <gensim.models.keyedvectors.Vocab at 0x228eebbd7f0>,
#  'ADVISORY': <gensim.models.keyedvectors.Vocab at 0x228eebbd828>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x228eebbd860>,
#  'NO': <gensim.models.keyedvectors.Vocab at 0x228eebbd898>,
#  'WAVES': <gensim.models.keyedvectors.Vocab at 0x228eebbd8d0>,
#  'REPORTED': <gensim.models.keyedvectors.Vocab at 0x228eebbd908>,
#  'YET': <gensim.models.keyedvectors.Vocab at 0x228eebbd940>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x228eebbd978>,
#  'BE': <gensim.models.keyedvectors.Vocab at 0x228eebbd9b0>,
#  'ON': <gensim.models.keyedvectors.Vocab at 0x228eebbd9e8>,
#  'PRECAUTIONARY': <gensim.models.keyedvectors.Vocab at 0x228eebbda20>,
#  'EVACUATION': <gensim.models.keyedvectors.Vocab at 0x228eebbda58>,
#  'RECOMMENDED': <gensim.models.keyedvectors.Vocab at 0x228eebbda90>,
#  'PTWC': <gensim.models.keyedvectors.Vocab at 0x228eebbdac8>,
#  'NEWS': <gensim.models.keyedvectors.Vocab at 0x228eebbdb00>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x228eebbdb38>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x228eebbdb70>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x228eebbdba8>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x228eebbdbe0>,
#  'Reported': <gensim.models.keyedvectors.Vocab at 0x228eebbdc18>,
#  'ABC': <gensim.models.keyedvectors.Vocab at 0x228eebbdc50>,
#  'nbcnightlynews': <gensim.models.keyedvectors.Vocab at 0x228eebbdc88>,
#  'Just': <gensim.models.keyedvectors.Vocab at 0x228eebbdcc0>,
#  'Disarm': <gensim.models.keyedvectors.Vocab at 0x228eebbdcf8>,
#  'Major': <gensim.models.keyedvectors.Vocab at 0x228eebbdd30>,
#  'Reutersâ€�': <gensim.models.keyedvectors.Vocab at 0x228eebbdd68>,
#  'DanielrBarron': <gensim.models.keyedvectors.Vocab at 0x228eebbdda0>,
#  'washingtonpost': <gensim.models.keyedvectors.Vocab at 0x228eebbddd8>,
#  'ABC7': <gensim.models.keyedvectors.Vocab at 0x228eebbde10>,
#  'BREAKINGNEWS': <gensim.models.keyedvectors.Vocab at 0x228ee6156d8>,
#  '7.9-mag': <gensim.models.keyedvectors.Vocab at 0x228ee615b38>,
#  'immediate': <gensim.models.keyedvectors.Vocab at 0x228ee615a20>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x228ee615908>,
#  'TheNextCorner': <gensim.models.keyedvectors.Vocab at 0x228ee615c50>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x228ee6157b8>,
#  'ninaism': <gensim.models.keyedvectors.Vocab at 0x228ee6150f0>,
#  'georgekourounis': <gensim.models.keyedvectors.Vocab at 0x228ee615a58>,
#  'landslides': <gensim.models.keyedvectors.Vocab at 0x228ee6152b0>,
#  'inland': <gensim.models.keyedvectors.Vocab at 0x228ee615630>,
#  'RDLKid': <gensim.models.keyedvectors.Vocab at 0x228ee615940>,
#  'springrose12': <gensim.models.keyedvectors.Vocab at 0x228ee6150b8>,
#  'HDNER': <gensim.models.keyedvectors.Vocab at 0x228ee615400>,
#  'cancel': <gensim.models.keyedvectors.Vocab at 0x228ee615fd0>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x228eebbde48>,
#  'Ocean': <gensim.models.keyedvectors.Vocab at 0x228eebbde80>,
#  'moanikitv': <gensim.models.keyedvectors.Vocab at 0x228eebbdeb8>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x228eebbdef0>,
#  'costarica': <gensim.models.keyedvectors.Vocab at 0x228eebbdf28>,
#  'temblorcr': <gensim.models.keyedvectors.Vocab at 0x228eebbdf60>,
#  'Is': <gensim.models.keyedvectors.Vocab at 0x228eebbdf98>,
#  'OK': <gensim.models.keyedvectors.Vocab at 0x228eebbdfd0>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x228eebc0048>,
#  'RobDavis_Wx': <gensim.models.keyedvectors.Vocab at 0x228eebc0080>,
#  'LANDSLIDE': <gensim.models.keyedvectors.Vocab at 0x228eebc00b8>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x228eebc00f0>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x228eebc0128>,
#  'M7.6': <gensim.models.keyedvectors.Vocab at 0x228eebc0160>,
#  'NOSARA': <gensim.models.keyedvectors.Vocab at 0x228eebc0198>,
#  'AP': <gensim.models.keyedvectors.Vocab at 0x228eebc01d0>,
#  'â€': <gensim.models.keyedvectors.Vocab at 0x228eebc0208>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x228eebc0240>,
#  'magnitude-7': <gensim.models.keyedvectors.Vocab at 0x228eebc0278>,
#  'AustralianBuzz': <gensim.models.keyedvectors.Vocab at 0x228eebc02b0>,
#  'Sth': <gensim.models.keyedvectors.Vocab at 0x228eebc02e8>,
#  'Michelle9647': <gensim.models.keyedvectors.Vocab at 0x228eebc0320>,
#  'Red': <gensim.models.keyedvectors.Vocab at 0x228eebc0358>,
#  'Cross': <gensim.models.keyedvectors.Vocab at 0x228eebc0390>,
#  'casualties': <gensim.models.keyedvectors.Vocab at 0x228eebc03c8>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x228eebc0400>,
#  'JALpalyul': <gensim.models.keyedvectors.Vocab at 0x228eebc0438>,
#  'AffiliateDesire': <gensim.models.keyedvectors.Vocab at 0x228eebc0470>,
#  'Quality': <gensim.models.keyedvectors.Vocab at 0x228eebc04a8>,
#  'Footage': <gensim.models.keyedvectors.Vocab at 0x228eebc04e0>,
#  'Sept': <gensim.models.keyedvectors.Vocab at 0x228eebc0518>,
#  '5th': <gensim.models.keyedvectors.Vocab at 0x228eebc0550>,
#  'Bummer': <gensim.models.keyedvectors.Vocab at 0x228eebc0588>,
#  'locals': <gensim.models.keyedvectors.Vocab at 0x228eebc05c0>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x228eebc05f8>,
#  'vacationers': <gensim.models.keyedvectors.Vocab at 0x228eebc0630>,
#  'TravelGov': <gensim.models.keyedvectors.Vocab at 0x228eebc0668>,
#  'EmergencyMessage': <gensim.models.keyedvectors.Vocab at 0x228eebc06a0>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x228eebc06d8>,
#  'ElSalvador': <gensim.models.keyedvectors.Vocab at 0x228eebc0710>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x228eebc0748>,
#  'ht': <gensim.models.keyedvectors.Vocab at 0x228eebc0780>,
#  'downgrade': <gensim.models.keyedvectors.Vocab at 0x228eebc07b8>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x228eebc07f0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x228eebc0828>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x228eebc0860>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x228eebc0898>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x228eebc08d0>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x228eebc0908>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x228eebc0940>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x228eebc0978>,
#  'duration': <gensim.models.keyedvectors.Vocab at 0x228eebc09b0>,
#  'WorldNews': <gensim.models.keyedvectors.Vocab at 0x228eebc09e8>,
#  'Some': <gensim.models.keyedvectors.Vocab at 0x228eebc0a20>,
#  'razaespn': <gensim.models.keyedvectors.Vocab at 0x228eebc0a58>,
#  'Estadio': <gensim.models.keyedvectors.Vocab at 0x228eebc0a90>,
#  'Nacional': <gensim.models.keyedvectors.Vocab at 0x228eebc0ac8>,
#  'Issued': <gensim.models.keyedvectors.Vocab at 0x228eebc0b00>,
#  'far-Red': <gensim.models.keyedvectors.Vocab at 0x228eebc0b38>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x228eebc0b70>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x228eebc0ba8>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x228eebc0be0>,
#  'honeymoon': <gensim.models.keyedvectors.Vocab at 0x228eebc0c18>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x228eebc0c50>,
#  'NBCNews': <gensim.models.keyedvectors.Vocab at 0x228eebc0c88>,
#  'That': <gensim.models.keyedvectors.Vocab at 0x228eebc0cc0>,
#  'sustain': <gensim.models.keyedvectors.Vocab at 0x228eebc0cf8>,
#  'tens': <gensim.models.keyedvectors.Vocab at 0x228eebc0d30>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x228eebc0d68>,
#  'dollars': <gensim.models.keyedvectors.Vocab at 0x228eebc0da0>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x228eebc0dd8>,
#  'Very': <gensim.models.keyedvectors.Vocab at 0x228eebc0e10>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x228eebc0e48>,
#  'magnitude-7.6': <gensim.models.keyedvectors.Vocab at 0x228eebc0e80>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x228eebc0eb8>,
#  'swath': <gensim.models.keyedvectors.Vocab at 0x228eebc0ef0>,
#  'Wednesday': <gensim.models.keyedvectors.Vocab at 0x228eebc0f28>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x228eebc0f60>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x228eebc0f98>,
#  'tod': <gensim.models.keyedvectors.Vocab at 0x228eebc0fd0>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x228eebc5048>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x228eebc5080>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x228eebc50b8>,
#  'fatalities': <gensim.models.keyedvectors.Vocab at 0x228eebc50f0>,
#  'Strikes': <gensim.models.keyedvectors.Vocab at 0x228eebc5128>,
#  'Off': <gensim.models.keyedvectors.Vocab at 0x228eebc5160>,
#  'measurin': <gensim.models.keyedvectors.Vocab at 0x228eebc5198>,
#  'HuffingtonPost': <gensim.models.keyedvectors.Vocab at 0x228eebc51d0>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x228eebc5208>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x228eebc5240>,
#  '1991': <gensim.models.keyedvectors.Vocab at 0x228eebc5278>,
#  'LoL..WTH': <gensim.models.keyedvectors.Vocab at 0x228eebc52b0>,
#  'earthquake..': <gensim.models.keyedvectors.Vocab at 0x228eebc52e8>,
#  'God': <gensim.models.keyedvectors.Vocab at 0x228eebc5320>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x228eebc5358>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x228eebc5390>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x228eebc53c8>,
#  'First': <gensim.models.keyedvectors.Vocab at 0x228eebc5400>,
#  'VIDEO': <gensim.models.keyedvectors.Vocab at 0x228eebc5438>,
#  'Independent': <gensim.models.keyedvectors.Vocab at 0x228eebc5470>,
#  '28-mile': <gensim.models.keyedvectors.Vocab at 0x228eebc54a8>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x228eebc54e0>,
#  'Wednes': <gensim.models.keyedvectors.Vocab at 0x228eebc5518>,
#  'Pray': <gensim.models.keyedvectors.Vocab at 0x228eebc5550>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x228eebc5588>,
#  'CostaRican': <gensim.models.keyedvectors.Vocab at 0x228eebc55c0>,
#  'Nooo': <gensim.models.keyedvectors.Vocab at 0x228eebc55f8>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x228eebc5630>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x228eebc5668>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x228eebc56a0>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x228eebc56d8>,
#  'â—¦': <gensim.models.keyedvectors.Vocab at 0x228eebc5710>,
#  'Kyodo': <gensim.models.keyedvectors.Vocab at 0x228eebc5748>,
#  'jolt': <gensim.models.keyedvectors.Vocab at 0x228eebc5780>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x228eebc57b8>,
#  'WilliamTeach': <gensim.models.keyedvectors.Vocab at 0x228eebc57f0>,
#  'Which': <gensim.models.keyedvectors.Vocab at 0x228eebc5828>,
#  'Warmist': <gensim.models.keyedvectors.Vocab at 0x228eebc5860>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x228eebc5898>,
#  'blame': <gensim.models.keyedvectors.Vocab at 0x228eebc58d0>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x228eebc5908>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x228eebc5940>,
#  '//': <gensim.models.keyedvectors.Vocab at 0x228eebc5978>,
#  'Dumbass': <gensim.models.keyedvectors.Vocab at 0x228eebc59b0>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x228eebc59e8>,
#  'GEOLOGY..': <gensim.models.keyedvectors.Vocab at 0x228eebc5a20>,
#  'TimJohnson4': <gensim.models.keyedvectors.Vocab at 0x228eebc5a58>,
#  'prez': <gensim.models.keyedvectors.Vocab at 0x228eebc5a90>,
#  'Damage': <gensim.models.keyedvectors.Vocab at 0x228eebc5ac8>,
#  'deaths': <gensim.models.keyedvectors.Vocab at 0x228eebc5b00>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x228eebc5b38>,
#  'survey': <gensim.models.keyedvectors.Vocab at 0x228eebc5b70>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x228eebc5ba8>,
#  'CHICABRAVA': <gensim.models.keyedvectors.Vocab at 0x228eebc5be0>,
#  'stoke': <gensim.models.keyedvectors.Vocab at 0x228eebc5c18>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x228eebc5c50>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x228eebc5c88>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x228eebc5cc0>,
#  'Hope': <gensim.models.keyedvectors.Vocab at 0x228eebc5cf8>,
#  'TIME': <gensim.models.keyedvectors.Vocab at 0x228eebc5d30>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x228eebc5d68>,
#  'Holy': <gensim.models.keyedvectors.Vocab at 0x228eebc5da0>,
#  'shit': <gensim.models.keyedvectors.Vocab at 0x228eebc5dd8>,
#  'Unbelievable..': <gensim.models.keyedvectors.Vocab at 0x228eebc5e10>,
#  'Would': <gensim.models.keyedvectors.Vocab at 0x228eebc5e48>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x228eebc5e80>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x228eebc5eb8>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x228eebc5ef0>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x228eebc5f28>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x228eebc5f60>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x228eebc5f98>,
#  'region..': <gensim.models.keyedvectors.Vocab at 0x228eebc5fd0>,
#  'prayers😔': <gensim.models.keyedvectors.Vocab at 0x228eebc8048>,
#  'URGENT': <gensim.models.keyedvectors.Vocab at 0x228eebc8080>,
#  'csmonitor': <gensim.models.keyedvectors.Vocab at 0x228eebc80b8>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x228eebc80f0>,
#  'dustinbrowning': <gensim.models.keyedvectors.Vocab at 0x228eebc8128>,
#  'SamuRojas': <gensim.models.keyedvectors.Vocab at 0x228eebc8160>,
#  'antikCR': <gensim.models.keyedvectors.Vocab at 0x228eebc8198>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x228eebc81d0>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x228eebc8208>,
#  'newslocker': <gensim.models.keyedvectors.Vocab at 0x228eebc8240>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x228eebc8278>,
#  'Ca': <gensim.models.keyedvectors.Vocab at 0x228eebc82b0>,
#  "n't": <gensim.models.keyedvectors.Vocab at 0x228eebc82e8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x228eebc8320>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x228eebc8358>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x228eebc8390>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x228eebc83c8>,
#  'DICE': <gensim.models.keyedvectors.Vocab at 0x228eebc8400>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x228eebc8438>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x228eebc8470>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x228eebc84a8>,
#  'fatality': <gensim.models.keyedvectors.Vocab at 0x228eebc84e0>,
#  'resu': <gensim.models.keyedvectors.Vocab at 0x228eebc8518>,
#  'Update': <gensim.models.keyedvectors.Vocab at 0x228eebc8550>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x228eebc8588>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x228eebc85c0>,
#  'CPPGeophysics': <gensim.models.keyedvectors.Vocab at 0x228eebc85f8>,
#  'Nice': <gensim.models.keyedvectors.Vocab at 0x228eebc8630>,
#  'visualization': <gensim.models.keyedvectors.Vocab at 0x228eebc8668>,
#  'seismic': <gensim.models.keyedvectors.Vocab at 0x228eebc86a0>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x228eebc86d8>,
#  'propagate': <gensim.models.keyedvectors.Vocab at 0x228eebc8710>,
#  'USArray': <gensim.models.keyedvectors.Vocab at 0x228eebc8748>,
#  'EarthScopeInfo': <gensim.models.keyedvectors.Vocab at 0x228eebc8780>,
#  'DarinRMcClure': <gensim.models.keyedvectors.Vocab at 0x228eebc87b8>,
#  'Praying': <gensim.models.keyedvectors.Vocab at 0x228eebc87f0>,
#  'YourAnonNews': <gensim.models.keyedvectors.Vocab at 0x228eebc8828>,
#  'YAN': <gensim.models.keyedvectors.Vocab at 0x228eebc8860>,
#  'Bad': <gensim.models.keyedvectors.Vocab at 0x228eebc8898>,
#  'Know': <gensim.models.keyedvectors.Vocab at 0x228eebc88d0>,
#  'Pac': <gensim.models.keyedvectors.Vocab at 0x228eebc8908>,
#  'NWers': <gensim.models.keyedvectors.Vocab at 0x228eebc8940>,
#  'Pls': <gensim.models.keyedvectors.Vocab at 0x228eebc8978>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x228eebc89b0>,
#  'NW': <gensim.models.keyedvectors.Vocab at 0x228eebc89e8>,
#  'NPR': <gensim.models.keyedvectors.Vocab at 0x228eebc8a20>,
#  'tombanse': <gensim.models.keyedvectors.Vocab at 0x228eebc8a58>,
#  'worldnews': <gensim.models.keyedvectors.Vocab at 0x228eebc8a90>,
#  'Canceled': <gensim.models.keyedvectors.Vocab at 0x228eebc8ac8>,
#  'After': <gensim.models.keyedvectors.Vocab at 0x228eebc8b00>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x228eebc8b38>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x228eebc8b70>,
#  'Two-Way': <gensim.models.keyedvectors.Vocab at 0x228eebc8ba8>,
#  'Earth': <gensim.models.keyedvectors.Vocab at 0x228eebc8be0>,
#  'Matias': <gensim.models.keyedvectors.Vocab at 0x228eebc8c18>,
#  'Doing': <gensim.models.keyedvectors.Vocab at 0x228eebc8c50>,
#  'Good': <gensim.models.keyedvectors.Vocab at 0x228eebc8c88>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x228eebc8cc0>,
#  'Gon': <gensim.models.keyedvectors.Vocab at 0x228eebc8cf8>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x228eebc8d30>,
#  'Try': <gensim.models.keyedvectors.Vocab at 0x228eebc8d68>,
#  'Calling': <gensim.models.keyedvectors.Vocab at 0x228eebc8da0>,
#  'His': <gensim.models.keyedvectors.Vocab at 0x228eebc8dd8>,
#  'Momma': <gensim.models.keyedvectors.Vocab at 0x228eebc8e10>,
#  'Later': <gensim.models.keyedvectors.Vocab at 0x228eebc8e48>,
#  'fo': <gensim.models.keyedvectors.Vocab at 0x228eebc8e80>,
#  'Angie': <gensim.models.keyedvectors.Vocab at 0x228eebc8eb8>,
#  'Thompson': <gensim.models.keyedvectors.Vocab at 0x228eebc8ef0>,
#  'Messerschmidt': <gensim.models.keyedvectors.Vocab at 0x228eebc8f28>,
#  'Claryssa-Faye': <gensim.models.keyedvectors.Vocab at 0x228eebc8f60>,
#  'Skie': <gensim.models.keyedvectors.Vocab at 0x228eebc8f98>,
#  'Did': <gensim.models.keyedvectors.Vocab at 0x228eebc8fd0>,
#  '14:42:10': <gensim.models.keyedvectors.Vocab at 0x228eebcb048>,
#  'India': <gensim.models.keyedvectors.Vocab at 0x228eebcb080>,
#  'IBNLive.comPowerful': <gensim.models.keyedvectors.Vocab at 0x228eebcb0b8>,
#  'deadReu': <gensim.models.keyedvectors.Vocab at 0x228eebcb0f0>,
#  'Two': <gensim.models.keyedvectors.Vocab at 0x228eebcb128>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x228eebcb160>,
#  'injure': <gensim.models.keyedvectors.Vocab at 0x228eebcb198>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x228eebcb1d0>,
#  'Piedras': <gensim.models.keyedvectors.Vocab at 0x228eebcb208>,
#  'homestay': <gensim.models.keyedvectors.Vocab at 0x228eebcb240>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x228eebcb278>,
#  'Isidro': <gensim.models.keyedvectors.Vocab at 0x228eebcb2b0>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x228eebcb2e8>,
#  'Heredia': <gensim.models.keyedvectors.Vocab at 0x228eebcb320>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x228eebcb358>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x228eebcb390>,
#  'MrVop': <gensim.models.keyedvectors.Vocab at 0x228eebcb3c8>,
#  'RandyDorfman': <gensim.models.keyedvectors.Vocab at 0x228eebcb400>,
#  'WCOOP': <gensim.models.keyedvectors.Vocab at 0x228eebcb438>,
#  'players': <gensim.models.keyedvectors.Vocab at 0x228eebcb470>,
#  'USA': <gensim.models.keyedvectors.Vocab at 0x228eebcb4a8>,
#  'TODAY7.6-magnitude': <gensim.models.keyedvectors.Vocab at 0x228eebcb4e0>,
#  'coastCNN': <gensim.models.keyedvectors.Vocab at 0x228eebcb518>,
#  'Online': <gensim.models.keyedvectors.Vocab at 0x228eebcb550>,
#  'NewsMagnitude': <gensim.models.keyedvectors.Vocab at 0x228eebcb588>,
#  'RicaABC': <gensim.models.keyedvectors.Vocab at 0x228eebcb5c0>,
#  'OnlineA': <gensim.models.keyedvectors.Vocab at 0x228eebcb5f8>,
#  'pow': <gensim.models.keyedvectors.Vocab at 0x228eebcb630>,
#  'Our': <gensim.models.keyedvectors.Vocab at 0x228eebcb668>,
#  'hearts': <gensim.models.keyedvectors.Vocab at 0x228eebcb6a0>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x228eebcb6d8>,
#  'Covering': <gensim.models.keyedvectors.Vocab at 0x228eebcb710>,
#  'TheAngieShow': <gensim.models.keyedvectors.Vocab at 0x228eebcb748>,
#  'Associated': <gensim.models.keyedvectors.Vocab at 0x228eebcb780>,
#  'Press': <gensim.models.keyedvectors.Vocab at 0x228eebcb7b8>,
#  'ar': <gensim.models.keyedvectors.Vocab at 0x228eebcb7f0>,
#  'Fox': <gensim.models.keyedvectors.Vocab at 0x228eebcb828>,
#  'SAN': <gensim.models.keyedvectors.Vocab at 0x228eebcb860>,
#  'JOSE': <gensim.models.keyedvectors.Vocab at 0x228eebcb898>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x228eebcb8d0>,
#  'trend': <gensim.models.keyedvectors.Vocab at 0x228eebcb908>,
#  'Viva': <gensim.models.keyedvectors.Vocab at 0x228eebcb940>,
#  'bitch': <gensim.models.keyedvectors.Vocab at 0x228eebcb978>,
#  'CostaRicaEarthquake': <gensim.models.keyedvectors.Vocab at 0x228eebcb9b0>,
#  'REN': <gensim.models.keyedvectors.Vocab at 0x228eebcb9e8>,
#  'Federation': <gensim.models.keyedvectors.Vocab at 0x228eebcba20>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x228eebcba58>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x228eebcba90>,
#  '4:11pm': <gensim.models.keyedvectors.Vocab at 0x228eebcbac8>,
#  '15m': <gensim.models.keyedvectors.Vocab at 0x228eebcbb00>,
#  '71km': <gensim.models.keyedvectors.Vocab at 0x228eebcbb38>,
#  '35km': <gensim.models.keyedvectors.Vocab at 0x228eebcbb70>,
#  'We': <gensim.models.keyedvectors.Vocab at 0x228eebcbba8>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x228eebcbbe0>,
#  '20km': <gensim.models.keyedvectors.Vocab at 0x228eebcbc18>,
#  'Guanacaste': <gensim.models.keyedvectors.Vocab at 0x228eebcbc50>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x228eebcbc88>,
#  'Nosara': <gensim.models.keyedvectors.Vocab at 0x228eebcbcc0>,
#  'panic': <gensim.models.keyedvectors.Vocab at 0x228eebcbcf8>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x228eebcbd30>,
#  'IBNLive.comStrong': <gensim.models.keyedvectors.Vocab at 0x228eebcbd68>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x228eebcbda0>,
#  'Living': <gensim.models.keyedvectors.Vocab at 0x228eebcbdd8>,
#  'Social': <gensim.models.keyedvectors.Vocab at 0x228eebcbe10>,
#  'Andy': <gensim.models.keyedvectors.Vocab at 0x228eebcbe48>,
#  'Roddick': <gensim.models.keyedvectors.Vocab at 0x228eebcbe80>,
#  'onedirection': <gensim.models.keyedvectors.Vocab at 0x228eebcbeb8>,
#  '=/': <gensim.models.keyedvectors.Vocab at 0x228eebcbef0>,
#  'EarthquakeCalifornia': <gensim.models.keyedvectors.Vocab at 0x228eebcbf28>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x228eebcbf60>,
#  'World': <gensim.models.keyedvectors.Vocab at 0x228eebcbf98>,
#  'Cup': <gensim.models.keyedvectors.Vocab at 0x228eebcbfd0>,
#  'qualifier': <gensim.models.keyedvectors.Vocab at 0x228eebcf048>,
#  'Mexican': <gensim.models.keyedvectors.Vocab at 0x228eebcf080>,
#  'Buildings': <gensim.models.keyedvectors.Vocab at 0x228eebcf0b8>,
#  'sway': <gensim.models.keyedvectors.Vocab at 0x228eebcf0f0>,
#  'residents': <gensim.models.keyedvectors.Vocab at 0x228eebcf128>,
#  'rush': <gensim.models.keyedvectors.Vocab at 0x228eebcf160>,
#  'streets': <gensim.models.keyedvectors.Vocab at 0x228eebcf198>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x228eebcf1d0>,
#  'Geologyupdate': <gensim.models.keyedvectors.Vocab at 0x228eebcf208>,
#  'Seattle': <gensim.models.keyedvectors.Vocab at 0x228eebcf240>,
#  'Times': <gensim.models.keyedvectors.Vocab at 0x228eebcf278>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x228eebcf2b0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x228eebcf2e8>,
#  'Washington': <gensim.models.keyedvectors.Vocab at 0x228eebcf320>,
#  'Post': <gensim.models.keyedvectors.Vocab at 0x228eebcf358>,
#  'CBC.caPowerf': <gensim.models.keyedvectors.Vocab at 0x228eebcf390>,
#  'Three': <gensim.models.keyedvectors.Vocab at 0x228eebcf3c8>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x228eebcf400>,
#  'Xinhua': <gensim.models.keyedvectors.Vocab at 0x228eebcf438>,
#  'NationThree': <gensim.models.keyedvectors.Vocab at 0x228eebcf470>,
#  'quak': <gensim.models.keyedvectors.Vocab at 0x228eebcf4a8>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x228eebcf4e0>,
#  'resistant': <gensim.models.keyedvectors.Vocab at 0x228eebcf518>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x228eebcf550>,
#  'Cangrejal': <gensim.models.keyedvectors.Vocab at 0x228eebcf588>,
#  'sho': <gensim.models.keyedvectors.Vocab at 0x228eebcf5c0>,
#  'Rocked': <gensim.models.keyedvectors.Vocab at 0x228eebcf5f8>,
#  '1.0': <gensim.models.keyedvectors.Vocab at 0x228eebcf630>,
#  'Southern': <gensim.models.keyedvectors.Vocab at 0x228eebcf668>,
#  'California': <gensim.models.keyedvectors.Vocab at 0x228eebcf6a0>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x228eebcf6d8>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x228eebcf710>,
#  'bulletin': <gensim.models.keyedvectors.Vocab at 0x228eebcf748>,
#  'terrify': <gensim.models.keyedvectors.Vocab at 0x228eebcf780>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x228eebcf7b8>,
#  'QuakeÂ': <gensim.models.keyedvectors.Vocab at 0x228eebcf7f0>,
#  'Ready': <gensim.models.keyedvectors.Vocab at 0x228eebcf828>,
#  'Action': <gensim.models.keyedvectors.Vocab at 0x228eebcf860>,
#  'Source': <gensim.models.keyedvectors.Vocab at 0x228eebcf898>,
#  'Â': <gensim.models.keyedvectors.Vocab at 0x228eebcf8d0>,
#  'Irish': <gensim.models.keyedvectors.Vocab at 0x228eebcf908>,
#  'Cro': <gensim.models.keyedvectors.Vocab at 0x228eebcf940>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x228eebcf978>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x228eebcf9b0>,
#  'Thursday': <gensim.models.keyedvectors.Vocab at 0x228eebcf9e8>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x228eebcfa20>,
#  'unsc': <gensim.models.keyedvectors.Vocab at 0x228eebcfa58>,
#  'Terror': <gensim.models.keyedvectors.Vocab at 0x228eebcfa90>,
#  'casino': <gensim.models.keyedvectors.Vocab at 0x228eebcfac8>,
#  'Capital': <gensim.models.keyedvectors.Vocab at 0x228eebcfb00>,
#  'Videos': <gensim.models.keyedvectors.Vocab at 0x228eebcfb38>,
#  'Surface': <gensim.models.keyedvectors.Vocab at 0x228eebcfb70>,
#  'Video': <gensim.models.keyedvectors.Vocab at 0x228eebcfba8>,
#  '1.8': <gensim.models.keyedvectors.Vocab at 0x228eebcfbe0>,
#  'Island': <gensim.models.keyedvectors.Vocab at 0x228eebcfc18>,
#  'Environment': <gensim.models.keyedvectors.Vocab at 0x228eebcfc50>,
#  'Planet': <gensim.models.keyedvectors.Vocab at 0x228eebcfc88>,
#  'Ark': <gensim.models.keyedvectors.Vocab at 0x228eebcfcc0>,
#  'EARTHQUAKE': <gensim.models.keyedvectors.Vocab at 0x228eebcfcf8>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x228eebcfd30>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x228eebcfd68>,
#  'Another': <gensim.models.keyedvectors.Vocab at 0x228eebcfda0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x228eebcfdd8>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x228eebcfe10>,
#  'awake': <gensim.models.keyedvectors.Vocab at 0x228eebcfe48>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x228eebcfe80>,
#  'Dang': <gensim.models.keyedvectors.Vocab at 0x228eebcfeb8>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x228eebcfef0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x228eebcff28>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x228eebcff60>,
#  '3.5': <gensim.models.keyedvectors.Vocab at 0x228eebcff98>,
#  'Beverly': <gensim.models.keyedvectors.Vocab at 0x228eebcffd0>,
#  'Hills': <gensim.models.keyedvectors.Vocab at 0x228eebd3048>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x228eebd3080>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x228eebd30b8>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x228eebd30f0>,
#  'zomanno': <gensim.models.keyedvectors.Vocab at 0x228eebd3128>,
#  'EARTHQUAKEEE': <gensim.models.keyedvectors.Vocab at 0x228eebd3160>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x228eebd3198>,
#  'coincidence': <gensim.models.keyedvectors.Vocab at 0x228eebd31d0>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x228eebd3208>,
#  'HoneyBooBoo': <gensim.models.keyedvectors.Vocab at 0x228eebd3240>,
#  '9021uh-0': <gensim.models.keyedvectors.Vocab at 0x228eebd3278>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x228eebd32b0>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x228eebd32e8>,
#  'westside': <gensim.models.keyedvectors.Vocab at 0x228eebd3320>,
#  'eastern': <gensim.models.keyedvectors.Vocab at 0x228eebd3358>,
#  'SFV': <gensim.models.keyedvectors.Vocab at 0x228eebd3390>,
#  'TheLAScene': <gensim.models.keyedvectors.Vocab at 0x228eebd33c8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x228eebd3400>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x228eebd3438>,
#  'BeverlyHills': <gensim.models.keyedvectors.Vocab at 0x228eebd3470>,
#  'upgrade': <gensim.models.keyedvectors.Vocab at 0x228eebd34a8>,
#  'ArianaGrande': <gensim.models.keyedvectors.Vocab at 0x228eebd34e0>,
#  'Hi': <gensim.models.keyedvectors.Vocab at 0x228eebd3518>,
#  'IÂ´m': <gensim.models.keyedvectors.Vocab at 0x228eebd3550>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x228eebd3588>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x228eebd35c0>,
#  'again..': <gensim.models.keyedvectors.Vocab at 0x228eebd35f8>,
#  'seriously..': <gensim.models.keyedvectors.Vocab at 0x228eebd3630>,
#  'Tell': <gensim.models.keyedvectors.Vocab at 0x228eebd3668>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x228eebd36a0>,
#  'bout': <gensim.models.keyedvectors.Vocab at 0x228eebd36d8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x228eebd3710>,
#  'Bobak9': <gensim.models.keyedvectors.Vocab at 0x228eebd3748>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x228eebd3780>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x228eebd37b8>,
#  'UsainBolt': <gensim.models.keyedvectors.Vocab at 0x228eebd37f0>,
#  'Never': <gensim.models.keyedvectors.Vocab at 0x228eebd3828>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x228eebd3860>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x228eebd3898>,
#  'SO': <gensim.models.keyedvectors.Vocab at 0x228eebd38d0>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x228eebd3908>,
#  'Lol': <gensim.models.keyedvectors.Vocab at 0x228eebd3940>,
#  'DNC2012': <gensim.models.keyedvectors.Vocab at 0x228eebd3978>,
#  'Was': <gensim.models.keyedvectors.Vocab at 0x228eebd39b0>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x228eebd39e8>,
#  'shatter': <gensim.models.keyedvectors.Vocab at 0x228eebd3a20>,
# ...
#  'LAquake': <gensim.models.keyedvectors.Vocab at 0x228eebd3ac8>,
#  'Emergency': <gensim.models.keyedvectors.Vocab at 0x228eebd3b00>,
#  'Mode': <gensim.models.keyedvectors.Vocab at 0x228eebd3b38>,
#  'discontinue': <gensim.models.keyedvectors.Vocab at 0x228eebd3b70>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x228eebd3ba8>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x228eebd3be0>,
#  'normalâ€¦': <gensim.models.keyedvectors.Vocab at 0x228eebd3c18>,
#  'Quakes': <gensim.models.keyedvectors.Vocab at 0x228eebd3c50>,
#  'southwest': <gensim.models.keyedvectors.Vocab at 0x228eebd3c88>,
#  'China': <gensim.models.keyedvectors.Vocab at 0x228eebd3cc0>,
#  'dozens': <gensim.models.keyedvectors.Vocab at 0x228eebd3cf8>,
#  '20,000': <gensim.models.keyedvectors.Vocab at 0x228eebd3d30>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x228eebd3d68>,
#  'Earthquakes': <gensim.models.keyedvectors.Vocab at 0x228eebd3da0>,
#  'alertã€': <gensim.models.keyedvectors.Vocab at 0x228eebd3dd8>,
#  '2.1': <gensim.models.keyedvectors.Vocab at 0x228eebd3e10>,
#  '07': <gensim.models.keyedvectors.Vocab at 0x228eebd3e48>,
#  '15:33:36': <gensim.models.keyedvectors.Vocab at 0x228eebd3e80>,
#  'Dear': <gensim.models.keyedvectors.Vocab at 0x228eebd3eb8>,
#  '2x': <gensim.models.keyedvectors.Vocab at 0x228eebd3ef0>,
#  "'ve": <gensim.models.keyedvectors.Vocab at 0x228eebd3f28>,
#  '1/2': <gensim.models.keyedvectors.Vocab at 0x228eebd3f60>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x228eebd3f98>,
#  'away-Results': <gensim.models.keyedvectors.Vocab at 0x228eebd3fd0>,
#  'crappy': <gensim.models.keyedvectors.Vocab at 0x228eebd6048>,
#  'workout': <gensim.models.keyedvectors.Vocab at 0x228eebd6080>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x228eebd60b8>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x228eebd60f0>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x228eebd6128>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x228eebd6160>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x228eebd6198>,
#  'Shakes': <gensim.models.keyedvectors.Vocab at 0x228eebd61d0>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x228eebd6208>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x228eebd6240>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x228eebd6278>,
#  'Yea': <gensim.models.keyedvectors.Vocab at 0x228eebd62b0>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x228eebd62e8>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x228eebd6320>,
#  'uselessinfo': <gensim.models.keyedvectors.Vocab at 0x228eebd6358>,
#  'Watchers': <gensim.models.keyedvectors.Vocab at 0x228eebd6390>,
#  'Massive': <gensim.models.keyedvectors.Vocab at 0x228eebd63c8>,
#  'awaken': <gensim.models.keyedvectors.Vocab at 0x228eebd6400>,
#  'Nicaraguan': <gensim.models.keyedvectors.Vocab at 0x228eebd6438>,
#  'Apoyeque': <gensim.models.keyedvectors.Vocab at 0x228eebd6470>,
#  'volcano': <gensim.models.keyedvectors.Vocab at 0x228eebd64a8>,
#  'At': <gensim.models.keyedvectors.Vocab at 0x228eebd64e0>,
#  '12:35': <gensim.models.keyedvectors.Vocab at 0x228eebd6518>,
#  'PM': <gensim.models.keyedvectors.Vocab at 0x228eebd6550>,
#  'UTC': <gensim.models.keyedvectors.Vocab at 0x228eebd6588>,
#  'Minahasa': <gensim.models.keyedvectors.Vocab at 0x228eebd65c0>,
#  'M4.7': <gensim.models.keyedvectors.Vocab at 0x228eebd65f8>,
#  '35.70km': <gensim.models.keyedvectors.Vocab at 0x228eebd6630>,
#  'Stay': <gensim.models.keyedvectors.Vocab at 0x228eebd6668>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x228eebd66a0>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x228eebd66d8>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x228eebd6710>,
#  'BECOME': <gensim.models.keyedvectors.Vocab at 0x228eebd6748>,
#  'ASEXUAL': <gensim.models.keyedvectors.Vocab at 0x228eebd6780>,
#  'NOW': <gensim.models.keyedvectors.Vocab at 0x228eebd67b8>,
#  '5.6': <gensim.models.keyedvectors.Vocab at 0x228eebd67f0>,
#  'earthqu': <gensim.models.keyedvectors.Vocab at 0x228eebd6828>,
#  'Felt': <gensim.models.keyedvectors.Vocab at 0x228eebd6860>,
#  'South': <gensim.models.keyedvectors.Vocab at 0x228eebd6898>,
#  'tremor': <gensim.models.keyedvectors.Vocab at 0x228eebd68d0>,
#  'TrafficSA': <gensim.models.keyedvectors.Vocab at 0x228eebd6908>,
#  'offtraffic': <gensim.models.keyedvectors.Vocab at 0x228eebd6940>,
#  'East': <gensim.models.keyedvectors.Vocab at 0x228eebd6978>,
#  'Rand': <gensim.models.keyedvectors.Vocab at 0x228eebd69b0>,
#  'Otro': <gensim.models.keyedvectors.Vocab at 0x228eebd69e8>,
#  'temblor': <gensim.models.keyedvectors.Vocab at 0x228eebd6a20>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x228eebd6a58>,
#  'Sat': <gensim.models.keyedvectors.Vocab at 0x228eebd6a90>,
#  '08': <gensim.models.keyedvectors.Vocab at 0x228eebd6ac8>,
#  '16:29:32': <gensim.models.keyedvectors.Vocab at 0x228eebd6b00>,
#  'AMT': <gensim.models.keyedvectors.Vocab at 0x228eebd6b38>,
#  'Interesting': <gensim.models.keyedvectors.Vocab at 0x228eebd6b70>,
#  'Hojancha': <gensim.models.keyedvectors.Vocab at 0x228eebd6ba8>,
#  'REPORTS': <gensim.models.keyedvectors.Vocab at 0x228eebd6be0>,
#  'â€¢': <gensim.models.keyedvectors.Vocab at 0x228eebd6c18>,
#  'ENE': <gensim.models.keyedvectors.Vocab at 0x228eebd6c50>,
#  'OF': <gensim.models.keyedvectors.Vocab at 0x228eebd6c88>,
#  'HOJANCHA': <gensim.models.keyedvectors.Vocab at 0x228eebd6cc0>,
#  'M5.6': <gensim.models.keyedvectors.Vocab at 0x228eebd6cf8>,
#  '11km': <gensim.models.keyedvectors.Vocab at 0x228eebd6d30>,
#  '2012-09-08': <gensim.models.keyedvectors.Vocab at 0x228eebd6d68>,
#  'USGSBigQuakes': <gensim.models.keyedvectors.Vocab at 0x228eebd6da0>,
#  'Sep-8': <gensim.models.keyedvectors.Vocab at 0x228eebd6dd8>,
#  '20:29': <gensim.models.keyedvectors.Vocab at 0x228eebd6e10>,
#  'YouTube': <gensim.models.keyedvectors.Vocab at 0x228eebd6e48>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x228eebd6e80>,
#  '4.1': <gensim.models.keyedvectors.Vocab at 0x228eebd6eb8>,
#  'Islands': <gensim.models.keyedvectors.Vocab at 0x228eebd6ef0>,
#  'Aleutian': <gensim.models.keyedvectors.Vocab at 0x228eebd6f28>,
#  'nswia_weather': <gensim.models.keyedvectors.Vocab at 0x228eebd6f60>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x228eebd6f98>,
#  'Woy': <gensim.models.keyedvectors.Vocab at 0x228eebd6fd0>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x228eebd9048>,
#  '16:23:51': <gensim.models.keyedvectors.Vocab at 0x228eebd9080>,
#  'AEST': <gensim.models.keyedvectors.Vocab at 0x228eebd90b8>,
#  'Andaman': <gensim.models.keyedvectors.Vocab at 0x228eebd90f0>,
#  'Region': <gensim.models.keyedvectors.Vocab at 0x228eebd9128>,
#  'relieve': <gensim.models.keyedvectors.Vocab at 0x228eebd9160>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x228eebd9198>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x228eebd91d0>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x228eebd9208>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x228eebd9240>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x228eebd9278>,
#  '4.6': <gensim.models.keyedvectors.Vocab at 0x228eebd92b0>,
#  '5km': <gensim.models.keyedvectors.Vocab at 0x228eebd92e8>,
#  'NNE': <gensim.models.keyedvectors.Vocab at 0x228eebd9320>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x228eebd9358>,
#  '20:13': <gensim.models.keyedvectors.Vocab at 0x228eebd9390>,
#  '21m': <gensim.models.keyedvectors.Vocab at 0x228eebd93c8>,
#  '37km': <gensim.models.keyedvectors.Vocab at 0x228eebd9400>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x228eebd9438>,
#  '06:29:35': <gensim.models.keyedvectors.Vocab at 0x228eebd9470>,
#  'quakemonitor': <gensim.models.keyedvectors.Vocab at 0x228eebd94a8>,
#  'Depth': <gensim.models.keyedvectors.Vocab at 0x228eebd94e0>,
#  '35.00': <gensim.models.keyedvectors.Vocab at 0x228eebd9518>,
#  'km': <gensim.models.keyedvectors.Vocab at 0x228eebd9550>,
#  '7:29:35': <gensim.models.keyedvectors.Vocab at 0x228eebd9588>,
#  'BST': <gensim.models.keyedvectors.Vocab at 0x228eebd95c0>,
#  '42km': <gensim.models.keyedvectors.Vocab at 0x228eebd95f8>,
#  'SW': <gensim.models.keyedvectors.Vocab at 0x228eebd9630>,
#  'Paquera': <gensim.models.keyedvectors.Vocab at 0x228eebd9668>,
#  '00:29': <gensim.models.keyedvectors.Vocab at 0x228eebd96a0>,
#  '10:05:02': <gensim.models.keyedvectors.Vocab at 0x228eebd96d8>,
#  'Sott': <gensim.models.keyedvectors.Vocab at 0x228eebd9710>,
#  'Officials': <gensim.models.keyedvectors.Vocab at 0x228eebd9748>,
#  'Could': <gensim.models.keyedvectors.Vocab at 0x228eebd9780>,
#  'Still': <gensim.models.keyedvectors.Vocab at 0x228eebd97b8>,
#  'Occur': <gensim.models.keyedvectors.Vocab at 0x228eebd97f0>,
#  'fondalo': <gensim.models.keyedvectors.Vocab at 0x228eebd9828>,
#  'socialmedia': <gensim.models.keyedvectors.Vocab at 0x228eebd9860>,
#  'Exchange': <gensim.models.keyedvectors.Vocab at 0x228eebd9898>,
#  'Site': <gensim.models.keyedvectors.Vocab at 0x228eebd98d0>,
#  'Reaffirms': <gensim.models.keyedvectors.Vocab at 0x228eebd9908>,
#  'terremoto': <gensim.models.keyedvectors.Vocab at 0x228eebd9940>,
#  '5.1': <gensim.models.keyedvectors.Vocab at 0x228eebd9978>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x228eebd99b0>,
#  'Mid-Atlantic': <gensim.models.keyedvectors.Vocab at 0x228eebd99e8>,
#  'Ridge': <gensim.models.keyedvectors.Vocab at 0x228eebd9a20>,
#  '3.2': <gensim.models.keyedvectors.Vocab at 0x228eebd9a58>,
#  'Northern': <gensim.models.keyedvectors.Vocab at 0x228eebd9a90>,
#  'Dispatch': <gensim.models.keyedvectors.Vocab at 0x228eebd9ac8>,
#  '5.2': <gensim.models.keyedvectors.Vocab at 0x228eebd9b00>,
#  '8km': <gensim.models.keyedvectors.Vocab at 0x228eebd9b38>,
#  'W': <gensim.models.keyedvectors.Vocab at 0x228eebd9b70>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x228eebd9ba8>,
#  '23:51': <gensim.models.keyedvectors.Vocab at 0x228eebd9be0>,
#  '24km': <gensim.models.keyedvectors.Vocab at 0x228eebd9c18>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x228eebd9c50>,
#  '05:51:09': <gensim.models.keyedvectors.Vocab at 0x228eebd9c88>,
#  '10km': <gensim.models.keyedvectors.Vocab at 0x228eebd9cc0>,
#  'Samara': <gensim.models.keyedvectors.Vocab at 0x228eebd9cf8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x228eebd9d30>,
#  '13:10': <gensim.models.keyedvectors.Vocab at 0x228eebd9d68>,
#  '57m': <gensim.models.keyedvectors.Vocab at 0x228eebd9da0>,
#  '44km': <gensim.models.keyedvectors.Vocab at 0x228eebd9dd8>,
#  'ChileEarthquake': <gensim.models.keyedvectors.Vocab at 0x228eebd9e10>,
#  'Chilean': <gensim.models.keyedvectors.Vocab at 0x228eebd9e48>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x228eebd9e80>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x228eebd9eb8>,
#  'emergency': <gensim.models.keyedvectors.Vocab at 0x228eebd9ef0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x228eebd9f28>,
#  '-via': <gensim.models.keyedvectors.Vocab at 0x228eebd9f60>,
#  'AFP': <gensim.models.keyedvectors.Vocab at 0x228eebd9f98>,
#  'PrayForChile': <gensim.models.keyedvectors.Vocab at 0x228eebd9fd0>,
#  'Five': <gensim.models.keyedvectors.Vocab at 0x228eebde048>,
#  '8.2': <gensim.models.keyedvectors.Vocab at 0x228eebde080>,
#  'aftermath': <gensim.models.keyedvectors.Vocab at 0x228eebde0b8>,
#  'FOX8NOLA': <gensim.models.keyedvectors.Vocab at 0x228eebde0f0>,
#  'unbelievable': <gensim.models.keyedvectors.Vocab at 0x228eebde128>,
#  'img': <gensim.models.keyedvectors.Vocab at 0x228eebde160>,
#  'Larryferlazzo': <gensim.models.keyedvectors.Vocab at 0x228eebde198>,
#  'stevesilberman': <gensim.models.keyedvectors.Vocab at 0x228eebde1d0>,
#  'Evacuation': <gensim.models.keyedvectors.Vocab at 0x228eebde208>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x228eebde240>,
#  'Iquique': <gensim.models.keyedvectors.Vocab at 0x228eebde278>,
#  'googlenews': <gensim.models.keyedvectors.Vocab at 0x228eebde2b0>,
#  'Least': <gensim.models.keyedvectors.Vocab at 0x228eebde2e8>,
#  'Dead': <gensim.models.keyedvectors.Vocab at 0x228eebde320>,
#  'Near': <gensim.models.keyedvectors.Vocab at 0x228eebde358>,
#  'Wall': <gensim.models.keyedvectors.Vocab at 0x228eebde390>,
#  'Street': <gensim.models.keyedvectors.Vocab at 0x228eebde3c8>,
#  'Journal': <gensim.models.keyedvectors.Vocab at 0x228eebde400>,
#  'Montreal': <gensim.models.keyedvectors.Vocab at 0x228eebde438>,
#  'Gazet': <gensim.models.keyedvectors.Vocab at 0x228eebde470>,
#  'spark': <gensim.models.keyedvectors.Vocab at 0x228eebde4a8>,
#  'tsunamiwarning': <gensim.models.keyedvectors.Vocab at 0x228eebde4e0>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x228eebde518>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x228eebde550>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x228eebde588>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x228eebde5c0>,
#  'vessels': <gensim.models.keyedvectors.Vocab at 0x228eebde5f8>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x228eebde630>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x228eebde668>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x228eebde6a0>,
#  'remarkable': <gensim.models.keyedvectors.Vocab at 0x228eebde6d8>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x228eebde710>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x228eebde748>,
#  'Tweeted': <gensim.models.keyedvectors.Vocab at 0x228eebde780>,
#  'Top': <gensim.models.keyedvectors.Vocab at 0x228eebde7b8>,
#  'CNN.â€¦': <gensim.models.keyedvectors.Vocab at 0x228eebde7f0>,
#  'Incredible': <gensim.models.keyedvectors.Vocab at 0x228eebde828>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x228eebde860>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x228eebde898>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x228eebde8d0>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x228eebde908>,
#  'People': <gensim.models.keyedvectors.Vocab at 0x228eebde940>,
#  'flee': <gensim.models.keyedvectors.Vocab at 0x228eebde978>,
#  'Way': <gensim.models.keyedvectors.Vocab at 0x228eebde9b0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x228eebde9e8>,
#  'May': <gensim.models.keyedvectors.Vocab at 0x228eebdea20>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x228eebdea58>,
#  'Deadly': <gensim.models.keyedvectors.Vocab at 0x228eebdea90>,
#  'Magnitude-8.2': <gensim.models.keyedvectors.Vocab at 0x228eebdeac8>,
#  'Temblor': <gensim.models.keyedvectors.Vocab at 0x228eebdeb00>,
#  'Rocks': <gensim.models.keyedvectors.Vocab at 0x228eebdeb38>,
#  '5.5': <gensim.models.keyedvectors.Vocab at 0x228eebdeb70>,
#  '2014-04-02': <gensim.models.keyedvectors.Vocab at 0x228eebdeba8>,
#  '11:07:31': <gensim.models.keyedvectors.Vocab at 0x228eebdebe0>,
#  '-19.99': <gensim.models.keyedvectors.Vocab at 0x228eebdec18>,
#  '-70.92': <gensim.models.keyedvectors.Vocab at 0x228eebdec50>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x228eebdec88>,
#  'ANEWS': <gensim.models.keyedvectors.Vocab at 0x228eebdecc0>,
#  'interior': <gensim.models.keyedvectors.Vocab at 0x228eebdecf8>,
#  'minister': <gensim.models.keyedvectors.Vocab at 0x228eebded30>,
#  'Tsunami-triggering': <gensim.models.keyedvectors.Vocab at 0x228eebded68>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x228eebdeda0>,
#  '300Â': <gensim.models.keyedvectors.Vocab at 0x228eebdedd8>,
#  'prisoners': <gensim.models.keyedvectors.Vocab at 0x228eebdee10>,
#  'aftershocks': <gensim.models.keyedvectors.Vocab at 0x228eebdee48>,
#  'Read': <gensim.models.keyedvectors.Vocab at 0x228eebdee80>,
#  'Peru': <gensim.models.keyedvectors.Vocab at 0x228eebdeeb8>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x228eebdeef0>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x228eebdef28>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x228eebdef60>,
#  'inmates': <gensim.models.keyedvectors.Vocab at 0x228eebdef98>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x228eebdefd0>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x228eebe1048>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x228eebe1080>,
#  'Arica': <gensim.models.keyedvectors.Vocab at 0x228eebe10b8>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x228eebe10f0>,
#  'TRENDING': <gensim.models.keyedvectors.Vocab at 0x228eebe1128>,
#  'TODAY': <gensim.models.keyedvectors.Vocab at 0x228eebe1160>,
#  'Tuesday': <gensim.models.keyedvectors.Vocab at 0x228eebe1198>,
#  'Via': <gensim.models.keyedvectors.Vocab at 0x228eebe11d0>,
#  'canadafreepress': <gensim.models.keyedvectors.Vocab at 0x228eebe1208>,
#  'disaster': <gensim.models.keyedvectors.Vocab at 0x228eebe1240>,
#  ...}

# %%
w2v_quake.train(list_of_words_quake, total_examples=w2v_quake.corpus_count, epochs=30, report_delay=1)
w2v_flood.train(list_of_words_flood, total_examples=w2v_quake.corpus_count, epochs=30, report_delay=1)
# Out:
# INFO - 11:02:04: training model with 3 workers on 11096 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=4
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 1 : training on 61156 raw words (29091 effective words) took 0.1s, 226404 effective words/s
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 2 : training on 61156 raw words (29171 effective words) took 0.1s, 386010 effective words/s
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 3 : training on 61156 raw words (29315 effective words) took 0.1s, 432289 effective words/s
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 4 : training on 61156 raw words (29140 effective words) took 0.1s, 466629 effective words/s
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 5 : training on 61156 raw words (29150 effective words) took 0.1s, 459275 effective words/s
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 6 : training on 61156 raw words (29286 effective words) took 0.1s, 482596 effective words/s
# INFO - 11:02:04: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:04: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:04: EPOCH - 7 : training on 61156 raw words (29171 effective words) took 0.1s, 454898 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 8 : training on 61156 raw words (29252 effective words) took 0.1s, 375336 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 9 : training on 61156 raw words (29159 effective words) took 0.1s, 376537 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 10 : training on 61156 raw words (29318 effective words) took 0.1s, 418075 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 11 : training on 61156 raw words (29123 effective words) took 0.1s, 468775 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 12 : training on 61156 raw words (29313 effective words) took 0.1s, 431759 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 13 : training on 61156 raw words (29032 effective words) took 0.1s, 490688 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 14 : training on 61156 raw words (29174 effective words) took 0.1s, 410487 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 15 : training on 61156 raw words (29111 effective words) took 0.1s, 377673 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 16 : training on 61156 raw words (29266 effective words) took 0.1s, 302158 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 17 : training on 61156 raw words (29224 effective words) took 0.1s, 374264 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 18 : training on 61156 raw words (29327 effective words) took 0.1s, 396733 effective words/s
# INFO - 11:02:05: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:05: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:05: EPOCH - 19 : training on 61156 raw words (29259 effective words) took 0.1s, 404488 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 20 : training on 61156 raw words (29155 effective words) took 0.1s, 498782 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 21 : training on 61156 raw words (29313 effective words) took 0.1s, 475085 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 22 : training on 61156 raw words (29057 effective words) took 0.1s, 429467 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 23 : training on 61156 raw words (29271 effective words) took 0.1s, 429294 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 24 : training on 61156 raw words (29340 effective words) took 0.1s, 368265 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 25 : training on 61156 raw words (29246 effective words) took 0.1s, 446054 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 26 : training on 61156 raw words (29366 effective words) took 0.1s, 415310 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 27 : training on 61156 raw words (29266 effective words) took 0.1s, 470689 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 28 : training on 61156 raw words (29188 effective words) took 0.1s, 365017 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 29 : training on 61156 raw words (29226 effective words) took 0.1s, 290784 effective words/s
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 30 : training on 61156 raw words (29301 effective words) took 0.1s, 422596 effective words/s
# INFO - 11:02:06: training on a 1834680 raw words (876611 effective words) took 2.5s, 356770 effective words/s
# INFO - 11:02:06: training model with 3 workers on 8277 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=4
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 1 : training on 43000 raw words (19883 effective words) took 0.1s, 360313 effective words/s
# WARNING - 11:02:06: EPOCH - 1 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:06: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:06: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:06: EPOCH - 2 : training on 43000 raw words (19949 effective words) took 0.1s, 390256 effective words/s
# WARNING - 11:02:06: EPOCH - 2 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 3 : training on 43000 raw words (19876 effective words) took 0.1s, 378509 effective words/s
# WARNING - 11:02:07: EPOCH - 3 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 4 : training on 43000 raw words (19946 effective words) took 0.1s, 391904 effective words/s
# WARNING - 11:02:07: EPOCH - 4 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 5 : training on 43000 raw words (19903 effective words) took 0.1s, 352274 effective words/s
# WARNING - 11:02:07: EPOCH - 5 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 6 : training on 43000 raw words (19880 effective words) took 0.1s, 376358 effective words/s
# WARNING - 11:02:07: EPOCH - 6 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 7 : training on 43000 raw words (19935 effective words) took 0.0s, 412417 effective words/s
# WARNING - 11:02:07: EPOCH - 7 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 8 : training on 43000 raw words (19978 effective words) took 0.1s, 365453 effective words/s
# WARNING - 11:02:07: EPOCH - 8 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 9 : training on 43000 raw words (19882 effective words) took 0.1s, 380887 effective words/s
# WARNING - 11:02:07: EPOCH - 9 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 10 : training on 43000 raw words (19940 effective words) took 0.1s, 348480 effective words/s
# WARNING - 11:02:07: EPOCH - 10 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 11 : training on 43000 raw words (20001 effective words) took 0.1s, 379468 effective words/s
# WARNING - 11:02:07: EPOCH - 11 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 12 : training on 43000 raw words (19931 effective words) took 0.1s, 377248 effective words/s
# WARNING - 11:02:07: EPOCH - 12 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 13 : training on 43000 raw words (19970 effective words) took 0.1s, 348956 effective words/s
# WARNING - 11:02:07: EPOCH - 13 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 14 : training on 43000 raw words (19917 effective words) took 0.1s, 353502 effective words/s
# WARNING - 11:02:07: EPOCH - 14 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 15 : training on 43000 raw words (19841 effective words) took 0.0s, 404942 effective words/s
# WARNING - 11:02:07: EPOCH - 15 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 16 : training on 43000 raw words (19965 effective words) took 0.1s, 370136 effective words/s
# WARNING - 11:02:07: EPOCH - 16 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 17 : training on 43000 raw words (19908 effective words) took 0.1s, 385860 effective words/s
# WARNING - 11:02:07: EPOCH - 17 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:07: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:07: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:07: EPOCH - 18 : training on 43000 raw words (19962 effective words) took 0.1s, 360798 effective words/s
# WARNING - 11:02:07: EPOCH - 18 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 19 : training on 43000 raw words (20012 effective words) took 0.1s, 370057 effective words/s
# WARNING - 11:02:08: EPOCH - 19 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 20 : training on 43000 raw words (20005 effective words) took 0.1s, 364896 effective words/s
# WARNING - 11:02:08: EPOCH - 20 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 21 : training on 43000 raw words (20017 effective words) took 0.0s, 406693 effective words/s
# WARNING - 11:02:08: EPOCH - 21 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 22 : training on 43000 raw words (19942 effective words) took 0.1s, 378604 effective words/s
# WARNING - 11:02:08: EPOCH - 22 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 23 : training on 43000 raw words (19958 effective words) took 0.1s, 388567 effective words/s
# WARNING - 11:02:08: EPOCH - 23 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 24 : training on 43000 raw words (19886 effective words) took 0.1s, 373874 effective words/s
# WARNING - 11:02:08: EPOCH - 24 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 25 : training on 43000 raw words (19869 effective words) took 0.1s, 387185 effective words/s
# WARNING - 11:02:08: EPOCH - 25 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 26 : training on 43000 raw words (19939 effective words) took 0.1s, 372577 effective words/s
# WARNING - 11:02:08: EPOCH - 26 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 27 : training on 43000 raw words (20079 effective words) took 0.1s, 379676 effective words/s
# WARNING - 11:02:08: EPOCH - 27 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 28 : training on 43000 raw words (19948 effective words) took 0.1s, 375636 effective words/s
# WARNING - 11:02:08: EPOCH - 28 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 29 : training on 43000 raw words (19854 effective words) took 0.1s, 391665 effective words/s
# WARNING - 11:02:08: EPOCH - 29 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:02:08: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:02:08: EPOCH - 30 : training on 43000 raw words (19937 effective words) took 0.1s, 368874 effective words/s
# WARNING - 11:02:08: EPOCH - 30 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:02:08: training on a 1290000 raw words (598113 effective words) took 1.8s, 332821 effective words/s
# (598113, 1290000)

# %% [markdown]
# The following code allows us to see words closely related (positively or negatively) with any other word. In this case we put in the word 'help'.

# %%
w2v_quake.wv.most_similar(positive=["dead"])
# Out:
# INFO - 11:02:08: precomputing L2-norms of word weight vectors
# [('kill', 0.9996314644813538),
#  ('northern', 0.9996073246002197),
#  ('A', 0.9995359778404236),
#  ('7.4-magnitude', 0.9994767308235168),
#  ('report', 0.9994566440582275),
#  ('rock', 0.9994409680366516),
#  ('Italy', 0.9994329810142517),
#  ('powerful', 0.9994298219680786),
#  ('6', 0.9993337392807007),
#  ('least', 0.9993335008621216)]

# %% [markdown]
# We will now convert these word2vec embeddings into a pandas dataframe. This can be converted into a csv for use later in maybe R. We will also explore ways to use this in an SVM model to classify our tweets.

# %%
word_list_quake = []
vector_list_quake = []
for word in w2v_quake.wv.vocab:
    word_list_quake.append(word)
    vector_list_quake.append(w2v_quake.wv.get_vector(word))
    
word_list_flood = []
vector_list_flood = []
for word in w2v_flood.wv.vocab:
    word_list_flood.append(word)
    vector_list_flood.append(w2v_flood.wv.get_vector(word))

# %%
quake_embeddings = pd.DataFrame()
quake_embeddings['Word'] = word_list_quake
quake_embeddings['Vector'] = vector_list_quake

# %%
flood_embeddings = pd.DataFrame()
flood_embeddings['Word'] = word_list_flood
flood_embeddings['Vector'] = vector_list_flood

# %%
quake_embeddings.to_csv('Word2Vec_Earthquake.csv')
flood_embeddings.to_csv('Word2Vec_Flood.csv')

# %% [markdown]
# ## SVM Classifier
#
# ### Creating Word2Vec Vectors for Train Data:
#
# Before we can implement the classifier, we need to convert our sentences (from balanced df) to a word2vec representation using our word2vec model that we trained above.

# %%
def word2vec_convert(all_tweets, model):
    whole_vec = []
    vec = np.zeros(100)
    numw = 0
    for tweet in all_tweets:
        tweet_vec = []
        vec = np.zeros(100)
        for word in tweet:
            try:
                vec = np.add(vec, model[word])
                tweet_vec.append(vec)
                numw = numw + 1
            except:
                pass
        whole_vec.append(tweet_vec)
    return(whole_vec)

# %% [markdown]
# Getting the quake data into vector form using our trained embeddings. We also append it to the original df.

# %%
l_quake = preProcess(df_quake)
word2vec_convert_quake = word2vec_convert(l_quake, w2v_quake)
df_quake['word2vec'] = word2vec_convert_quake
# Out:
# C:\Users\Vishaal\Anaconda3_Mod\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Getting the flood data into vector form using our trained embeddings. We also append it to the original df.

# %%
l_flood = preProcess(df_flood)
word2vec_convert_flood = word2vec_convert(l_flood, w2v_flood)
df_flood['word2vec'] = word2vec_convert_flood
# Out:
# C:\Users\Vishaal\Anaconda3_Mod\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
X_train, X_val, Y_train, Y_val = model_selection.train_test_split(text_lc, t_lc, test_size=0.2, random_state=100)
