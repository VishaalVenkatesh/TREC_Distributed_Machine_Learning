# %%
import os
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import string
import re
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
import logging
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
from nltk import bigrams
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Vishaal\\Documents\\GitHub\\TREC_Distributed_Machine_Learning\\TREC\\30_Models'

# %% [markdown]
# ## Reading in the Data:
#
# We have used all the tweets from 2018 (train and test) to create the embeddings. However, balanced datasets have been used to train and test the model. The following code reads in all the data. Note, we are only considering earthquakes and floods in the following sections and we will build separate models for each earthquakes and floods.

# %%
os.chdir('../10_Data/30_Balanced Tweets (Crit = High = Medium = Low)/10_2018 Train')

# %%
df_e1 = pd.read_csv('earthquake_TREC_2018_train_BALANCED.csv')
df_f1 = pd.read_csv('flood_TREC_2018_train_BALANCED.csv')

# %%
os.chdir('../15_2018 Test')

# %%
df_e2 = pd.read_csv('earthquake_TREC_2018_test_BALANCED.csv')
df_f2 = pd.read_csv('flood_TREC_2018_test_BALANCED.csv')

# %%
os.chdir('../../20_Extracted Tweets/10_2018 Train')

# %%
df_e1_embed = pd.read_csv('Earthquake_TREC_2018_train.csv')
df_f1_embed = pd.read_csv('flood_TREC_2018_train.csv')

# %%
os.chdir('../15_2018 Test')

# %%
df_e2_embed = pd.read_csv('Earthquake_TREC_2018_test.csv')
df_f2_embed = pd.read_csv('Floods_TREC_2018_test.csv')

# %% [markdown]
# ## Combining dataframes
# We are now combine earthquake tweets into one df and flood tweets into another df. We have subsetting on the tweets and priority columns. We do this for both the embedding dataframes and our balanced datasets, although we will not use the balanced datasets until later.

# %%
df_quake_e = pd.DataFrame()
df_quake_e['Tweet'] = pd.concat([df_e1_embed['Tweet'] , df_e2_embed['Tweet']])
df_quake_e['Priority'] = pd.concat([df_e1_embed['Priority'] , df_e2_embed['Priority']])

# %%
df_flood_e = pd.DataFrame()
df_flood_e['Tweet'] = pd.concat([df_f1_embed['Tweet'] , df_f2_embed['Tweet']])
df_flood_e['Priority'] = pd.concat([df_f1_embed['Priority'] , df_f2_embed['Priority']])

# %%
df_quake = pd.DataFrame()
df_quake['Tweet'] = pd.concat([df_e1['Tweet'] , df_e2['Tweet']])
df_quake['Priority'] = pd.concat([df_e1['Priority'] , df_e2['Priority']])

# %%
df_flood = pd.DataFrame()
df_flood['Tweet'] = pd.concat([df_f1['Tweet'] , df_f2['Tweet']])
df_flood['Priority'] = pd.concat([df_f1['Priority'] , df_f2['Priority']])

# %% [markdown]
# Cross checking the shapes to make sure they match. **They do match**

# %%
df_quake_e.shape, df_flood_e.shape, df_quake.shape, df_flood.shape
# Out:
# ((5140, 2), (2518, 2), (100, 2), (120, 2))

# %% [markdown]
# ## Converting to categorical (0 & 1)
#
# We will now define a function to convert the priority to a categorical 0 & 1. This will be necessary when we train a model.

# %%
'''
Creating a categorical variable to keep label critical tweets as 1 and 0 otherwise
'''
def to_categorical(array):
    t = []
    for element in array:
        if element =='Critical':
            t.append(1)
        else:
            t.append(0)
        
    return (t)

# %% [markdown]
# ## Pre-Processing
#
# We shall now perform a series of pre processing to our tweets. This includes tokenizing them, removing stop words and lemmatising them.
#
# **I also wrote a line of code to remove the links in the tweets as it was throwing in a lot of gibberish into the emebddings.** The link is almost always at the end of the tweet so its relatively easy to remove.
#
# I left the punctuation marks in. We have to take a call on this later.

# %%
def preProcess(df):
    df['Tweet'] = df['Tweet'].astype('str')
    
    df['Tweet'] = df['Tweet'].apply(lambda x: re.split('http?s *: *\/\/.*', str(x))[0])
    
    token_array = []
    #for tweet in df['Tweet']:
    #    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    #    tweet = tweet.translate(translator)
    #    token_tweet = word_tokenize(tweet)
    #    token_array.append(token_tweet)
    
    for tweet in df['Tweet']:
        token_tweet = word_tokenize(tweet)
        token_array.append(token_tweet)
        
    stop_words=set(stopwords.words("english"))
    filtered_token_array=[]
    for tweet in token_array:
        filtered_tweet = []
        for word in tweet:
                if word not in stop_words:
                    filtered_tweet.append(word)
        filtered_token_array.append(filtered_tweet)
        
    lem = WordNetLemmatizer()

    lemmatized_array=[]
    for tweet in filtered_token_array:
        lemmatized_tweet = []
        for word in tweet:
            lemmatized_tweet.append(lem.lemmatize(word,'v'))
        lemmatized_array.append(lemmatized_tweet)
    
    lemmatized_array_join = []
    for element in lemmatized_array:
        lemmatized_array_join.append(' '.join(element))
        
    return (lemmatized_array_join)

# %% [markdown]
# The tweets have been pre processed and we now have a collection of tweets. Word2Vec takes in a list of words together contained in a bigger list (Corpus -> List of Tweet -> List of Words).

# %%
l_quake_e = preProcess(df_quake_e)
l_flood_e = preProcess(df_flood_e)

list_of_words_quake = []
list_of_words_flood = []

for tweet in l_quake_e:
        token_tweet = word_tokenize(tweet)
        list_of_words_quake.append(token_tweet)
        
for tweet in l_flood_e:
        token_tweet = word_tokenize(tweet)
        list_of_words_flood.append(token_tweet)

# %% [markdown]
# ## Creating a Word2Vec model
#
# We will now initialise a word2vec model. This takes in a paramter 'min_count' which is the number of minimum occurences of a word required for it be included in the embeddings. **For now we set min_count = 1**. I did this because we are creating our own embeddings (not picking from wikipedia embeddings etc) and our data is not that huge.

# %%
'''
min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)

window = int - The maximum distance between the current and predicted word within a sentence. 
        E.g. window words on the left and window words on the left of our target - (2, 10)

size = int - Dimensionality of the feature vectors. - (50, 300)

sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. 
        Highly influencial. - (0, 1e-5)

alpha = float - The initial learning rate - (0.01, 0.05)

min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. 
        To set it: alpha - (min_alpha * epochs) ~ 0.00

negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" 
        should be drown. If set to 0, no negative sampling is used. - (5, 20)
        
workers = int - Use these many worker threads to train the model (=faster training with multicore machines)
'''
w2v_quake = Word2Vec(min_count=1,
                     window=4,
                     size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20)
w2v_flood = Word2Vec(min_count=1,
                     window=4,
                     size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20)

# %% [markdown]
# We will now build our vocabulary. Do not run the following code multiple times before initialising the w2v instance again from above.

# %%
w2v_quake.build_vocab(list_of_words_quake)
w2v_flood.build_vocab(list_of_words_flood)
# Out:
# INFO - 11:37:12: collecting all words and their counts
# INFO - 11:37:12: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 11:37:12: collected 13732 word types from a corpus of 70267 raw words and 5140 sentences
# INFO - 11:37:12: Loading a fresh vocabulary
# INFO - 11:37:12: effective_min_count=1 retains 13732 unique words (100% of original 13732, drops 0)
# INFO - 11:37:12: effective_min_count=1 leaves 70267 word corpus (100% of original 70267, drops 0)
# INFO - 11:37:12: deleting the raw counts dictionary of 13732 items
# INFO - 11:37:12: sample=6e-05 downsamples 669 most-common words
# INFO - 11:37:12: downsampling leaves estimated 33474 word corpus (47.6% of prior 70267)
# INFO - 11:37:12: estimated required memory for 13732 words and 100 dimensions: 17851600 bytes
# INFO - 11:37:12: resetting layer weights
# INFO - 11:37:14: collecting all words and their counts
# INFO - 11:37:14: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 11:37:14: collected 9614 word types from a corpus of 48396 raw words and 2518 sentences
# INFO - 11:37:14: Loading a fresh vocabulary
# INFO - 11:37:14: effective_min_count=1 retains 9614 unique words (100% of original 9614, drops 0)
# INFO - 11:37:14: effective_min_count=1 leaves 48396 word corpus (100% of original 48396, drops 0)
# INFO - 11:37:14: deleting the raw counts dictionary of 9614 items
# INFO - 11:37:14: sample=6e-05 downsamples 733 most-common words
# INFO - 11:37:14: downsampling leaves estimated 22299 word corpus (46.1% of prior 48396)
# INFO - 11:37:14: estimated required memory for 9614 words and 100 dimensions: 12498200 bytes
# INFO - 11:37:14: resetting layer weights

# %% [markdown]
# The following code is to view the vocabulary that we created

# %%
vocabulary_quake = w2v_quake.wv.vocab
vocabulary_flood = w2v_flood.wv.vocab
vocabulary_quake
# Out:
# {'ã€�': <gensim.models.keyedvectors.Vocab at 0x228ea2f7dd8>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x228eed580b8>,
#  'USGS': <gensim.models.keyedvectors.Vocab at 0x228eeb2fc88>,
#  'Breakingã€': <gensim.models.keyedvectors.Vocab at 0x228eeb09dd8>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x228eeb09f60>,
#  'M': <gensim.models.keyedvectors.Vocab at 0x228eeb272b0>,
#  '1.1': <gensim.models.keyedvectors.Vocab at 0x228eeb27da0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x228eeb27f98>,
#  '28km': <gensim.models.keyedvectors.Vocab at 0x228eeb273c8>,
#  'SSW': <gensim.models.keyedvectors.Vocab at 0x228eeb27588>,
#  'Fairbanks': <gensim.models.keyedvectors.Vocab at 0x228eeb27ef0>,
#  'Alaska': <gensim.models.keyedvectors.Vocab at 0x228eeb27128>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x228eeb275c0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x228f36de9b0>,
#  '//t.co/hSyciQFM': <gensim.models.keyedvectors.Vocab at 0x228f36de7b8>,
#  'PastHour': <gensim.models.keyedvectors.Vocab at 0x228f36de668>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x228ee78ada0>,
#  'earthquake': <gensim.models.keyedvectors.Vocab at 0x228ee78ab38>,
#  'tsunami': <gensim.models.keyedvectors.Vocab at 0x228ee78ac50>,
#  'prayfromjapan': <gensim.models.keyedvectors.Vocab at 0x228ee78aba8>,
#  'Earthquake': <gensim.models.keyedvectors.Vocab at 0x228eebb1b70>,
#  '4.8': <gensim.models.keyedvectors.Vocab at 0x228eebb1b00>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x228ea2f8588>,
#  'Bali': <gensim.models.keyedvectors.Vocab at 0x228ea2f85c0>,
#  'Indonesia': <gensim.models.keyedvectors.Vocab at 0x228ea2f85f8>,
#  'September': <gensim.models.keyedvectors.Vocab at 0x228ea2f8630>,
#  '04': <gensim.models.keyedvectors.Vocab at 0x228ea2f8668>,
#  '2012': <gensim.models.keyedvectors.Vocab at 0x228ea2f87f0>,
#  '21:19:30': <gensim.models.keyedvectors.Vocab at 0x228ea2f8828>,
#  'GMT': <gensim.models.keyedvectors.Vocab at 0x228ea2f8860>,
#  '//t.co/iEelaYGO': <gensim.models.keyedvectors.Vocab at 0x228ea2f8898>,
#  '4.5': <gensim.models.keyedvectors.Vocab at 0x228ea2f88d0>,
#  'Taiwan': <gensim.models.keyedvectors.Vocab at 0x228ea2f8908>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x228ea2f8940>,
#  '//t.co/7FmNQZdm': <gensim.models.keyedvectors.Vocab at 0x228ea2f8978>,
#  '2.6': <gensim.models.keyedvectors.Vocab at 0x228ea2f89b0>,
#  'Hawaii': <gensim.models.keyedvectors.Vocab at 0x228ea2f89e8>,
#  '//t.co/S2GbQIaO': <gensim.models.keyedvectors.Vocab at 0x228ea2f8a20>,
#  'Magnitude': <gensim.models.keyedvectors.Vocab at 0x228ea2f8a58>,
#  '7.9': <gensim.models.keyedvectors.Vocab at 0x228ea2f8a90>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x228ea2f8ac8>,
#  'coast': <gensim.models.keyedvectors.Vocab at 0x228ea2f8b00>,
#  'Costa': <gensim.models.keyedvectors.Vocab at 0x228ea2f8b38>,
#  'Rica': <gensim.models.keyedvectors.Vocab at 0x228ea2f8b70>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x228ea2f8ba8>,
#  'RT': <gensim.models.keyedvectors.Vocab at 0x228ea2f8be0>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x228ea2f8c18>,
#  'Reuters': <gensim.models.keyedvectors.Vocab at 0x228ea2f8c50>,
#  'Live': <gensim.models.keyedvectors.Vocab at 0x228ea2f8c88>,
#  'coverage': <gensim.models.keyedvectors.Vocab at 0x228ea2f8cc0>,
#  '7.9-magnitude': <gensim.models.keyedvectors.Vocab at 0x228ea2f8cf8>,
#  'rattle': <gensim.models.keyedvectors.Vocab at 0x228ea2f8d30>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x228ea2f8d68>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x228ea2f8da0>,
#  'Caribbean': <gensim.models.keyedvectors.Vocab at 0x228ea2f8dd8>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x228ea2f8e10>,
#  '//t.c': <gensim.models.keyedvectors.Vocab at 0x228ea2f8e48>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x228ea2f8e80>,
#  'ãƒ‡ã‚': <gensim.models.keyedvectors.Vocab at 0x228ea2f8eb8>,
#  '«': <gensim.models.keyedvectors.Vocab at 0x228ea2f8ef0>,
#  'ã‚¤ã�ªã€‚ã�§ã�‹ã�™ã�Žã‚‹ã�œã€�ãƒ™ã‚¯ãƒ†ãƒ': <gensim.models.keyedvectors.Vocab at 0x228ea2f8f28>,
#  'ï¼�http': <gensim.models.keyedvectors.Vocab at 0x228ea2f8f60>,
#  '//t.co/SvC7zoN5ã€€RTx2': <gensim.models.keyedvectors.Vocab at 0x228ea2f8f98>,
#  'ã€€': <gensim.models.keyedvectors.Vocab at 0x228ea2f8fd0>,
#  'NewEarthquake': <gensim.models.keyedvectors.Vocab at 0x228ea2fc048>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x228ea2fc080>,
#  'Sep': <gensim.models.keyedvectors.Vocab at 0x228ea2fc0b8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x228ea2fc0f0>,
#  '8:42amã€€http': <gensim.models.keyedvectors.Vocab at 0x228ea2fc128>,
#  '//t.co/mwsMLQ3Z': <gensim.models.keyedvectors.Vocab at 0x228ea2fc160>,
#  'BreakingNews': <gensim.models.keyedvectors.Vocab at 0x228ea2fc198>,
#  'Caribbean-wide': <gensim.models.keyedvectors.Vocab at 0x228ea2fc1d0>,
#  'Rican': <gensim.models.keyedvectors.Vocab at 0x228ea2fc208>,
#  'quake': <gensim.models.keyedvectors.Vocab at 0x228ea2fc240>,
#  'Pacific': <gensim.models.keyedvectors.Vocab at 0x228ea2fc278>,
#  'Tsunami': <gensim.models.keyedvectors.Vocab at 0x228ea2fc2b0>,
#  'Warning': <gensim.models.keyedvectors.Vocab at 0x228ea2fc2e8>,
#  'Center': <gensim.models.keyedvectors.Vocab at 0x228ea2fc320>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x228ea2fc358>,
#  'lgf': <gensim.models.keyedvectors.Vocab at 0x228ea2fc390>,
#  'p2': <gensim.models.keyedvectors.Vocab at 0x228ea2fc3c8>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x228ea2fc400>,
#  'magnitude-5.8': <gensim.models.keyedvectors.Vocab at 0x228ea2fc438>,
#  '//t.co/454IrRdA': <gensim.models.keyedvectors.Vocab at 0x228ea2fc470>,
#  'costarica': <gensim.models.keyedvectors.Vocab at 0x228ea2fc4a8>,
#  'More': <gensim.models.keyedvectors.Vocab at 0x228ea2fc4e0>,
#  'coastline': <gensim.models.keyedvectors.Vocab at 0x228ea2fc518>,
#  '//t.co/9YqdEq9g': <gensim.models.keyedvectors.Vocab at 0x228ea2fc550>,
#  'AlertNet': <gensim.models.keyedvectors.Vocab at 0x228ea2fc588>,
#  'Strong': <gensim.models.keyedvectors.Vocab at 0x228ea2fc5c0>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x228ea2fc5f8>,
#  '//t.co/sxICdjwl': <gensim.models.keyedvectors.Vocab at 0x228ea2fc630>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x228ea2fc668>,
#  'RobertaCBS5': <gensim.models.keyedvectors.Vocab at 0x228ea2fc6a0>,
#  'Breaking': <gensim.models.keyedvectors.Vocab at 0x228ea2fc6d8>,
#  'Tsunmai': <gensim.models.keyedvectors.Vocab at 0x228ea2fc710>,
#  'WARNING': <gensim.models.keyedvectors.Vocab at 0x228ea2fc748>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x228ea2fc780>,
#  'Central': <gensim.models.keyedvectors.Vocab at 0x228ea2fc7b8>,
#  'America': <gensim.models.keyedvectors.Vocab at 0x228ea2fc7f0>,
#  'magnitude': <gensim.models.keyedvectors.Vocab at 0x228ea2fc828>,
#  'Birth': <gensim.models.keyedvectors.Vocab at 0x228ea2fc860>,
#  'pangs': <gensim.models.keyedvectors.Vocab at 0x228ea2fc898>,
#  '8:42am': <gensim.models.keyedvectors.Vocab at 0x228ea2fc8d0>,
#  'epicenter': <gensim.models.keyedvectors.Vocab at 0x228ea2fc908>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x228ea2fc940>,
#  '6m': <gensim.models.keyedvectors.Vocab at 0x228ea2fc978>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x228ea2fc9b0>,
#  '83km': <gensim.models.keyedvectors.Vocab at 0x228ea2fc9e8>,
#  'S': <gensim.models.keyedvectors.Vocab at 0x228ea2fca20>,
#  'Liberia': <gensim.models.keyedvectors.Vocab at 0x228ea2fca58>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x228ea2fca90>,
#  '46km': <gensim.models.keyedvectors.Vocab at 0x228ea2fcac8>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x228ea2fcb00>,
#  'Oh': <gensim.models.keyedvectors.Vocab at 0x228ea2fcb38>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x228ea2fcb70>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x228ea2fcba8>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x228ea2fcbe0>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x228ea2fcc18>,
#  'Nids_ShriKant': <gensim.models.keyedvectors.Vocab at 0x228ea2fcc50>,
#  'Rica..': <gensim.models.keyedvectors.Vocab at 0x228ea2fcc88>,
#  'Now': <gensim.models.keyedvectors.Vocab at 0x228ea2fccc0>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x228ea2fccf8>,
#  'KeepSafe': <gensim.models.keyedvectors.Vocab at 0x228ea2fcd30>,
#  'GodBless': <gensim.models.keyedvectors.Vocab at 0x228ea2fcd68>,
#  'costa': <gensim.models.keyedvectors.Vocab at 0x228ea2fcda0>,
#  'rica': <gensim.models.keyedvectors.Vocab at 0x228ea2fcdd8>,
#  '7,9SR': <gensim.models.keyedvectors.Vocab at 0x228ea2fce10>,
#  'CHILE': <gensim.models.keyedvectors.Vocab at 0x228ea2fce48>,
#  "'S": <gensim.models.keyedvectors.Vocab at 0x228ea2fce80>,
#  'NAVY': <gensim.models.keyedvectors.Vocab at 0x228ea2fceb8>,
#  'SAYS': <gensim.models.keyedvectors.Vocab at 0x228ea2fcef0>,
#  'DECLARES': <gensim.models.keyedvectors.Vocab at 0x228ea2fcf28>,
#  'TSUNAMI': <gensim.models.keyedvectors.Vocab at 0x228ea2fcf60>,
#  'ALERT': <gensim.models.keyedvectors.Vocab at 0x228ea2fcf98>,
#  'FOR': <gensim.models.keyedvectors.Vocab at 0x228ea2fcfd0>,
#  'CHILEAN': <gensim.models.keyedvectors.Vocab at 0x228ea2ff048>,
#  'COAST': <gensim.models.keyedvectors.Vocab at 0x228ea2ff080>,
#  'FOLLOWING': <gensim.models.keyedvectors.Vocab at 0x228ea2ff0b8>,
#  'COSTA': <gensim.models.keyedvectors.Vocab at 0x228ea2ff0f0>,
#  'RICA': <gensim.models.keyedvectors.Vocab at 0x228ea2ff128>,
#  'QUAKE': <gensim.models.keyedvectors.Vocab at 0x228ea2ff160>,
#  'CP24': <gensim.models.keyedvectors.Vocab at 0x228ea2ff198>,
#  'BREAKING': <gensim.models.keyedvectors.Vocab at 0x228ea2ff1d0>,
#  'Coast': <gensim.models.keyedvectors.Vocab at 0x228ea2ff208>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x228ea2ff240>,
#  'No': <gensim.models.keyedvectors.Vocab at 0x228ea2ff278>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x228ea2ff2b0>,
#  'damage/injuries': <gensim.models.keyedvectors.Vocab at 0x228ea2ff2e8>,
#  'TWCBreaking': <gensim.models.keyedvectors.Vocab at 0x228ea2ff320>,
#  'Mag': <gensim.models.keyedvectors.Vocab at 0x228ea2ff358>,
#  'Mexico': <gensim.models.keyedvectors.Vocab at 0x228ea2ff390>,
#  'C.': <gensim.models.keyedvectors.Vocab at 0x228ea2ff3c8>,
#  'S.': <gensim.models.keyedvectors.Vocab at 0x228ea2ff400>,
#  'â€œ': <gensim.models.keyedvectors.Vocab at 0x228ea2ff438>,
#  'USGSâ€�': <gensim.models.keyedvectors.Vocab at 0x228ea2ff470>,
#  'YahooNews': <gensim.models.keyedvectors.Vocab at 0x228ea2ff4a8>,
#  'Please': <gensim.models.keyedvectors.Vocab at 0x228ea2ff4e0>,
#  'pray': <gensim.models.keyedvectors.Vocab at 0x228ea2ff518>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x228ea2ff550>,
#  'magnitude-7.9': <gensim.models.keyedvectors.Vocab at 0x228ea2ff588>,
#  'CostaRica': <gensim.models.keyedvectors.Vocab at 0x228ea2ff5c0>,
#  'accord': <gensim.models.keyedvectors.Vocab at 0x228ea2ff5f8>,
#  'BBCWorld': <gensim.models.keyedvectors.Vocab at 0x228ea2ff630>,
#  'Details': <gensim.models.keyedvectors.Vocab at 0x228ea2ff668>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x228ea2ff6a0>,
#  '//t.co/TcpLwxJJ': <gensim.models.keyedvectors.Vocab at 0x228ea2ff6d8>,
#  'QuakeReports': <gensim.models.keyedvectors.Vocab at 0x228ea2ff710>,
#  '//t.co/iYnWzKuL': <gensim.models.keyedvectors.Vocab at 0x228ea2ff748>,
#  'MEXICO': <gensim.models.keyedvectors.Vocab at 0x228ea2ff780>,
#  'CITY': <gensim.models.keyedvectors.Vocab at 0x228ea2ff7b8>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x228ea2ff7f0>,
#  'miles': <gensim.models.keyedvectors.Vocab at 0x228ea2ff828>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x228ea2ff860>,
#  'northwestern': <gensim.models.keyedvectors.Vocab at 0x228ea2ff898>,
#  'Wednesday..': <gensim.models.keyedvectors.Vocab at 0x228ea2ff8d0>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x228ea2ff908>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x228ea2ff940>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x228ea2ff978>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x228ea2ff9b0>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x228ea2ff9e8>,
#  'fieldproducer': <gensim.models.keyedvectors.Vocab at 0x228ea2ffa20>,
#  'revise': <gensim.models.keyedvectors.Vocab at 0x228ea2ffa58>,
#  '7.6': <gensim.models.keyedvectors.Vocab at 0x228ea2ffa90>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x228ea2ffac8>,
#  '//t.co/3vxo2zBN': <gensim.models.keyedvectors.Vocab at 0x228ea2ffb00>,
#  'My': <gensim.models.keyedvectors.Vocab at 0x228ea2ffb38>,
#  'prayers': <gensim.models.keyedvectors.Vocab at 0x228ea2ffb70>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x228ea2ffba8>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x228ea2ffbe0>,
#  'They': <gensim.models.keyedvectors.Vocab at 0x228ea2ffc18>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x228ea2ffc50>,
#  'Powerful': <gensim.models.keyedvectors.Vocab at 0x228ea2ffc88>,
#  '//t.co/6ZoS6sxc': <gensim.models.keyedvectors.Vocab at 0x228ea2ffcc0>,
#  'CNBC': <gensim.models.keyedvectors.Vocab at 0x228ea2ffcf8>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x228ea2ffd30>,
#  '98': <gensim.models.keyedvectors.Vocab at 0x228ea2ffd68>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x228ea2ffda0>,
#  'Jose': <gensim.models.keyedvectors.Vocab at 0x228ea2ffdd8>,
#  'Chile': <gensim.models.keyedvectors.Vocab at 0x228ea2ffe10>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x228ea2ffe48>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x228ea2ffe80>,
#  'declare': <gensim.models.keyedvectors.Vocab at 0x228ea2ffeb8>,
#  'alert': <gensim.models.keyedvectors.Vocab at 0x228ea2ffef0>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x228ea2fff28>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x228ea2fff60>,
#  'Revised': <gensim.models.keyedvectors.Vocab at 0x228ea2fff98>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x228ea2fffd0>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x228ea2c3048>,
#  '24m': <gensim.models.keyedvectors.Vocab at 0x228ea2c3080>,
#  '60km': <gensim.models.keyedvectors.Vocab at 0x228ea2c30b8>,
#  'SSE': <gensim.models.keyedvectors.Vocab at 0x228ea2c30f0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x228ea2c3128>,
#  'irasuwindro': <gensim.models.keyedvectors.Vocab at 0x228ea2c3160>,
#  '//t.co/QXqN9Xo2': <gensim.models.keyedvectors.Vocab at 0x228ea2c3198>,
#  'RT_com': <gensim.models.keyedvectors.Vocab at 0x228ea2c31d0>,
#  'Quake': <gensim.models.keyedvectors.Vocab at 0x228ea2c3208>,
#  'Hits': <gensim.models.keyedvectors.Vocab at 0x228ea2c3240>,
#  '//t.co/dtHKXF2v': <gensim.models.keyedvectors.Vocab at 0x228ea2c3278>,
#  'jcagain': <gensim.models.keyedvectors.Vocab at 0x228ea2c32b0>,
#  'Damn': <gensim.models.keyedvectors.Vocab at 0x228ea2c32e8>,
#  'Poor': <gensim.models.keyedvectors.Vocab at 0x228ea2c3320>,
#  'cnnbrk': <gensim.models.keyedvectors.Vocab at 0x228ea2c3358>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x228ea2c3390>,
#  '7.6.': <gensim.models.keyedvectors.Vocab at 0x228ea2c33c8>,
#  '//t.co/nVvZPUSG': <gensim.models.keyedvectors.Vocab at 0x228ea2c3400>,
#  'ccbp': <gensim.models.keyedvectors.Vocab at 0x228ea2c3438>,
#  'Big': <gensim.models.keyedvectors.Vocab at 0x228ea2c3470>,
#  'M7.9': <gensim.models.keyedvectors.Vocab at 0x228ea2c34a8>,
#  'occurrred': <gensim.models.keyedvectors.Vocab at 0x228ea2c34e0>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x228ea2c3518>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x228ea2c3550>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x228ea2c3588>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x228ea2c35c0>,
#  '7.6-magnitude': <gensim.models.keyedvectors.Vocab at 0x228ea2c35f8>,
#  '//t.co/WmdiDVXx': <gensim.models.keyedvectors.Vocab at 0x228ea2c3630>,
#  'cnn': <gensim.models.keyedvectors.Vocab at 0x228ea2c3668>,
#  'weathernetwork': <gensim.models.keyedvectors.Vocab at 0x228ea2c36a0>,
#  'Reports': <gensim.models.keyedvectors.Vocab at 0x228ea2c36d8>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x228ea2c3710>,
#  'collapse': <gensim.models.keyedvectors.Vocab at 0x228ea2c3748>,
#  'church': <gensim.models.keyedvectors.Vocab at 0x228ea2c3780>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x228ea2c37b8>,
#  'Nicoya': <gensim.models.keyedvectors.Vocab at 0x228ea2c37f0>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x228ea2c3828>,
#  'epicentre': <gensim.models.keyedvectors.Vocab at 0x228ea2c3860>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x228ea2c3898>,
#  '7.6-mag': <gensim.models.keyedvectors.Vocab at 0x228ea2c38d0>,
#  '//t.co/NyfZ4eSU': <gensim.models.keyedvectors.Vocab at 0x228ea2c3908>,
#  'For': <gensim.models.keyedvectors.Vocab at 0x228ea2c3940>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x228ea2c3978>,
#  'Hawaii..': <gensim.models.keyedvectors.Vocab at 0x228ea2c39b0>,
#  'case..': <gensim.models.keyedvectors.Vocab at 0x228ea2c39e8>,
#  'mag': <gensim.models.keyedvectors.Vocab at 0x228ea2c3a20>,
#  'prompt': <gensim.models.keyedvectors.Vocab at 0x228ea2c3a58>,
#  '//t.co/YOXlVpn4': <gensim.models.keyedvectors.Vocab at 0x228ea2c3a90>,
#  'karmonan': <gensim.models.keyedvectors.Vocab at 0x228ea2c3ac8>,
#  '//t.co/i98cKt0n': <gensim.models.keyedvectors.Vocab at 0x228ea2c3b00>,
#  'Radio_Riquelme': <gensim.models.keyedvectors.Vocab at 0x228ea2c3b38>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x228ea2c3b70>,
#  'coastal': <gensim.models.keyedvectors.Vocab at 0x228ea2c3ba8>,
#  'htt': <gensim.models.keyedvectors.Vocab at 0x228ea2c3be0>,
#  '//t.co/G6t1GwTW': <gensim.models.keyedvectors.Vocab at 0x228ea2c3c18>,
#  'CNN': <gensim.models.keyedvectors.Vocab at 0x228ea2c3c50>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x228ea2c3c88>,
#  '//t.co/2HehvYYZ': <gensim.models.keyedvectors.Vocab at 0x228ea2c3cc0>,
#  'CBSNews': <gensim.models.keyedvectors.Vocab at 0x228ea2c3cf8>,
#  'LATEST': <gensim.models.keyedvectors.Vocab at 0x228ea2c3d30>,
#  'DETAILS': <gensim.models.keyedvectors.Vocab at 0x228ea2c3d68>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x228ea2c3da0>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x228ea2c3dd8>,
#  '//t.co/FuS54wrA': <gensim.models.keyedvectors.Vocab at 0x228ea2c3e10>,
#  'JamaicaGleaner': <gensim.models.keyedvectors.Vocab at 0x228ea2c3e48>,
#  '//t.co/uZAnla8U': <gensim.models.keyedvectors.Vocab at 0x228ea2c3e80>,
#  'Yahoo/Space-': <gensim.models.keyedvectors.Vocab at 0x228ea2c3eb8>,
#  'WASHINGTON': <gensim.models.keyedvectors.Vocab at 0x228ea2c3ef0>,
#  'magnit': <gensim.models.keyedvectors.Vocab at 0x228ea2c3f28>,
#  '//t.co/o60LTx4g': <gensim.models.keyedvectors.Vocab at 0x228ea2c3f60>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x228ea2c3f98>,
#  '//t.co/dFBziPuJ': <gensim.models.keyedvectors.Vocab at 0x228ea2c3fd0>,
#  'International': <gensim.models.keyedvectors.Vocab at 0x228ea2da048>,
#  'Yahoo': <gensim.models.keyedvectors.Vocab at 0x228ea2da080>,
#  'News': <gensim.models.keyedvectors.Vocab at 0x228ea2da0b8>,
#  '//t.co/IgSLlNPo': <gensim.models.keyedvectors.Vocab at 0x228ea2da0f0>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x228ea2da128>,
#  '//t.co/5paIoWUj': <gensim.models.keyedvectors.Vocab at 0x228ea2da160>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x228ea2da198>,
#  'preliminary': <gensim.models.keyedvectors.Vocab at 0x228ea2da1d0>,
#  '//t.co/4vALj5az': <gensim.models.keyedvectors.Vocab at 0x228ea2da208>,
#  'Pura': <gensim.models.keyedvectors.Vocab at 0x228ea2da240>,
#  'Vida': <gensim.models.keyedvectors.Vocab at 0x228ea2da278>,
#  'EliteDaily': <gensim.models.keyedvectors.Vocab at 0x228ea2da2b0>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x228ea2da2e8>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x228ea2da320>,
#  'warning-': <gensim.models.keyedvectors.Vocab at 0x228ea2da358>,
#  '//t.co/sgyaU24e': <gensim.models.keyedvectors.Vocab at 0x228ea2da390>,
#  'there-just': <gensim.models.keyedvectors.Vocab at 0x228ea2da3c8>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x228ea2da400>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x228ea2da438>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x228ea2da470>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x228ea2da4a8>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x228ea2da4e0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x228ea2da518>,
#  'abc7newsBayArea': <gensim.models.keyedvectors.Vocab at 0x228ea2da550>,
#  'abcnews': <gensim.models.keyedvectors.Vocab at 0x228ea2da588>,
#  '//t.co/HVOzoRQW': <gensim.models.keyedvectors.Vocab at 0x228ea2da5c0>,
#  'Magnitude-7.6': <gensim.models.keyedvectors.Vocab at 0x228ea2da5f8>,
#  '//t.co/Y8pp9Q4b': <gensim.models.keyedvectors.Vocab at 0x228ea2da630>,
#  '_mannymeister': <gensim.models.keyedvectors.Vocab at 0x228ea2da668>,
#  'thankyou': <gensim.models.keyedvectors.Vocab at 0x228ea2da6a0>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x228ea2da6d8>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x228ea2da710>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x228ea2da748>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x228ea2da780>,
#  "'m": <gensim.models.keyedvectors.Vocab at 0x228ea2da7b8>,
#  'md': <gensim.models.keyedvectors.Vocab at 0x228ea2da7f0>,
#  'SonOfAKing3': <gensim.models.keyedvectors.Vocab at 0x228ea2da828>,
#  'UnivisionNews': <gensim.models.keyedvectors.Vocab at 0x228ea2da860>,
#  'Northwestern': <gensim.models.keyedvectors.Vocab at 0x228ea2da898>,
#  'Ricaâ€�': <gensim.models.keyedvectors.Vocab at 0x228ea2da8d0>,
#  '100prayingwomen': <gensim.models.keyedvectors.Vocab at 0x228ea2da908>,
#  'Interior': <gensim.models.keyedvectors.Vocab at 0x228ea2da940>,
#  'Minister': <gensim.models.keyedvectors.Vocab at 0x228ea2da978>,
#  'Hinzpeter': <gensim.models.keyedvectors.Vocab at 0x228ea2da9b0>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x228ea2da9e8>,
#  'evacuation': <gensim.models.keyedvectors.Vocab at 0x228ea2daa20>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x228ea2daa58>,
#  'LisaDCNN': <gensim.models.keyedvectors.Vocab at 0x228ea2daa90>,
#  'UPDATE': <gensim.models.keyedvectors.Vocab at 0x228ea2daac8>,
#  'CNNweather': <gensim.models.keyedvectors.Vocab at 0x228ea2dab00>,
#  'Warnings': <gensim.models.keyedvectors.Vocab at 0x228ea2dab38>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x228e4f00358>,
#  'Panama': <gensim.models.keyedvectors.Vocab at 0x228e4f007f0>,
#  'Nicaragua': <gensim.models.keyedvectors.Vocab at 0x228f36de9e8>,
#  '7.6M': <gensim.models.keyedvectors.Vocab at 0x228f36de780>,
#  '//t.co/4jg0FjYJ': <gensim.models.keyedvectors.Vocab at 0x228f36dee80>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x228f36deb38>,
#  'COSTARICA': <gensim.models.keyedvectors.Vocab at 0x228f36de240>,
#  'ADVISORY': <gensim.models.keyedvectors.Vocab at 0x228f36deeb8>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x228f36de8d0>,
#  'NO': <gensim.models.keyedvectors.Vocab at 0x228ea3a7ef0>,
#  'WAVES': <gensim.models.keyedvectors.Vocab at 0x228ea3a7fd0>,
#  'REPORTED': <gensim.models.keyedvectors.Vocab at 0x228ea3a7f28>,
#  'YET': <gensim.models.keyedvectors.Vocab at 0x228eeb428d0>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x228eeb42978>,
#  'BE': <gensim.models.keyedvectors.Vocab at 0x228ea2dab70>,
#  'ON': <gensim.models.keyedvectors.Vocab at 0x228ea2daba8>,
#  'PRECAUTIONARY': <gensim.models.keyedvectors.Vocab at 0x228ea2dabe0>,
#  'EVACUATION': <gensim.models.keyedvectors.Vocab at 0x228ea2dac18>,
#  'RECOMMENDED': <gensim.models.keyedvectors.Vocab at 0x228ea2dac50>,
#  'PTWC': <gensim.models.keyedvectors.Vocab at 0x228ea2dac88>,
#  'NEWS': <gensim.models.keyedvectors.Vocab at 0x228ea2dacc0>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x228ea2dacf8>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x228ea2dad30>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x228ea2dad68>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x228ea2dada0>,
#  '//t.co/7bpHsLIw': <gensim.models.keyedvectors.Vocab at 0x228ea2dadd8>,
#  'Reported': <gensim.models.keyedvectors.Vocab at 0x228ea2dae10>,
#  'ABC': <gensim.models.keyedvectors.Vocab at 0x228ea2dae48>,
#  '//t.co/W6UmjhiY': <gensim.models.keyedvectors.Vocab at 0x228ea2dae80>,
#  'nbcnightlynews': <gensim.models.keyedvectors.Vocab at 0x228ea2daeb8>,
#  'Just': <gensim.models.keyedvectors.Vocab at 0x228ea2daef0>,
#  '//t.co/3i2HJ0e6': <gensim.models.keyedvectors.Vocab at 0x228ea2daf28>,
#  'Disarm': <gensim.models.keyedvectors.Vocab at 0x228ea2daf60>,
#  'Major': <gensim.models.keyedvectors.Vocab at 0x228ea2daf98>,
#  '//t.co/fF1uny0U': <gensim.models.keyedvectors.Vocab at 0x228ea2dafd0>,
#  'nbcnews': <gensim.models.keyedvectors.Vocab at 0x228e5144048>,
#  'LatinAmerica': <gensim.models.keyedvectors.Vocab at 0x228e5144080>,
#  'Reutersâ€�': <gensim.models.keyedvectors.Vocab at 0x228e51440b8>,
#  'DanielrBarron': <gensim.models.keyedvectors.Vocab at 0x228e51440f0>,
#  'washingtonpost': <gensim.models.keyedvectors.Vocab at 0x228e5144128>,
#  '//t.co/U7u7FDY4â€�': <gensim.models.keyedvectors.Vocab at 0x228e5144160>,
#  'sismocr': <gensim.models.keyedvectors.Vocab at 0x228e5144198>,
#  'Temblocr': <gensim.models.keyedvectors.Vocab at 0x228e51441d0>,
#  'ABC7': <gensim.models.keyedvectors.Vocab at 0x228e5144208>,
#  'BREAKINGNEWS': <gensim.models.keyedvectors.Vocab at 0x228e5144240>,
#  '7.9-mag': <gensim.models.keyedvectors.Vocab at 0x228e5144278>,
#  'immediate': <gensim.models.keyedvectors.Vocab at 0x228e51442b0>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x228e51442e8>,
#  'TheNextCorner': <gensim.models.keyedvectors.Vocab at 0x228e5144320>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x228e5144358>,
#  '//t.co/iRzYxUA0': <gensim.models.keyedvectors.Vocab at 0x228e5144390>,
#  'ninaism': <gensim.models.keyedvectors.Vocab at 0x228e51443c8>,
#  'georgekourounis': <gensim.models.keyedvectors.Vocab at 0x228e5144400>,
#  'landslides': <gensim.models.keyedvectors.Vocab at 0x228e5144438>,
#  'inland': <gensim.models.keyedvectors.Vocab at 0x228e5144470>,
#  'RDLKid': <gensim.models.keyedvectors.Vocab at 0x228e51444a8>,
#  'springrose12': <gensim.models.keyedvectors.Vocab at 0x228e51444e0>,
#  'HDNER': <gensim.models.keyedvectors.Vocab at 0x228e5144518>,
#  'cancel': <gensim.models.keyedvectors.Vocab at 0x228e5144550>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x228e5144588>,
#  'Ocean': <gensim.models.keyedvectors.Vocab at 0x228e51445c0>,
#  'moanikitv': <gensim.models.keyedvectors.Vocab at 0x228e51445f8>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x228e5144630>,
#  'temblorcr': <gensim.models.keyedvectors.Vocab at 0x228e5144668>,
#  'Is': <gensim.models.keyedvectors.Vocab at 0x228e51446a0>,
#  'OK': <gensim.models.keyedvectors.Vocab at 0x228e51446d8>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x228e5144710>,
#  'RobDavis_Wx': <gensim.models.keyedvectors.Vocab at 0x228e5144748>,
#  'LANDSLIDE': <gensim.models.keyedvectors.Vocab at 0x228e5144780>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x228e51447b8>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x228e51447f0>,
#  'M7.6': <gensim.models.keyedvectors.Vocab at 0x228e5144828>,
#  '//t.co/e5c2AUas': <gensim.models.keyedvectors.Vocab at 0x228e5144860>,
#  'courtesy': <gensim.models.keyedvectors.Vocab at 0x228e5144898>,
#  'skasoul': <gensim.models.keyedvectors.Vocab at 0x228e51448d0>,
#  'NOSARA': <gensim.models.keyedvectors.Vocab at 0x228e5144908>,
#  'AP': <gensim.models.keyedvectors.Vocab at 0x228e5144940>,
#  'â€': <gensim.models.keyedvectors.Vocab at 0x228e5144978>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x228e51449b0>,
#  'magnitude-7': <gensim.models.keyedvectors.Vocab at 0x228e51449e8>,
#  '//t.co/fueoYIDe': <gensim.models.keyedvectors.Vocab at 0x228e5144a20>,
#  'Newsfeed': <gensim.models.keyedvectors.Vocab at 0x228e5144a58>,
#  '//t.co/odMEBADD': <gensim.models.keyedvectors.Vocab at 0x228e5144a90>,
#  'Politics': <gensim.models.keyedvectors.Vocab at 0x228e5144ac8>,
#  'AustralianBuzz': <gensim.models.keyedvectors.Vocab at 0x228e5144b00>,
#  'Sth': <gensim.models.keyedvectors.Vocab at 0x228e5144b38>,
#  '//t.co/8ojLIy2i': <gensim.models.keyedvectors.Vocab at 0x228e5144b70>,
#  'theBuzz': <gensim.models.keyedvectors.Vocab at 0x228e5144ba8>,
#  'Michelle9647': <gensim.models.keyedvectors.Vocab at 0x228e5144be0>,
#  'Red': <gensim.models.keyedvectors.Vocab at 0x228e5144c18>,
#  'Cross': <gensim.models.keyedvectors.Vocab at 0x228e5144c50>,
#  'casualties': <gensim.models.keyedvectors.Vocab at 0x228e5144c88>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x228e5144cc0>,
#  'JALpalyul': <gensim.models.keyedvectors.Vocab at 0x228e5144cf8>,
#  '//t.co/IroAyLyv': <gensim.models.keyedvectors.Vocab at 0x228e5144d30>,
#  '//t.co/kZ20IzD0': <gensim.models.keyedvectors.Vocab at 0x228e5144d68>,
#  'AffiliateDesire': <gensim.models.keyedvectors.Vocab at 0x228e5144da0>,
#  'Quality': <gensim.models.keyedvectors.Vocab at 0x228e5144dd8>,
#  'Footage': <gensim.models.keyedvectors.Vocab at 0x228e5144e10>,
#  'Sept': <gensim.models.keyedvectors.Vocab at 0x228e5144e48>,
#  '5th': <gensim.models.keyedvectors.Vocab at 0x228e5144e80>,
#  '//t.co/fqZodBMJ': <gensim.models.keyedvectors.Vocab at 0x228e5144eb8>,
#  'Bummer': <gensim.models.keyedvectors.Vocab at 0x228e5144ef0>,
#  'locals': <gensim.models.keyedvectors.Vocab at 0x228e5144f28>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x228e5144f60>,
#  'vacationers': <gensim.models.keyedvectors.Vocab at 0x228e5144f98>,
#  '//t.co/6sL4AtOj': <gensim.models.keyedvectors.Vocab at 0x228e5144fd0>,
#  'Hope': <gensim.models.keyedvectors.Vocab at 0x228ea2fa048>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x228ea2fa080>,
#  'TravelGov': <gensim.models.keyedvectors.Vocab at 0x228ea2fa0b8>,
#  'EmergencyMessage': <gensim.models.keyedvectors.Vocab at 0x228ea2fa0f0>,
#  'ElSalvador': <gensim.models.keyedvectors.Vocab at 0x228ea2fa128>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x228ea2fa160>,
#  'ht': <gensim.models.keyedvectors.Vocab at 0x228ea2fa198>,
#  'downgrade': <gensim.models.keyedvectors.Vocab at 0x228ea2fa1d0>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x228ea2fa208>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x228ea2fa240>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x228ea2fa278>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x228ea2fa2b0>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x228ea2fa2e8>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x228ea2fa320>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x228ea2fa358>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x228ea2fa390>,
#  'duration': <gensim.models.keyedvectors.Vocab at 0x228ea2fa3c8>,
#  '//t.co/XM78Yz5P': <gensim.models.keyedvectors.Vocab at 0x228ea2fa400>,
#  '-MM': <gensim.models.keyedvectors.Vocab at 0x228ea2fa438>,
#  'WorldNews': <gensim.models.keyedvectors.Vocab at 0x228ea2fa470>,
#  'Some': <gensim.models.keyedvectors.Vocab at 0x228ea2fa4a8>,
#  '//t.co/qi7aZ6mk': <gensim.models.keyedvectors.Vocab at 0x228ea2fa4e0>,
#  '//t.co/c9TCmf1F': <gensim.models.keyedvectors.Vocab at 0x228ea2fa518>,
#  'north-west': <gensim.models.keyedvectors.Vocab at 0x228ea2fa550>,
#  'C': <gensim.models.keyedvectors.Vocab at 0x228ea2fa588>,
#  '//t.co/9lsjq70l': <gensim.models.keyedvectors.Vocab at 0x228ea2fa5c0>,
#  'razaespn': <gensim.models.keyedvectors.Vocab at 0x228ea2fa5f8>,
#  'Estadio': <gensim.models.keyedvectors.Vocab at 0x228ea2fa630>,
#  'Nacional': <gensim.models.keyedvectors.Vocab at 0x228ea2fa668>,
#  'Issued': <gensim.models.keyedvectors.Vocab at 0x228ea2fa6a0>,
#  '//t.co/0o4UuN0t': <gensim.models.keyedvectors.Vocab at 0x228ea2fa6d8>,
#  'far-Red': <gensim.models.keyedvectors.Vocab at 0x228ea2fa710>,
#  '//t.co/JwixjWBI': <gensim.models.keyedvectors.Vocab at 0x228ea2fa748>,
#  'redcross': <gensim.models.keyedvectors.Vocab at 0x228ea2fa780>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x228ea2fa7b8>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x228ea2fa7f0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x228ea2fa828>,
#  'honeymoon': <gensim.models.keyedvectors.Vocab at 0x228ea2fa860>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x228ea2fa898>,
#  'NBCNews': <gensim.models.keyedvectors.Vocab at 0x228ea2fa8d0>,
#  '//t.co/i4mBTrzG': <gensim.models.keyedvectors.Vocab at 0x228ea2fa908>,
#  '//t.co/u8DiLvBG': <gensim.models.keyedvectors.Vocab at 0x228ea2fa940>,
#  'amarchugg': <gensim.models.keyedvectors.Vocab at 0x228ea2fa978>,
#  'That': <gensim.models.keyedvectors.Vocab at 0x228ea2fa9b0>,
#  'sustain': <gensim.models.keyedvectors.Vocab at 0x228ea2fa9e8>,
#  'tens': <gensim.models.keyedvectors.Vocab at 0x228ea2faa20>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x228ea2faa58>,
#  'dollars': <gensim.models.keyedvectors.Vocab at 0x228ea2faa90>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x228ea2faac8>,
#  'Very': <gensim.models.keyedvectors.Vocab at 0x228ea2fab00>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x228ea2fab38>,
#  'magnitude-7.6': <gensim.models.keyedvectors.Vocab at 0x228ea2fab70>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x228ea2faba8>,
#  'swath': <gensim.models.keyedvectors.Vocab at 0x228ea2fabe0>,
#  'Wednesday': <gensim.models.keyedvectors.Vocab at 0x228ea2fac18>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x228ea2fac50>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x228ea2fac88>,
#  'tod': <gensim.models.keyedvectors.Vocab at 0x228ea2facc0>,
#  '//t.co/arJ2dp3x': <gensim.models.keyedvectors.Vocab at 0x228ea2facf8>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x228ea2fad30>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x228ea2fad68>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x228ea2fada0>,
#  'fatalities': <gensim.models.keyedvectors.Vocab at 0x228ea2fadd8>,
#  'Strikes': <gensim.models.keyedvectors.Vocab at 0x228ea2fae10>,
#  'Off': <gensim.models.keyedvectors.Vocab at 0x228ea2fae48>,
#  'measurin': <gensim.models.keyedvectors.Vocab at 0x228ea2fae80>,
#  '//t.co/HgyxRGCP': <gensim.models.keyedvectors.Vocab at 0x228ea2faeb8>,
#  'HuffingtonPost': <gensim.models.keyedvectors.Vocab at 0x228ea2faef0>,
#  '//t.co/c9fM5iGF': <gensim.models.keyedvectors.Vocab at 0x228ea2faf28>,
#  '//t.co/uRzQz9oh': <gensim.models.keyedvectors.Vocab at 0x228ea2faf60>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x228ea2faf98>,
#  '//t.co/5FyzyrGC': <gensim.models.keyedvectors.Vocab at 0x228ea2fafd0>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x228ea6d3048>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x228ea6d3080>,
#  '1991': <gensim.models.keyedvectors.Vocab at 0x228ea6d30b8>,
#  '//t.co/bDiSXERD': <gensim.models.keyedvectors.Vocab at 0x228ea6d30f0>,
#  '//t.co/5wnQNFw7': <gensim.models.keyedvectors.Vocab at 0x228ea6d3128>,
#  'LoL..WTH': <gensim.models.keyedvectors.Vocab at 0x228ea6d3160>,
#  'earthquake..': <gensim.models.keyedvectors.Vocab at 0x228ea6d3198>,
#  'God': <gensim.models.keyedvectors.Vocab at 0x228ea6d31d0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x228ea6d3208>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x228ea6d3240>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x228ea6d3278>,
#  'First': <gensim.models.keyedvectors.Vocab at 0x228ea6d32b0>,
#  'VIDEO': <gensim.models.keyedvectors.Vocab at 0x228ea6d32e8>,
#  '//t.co/pkSZQESr': <gensim.models.keyedvectors.Vocab at 0x228ea6d3320>,
#  'Independent': <gensim.models.keyedvectors.Vocab at 0x228ea6d3358>,
#  '//t.co/PyeTR5b8': <gensim.models.keyedvectors.Vocab at 0x228ea6d3390>,
#  '28-mile': <gensim.models.keyedvectors.Vocab at 0x228ea6d33c8>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x228ea6d3400>,
#  'Wednes': <gensim.models.keyedvectors.Vocab at 0x228ea6d3438>,
#  '//t.co/QUEEUkYS': <gensim.models.keyedvectors.Vocab at 0x228ea6d3470>,
#  'Pray': <gensim.models.keyedvectors.Vocab at 0x228ea6d34a8>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x228ea6d34e0>,
#  'CostaRican': <gensim.models.keyedvectors.Vocab at 0x228ea6d3518>,
#  '//t.co/3PBwSz4y': <gensim.models.keyedvectors.Vocab at 0x228ea6d3550>,
#  'Nooo': <gensim.models.keyedvectors.Vocab at 0x228ea6d3588>,
#  '//t.co/ta2f2KpZ': <gensim.models.keyedvectors.Vocab at 0x228ea6d35c0>,
#  '-MMâ€�': <gensim.models.keyedvectors.Vocab at 0x228ea6d35f8>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x228ea6d3630>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x228ea6d3668>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x228ea6d36a0>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x228ea6d36d8>,
#  '//t.co/BGETbzo': <gensim.models.keyedvectors.Vocab at 0x228ea6d3710>,
#  '//t.co/UNj9Z75K': <gensim.models.keyedvectors.Vocab at 0x228ea6d3748>,
#  'â—¦': <gensim.models.keyedvectors.Vocab at 0x228ea6d3780>,
#  'Kyodo': <gensim.models.keyedvectors.Vocab at 0x228ea6d37b8>,
#  'jolt': <gensim.models.keyedvectors.Vocab at 0x228ea6d37f0>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x228ea6d3828>,
#  '//t.co/bALQNQ0l': <gensim.models.keyedvectors.Vocab at 0x228ea6d3860>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x228ea6d3898>,
#  '//t.co/nQscFMTU': <gensim.models.keyedvectors.Vocab at 0x228ea6d38d0>,
#  'WilliamTeach': <gensim.models.keyedvectors.Vocab at 0x228ea6d3908>,
#  'Which': <gensim.models.keyedvectors.Vocab at 0x228ea6d3940>,
#  'Warmist': <gensim.models.keyedvectors.Vocab at 0x228ea6d3978>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x228ea6d39b0>,
#  'blame': <gensim.models.keyedvectors.Vocab at 0x228ea6d39e8>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x228ea6d3a20>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x228ea6d3a58>,
#  '//': <gensim.models.keyedvectors.Vocab at 0x228ea6d3a90>,
#  'Dumbass': <gensim.models.keyedvectors.Vocab at 0x228ea6d3ac8>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x228ea6d3b00>,
#  'GEOLOGY..': <gensim.models.keyedvectors.Vocab at 0x228ea6d3b38>,
#  '//t.co/i7KZ1uZX': <gensim.models.keyedvectors.Vocab at 0x228ea6d3b70>,
#  '//t.co/nzoIPEe7': <gensim.models.keyedvectors.Vocab at 0x228ea6d3ba8>,
#  'TimJohnson4': <gensim.models.keyedvectors.Vocab at 0x228ea6d3be0>,
#  'prez': <gensim.models.keyedvectors.Vocab at 0x228ea6d3c18>,
#  'Damage': <gensim.models.keyedvectors.Vocab at 0x228ea6d3c50>,
#  'deaths': <gensim.models.keyedvectors.Vocab at 0x228ea6d3c88>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x228ea6d3cc0>,
#  'survey': <gensim.models.keyedvectors.Vocab at 0x228ea6d3cf8>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x228ea6d3d30>,
#  '//t.co/kYreOVVw': <gensim.models.keyedvectors.Vocab at 0x228ea6d3d68>,
#  'CHICABRAVA': <gensim.models.keyedvectors.Vocab at 0x228ea6d3da0>,
#  'stoke': <gensim.models.keyedvectors.Vocab at 0x228ea6d3dd8>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x228ea6d3e10>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x228ea6d3e48>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x228ea6d3e80>,
#  '//t.co/fYuOgSmR': <gensim.models.keyedvectors.Vocab at 0x228ea6d3eb8>,
#  'TIME': <gensim.models.keyedvectors.Vocab at 0x228ea6d3ef0>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x228ea6d3f28>,
#  '//t.co/NairyArP': <gensim.models.keyedvectors.Vocab at 0x228ea6d3f60>,
#  'Holy': <gensim.models.keyedvectors.Vocab at 0x228ea6d3f98>,
#  'shit': <gensim.models.keyedvectors.Vocab at 0x228ea6d3fd0>,
#  'Unbelievable..': <gensim.models.keyedvectors.Vocab at 0x228ea6d7080>,
#  'Would': <gensim.models.keyedvectors.Vocab at 0x228ea6d7048>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x228ea6d70f0>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x228ea6d70b8>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x228ea6d71d0>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x228ea6d7208>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x228ea6d7320>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x228ea6d74a8>,
#  'region..': <gensim.models.keyedvectors.Vocab at 0x228ea6d7390>,
#  'prayers😔': <gensim.models.keyedvectors.Vocab at 0x228ea6d7438>,
#  'URGENT': <gensim.models.keyedvectors.Vocab at 0x228ea6d7400>,
#  '//t.co/3EC6L3wM': <gensim.models.keyedvectors.Vocab at 0x228ea6d73c8>,
#  'csmonitor': <gensim.models.keyedvectors.Vocab at 0x228ea6d7588>,
#  '//t.co/jhgKhyJDâ€�///': <gensim.models.keyedvectors.Vocab at 0x228ea6d75f8>,
#  'prayer': <gensim.models.keyedvectors.Vocab at 0x228ea6d7630>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x228ea6d76a0>,
#  '//t.co/JwTblOtO': <gensim.models.keyedvectors.Vocab at 0x228ea6d7668>,
#  'dustinbrowning': <gensim.models.keyedvectors.Vocab at 0x228ea6d7710>,
#  'SamuRojas': <gensim.models.keyedvectors.Vocab at 0x228ea6d7860>,
#  'antikCR': <gensim.models.keyedvectors.Vocab at 0x228ea6d7908>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x228ea6d7a20>,
#  'newslocker': <gensim.models.keyedvectors.Vocab at 0x228ea6d7ac8>,
#  '//t.co/k3CiuTKR': <gensim.models.keyedvectors.Vocab at 0x228ea6d7b00>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x228ea6d7b70>,
#  '//t.co/ee16Q4z8': <gensim.models.keyedvectors.Vocab at 0x228ea6d7c18>,
#  'Ca': <gensim.models.keyedvectors.Vocab at 0x228ea6d7c88>,
#  "n't": <gensim.models.keyedvectors.Vocab at 0x228ea6d7c50>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x228ea6d7cc0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x228ea6d7ba8>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x228ea6d7d68>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x228ea6d7da0>,
#  'DICE': <gensim.models.keyedvectors.Vocab at 0x228ea6d7dd8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x228ea6d7e10>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x228ea6d7f98>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x228ea6d7160>,
#  'fatality': <gensim.models.keyedvectors.Vocab at 0x228ea6d7198>,
#  'resu': <gensim.models.keyedvectors.Vocab at 0x228ea6d7828>,
#  '//t.co/02a3OoUX': <gensim.models.keyedvectors.Vocab at 0x228ea6d7be0>,
#  'cuba': <gensim.models.keyedvectors.Vocab at 0x228ea6d7e80>,
#  'abajoRaul': <gensim.models.keyedvectors.Vocab at 0x228ea6d7128>,
#  'Update': <gensim.models.keyedvectors.Vocab at 0x228ea6d7240>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x228ea6d7278>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x228ea6d72b0>,
#  'CPPGeophysics': <gensim.models.keyedvectors.Vocab at 0x228ea6d72e8>,
#  'Nice': <gensim.models.keyedvectors.Vocab at 0x228ea6d7358>,
#  'visualization': <gensim.models.keyedvectors.Vocab at 0x228ea6d7470>,
#  'seismic': <gensim.models.keyedvectors.Vocab at 0x228ea6d74e0>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x228ea6d7518>,
#  'propagate': <gensim.models.keyedvectors.Vocab at 0x228ea6d7550>,
#  'USArray': <gensim.models.keyedvectors.Vocab at 0x228ea6d75c0>,
#  'EarthScopeInfo': <gensim.models.keyedvectors.Vocab at 0x228ea6d76d8>,
#  'DarinRMcClure': <gensim.models.keyedvectors.Vocab at 0x228ea6d7748>,
#  'Praying': <gensim.models.keyedvectors.Vocab at 0x228ea6d7780>,
#  'YourAnonNews': <gensim.models.keyedvectors.Vocab at 0x228ea6d77b8>,
#  'YAN': <gensim.models.keyedvectors.Vocab at 0x228ea6d77f0>,
#  '//t.co/GKGYrsLT': <gensim.models.keyedvectors.Vocab at 0x228ea6d7898>,
#  'Bad': <gensim.models.keyedvectors.Vocab at 0x228ea6d78d0>,
#  'Know': <gensim.models.keyedvectors.Vocab at 0x228ea6d7940>,
#  'Pac': <gensim.models.keyedvectors.Vocab at 0x228ea6d7978>,
#  'NWers': <gensim.models.keyedvectors.Vocab at 0x228ea6d79b0>,
#  'Pls': <gensim.models.keyedvectors.Vocab at 0x228ea6d79e8>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x228ea6d7a58>,
#  'NW': <gensim.models.keyedvectors.Vocab at 0x228ea6d7a90>,
#  'NPR': <gensim.models.keyedvectors.Vocab at 0x228ea6d7b38>,
#  'tombanse': <gensim.models.keyedvectors.Vocab at 0x228ea6d7cf8>,
#  '//t.co/n4HTkpYt': <gensim.models.keyedvectors.Vocab at 0x228ea6d7d30>,
#  'worldnews': <gensim.models.keyedvectors.Vocab at 0x228ea6d7f28>,
#  '//t.co/n1r84z2j.auPowerful': <gensim.models.keyedvectors.Vocab at 0x228ea6d7eb8>,
#  'q': <gensim.models.keyedvectors.Vocab at 0x228ea6d7e48>,
#  '//t.co/kZjsFTDY': <gensim.models.keyedvectors.Vocab at 0x228ea6d7ef0>,
#  'WideRangeMarket': <gensim.models.keyedvectors.Vocab at 0x228ea6d7f60>,
#  '//t.co/oKAri8Tq': <gensim.models.keyedvectors.Vocab at 0x228ea6d7fd0>,
#  'Canceled': <gensim.models.keyedvectors.Vocab at 0x228ea6db048>,
#  'After': <gensim.models.keyedvectors.Vocab at 0x228ea6db080>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x228ea6db0b8>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x228ea6db0f0>,
#  'Two-Way': <gensim.models.keyedvectors.Vocab at 0x228ea6db128>,
#  '//t.co/IVlHkIFm': <gensim.models.keyedvectors.Vocab at 0x228ea6db160>,
#  'Earth': <gensim.models.keyedvectors.Vocab at 0x228ea6db198>,
#  'Matias': <gensim.models.keyedvectors.Vocab at 0x228ea6db1d0>,
#  'Doing': <gensim.models.keyedvectors.Vocab at 0x228ea6db208>,
#  'Good': <gensim.models.keyedvectors.Vocab at 0x228ea6db240>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x228ea6db278>,
#  'Gon': <gensim.models.keyedvectors.Vocab at 0x228ea6db2b0>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x228ea6db2e8>,
#  'Try': <gensim.models.keyedvectors.Vocab at 0x228ea6db320>,
#  'Calling': <gensim.models.keyedvectors.Vocab at 0x228ea6db358>,
#  'His': <gensim.models.keyedvectors.Vocab at 0x228ea6db390>,
#  'Momma': <gensim.models.keyedvectors.Vocab at 0x228ea6db3c8>,
#  'Later': <gensim.models.keyedvectors.Vocab at 0x228ea6db400>,
#  'fo': <gensim.models.keyedvectors.Vocab at 0x228ea6db438>,
#  'Angie': <gensim.models.keyedvectors.Vocab at 0x228ea6db470>,
#  'Thompson': <gensim.models.keyedvectors.Vocab at 0x228ea6db4a8>,
#  'Messerschmidt': <gensim.models.keyedvectors.Vocab at 0x228ea6db4e0>,
#  'Claryssa-Faye': <gensim.models.keyedvectors.Vocab at 0x228ea6db518>,
#  'Skie': <gensim.models.keyedvectors.Vocab at 0x228ea6db550>,
#  '//t.co/gwzRqTYE': <gensim.models.keyedvectors.Vocab at 0x228ea6db588>,
#  'Did': <gensim.models.keyedvectors.Vocab at 0x228ea6db5c0>,
#  '14:42:10': <gensim.models.keyedvectors.Vocab at 0x228ea6db5f8>,
#  '//t.co/kErgzOEC': <gensim.models.keyedvectors.Vocab at 0x228ea6db630>,
#  'eTN': <gensim.models.keyedvectors.Vocab at 0x228ea6db668>,
#  'India': <gensim.models.keyedvectors.Vocab at 0x228ea6db6a0>,
#  'IBNLive.comPowerful': <gensim.models.keyedvectors.Vocab at 0x228ea6db6d8>,
#  'deadReu': <gensim.models.keyedvectors.Vocab at 0x228ea6db710>,
#  '//t.co/fdR7rYY2': <gensim.models.keyedvectors.Vocab at 0x228ea6db748>,
#  'Two': <gensim.models.keyedvectors.Vocab at 0x228ea6db780>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x228ea6db7b8>,
#  'injure': <gensim.models.keyedvectors.Vocab at 0x228ea6db7f0>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x228ea6db828>,
#  'Piedras': <gensim.models.keyedvectors.Vocab at 0x228ea6db860>,
#  'homestay': <gensim.models.keyedvectors.Vocab at 0x228ea6db898>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x228ea6db8d0>,
#  'Isidro': <gensim.models.keyedvectors.Vocab at 0x228ea6db908>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x228ea6db940>,
#  'Heredia': <gensim.models.keyedvectors.Vocab at 0x228ea6db978>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x228ea6db9b0>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x228ea6db9e8>,
#  'MrVop': <gensim.models.keyedvectors.Vocab at 0x228ea6dba20>,
#  '//t.co/c9CDEDv0': <gensim.models.keyedvectors.Vocab at 0x228ea6dba58>,
#  'BBC': <gensim.models.keyedvectors.Vocab at 0x228ea6dba90>,
#  'RandyDorfman': <gensim.models.keyedvectors.Vocab at 0x228ea6dbac8>,
#  'WCOOP': <gensim.models.keyedvectors.Vocab at 0x228ea6dbb00>,
#  'players': <gensim.models.keyedvectors.Vocab at 0x228ea6dbb38>,
#  'USA': <gensim.models.keyedvectors.Vocab at 0x228ea6dbb70>,
#  'TODAY7.6-magnitude': <gensim.models.keyedvectors.Vocab at 0x228ea6dbba8>,
#  'coastCNN': <gensim.models.keyedvectors.Vocab at 0x228ea6dbbe0>,
#  '//t.co/h76G8HKq': <gensim.models.keyedvectors.Vocab at 0x228ea6dbc18>,
#  'Online': <gensim.models.keyedvectors.Vocab at 0x228ea6dbc50>,
#  'NewsMagnitude': <gensim.models.keyedvectors.Vocab at 0x228ea6dbc88>,
#  'RicaABC': <gensim.models.keyedvectors.Vocab at 0x228ea6dbcc0>,
#  'OnlineA': <gensim.models.keyedvectors.Vocab at 0x228ea6dbcf8>,
#  'pow': <gensim.models.keyedvectors.Vocab at 0x228ea6dbd30>,
#  '//t.co/WHyfdam5': <gensim.models.keyedvectors.Vocab at 0x228ea6dbd68>,
#  'Our': <gensim.models.keyedvectors.Vocab at 0x228ea6dbda0>,
#  'hearts': <gensim.models.keyedvectors.Vocab at 0x228ea6dbdd8>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x228ea6dbe10>,
#  'Covering': <gensim.models.keyedvectors.Vocab at 0x228ea6dbe48>,
#  'TheAngieShow': <gensim.models.keyedvectors.Vocab at 0x228ea6dbe80>,
#  'Associated': <gensim.models.keyedvectors.Vocab at 0x228ea6dbeb8>,
#  'Press': <gensim.models.keyedvectors.Vocab at 0x228ea6dbef0>,
#  'ar': <gensim.models.keyedvectors.Vocab at 0x228ea6dbf28>,
#  '//t.co/5uNpnKeL': <gensim.models.keyedvectors.Vocab at 0x228ea6dbf60>,
#  'Fox': <gensim.models.keyedvectors.Vocab at 0x228ea6dbf98>,
#  'SAN': <gensim.models.keyedvectors.Vocab at 0x228ea6dbfd0>,
#  'JOSE': <gensim.models.keyedvectors.Vocab at 0x228ea6e0048>,
#  '//t.co/I9VkFGdB': <gensim.models.keyedvectors.Vocab at 0x228ea6e00b8>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x228ea6e0198>,
#  'trend': <gensim.models.keyedvectors.Vocab at 0x228ea6e0208>,
#  'Viva': <gensim.models.keyedvectors.Vocab at 0x228ea6e02b0>,
#  'bitch': <gensim.models.keyedvectors.Vocab at 0x228ea6e02e8>,
#  'CostaRicaEarthquake': <gensim.models.keyedvectors.Vocab at 0x228ea6e0358>,
#  'REN': <gensim.models.keyedvectors.Vocab at 0x228ea6e0320>,
# ...
#  'Living': <gensim.models.keyedvectors.Vocab at 0x228ea6e0da0>,
#  'Social': <gensim.models.keyedvectors.Vocab at 0x228ea6e0dd8>,
#  'Andy': <gensim.models.keyedvectors.Vocab at 0x228ea6e0e10>,
#  'Roddick': <gensim.models.keyedvectors.Vocab at 0x228ea6e0e48>,
#  '//t.co/4igC5NpM': <gensim.models.keyedvectors.Vocab at 0x228ea6e0ef0>,
#  'earthquake-ready': <gensim.models.keyedvectors.Vocab at 0x228ea6e0eb8>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x228ea6e0fd0>,
#  '+video': <gensim.models.keyedvectors.Vocab at 0x228ea6e0710>,
#  'onedirection': <gensim.models.keyedvectors.Vocab at 0x228ea6e0908>,
#  '=/': <gensim.models.keyedvectors.Vocab at 0x228ea6e0a20>,
#  '//t.co/bzZ1s8Of': <gensim.models.keyedvectors.Vocab at 0x228ea6e0d30>,
#  'Eart': <gensim.models.keyedvectors.Vocab at 0x228ea6e0f28>,
#  'This': <gensim.models.keyedvectors.Vocab at 0x228ea6e0f98>,
#  'Google': <gensim.models.keyedvectors.Vocab at 0x228ea6e0080>,
#  'Trend': <gensim.models.keyedvectors.Vocab at 0x228ea6e00f0>,
#  '//t.co/PI0h78RM': <gensim.models.keyedvectors.Vocab at 0x228ea6e0128>,
#  'Hour': <gensim.models.keyedvectors.Vocab at 0x228ea6e0160>,
#  'Woman': <gensim.models.keyedvectors.Vocab at 0x228ea6e01d0>,
#  'Died': <gensim.models.keyedvectors.Vocab at 0x228ea6e0240>,
#  'Heat': <gensim.models.keyedvectors.Vocab at 0x228ea6e0278>,
#  'Attack': <gensim.models.keyedvectors.Vocab at 0x228ea6e0390>,
#  'Man': <gensim.models.keyedvectors.Vocab at 0x228ea6e0400>,
#  'Who': <gensim.models.keyedvectors.Vocab at 0x228ea6e0438>,
#  'Fallen': <gensim.models.keyedvectors.Vocab at 0x228ea6e0470>,
#  'Die': <gensim.models.keyedvectors.Vocab at 0x228ea6e04e0>,
#  'Said': <gensim.models.keyedvectors.Vocab at 0x228ea6e0550>,
#  'President': <gensim.models.keyedvectors.Vocab at 0x228ea6e0588>,
#  '//t.co/rw5Brly8': <gensim.models.keyedvectors.Vocab at 0x228ea6e05c0>,
#  'EarthquakeCalifornia': <gensim.models.keyedvectors.Vocab at 0x228ea6e06d8>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x228ea6e0748>,
#  'World': <gensim.models.keyedvectors.Vocab at 0x228ea6e0780>,
#  'Cup': <gensim.models.keyedvectors.Vocab at 0x228ea6e07f0>,
#  'qualifier': <gensim.models.keyedvectors.Vocab at 0x228ea6e0828>,
#  'Mexican': <gensim.models.keyedvectors.Vocab at 0x228ea6e09b0>,
#  '//t.co/uv45lA0q': <gensim.models.keyedvectors.Vocab at 0x228ea6e0978>,
#  'Buildings': <gensim.models.keyedvectors.Vocab at 0x228ea6e0860>,
#  'sway': <gensim.models.keyedvectors.Vocab at 0x228ea6e0940>,
#  'residents': <gensim.models.keyedvectors.Vocab at 0x228ea6e0be0>,
#  'rush': <gensim.models.keyedvectors.Vocab at 0x228ea6e0c18>,
#  'streets': <gensim.models.keyedvectors.Vocab at 0x228ea6e0c88>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x228ea6e0d68>,
#  '//t.co/m3TI2LMz': <gensim.models.keyedvectors.Vocab at 0x228ea6e0e80>,
#  'Geologyupdate': <gensim.models.keyedvectors.Vocab at 0x228ea6e0f60>,
#  'Seattle': <gensim.models.keyedvectors.Vocab at 0x228ea6e2048>,
#  'Times': <gensim.models.keyedvectors.Vocab at 0x228ea6e20b8>,
#  '//t.co/C77uRB7g': <gensim.models.keyedvectors.Vocab at 0x228ea6e2128>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x228ea6e21d0>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x228ea6e2208>,
#  'Washington': <gensim.models.keyedvectors.Vocab at 0x228ea6e2240>,
#  'Post': <gensim.models.keyedvectors.Vocab at 0x228ea6e2278>,
#  'CBC.caPowerf': <gensim.models.keyedvectors.Vocab at 0x228ea6e22e8>,
#  '//t.co/x3Pt7hR5': <gensim.models.keyedvectors.Vocab at 0x228ea6e22b0>,
#  '//t.co/nyWQMUwk': <gensim.models.keyedvectors.Vocab at 0x228ea6e2320>,
#  'Three': <gensim.models.keyedvectors.Vocab at 0x228ea6e2358>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x228ea6e2400>,
#  'Xinhua': <gensim.models.keyedvectors.Vocab at 0x228ea6e24a8>,
#  'NationThree': <gensim.models.keyedvectors.Vocab at 0x228ea6e2438>,
#  'quak': <gensim.models.keyedvectors.Vocab at 0x228ea6e2390>,
#  '//t.co/2QKsXs8w': <gensim.models.keyedvectors.Vocab at 0x228ea6e2588>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x228ea6e25c0>,
#  'resistant': <gensim.models.keyedvectors.Vocab at 0x228ea6e25f8>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x228ea6e2668>,
#  '//t.co/n4y6x1yj': <gensim.models.keyedvectors.Vocab at 0x228ea6e26a0>,
#  'Cangrejal': <gensim.models.keyedvectors.Vocab at 0x228ea6e26d8>,
#  'sho': <gensim.models.keyedvectors.Vocab at 0x228ea6e2828>,
#  '//t.co/syQpSkg0': <gensim.models.keyedvectors.Vocab at 0x228ea6e2860>,
#  'Rocked': <gensim.models.keyedvectors.Vocab at 0x228ea6e2898>,
#  '//t.co/9Q0w3CD7': <gensim.models.keyedvectors.Vocab at 0x228ea6e28d0>,
#  '1.0': <gensim.models.keyedvectors.Vocab at 0x228ea6e2940>,
#  'Southern': <gensim.models.keyedvectors.Vocab at 0x228ea6e29b0>,
#  'California': <gensim.models.keyedvectors.Vocab at 0x228ea6e29e8>,
#  '//t.co/Ms4Sj0eR': <gensim.models.keyedvectors.Vocab at 0x228ea6e2a20>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x228ea6e2a58>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x228ea6e2ac8>,
#  'bulletin': <gensim.models.keyedvectors.Vocab at 0x228ea6e2ba8>,
#  'terrify': <gensim.models.keyedvectors.Vocab at 0x228ea6e2b70>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x228ea6e2c50>,
#  '//t.co/Dlj3rlpE': <gensim.models.keyedvectors.Vocab at 0x228ea6e2c88>,
#  '//t.co/1Dhcy6ki': <gensim.models.keyedvectors.Vocab at 0x228ea6e2cc0>,
#  '//t.co/SpG6MDUe': <gensim.models.keyedvectors.Vocab at 0x228ea6e2cf8>,
#  'QuakeÂ': <gensim.models.keyedvectors.Vocab at 0x228ea6e2d68>,
#  '//t.co/nkD5tU8v': <gensim.models.keyedvectors.Vocab at 0x228ea6e2da0>,
#  'Ready': <gensim.models.keyedvectors.Vocab at 0x228ea6e2dd8>,
#  'Action': <gensim.models.keyedvectors.Vocab at 0x228ea6e2e10>,
#  'Source': <gensim.models.keyedvectors.Vocab at 0x228ea6e2e80>,
#  'Â': <gensim.models.keyedvectors.Vocab at 0x228ea6e2e48>,
#  'Irish': <gensim.models.keyedvectors.Vocab at 0x228ea6e2eb8>,
#  'Cro': <gensim.models.keyedvectors.Vocab at 0x228ea6e2f28>,
#  '//t.co/8i9vCIV6': <gensim.models.keyedvectors.Vocab at 0x228ea6e2f60>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x228ea6e2f98>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x228ea6e2fd0>,
#  'Thursday': <gensim.models.keyedvectors.Vocab at 0x228ea6e2908>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x228ea6e2c18>,
#  'unsc': <gensim.models.keyedvectors.Vocab at 0x228ea6e2080>,
#  '//t.co/dFTSbh5e': <gensim.models.keyedvectors.Vocab at 0x228ea6e20f0>,
#  'Terror': <gensim.models.keyedvectors.Vocab at 0x228ea6e2160>,
#  'casino': <gensim.models.keyedvectors.Vocab at 0x228ea6e2198>,
#  'Capital': <gensim.models.keyedvectors.Vocab at 0x228ea6e24e0>,
#  'Videos': <gensim.models.keyedvectors.Vocab at 0x228ea6e2470>,
#  'Surface': <gensim.models.keyedvectors.Vocab at 0x228ea6e2518>,
#  'Video': <gensim.models.keyedvectors.Vocab at 0x228ea6e23c8>,
#  '//t.co/btm5k37V': <gensim.models.keyedvectors.Vocab at 0x228ea6e2550>,
#  '1.8': <gensim.models.keyedvectors.Vocab at 0x228ea6e2630>,
#  'Island': <gensim.models.keyedvectors.Vocab at 0x228ea6e2710>,
#  '//t.co/f28j4Ykf': <gensim.models.keyedvectors.Vocab at 0x228ea6e2748>,
#  'Environment': <gensim.models.keyedvectors.Vocab at 0x228ea6e2780>,
#  'Planet': <gensim.models.keyedvectors.Vocab at 0x228ea6e27b8>,
#  'Ark': <gensim.models.keyedvectors.Vocab at 0x228ea6e27f0>,
#  '//t.co/uptiMQMP': <gensim.models.keyedvectors.Vocab at 0x228ea6e2978>,
#  'EARTHQUAKE': <gensim.models.keyedvectors.Vocab at 0x228ea6e2a90>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x228ea6e2b00>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x228ea6e2b38>,
#  'Another': <gensim.models.keyedvectors.Vocab at 0x228ea6e2be0>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x228ea6e2d30>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x228ea6e2ef0>,
#  'awake': <gensim.models.keyedvectors.Vocab at 0x228ea6e7048>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x228ea6e7080>,
#  'Dang': <gensim.models.keyedvectors.Vocab at 0x228ea6e70b8>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x228ea6e70f0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x228ea6e7128>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x228ea6e7160>,
#  '3.5': <gensim.models.keyedvectors.Vocab at 0x228ea6e7198>,
#  'Beverly': <gensim.models.keyedvectors.Vocab at 0x228ea6e71d0>,
#  'Hills': <gensim.models.keyedvectors.Vocab at 0x228ea6e7208>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x228ea6e7240>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x228ea6e7278>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x228ea6e72b0>,
#  '//t.co/CftE5nrt': <gensim.models.keyedvectors.Vocab at 0x228ea6e72e8>,
#  'zomanno': <gensim.models.keyedvectors.Vocab at 0x228ea6e7320>,
#  'EARTHQUAKEEE': <gensim.models.keyedvectors.Vocab at 0x228ea6e7358>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x228ea6e7390>,
#  'coincidence': <gensim.models.keyedvectors.Vocab at 0x228ea6e73c8>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x228ea6e7400>,
#  'HoneyBooBoo': <gensim.models.keyedvectors.Vocab at 0x228ea6e7438>,
#  '9021uh-0': <gensim.models.keyedvectors.Vocab at 0x228ea6e7470>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x228ea6e74a8>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x228ea6e74e0>,
#  'westside': <gensim.models.keyedvectors.Vocab at 0x228ea6e7518>,
#  'eastern': <gensim.models.keyedvectors.Vocab at 0x228ea6e7550>,
#  'SFV': <gensim.models.keyedvectors.Vocab at 0x228ea6e7588>,
#  '//t.co/G1Ga1v0T': <gensim.models.keyedvectors.Vocab at 0x228ea6e75c0>,
#  'lanow': <gensim.models.keyedvectors.Vocab at 0x228ea6e75f8>,
#  'TheLAScene': <gensim.models.keyedvectors.Vocab at 0x228ea6e7630>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x228ea6e7668>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x228ea6e76a0>,
#  'BeverlyHills': <gensim.models.keyedvectors.Vocab at 0x228ea6e76d8>,
#  'upgrade': <gensim.models.keyedvectors.Vocab at 0x228ea6e7710>,
#  '3.5.': <gensim.models.keyedvectors.Vocab at 0x228ea6e7748>,
#  '//t.co/UThFGsv1': <gensim.models.keyedvectors.Vocab at 0x228ea6e7780>,
#  'ArianaGrande': <gensim.models.keyedvectors.Vocab at 0x228ea6e77b8>,
#  'Hi': <gensim.models.keyedvectors.Vocab at 0x228ea6e77f0>,
#  'IÂ´m': <gensim.models.keyedvectors.Vocab at 0x228ea6e7828>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x228ea6e7860>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x228ea6e7898>,
#  'again..': <gensim.models.keyedvectors.Vocab at 0x228ea6e78d0>,
#  'seriously..': <gensim.models.keyedvectors.Vocab at 0x228ea6e7908>,
#  'Tell': <gensim.models.keyedvectors.Vocab at 0x228ea6e7940>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x228ea6e7978>,
#  'bout': <gensim.models.keyedvectors.Vocab at 0x228ea6e79b0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x228ea6e79e8>,
#  'Bobak9': <gensim.models.keyedvectors.Vocab at 0x228ea6e7a20>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x228ea6e7a58>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x228ea6e7a90>,
#  'UsainBolt': <gensim.models.keyedvectors.Vocab at 0x228ea6e7ac8>,
#  'Never': <gensim.models.keyedvectors.Vocab at 0x228ea6e7b00>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x228ea6e7b38>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x228ea6e7b70>,
#  'SO': <gensim.models.keyedvectors.Vocab at 0x228ea6e7ba8>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x228ea6e7be0>,
#  'Lol': <gensim.models.keyedvectors.Vocab at 0x228ea6e7c18>,
#  'DNC2012': <gensim.models.keyedvectors.Vocab at 0x228ea6e7c50>,
#  'Was': <gensim.models.keyedvectors.Vocab at 0x228ea6e7c88>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x228ea6e7cc0>,
#  'shatter': <gensim.models.keyedvectors.Vocab at 0x228ea6e7cf8>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x228ea6e7d30>,
#  'LAFD': <gensim.models.keyedvectors.Vocab at 0x228ea6e7d68>,
#  'LAquake': <gensim.models.keyedvectors.Vocab at 0x228ea6e7da0>,
#  'Emergency': <gensim.models.keyedvectors.Vocab at 0x228ea6e7dd8>,
#  'Mode': <gensim.models.keyedvectors.Vocab at 0x228ea6e7e10>,
#  'discontinue': <gensim.models.keyedvectors.Vocab at 0x228ea6e7e48>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x228ea6e7e80>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x228ea6e7eb8>,
#  'normalâ€¦': <gensim.models.keyedvectors.Vocab at 0x228ea6e7ef0>,
#  '//t.co': <gensim.models.keyedvectors.Vocab at 0x228ea6e7f28>,
#  '//t.co/q6uTSLEa': <gensim.models.keyedvectors.Vocab at 0x228ea6e7f60>,
#  'Quakes': <gensim.models.keyedvectors.Vocab at 0x228ea6e7f98>,
#  'southwest': <gensim.models.keyedvectors.Vocab at 0x228ea6e7fd0>,
#  'China': <gensim.models.keyedvectors.Vocab at 0x228ea6e9048>,
#  'dozens': <gensim.models.keyedvectors.Vocab at 0x228ea6e9080>,
#  '20,000': <gensim.models.keyedvectors.Vocab at 0x228ea6e90b8>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x228ea6e90f0>,
#  '//t.co/0j1oq79l': <gensim.models.keyedvectors.Vocab at 0x228ea6e9128>,
#  'Earthquakes': <gensim.models.keyedvectors.Vocab at 0x228ea6e9160>,
#  'alertã€': <gensim.models.keyedvectors.Vocab at 0x228ea6e9198>,
#  '2.1': <gensim.models.keyedvectors.Vocab at 0x228ea6e91d0>,
#  '07': <gensim.models.keyedvectors.Vocab at 0x228ea6e9208>,
#  '15:33:36': <gensim.models.keyedvectors.Vocab at 0x228ea6e9240>,
#  '//t.co/G9eJVAUP': <gensim.models.keyedvectors.Vocab at 0x228ea6e9278>,
#  'Dear': <gensim.models.keyedvectors.Vocab at 0x228ea6e92b0>,
#  '2x': <gensim.models.keyedvectors.Vocab at 0x228ea6e92e8>,
#  "'ve": <gensim.models.keyedvectors.Vocab at 0x228ea6e9320>,
#  '1/2': <gensim.models.keyedvectors.Vocab at 0x228ea6e9358>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x228ea6e9390>,
#  'away-Results': <gensim.models.keyedvectors.Vocab at 0x228ea6e93c8>,
#  'crappy': <gensim.models.keyedvectors.Vocab at 0x228ea6e9400>,
#  'workout': <gensim.models.keyedvectors.Vocab at 0x228ea6e9438>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x228ea6e9470>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x228ea6e94a8>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x228ea6e94e0>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x228ea6e9518>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x228ea6e9550>,
#  'Shakes': <gensim.models.keyedvectors.Vocab at 0x228ea6e9588>,
#  '//t.co/abFcLHdd': <gensim.models.keyedvectors.Vocab at 0x228ea6e95c0>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x228ea6e95f8>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x228ea6e9630>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x228ea6e9668>,
#  'Yea': <gensim.models.keyedvectors.Vocab at 0x228ea6e96a0>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x228ea6e96d8>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x228ea6e9710>,
#  'uselessinfo': <gensim.models.keyedvectors.Vocab at 0x228ea6e9748>,
#  'Watchers': <gensim.models.keyedvectors.Vocab at 0x228ea6e9780>,
#  'Massive': <gensim.models.keyedvectors.Vocab at 0x228ea6e97b8>,
#  'awaken': <gensim.models.keyedvectors.Vocab at 0x228ea6e97f0>,
#  'Nicaraguan': <gensim.models.keyedvectors.Vocab at 0x228ea6e9828>,
#  'Apoyeque': <gensim.models.keyedvectors.Vocab at 0x228ea6e9860>,
#  'volcano': <gensim.models.keyedvectors.Vocab at 0x228ea6e9898>,
#  '//t.co/pbc2QzSB': <gensim.models.keyedvectors.Vocab at 0x228ea6e98d0>,
#  'At': <gensim.models.keyedvectors.Vocab at 0x228ea6e9908>,
#  '12:35': <gensim.models.keyedvectors.Vocab at 0x228ea6e9940>,
#  'PM': <gensim.models.keyedvectors.Vocab at 0x228ea6e9978>,
#  'UTC': <gensim.models.keyedvectors.Vocab at 0x228ea6e99b0>,
#  'Minahasa': <gensim.models.keyedvectors.Vocab at 0x228ea6e99e8>,
#  'M4.7': <gensim.models.keyedvectors.Vocab at 0x228ea6e9a20>,
#  '35.70km': <gensim.models.keyedvectors.Vocab at 0x228ea6e9a58>,
#  'Stay': <gensim.models.keyedvectors.Vocab at 0x228ea6e9a90>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x228ea6e9ac8>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x228ea6e9b00>,
#  '//t.co/htMGUaTO': <gensim.models.keyedvectors.Vocab at 0x228ea6e9b38>,
#  'BECOME': <gensim.models.keyedvectors.Vocab at 0x228ea6e9b70>,
#  'ASEXUAL': <gensim.models.keyedvectors.Vocab at 0x228ea6e9ba8>,
#  'NOW': <gensim.models.keyedvectors.Vocab at 0x228ea6e9be0>,
#  '5.6': <gensim.models.keyedvectors.Vocab at 0x228ea6e9c18>,
#  'earthqu': <gensim.models.keyedvectors.Vocab at 0x228ea6e9c50>,
#  '//t.co/5jWMTB3H': <gensim.models.keyedvectors.Vocab at 0x228ea6e9c88>,
#  'asexual': <gensim.models.keyedvectors.Vocab at 0x228ea6e9cc0>,
#  ...}

# %%
w2v_quake.train(list_of_words_quake, total_examples=w2v_quake.corpus_count, epochs=30, report_delay=1)
w2v_flood.train(list_of_words_flood, total_examples=w2v_quake.corpus_count, epochs=30, report_delay=1)
# Out:
# INFO - 11:37:16: training model with 3 workers on 13732 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=4
# INFO - 11:37:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:16: EPOCH - 1 : training on 70267 raw words (33519 effective words) took 0.1s, 313607 effective words/s
# INFO - 11:37:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:16: EPOCH - 2 : training on 70267 raw words (33454 effective words) took 0.1s, 386996 effective words/s
# INFO - 11:37:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:16: EPOCH - 3 : training on 70267 raw words (33521 effective words) took 0.1s, 423731 effective words/s
# INFO - 11:37:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:16: EPOCH - 4 : training on 70267 raw words (33455 effective words) took 0.1s, 405312 effective words/s
# INFO - 11:37:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 5 : training on 70267 raw words (33408 effective words) took 0.1s, 380780 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 6 : training on 70267 raw words (33383 effective words) took 0.1s, 363155 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 7 : training on 70267 raw words (33500 effective words) took 0.1s, 374287 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 8 : training on 70267 raw words (33534 effective words) took 0.1s, 386693 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 9 : training on 70267 raw words (33585 effective words) took 0.1s, 358994 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 10 : training on 70267 raw words (33373 effective words) took 0.1s, 343043 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 11 : training on 70267 raw words (33434 effective words) took 0.1s, 358995 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 12 : training on 70267 raw words (33356 effective words) took 0.1s, 358698 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 13 : training on 70267 raw words (33593 effective words) took 0.1s, 390227 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:17: EPOCH - 14 : training on 70267 raw words (33518 effective words) took 0.1s, 384405 effective words/s
# INFO - 11:37:17: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:17: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 15 : training on 70267 raw words (33428 effective words) took 0.1s, 382857 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 16 : training on 70267 raw words (33512 effective words) took 0.1s, 392073 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 17 : training on 70267 raw words (33417 effective words) took 0.1s, 324062 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 18 : training on 70267 raw words (33447 effective words) took 0.1s, 382244 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 19 : training on 70267 raw words (33524 effective words) took 0.1s, 398575 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 20 : training on 70267 raw words (33278 effective words) took 0.1s, 362698 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 21 : training on 70267 raw words (33454 effective words) took 0.1s, 399704 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 22 : training on 70267 raw words (33424 effective words) took 0.1s, 353912 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 23 : training on 70267 raw words (33532 effective words) took 0.1s, 374338 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 24 : training on 70267 raw words (33353 effective words) took 0.1s, 399584 effective words/s
# INFO - 11:37:18: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:18: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:18: EPOCH - 25 : training on 70267 raw words (33478 effective words) took 0.1s, 370812 effective words/s
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 26 : training on 70267 raw words (33414 effective words) took 0.1s, 409780 effective words/s
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 27 : training on 70267 raw words (33557 effective words) took 0.1s, 391255 effective words/s
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 28 : training on 70267 raw words (33460 effective words) took 0.1s, 316826 effective words/s
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 29 : training on 70267 raw words (33378 effective words) took 0.1s, 377416 effective words/s
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 30 : training on 70267 raw words (33548 effective words) took 0.1s, 477743 effective words/s
# INFO - 11:37:19: training on a 2108010 raw words (1003837 effective words) took 3.0s, 336124 effective words/s
# INFO - 11:37:19: training model with 3 workers on 9614 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=4
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 1 : training on 48396 raw words (22115 effective words) took 0.1s, 389307 effective words/s
# WARNING - 11:37:19: EPOCH - 1 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 2 : training on 48396 raw words (22263 effective words) took 0.1s, 420615 effective words/s
# WARNING - 11:37:19: EPOCH - 2 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 3 : training on 48396 raw words (22327 effective words) took 0.1s, 406542 effective words/s
# WARNING - 11:37:19: EPOCH - 3 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 4 : training on 48396 raw words (22338 effective words) took 0.1s, 412460 effective words/s
# WARNING - 11:37:19: EPOCH - 4 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 5 : training on 48396 raw words (22331 effective words) took 0.1s, 423132 effective words/s
# WARNING - 11:37:19: EPOCH - 5 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 6 : training on 48396 raw words (22340 effective words) took 0.1s, 402966 effective words/s
# WARNING - 11:37:19: EPOCH - 6 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 7 : training on 48396 raw words (22266 effective words) took 0.1s, 430715 effective words/s
# WARNING - 11:37:19: EPOCH - 7 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:19: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:19: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:19: EPOCH - 8 : training on 48396 raw words (22369 effective words) took 0.1s, 402003 effective words/s
# WARNING - 11:37:19: EPOCH - 8 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 9 : training on 48396 raw words (22205 effective words) took 0.0s, 452409 effective words/s
# WARNING - 11:37:20: EPOCH - 9 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 10 : training on 48396 raw words (22347 effective words) took 0.1s, 372710 effective words/s
# WARNING - 11:37:20: EPOCH - 10 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 11 : training on 48396 raw words (22291 effective words) took 0.1s, 371743 effective words/s
# WARNING - 11:37:20: EPOCH - 11 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 12 : training on 48396 raw words (22269 effective words) took 0.1s, 385674 effective words/s
# WARNING - 11:37:20: EPOCH - 12 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 13 : training on 48396 raw words (22317 effective words) took 0.1s, 392787 effective words/s
# WARNING - 11:37:20: EPOCH - 13 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 14 : training on 48396 raw words (22366 effective words) took 0.1s, 378388 effective words/s
# WARNING - 11:37:20: EPOCH - 14 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 15 : training on 48396 raw words (22200 effective words) took 0.1s, 386631 effective words/s
# WARNING - 11:37:20: EPOCH - 15 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 16 : training on 48396 raw words (22321 effective words) took 0.1s, 416288 effective words/s
# WARNING - 11:37:20: EPOCH - 16 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 17 : training on 48396 raw words (22300 effective words) took 0.1s, 392662 effective words/s
# WARNING - 11:37:20: EPOCH - 17 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 18 : training on 48396 raw words (22269 effective words) took 0.1s, 396335 effective words/s
# WARNING - 11:37:20: EPOCH - 18 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 19 : training on 48396 raw words (22219 effective words) took 0.0s, 452520 effective words/s
# WARNING - 11:37:20: EPOCH - 19 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 20 : training on 48396 raw words (22379 effective words) took 0.1s, 408702 effective words/s
# WARNING - 11:37:20: EPOCH - 20 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 21 : training on 48396 raw words (22374 effective words) took 0.0s, 471726 effective words/s
# WARNING - 11:37:20: EPOCH - 21 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 22 : training on 48396 raw words (22232 effective words) took 0.1s, 403522 effective words/s
# WARNING - 11:37:20: EPOCH - 22 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 23 : training on 48396 raw words (22382 effective words) took 0.1s, 425749 effective words/s
# WARNING - 11:37:20: EPOCH - 23 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:20: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:20: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:20: EPOCH - 24 : training on 48396 raw words (22339 effective words) took 0.1s, 396782 effective words/s
# WARNING - 11:37:20: EPOCH - 24 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:21: EPOCH - 25 : training on 48396 raw words (22297 effective words) took 0.1s, 382886 effective words/s
# WARNING - 11:37:21: EPOCH - 25 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:21: EPOCH - 26 : training on 48396 raw words (22219 effective words) took 0.1s, 379517 effective words/s
# WARNING - 11:37:21: EPOCH - 26 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:21: EPOCH - 27 : training on 48396 raw words (22268 effective words) took 0.1s, 397518 effective words/s
# WARNING - 11:37:21: EPOCH - 27 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:21: EPOCH - 28 : training on 48396 raw words (22331 effective words) took 0.1s, 435816 effective words/s
# WARNING - 11:37:21: EPOCH - 28 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:21: EPOCH - 29 : training on 48396 raw words (22228 effective words) took 0.1s, 367247 effective words/s
# WARNING - 11:37:21: EPOCH - 29 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: worker thread finished; awaiting finish of 2 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 1 more threads
# INFO - 11:37:21: worker thread finished; awaiting finish of 0 more threads
# INFO - 11:37:21: EPOCH - 30 : training on 48396 raw words (22225 effective words) took 0.1s, 372492 effective words/s
# WARNING - 11:37:21: EPOCH - 30 : supplied example count (2518) did not equal expected count (5140)
# INFO - 11:37:21: training on a 1451880 raw words (668727 effective words) took 1.9s, 360406 effective words/s
# (668727, 1451880)

# %% [markdown]
# The following code allows us to see words closely related (positively or negatively) with any other word. In this case we put in the word 'help'.

# %%
w2v_quake.wv.most_similar(positive=["dead"])
# Out:
# INFO - 11:37:21: precomputing L2-norms of word weight vectors
# [('Powerful', 0.9995934963226318),
#  ('northern', 0.9995595216751099),
#  ('kill', 0.9994736909866333),
#  ('Italy', 0.9994498491287231),
#  ('A', 0.9994382858276367),
#  ('7.4-magnitude', 0.9994300603866577),
#  ('powerful', 0.9994100332260132),
#  ('rock', 0.9993358850479126),
#  ('report', 0.9992691874504089),
#  ('Reuters', 0.9992547631263733)]

# %% [markdown]
# We will now convert these word2vec embeddings into a pandas dataframe. This can be converted into a csv for use later in maybe R. We will also explore ways to use this in an SVM model to classify our tweets.

# %%
word_list_quake = []
vector_list_quake = []
for word in w2v_quake.wv.vocab:
    word_list_quake.append(word)
    vector_list_quake.append(w2v_quake.wv.get_vector(word))
    
word_list_flood = []
vector_list_flood = []
for word in w2v_flood.wv.vocab:
    word_list_flood.append(word)
    vector_list_flood.append(w2v_flood.wv.get_vector(word))

# %%
quake_embeddings = pd.DataFrame()
quake_embeddings['Word'] = word_list_quake
quake_embeddings['Vector'] = vector_list_quake

# %%
flood_embeddings = pd.DataFrame()
flood_embeddings['Word'] = word_list_flood
flood_embeddings['Vector'] = vector_list_flood

# %%
quake_embeddings.to_csv('Word2Vec_Earthquake.csv')
flood_embeddings.to_csv('Word2Vec_Flood.csv')

# %% [markdown]
# ## SVM Classifier
#
# ### Creating Word2Vec Vectors for Train Data:
#
# Before we can implement the classifier, we need to convert our sentences (from balanced df) to a word2vec representation using our word2vec model that we trained above.

# %%
def word2vec_convert(all_tweets, model):
    whole_vec = []
    vec = np.zeros(100)
    numw = 0
    for tweet in all_tweets:
        tweet_vec = []
        vec = np.zeros(100)
        for word in tweet:
            try:
                vec = np.add(vec, model[word])
                tweet_vec.append(vec)
                numw = numw + 1
            except:
                pass
        whole_vec.append(tweet_vec)
    return(whole_vec)

# %% [markdown]
# Getting the quake data into vector form using our trained embeddings. We also append it to the original df.

# %%
l_quake = preProcess(df_quake)
word2vec_convert_quake = word2vec_convert(l_quake, w2v_quake)
df_quake['word2vec'] = word2vec_convert_quake
# Out:
# C:\Users\Vishaal\Anaconda3_Mod\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Getting the flood data into vector form using our trained embeddings. We also append it to the original df.

# %%
l_flood = preProcess(df_flood)
word2vec_convert_flood = word2vec_convert(l_flood, w2v_flood)
df_flood['word2vec'] = word2vec_convert_flood
# Out:
# C:\Users\Vishaal\Anaconda3_Mod\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Breaking the quake df into 3 different dfs. Each df with have equal number of (citical, high), (critical, med) and (critical, low} tweets. We will analyse how the model does w.r.t to each of these categories.

# %%
df_quake_low = df_quake[(df_quake['Priority'] == 'Critical') | (df_quake['Priority'] == 'Low')]
df_quake_med = df_quake[(df_quake['Priority'] == 'Critical') | (df_quake['Priority'] == 'Medium')]
df_quake_high = df_quake[(df_quake['Priority'] == 'Critical') | (df_quake['Priority'] == 'High')]

# %% [markdown]
# Splitting low and critical df into train and val set.

# %%
X_train_q_l, X_val_q_l, Y_train_q_l, Y_val_q_l = train_test_split(df_quake_low['word2vec'], df_quake_low['Priority'], 
                                                  test_size=0.2, random_state=100)

# %% [markdown]
# Defining a model. We use SGD Classifer with SVM (hinge loss accomplishes this). We also define a calibrated classifier as SVM
# by default does not give use proba.

# %%
clf = SGDClassifier(loss = 'hinge', alpha = 0.001, max_iter=10000, tol=1e-3
                                                       , shuffle = True, learning_rate = 'optimal', penalty='l1')
model = CalibratedClassifierCV(clf)

# %%
'''

'''
clf.fit(X_train_q_l, to_categorical(Y_train_q_l))
y_pred_q_l = clf.predict(np.array(X_val_q_l)[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-2895bbab6fbf> in <module>
# ----> 1 clf.fit(X_train_q_l, to_categorical(Y_train_q_l))
#       2 y_pred_q_l = clf.predict(np.array(X_val_q_l)[0])
#
# ~\Anaconda3_Mod\lib\site-packages\sklearn\linear_model\stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     711                          loss=self.loss, learning_rate=self.learning_rate,
#     712                          coef_init=coef_init, intercept_init=intercept_init,
# --> 713                          sample_weight=sample_weight)
#     714
#     715
#
# ~\Anaconda3_Mod\lib\site-packages\sklearn\linear_model\stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     527
#     528         X, y = check_X_y(X, y, 'csr', dtype=np.float64, order="C",
# --> 529                          accept_large_sparse=False)
#     530
#     531         # labels can be encoded as float, int, or string literals
#
# ~\Anaconda3_Mod\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     717                     ensure_min_features=ensure_min_features,
#     718                     warn_on_dtype=warn_on_dtype,
# --> 719                     estimator=estimator)
#     720     if multi_output:
#     721         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3_Mod\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3_Mod\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     726             warnings.warn(msg, FutureWarning, stacklevel=3)
#     727             dtype = 'M8[ns]'
# --> 728         return np.asarray(self.array, dtype)
#     729
#     730     def __array_wrap__(self, result, context=None):
#
# ~\Anaconda3_Mod\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~\Anaconda3_Mod\lib\site-packages\pandas\core\arrays\numpy_.py in __array__(self, dtype)
#     169
#     170     def __array__(self, dtype=None):
# --> 171         return np.asarray(self._ndarray, dtype=dtype)
#     172
#     173     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# ~\Anaconda3_Mod\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: setting an array element with a sequence.
