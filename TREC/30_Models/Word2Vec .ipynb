# %%
import os
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import string
import re
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
import logging
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
from nltk import bigrams

# %% [markdown]
# ## Reading in the Data:
#
# We have used all the tweets from 2018 (train and test) to create the embeddings. However, balanced datasets have been used to train and test the model. The following code reads in all the data. Note, we are only considering earthquakes and floods in the following sections and we will build separate models for each earthquakes and floods.

# %%
os.chdir('../10_Data/30_Balanced Tweets (Crit = Non-Crit)/10_2018 Train')

# %%
df_e1 = pd.read_csv('earthquake_TREC_2018_train_BALANCED.csv')
df_f1 = pd.read_csv('flood_TREC_2018_train_BALANCED.csv')

# %%
os.chdir('../15_2018 Test')

# %%
df_e2 = pd.read_csv('earthquake_TREC_2018_test_BALANCED.csv')
df_f2 = pd.read_csv('flood_TREC_2018_test_BALANCED.csv')

# %%
os.chdir('../../20_Extracted Tweets/10_2018 Train')

# %%
df_e1_embed = pd.read_csv('Earthquake_TREC_2018_train.csv')
df_f1_embed = pd.read_csv('flood_TREC_2018_train.csv')

# %%
os.chdir('../15_2018 Test')

# %%
df_e2_embed = pd.read_csv('Earthquake_TREC_2018_test.csv')
df_f2_embed = pd.read_csv('Floods_TREC_2018_test.csv')

# %% [markdown]
# ## Combining dataframes
# We are now combine earthquake tweets into one df and flood tweets into another df. We have subsetting on the tweets and priority columns. We do this for both the embedding dataframes and our balanced datasets, although we will not use the balanced datasets until later.

# %%
df_quake_e = pd.DataFrame()
df_quake_e['Tweet'] = pd.concat([df_e1_embed['Tweet'] , df_e2_embed['Tweet']])
df_quake_e['Priority'] = pd.concat([df_e1_embed['Priority'] , df_e2_embed['Priority']])

# %%
df_flood_e = pd.DataFrame()
df_flood_e['Tweet'] = pd.concat([df_f1_embed['Tweet'] , df_f2_embed['Tweet']])
df_flood_e['Priority'] = pd.concat([df_f1_embed['Priority'] , df_f2_embed['Priority']])

# %%
df_quake = pd.DataFrame()
df_quake['Tweet'] = pd.concat([df_e1['Tweet'] , df_e2['Tweet']])
df_quake['Priority'] = pd.concat([df_e1['Priority'] , df_e2['Priority']])

# %%
df_flood = pd.DataFrame()
df_flood['Tweet'] = pd.concat([df_f1['Tweet'] , df_f2['Tweet']])
df_flood['Priority'] = pd.concat([df_f1['Priority'] , df_f2['Priority']])

# %% [markdown]
# Cross checking the shapes to make sure they match. **They do match**

# %%
df_quake_e.shape, df_flood_e.shape, df_quake.shape, df_flood.shape
# Out:
# ((5140, 2), (2518, 2), (50, 2), (60, 2))

# %% [markdown]
# ## Converting to categorical (0 & 1)
#
# We will now define a function to convert the priority to a categorical 0 & 1. This will be necessary when we train a model.

# %%
'''
Creating a categorical variable to keep label critical tweets as 1 and 0 otherwise
'''
def to_categorical(df_c):
    t = []
    for element in df_c['Priority']:
        if element =='Critical':
            t.append(1)
        else:
            t.append(0)
        
    t = np.array(t)
    df_c['Target'] = t

    df_c['Target'] = df_c['Target'].astype('category')
    t = df_c['Target']
    del df_c['Target']
    return (t)

t_quake_e = to_categorical(df_quake_e)
t_flood_e = to_categorical(df_flood_e)
t_quake = to_categorical(df_quake)
t_flood = to_categorical(df_flood)

# %% [markdown]
# ## Pre-Processing
#
# We shall now perform a series of pre processing to our tweets. This includes tokenizing them, removing stop words and lemmatising them.
#
# **I also wrote a line of code to remove the links in the tweets as it was throwing in a lot of gibberish into the emebddings.** The link is almost always at the end of the tweet so its relatively easy to remove.
#
# I left the punctuation marks in. We have to take a call on this later.

# %%
def preProcess(df):
    df['Tweet'] = df['Tweet'].astype('str')
    
    df['Tweet'] = df['Tweet'].apply(lambda x: re.split('http:\/\/.*', str(x))[0])
    
    token_array = []
    #for tweet in df['Tweet']:
    #    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))
    #    tweet = tweet.translate(translator)
    #    token_tweet = word_tokenize(tweet)
    #    token_array.append(token_tweet)
    
    for tweet in df['Tweet']:
        token_tweet = word_tokenize(tweet)
        token_array.append(token_tweet)
        
    stop_words=set(stopwords.words("english"))
    filtered_token_array=[]
    for tweet in token_array:
        filtered_tweet = []
        for word in tweet:
                if word not in stop_words:
                    filtered_tweet.append(word)
        filtered_token_array.append(filtered_tweet)
        
    lem = WordNetLemmatizer()

    lemmatized_array=[]
    for tweet in filtered_token_array:
        lemmatized_tweet = []
        for word in tweet:
            lemmatized_tweet.append(lem.lemmatize(word,'v'))
        lemmatized_array.append(lemmatized_tweet)
    
    lemmatized_array_join = []
    for element in lemmatized_array:
        lemmatized_array_join.append(' '.join(element))
        
    return (lemmatized_array_join)

# %% [markdown]
# The tweets have been pre processed and we now have a collection of tweets. Word2Vec takes in a list of words together contained in a bigger list (Corpus -> List of Tweet -> List of Words).

# %%
l_quake_e = preProcess(df_quake_e)
l_flood_e = preProcess(df_flood_e)

list_of_words_quake = []
list_of_words_flood = []

for tweet in l_quake_e:
        token_tweet = word_tokenize(tweet)
        list_of_words_quake.append(token_tweet)
        
for tweet in l_flood_e:
        token_tweet = word_tokenize(tweet)
        list_of_words_flood.append(token_tweet)

# %%
unique_words
# Out:
# {'mt',
#  'DavidBCohen1',
#  'Seventeen',
#  'todayâ€™',
#  'fact',
#  'company',
#  'electric',
#  'Dhobighat',
#  'GMT',
#  'Keeping',
#  'whoa',
#  '5.4',
#  '25M',
#  'PrayforHumanity',
#  'traumatise',
#  'Mayweather',
#  'UFOS',
#  'bbc',
#  'narcissistic',
#  '1457',
#  'Earthquakeâ€™s',
#  '//t.co/rozuJTcPES',
#  'M6.5',
#  'LORD',
#  '//t.co/RxBGlkCFHp',
#  'FATA',
#  '..kindly',
#  '8.2-magnitude',
#  'astroturfing',
#  'peril',
#  '85',
#  'Sikkim',
#  'Aaa',
#  'Battle',
#  'UK',
#  'garment',
#  '16000',
#  'race',
#  'inadequate',
#  'PHOTO',
#  'threaten',
#  'wheeze',
#  'Relieved',
#  '//t.co/dWGNkHy7jA',
#  'Warning',
#  'fullest',
#  'migrant',
#  'kr',
#  'idiotic',
#  'ho',
#  'Thank',
#  'though',
#  'trans',
#  'soldier',
#  '//t.co/nXzZ1CDtQl',
#  '//t.co/nAyUj3WQ3h',
#  'READERS',
#  'OttoPerezMolina',
#  'AvaAddams',
#  'families',
#  '//t.co/ybbSlOjnzM',
#  'monetary',
#  'erthquake',
#  'Premier',
#  'ArmadaHotel',
#  'kishorenepal',
#  'lonvining',
#  'dekho',
#  'Afraid',
#  '//t.co/prIJTH3AEv',
#  'redcrossnepal',
#  'Philippines',
#  'panelists',
#  'global',
#  '//t.co/fDXUccjgMw',
#  'wipe',
#  'mobiles',
#  'road',
#  'deadReu',
#  'brotherâ�¤',
#  'Gandhi',
#  'TopStories',
#  'chaitanya029',
#  'bag',
#  '9:30',
#  'hillsongunited',
#  'POSITIVE',
#  '//t.co/GXaTJTh8Is',
#  '2014-04-02',
#  'Inevitable',
#  'airport',
#  'chloe',
#  'Big',
#  'w/',
#  'colossal',
#  'beside',
#  'Vikram',
#  'MedairInt',
#  'frighten',
#  'religions',
#  'Truly',
#  '//t.co/R8eagsKxdp',
#  'Impending',
#  'Modi',
#  'Bill',
#  'fuelâ€¦',
#  'Agree',
#  '7.6-mag',
#  '//t.co/ROhGYAs3RB',
#  '//t.co/pbibwQMXXV',
#  'Skepticat',
#  'Shelter',
#  'airspace',
#  'Sq',
#  'display',
#  'Makes',
#  'Govt',
#  'pathetic',
#  'Paquera',
#  'Jean-Louis',
#  'office',
#  '//t.co/pTeup1dJYg',
#  '//t.co/plgIki6jNx',
#  'fetch',
#  'PMHarper',
#  'higher',
#  'Kanchankharel',
#  'Horrific',
#  'MOUNT',
#  'Sherpa',
#  'StaY',
#  'RamLeelaGroundPandal',
#  'users',
#  '5.6',
#  '//t.co/Z3or5Lrnvy',
#  'news..',
#  'OM',
#  'Haram',
#  'sink',
#  'prayforNepal',
#  'Quake-aid',
#  'twhiddleston',
#  'YAN',
#  'Nepal-size',
#  'audience',
#  'Hologram_State',
#  '//t.co/SzMcIYSVV4',
#  'StayStrongNepal',
#  'Hillary',
#  'Wendy',
#  'cyclone',
#  'Rockets',
#  '//t.co/r9vlOx5muY',
#  'sednonsatiata',
#  'shah',
#  'hapoy',
#  'Supply',
#  '//t.co/kfK41P88wP',
#  'magnitude-7.8',
#  'Landgraf',
#  'STILL',
#  'organisations',
#  '6.Nepal',
#  'more..',
#  'Facebook',
#  'UNREAL',
#  'sway',
#  'Sth',
#  'fragile',
#  'Corps',
#  '//t.co/5iVaLykcuc',
#  'pleged',
#  'DRR',
#  'Chronicle',
#  '//t.co/idVSG7tjo5',
#  'blogpost',
#  'TamilTwin',
#  'test',
#  '😞💔.â€�',
#  'Survival',
#  'region..',
#  'FROM',
#  'Left',
#  'christian_aid',
#  'female',
#  'nydailynews',
#  'BEST',
#  'Indigeneity',
#  '101',
#  'Sushma',
#  '😊',
#  'Popular',
#  'Darrick',
#  'SarahSLassez',
#  'EQ',
#  'petty',
#  'GASES',
#  'Severe',
#  'plz🎤',
#  '8:37',
#  'shut',
#  '//t.co/WfnLiYVx3m',
#  'Israel',
#  '500kidsvfrom',
#  'TinyHandsIntl',
#  'Response',
#  'Legit',
#  'nowâ€¦',
#  'PuchikaMucha',
#  'blackandwhite',
#  'worklifebalance',
#  'Plano',
#  'everest',
#  'Gujarati',
#  'Harry_Styles',
#  'Nepalmed',
#  'Calbuco',
#  'promote',
#  'Yr',
#  'Put',
#  'earthquakeNepal',
#  '//t.co/bDGFZAgtU1',
#  'Teenager',
#  'PM',
#  '//t.co/SnhwJ0JgCc',
#  'Anaridis',
#  'evac',
#  'BUT',
#  'Andy',
#  'soon..',
#  'heaviness',
#  'environment',
#  '//t.co/scDTgp3Pjp',
#  'NDFakeTV',
#  'CATHOLIC',
#  'However',
#  'VISIT',
#  'BASICALLY',
#  'villages',
#  'woth',
#  '🙏🏾',
#  'burns+',
#  'PGS047',
#  'navy',
#  'Outside',
#  'citizens',
#  'Congis',
#  'GABBARs',
#  'saint',
#  'informative',
#  '-20.23',
#  'WHO',
#  'nonstop',
#  '16:18:40',
#  'casino',
#  'Rahul',
#  'tanya_plibersek',
#  'BaliNine',
#  'contrast',
#  'SSE',
#  'dreadful',
#  'WARNING',
#  'thus',
#  'PlanCanada',
#  '2.5M',
#  'NEPALhelp',
#  'Docs',
#  'Yea',
#  'dwnld',
#  'GOT',
#  'py',
#  'Missionary',
#  'Beat',
#  'Ji',
#  'clearly',
#  'Partners',
#  'MAusbrod',
#  'mr.CNN',
#  'Chilaker277',
#  'rebuild',
#  'hughhewitt',
#  'HEALING',
#  '//t.co/s9mf7VUrJz',
#  'Over',
#  '//t.co/6uwJbzuGgd',
#  '5',
#  'IF',
#  'INC',
#  'MLE',
#  'CLE',
#  'Ancient',
#  'profile',
#  'Harvest',
#  'bt',
#  'Magnitude-7.8',
#  '//t.co/gcrQoEogJX',
#  '16:31',
#  'days..',
#  '1-Google',
#  'years',
#  'StandwithNepal',
#  'soo',
#  'å�‹',
#  'favore',
#  '100k',
#  'him',
#  'Nepal🙏🙏',
#  'UNOCHA',
#  'Seismic',
#  'Feared',
#  'Ø´ÙŠØ²ÙˆÙ�Ø±Ø§Ù†ÙŠØ§_Ø¯Ø¹Ø§Ø¡_Ø§Ù',
#  'mea',
#  'andrewulasich',
#  'Ivan',
#  'recently',
#  'jg21',
#  'grateful',
#  'secure',
#  'hey',
#  'purpose',
#  'heaven',
#  'murgi',
#  'instanepali',
#  'Brazil',
#  'rude',
#  'NonProfit',
#  'g0',
#  'Syriaâ€¦',
#  'RafaelNadal',
#  'locally-driven',
#  'sorry',
#  'abc7newsBayArea',
#  'cluster',
#  'bb',
#  'BONDENO',
#  'Zuckerberg',
#  '450',
#  'MEDICAL',
#  'hugeness',
#  'T-Mobile',
#  'TheNorthFaceEU',
#  'warning-',
#  'Environment',
#  'malachybrowne',
#  'NepalStrong',
#  'TXS',
#  'KevinLove',
#  'quickly',
#  'self-centered',
#  '4350',
#  'a/c-6511000100056038.pnb',
#  'Im',
#  '//t.co/Lm2CKkAWPp',
#  '130',
#  'WMBD',
#  '.ur',
#  'lOst',
#  'dick',
#  'prayers..',
#  'nearly',
#  'TACKLE',
#  'satyam219',
#  'Shocks',
#  '//t.co/7Z3OJNL9fJ',
#  'Bit',
#  'fit',
#  'Phenomenal',
#  'Nooo',
#  '//t.co/Uq7A6AW03y',
#  'Baoo',
#  'Iran',
#  'Strong',
#  're-build',
#  '//t.co/Mx0lJn8jKb',
#  'TwitterMusic',
#  '//t.co/a2qLYC3pqB',
#  '4.7',
#  'facebooksafety',
#  'whole',
#  'Photos',
#  'crack',
#  'nroute',
#  '//t.co/rMU7j4KYE0',
#  'YEAR',
#  '20M',
#  'UPMeinAkhilesh',
#  'bluffying',
#  'DNC2012',
#  'like',
#  'Sets',
#  'KTM',
#  'nannies',
#  'Goodness',
#  'hope',
#  '//t.co/YlAnZHlTrB',
#  'nofilter',
#  'WilDeji',
#  'GROUND',
#  'Waseq',
#  'wi',
#  'danfredinburg',
#  'form',
#  '//t.co/wWBesMYEHG',
#  'Here',
#  '😭',
#  '44km',
#  'RW',
#  'Paris',
#  'Ganesh',
#  'cblive',
#  'youâ€™ll',
#  'grant',
#  'quicker',
#  'evil',
#  'wh',
#  '//t.co/GnkKnJ8mmy',
#  'Stree',
#  '200',
#  'SAN',
#  'UL105',
#  'thousands',
#  '//t.co/3Ts96Tst90',
#  'Kinda',
#  'admin+gov',
#  'MCFC',
#  'frantically',
#  'MishraRabindra',
#  'king',
#  'NYC',
#  'Dutchsinse',
#  'Oxfam',
#  'prayfornepal',
#  'lucymitv',
#  'communication',
#  'wz',
#  'Sep',
#  'Evacuation',
#  'marian',
#  'morelovelesshate',
#  'reenaabbasi',
#  'Kennedy',
#  'predict',
#  '//t.co/EWmQnvKdad',
#  '09',
#  'Unbelievable..',
#  'naturopaths',
#  '//t.co/LYuz2TKpiz',
#  'rodeo',
#  'IFISpotlight',
#  'surrogates',
#  'CCTV',
#  'NON',
#  'Thrilled',
#  'unitednations',
#  'visible',
#  '//t.co/ZNzm6n9c7g',
#  'Indians',
#  'forever',
#  'ackermann',
#  'inform',
#  '//t.co/xQoxBfp7Kr',
#  '//t.co/CXyNT7ucPg',
#  'Authorities',
#  'low',
#  'Duffy',
#  'Island',
#  'Lookout',
#  'LATEST',
#  'Mohamed',
#  'market',
#  'stable',
#  '+4000',
#  'M7.9',
#  'Need',
#  '×¦×œ×—×',
#  'Nepal-related',
#  'niece',
#  'REPORTS',
#  'fascinate',
#  'handheld',
#  'Overheard',
#  'App',
#  "'following",
#  'AUThackeray',
#  'INMARSAT',
#  'BED',
#  'RealClear',
#  'Adelante',
#  'Aaaand',
#  'spine',
#  '//t.co/IUC7wTTyjR',
#  'Blade',
#  'alwaysdiscovering',
#  'hour',
#  'devasting',
#  'strong',
#  'Affairs',
#  '😧',
#  'babe',
#  'BBCWorld',
#  'strand',
#  'Sick',
#  'ScheuerJo',
#  'badly',
#  'Givers',
#  '41',
#  'label',
#  'davidmarcus',
#  'Past',
#  '💜😔',
#  'quake-prepared',
#  'Parking',
#  'concern..',
#  'Nepal.R',
#  'live',
#  'WTVR6.2',
#  'ridicule',
#  'NO',
#  'TanyaBarronPlan',
#  'yemenevacuation',
#  '2014-04-',
#  'donâ€™t',
#  'seldom',
#  'View',
#  'zomanno',
#  'Powerful',
#  '//t.co/DGWs8MZts6',
#  'SISMO',
#  'President',
#  'candidate',
#  '//t.co/CIrMskujYE',
#  'bend',
#  '1874',
#  '//t.co/RoqEqyTYbi',
#  'img',
#  'Liberia',
#  'palace',
#  'solid',
#  '//t.co/WIQOaLXeqL',
#  'Napal',
#  'through.So',
#  'humcoalition',
#  'sandwich',
#  'Planning',
#  'border',
#  'Bournemouth',
#  'homecoming',
#  'instagrams',
#  'PankajPachauri',
#  'None',
#  'Human',
#  '1D',
#  '3Novices',
#  'selfish',
#  'Ph.D',
#  'nots',
#  '//t.co/QgyQOAAivr',
#  'effect',
#  'Romo',
#  'emilyrauhala',
#  'torchlight',
#  'October',
#  'fat',
#  'BaltimoreRiots',
#  '=/',
#  'book',
#  'DisasterResponse',
#  'Daddy',
#  'RBD_4Siempre',
#  'flash',
#  'snd',
#  'USATODAY',
#  '//t.co/F0vFbYpfFO',
#  'IsraelinNepal',
#  '//t.co/fKPo8fwoBZ',
#  'Donated',
#  'wid',
#  '15:15',
#  'politics',
#  'EP',
#  'enough🙏',
#  'nope',
#  '21:17:18',
#  'ease',
#  'ex-RN',
#  'Anyone',
#  'upgrade',
#  'CPPGeophysics',
#  '//t.co/8z6c8R9D0b',
#  'Developing',
#  'background',
#  'Land',
#  'Dj',
#  '//t.co/0Zz8rqEMDy',
#  '2014',
#  'assess',
#  'Ab',
#  'inauspicious',
#  'Sadly',
#  'Person',
#  'While',
#  '//t.co/azjU93DOON',
#  'Indeed',
#  'facilities',
#  'Ian',
#  '//t.co/TlFy6H2lC0',
#  'Mondawmin',
#  'Hold',
#  'fox35',
#  'Reveals',
#  'teacher',
#  'atheist',
#  'F*****kin',
#  '01:06',
#  'pple',
#  '6.3',
#  'milaan.in',
#  'WORSHIP',
#  'M5.1',
#  'stake',
#  'THAT',
#  'rely',
#  'immediate',
#  'https',
#  'carry',
#  'Frightening',
#  'girlstravel',
#  'Spend',
#  'Airforce',
#  'venek11',
#  'ShameOnLenskart',
#  'helicopter',
#  'miracle',
#  '*bothhands*',
#  'facility',
#  'IB',
#  'prove',
#  'newspaper',
#  'unaware',
#  'BillGates',
#  'Mrs.Sarah',
#  'maybe',
#  'ournameisMAGIC',
#  'largest',
#  '//t.co/0p6fJKN8jz',
#  'adversity',
#  'Top',
#  'à¤®à¥‡à¤°à¥‹',
#  'Updates',
#  'well',
#  'toilet',
#  'random',
#  'Bodhgaya',
#  'Becky',
#  'google',
#  'directioners',
#  'ASEXUAL',
#  'trusty',
#  'tremble',
#  '//t.co/OG8dTgv5Tp',
#  'Full',
#  'everytym',
#  '4.3RegionÂ',
#  'MakeADifference',
#  'make',
#  '^^',
#  'belong',
#  'Jersey',
#  'ENJOY',
#  'Trained',
#  'govt',
#  'instability',
#  '+9779851083307',
#  'unhrd',
#  'Come',
#  'regardless',
#  '//t.co/sNUT2N8aDD',
#  'decade',
#  'Whilst',
#  'delay',
#  'Figures',
#  'face,2time',
#  'DISGRACE',
#  'wasteland',
#  '//t.co/oK2GyUvqTt',
#  'Stands',
#  'à¤\xadà¥‚à¤•à¤‚à¤ª',
#  'Dollars',
#  'ChileEarthquake',
#  'pagoda',
#  'Occur',
#  'jane',
#  'Rejoicing',
#  'lanray121',
#  'à¤•à¤°à¥�à¤¤à¤µà¥�à¤¯',
#  'casualty',
#  'Citizens',
#  '//t.co/zuwP0WbjB6',
#  'BITCHES',
#  'Prayers..',
#  '31',
#  'hate',
#  'MT',
#  'Government',
#  'Me',
#  'h/t',
#  'MY',
#  'hygienic',
#  'today',
#  'cmtdogandbeth',
#  'USC',
#  'hindu',
#  'MusicForRelief',
#  'QuakeReports',
#  'Read',
#  '//t.co/8l2hvzNo5U',
#  'little',
#  'dubarsquare',
#  'society',
#  'saD',
#  '08',
#  "'Ground",
#  '//t.co/FKqwVwq458',
#  '//t.co/B7MkxpajZy',
#  'Guess',
#  'uk',
#  'Boko',
#  'lead',
#  '3',
#  'Joanna_Lumley',
#  'DavidLMeyer',
#  'pryrs',
#  'ke',
#  'X',
#  'locations',
#  'eathquake',
#  'larger',
#  "'ve",
#  'priorities',
#  'Summer',
#  'ThankYouPM',
#  'ENDOFDAYS',
#  'AAPNautanki',
#  'Om',
#  'Those',
#  'Sep-8',
#  'fam',
#  'food/shelter/resources',
#  'TYM',
#  'python33r',
#  'awaken',
#  'fil',
#  'Riseabove',
#  'ruin',
#  'prensa_libre',
#  'paypal',
#  'RECOMMENDED',
#  'Renee',
#  'WakeUpAmerica',
#  'throw',
#  '100',
#  'GOOD',
#  'irasuwindro',
#  '--',
#  'Aalok',
#  '//t.co/V1NZb5CNFw',
#  'Mum',
#  'tho',
#  '1.8',
#  'BritishArmy',
#  '//t.co/3qy7PDra83',
#  'Wednesday',
#  'Hits',
#  'rattle',
#  'commander',
#  'loved-ones',
#  'Weâ€™re',
#  'sea-change',
#  'face',
#  'EarthquakeUSGS',
#  'songs',
#  'IQUIQUE',
#  'maruratti',
#  'Consequences',
#  'Ur',
#  'ebrinfo',
#  'Quality',
#  'untruth',
#  'appreciation',
#  'Eygpt',
#  'McCain',
#  '//t.co/LIMnkQM7yo',
#  'Modiji',
#  '2008',
#  'homework',
#  '😔🙏🙏',
#  'mhpss',
#  'Larryferlazzo',
#  '//t.co/i7obz0IB7c',
#  'anti',
#  'Kerry',
#  'argument',
#  'tue',
#  'DelhiTweeter',
#  'visuals',
#  'Habitat',
#  'AndyRichter',
#  'mountaineer',
#  'hearts',
#  '//t.co/uCTGrrzl2f',
#  'Though',
#  '16',
#  'Immortality',
#  'jaise',
#  'Geoff..please',
#  'BEIJING',
#  'Nepal🙏🏼🙌🏼',
#  "'UAE",
#  'Once',
#  'Nepal_earth_quake',
#  'Norway',
#  'Agency',
#  'hahaha',
#  'Nicaragua',
#  'Franchise_B',
#  'â�¤ï¸�',
#  '//t.co/VjglxxGGPj',
#  'apreciated',
#  'co-author',
#  '//t.co/JZ2M9NtUVf',
#  'RT_com',
#  '1000s',
#  '//t.co/g1KshdkCpI',
#  'HWDRepublican',
#  'meâ€¦',
#  'There',
#  'spark',
#  '😔💜',
#  'Army',
#  '..👏',
#  '388',
#  '//t.co/q49vxAwF3m',
#  'SMS',
#  'diff',
#  'ARMY',
#  'chip',
#  'stayingstrong',
#  'HFX',
#  'Bjork',
#  '9N1EMERGENCY',
#  'sakte',
#  '//t.co/2G9QZY4MUU',
#  'condolence',
#  'NewsMagnitude',
#  'survivor',
#  'Natural',
#  'stanzas',
#  'Chicago',
#  'elephantjournal',
#  'Gorkha/Lamjung',
#  'PeopleToPeople',
#  '//t.co/gwEfCW5bm7',
#  'GUATEMALA',
#  '50',
#  'tent',
#  'sagarika',
#  'Parker',
#  'LindaEdgecombPhotography',
#  'cont',
#  'Spread',
#  'weeks',
#  'Vida',
#  '74,000',
#  'Survivor',
#  'offer',
#  'hitsÂ',
#  'SSW',
#  'EvillySexyBitch',
#  'jaiswal',
#  'Jerusalem',
#  'jio',
#  'HAR',
#  'everestbivek',
#  'S.',
#  ')',
#  'StartTag',
#  'contact',
#  '//t.co/J65qST85tv',
#  '21m',
#  'Bharaat',
#  'K',
#  '//t.co/NO08c7pZwm',
#  'hand',
#  'Visit',
#  'sacred',
#  'akrgsrni',
#  'Renu',
#  'half',
#  'less',
#  'glad',
#  'EndTimesNews',
#  'Alert',
#  'voter',
#  'photoshop',
#  'rescuers',
#  'DougKScott',
#  'savethepeople',
#  'leader',
#  'Cheriton',
#  'STEP',
#  '.sad',
#  'sho',
#  'auspol',
#  'sisters',
#  'Ncell',
#  'Damn',
#  'heartsick',
#  'HBO',
#  'australian',
#  'respond',
#  'MONEY',
#  'info-nepal',
#  'Corporate',
#  'Looking',
#  '22',
#  'Statement',
#  'dfat',
#  'EPICentreUCL',
#  'gadvcares',
#  '//t.co/q3fUfCzCDr',
#  'Tiki-Thai',
#  'national',
#  'monitor',
#  'run',
#  'honeymoon',
#  'cynicism',
#  'Historic',
#  '//t.co/AKVrkG2bCb',
#  'loom',
#  'Worldâ€™s',
#  'Spanish',
#  'Buddhist',
#  'Wedged',
#  'Auerbach',
#  'minimal',
#  'insiders',
#  'BEING',
#  'UnivisionNews',
#  'Imagine',
#  'skimâ€�',
#  'microbelover',
#  'DONT',
#  'Raxaul',
#  'ã‚¤ã�ªã€‚ã�§ã�‹ã�™ã�Žã‚‹ã�œã€�ãƒ™ã‚¯ãƒ†ãƒ',
#  'fark',
#  'Shake',
#  '//t.co/ele4anZzCa',
#  'Stocks',
#  'tire',
#  '1950',
#  'dng',
#  '//t.co/mh2qz1Uojl',
#  'TAX',
#  'tuneyards',
#  'â€�',
#  'BankaMayank',
#  'Bef',
#  'opposition',
#  'amaiorana',
#  'billons',
#  'distant',
#  'ã€�',
#  'karmonan',
#  'Playoffs',
#  'WFP_IT',
#  'Donation',
#  'Babies',
#  'Bhupatindra',
#  'provision',
#  'Stonehouse',
#  'Aerospace',
#  'sir..salute..u',
#  'Riordan',
#  'Marking',
#  'NEVER',
#  'BlackLivesMatter',
#  'SearchDog',
#  'iamCARITAS',
#  'forÂ',
#  '33S,71N',
#  'TheTopStory',
#  'jesukaprem',
#  'ordinary',
#  'AAP',
#  'Americans',
#  'Steve',
#  'cryin',
#  'nepal.Infct',
#  'M5.2',
#  'balance',
#  ...}

# %% [markdown]
# ## Creating a Word2Vec model
#
# We will now initialise a word2vec model. This takes in a paramter 'min_count' which is the number of minimum occurences of a word required for it be included in the embeddings. **For now we set min_count = 1**. I did this because we are creating our own embeddings (not picking from wikipedia embeddings etc) and our data is not that huge.

# %%
'''
min_count = int - Ignores all words with total absolute frequency lower than this - (2, 100)

window = int - The maximum distance between the current and predicted word within a sentence. 
        E.g. window words on the left and window words on the left of our target - (2, 10)

size = int - Dimensionality of the feature vectors. - (50, 300)

sample = float - The threshold for configuring which higher-frequency words are randomly downsampled. 
        Highly influencial. - (0, 1e-5)

alpha = float - The initial learning rate - (0.01, 0.05)

min_alpha = float - Learning rate will linearly drop to min_alpha as training progresses. 
        To set it: alpha - (min_alpha * epochs) ~ 0.00

negative = int - If > 0, negative sampling will be used, the int for negative specifies how many "noise words" 
        should be drown. If set to 0, no negative sampling is used. - (5, 20)
        
workers = int - Use these many worker threads to train the model (=faster training with multicore machines)
'''
w2v_quake = Word2Vec(min_count=1,
                     window=4,
                     size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20)
w2v_flood = Word2Vec(min_count=1,
                     window=4,
                     size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20)

# %% [markdown]
# We will now build our vocabulary. Do not run the following code multiple times before initialising the w2v instance again from above.

# %%
w2v_quake.build_vocab(list_of_words_quake)
w2v_flood.build_vocab(list_of_words_flood)
# Out:
# INFO - 14:01:04: collecting all words and their counts
# INFO - 14:01:04: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 14:01:04: collected 12305 word types from a corpus of 64955 raw words and 5140 sentences
# INFO - 14:01:04: Loading a fresh vocabulary
# INFO - 14:01:04: effective_min_count=1 retains 12305 unique words (100% of original 12305, drops 0)
# INFO - 14:01:04: effective_min_count=1 leaves 64955 word corpus (100% of original 64955, drops 0)
# INFO - 14:01:04: deleting the raw counts dictionary of 12305 items
# INFO - 14:01:04: sample=6e-05 downsamples 716 most-common words
# INFO - 14:01:04: downsampling leaves estimated 31037 word corpus (47.8% of prior 64955)
# INFO - 14:01:04: estimated required memory for 12305 words and 100 dimensions: 15996500 bytes
# INFO - 14:01:04: resetting layer weights
# INFO - 14:01:07: collecting all words and their counts
# INFO - 14:01:07: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 14:01:07: collected 8305 word types from a corpus of 43113 raw words and 2518 sentences
# INFO - 14:01:07: Loading a fresh vocabulary
# INFO - 14:01:07: effective_min_count=1 retains 8305 unique words (100% of original 8305, drops 0)
# INFO - 14:01:07: effective_min_count=1 leaves 43113 word corpus (100% of original 43113, drops 0)
# INFO - 14:01:07: deleting the raw counts dictionary of 8305 items
# INFO - 14:01:07: sample=6e-05 downsamples 818 most-common words
# INFO - 14:01:07: downsampling leaves estimated 20005 word corpus (46.4% of prior 43113)
# INFO - 14:01:07: estimated required memory for 8305 words and 100 dimensions: 10796500 bytes
# INFO - 14:01:07: resetting layer weights

# %% [markdown]
# The following code is to view the vocabulary that we created

# %%
vocabulary_quake = w2v_quake.wv.vocab
vocabulary_flood = w2v_flood.wv.vocab
vocabulary_quake
# Out:
# {'ã€�': <gensim.models.keyedvectors.Vocab at 0x1c714cd0160>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x1c71142a358>,
#  'USGS': <gensim.models.keyedvectors.Vocab at 0x1c71142a128>,
#  'Breakingã€': <gensim.models.keyedvectors.Vocab at 0x1c714f5dc88>,
#  '‘': <gensim.models.keyedvectors.Vocab at 0x1c714f5d390>,
#  'M': <gensim.models.keyedvectors.Vocab at 0x1c714f5df28>,
#  '1.1': <gensim.models.keyedvectors.Vocab at 0x1c714f5d860>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x1c714f5df60>,
#  '28km': <gensim.models.keyedvectors.Vocab at 0x1c714f5d9e8>,
#  'SSW': <gensim.models.keyedvectors.Vocab at 0x1c714f5de10>,
#  'Fairbanks': <gensim.models.keyedvectors.Vocab at 0x1c714f5d828>,
#  'Alaska': <gensim.models.keyedvectors.Vocab at 0x1c714f5db70>,
#  'Earthquake': <gensim.models.keyedvectors.Vocab at 0x1c714f5d748>,
#  '4.8': <gensim.models.keyedvectors.Vocab at 0x1c714f5d7f0>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x1c714f5da58>,
#  'Bali': <gensim.models.keyedvectors.Vocab at 0x1c714f5d898>,
#  'Indonesia': <gensim.models.keyedvectors.Vocab at 0x1c714f5d6a0>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x1c714f5deb8>,
#  'September': <gensim.models.keyedvectors.Vocab at 0x1c714f5dbe0>,
#  '04': <gensim.models.keyedvectors.Vocab at 0x1c714f5d3c8>,
#  '2012': <gensim.models.keyedvectors.Vocab at 0x1c714f5df98>,
#  '21:19:30': <gensim.models.keyedvectors.Vocab at 0x1c714f5da90>,
#  'GMT': <gensim.models.keyedvectors.Vocab at 0x1c714f5d438>,
#  'earthquake': <gensim.models.keyedvectors.Vocab at 0x1c714f5ddd8>,
#  '4.5': <gensim.models.keyedvectors.Vocab at 0x1c714f5d0f0>,
#  'Taiwan': <gensim.models.keyedvectors.Vocab at 0x1c714f5def0>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x1c714f5de48>,
#  '2.6': <gensim.models.keyedvectors.Vocab at 0x1c714f5d2e8>,
#  'Hawaii': <gensim.models.keyedvectors.Vocab at 0x1c714f5de80>,
#  'Magnitude': <gensim.models.keyedvectors.Vocab at 0x1c714f5da20>,
#  '7.9': <gensim.models.keyedvectors.Vocab at 0x1c714f5d5f8>,
#  'strike': <gensim.models.keyedvectors.Vocab at 0x1c714f5d630>,
#  'coast': <gensim.models.keyedvectors.Vocab at 0x1c714f5db38>,
#  'Costa': <gensim.models.keyedvectors.Vocab at 0x1c714f5dac8>,
#  'Rica': <gensim.models.keyedvectors.Vocab at 0x1c715d2e2e8>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x1c715d2e240>,
#  'RT': <gensim.models.keyedvectors.Vocab at 0x1c715d2e400>,
#  '@': <gensim.models.keyedvectors.Vocab at 0x1c715d2e6d8>,
#  'Reuters': <gensim.models.keyedvectors.Vocab at 0x1c715d2ebe0>,
#  'Live': <gensim.models.keyedvectors.Vocab at 0x1c715d2e518>,
#  'coverage': <gensim.models.keyedvectors.Vocab at 0x1c715d2e278>,
#  '7.9-magnitude': <gensim.models.keyedvectors.Vocab at 0x1c715d2eb38>,
#  'rattle': <gensim.models.keyedvectors.Vocab at 0x1c715d2e550>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x1c715d2ec18>,
#  'tsunami': <gensim.models.keyedvectors.Vocab at 0x1c715d2e2b0>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1c715d2e0b8>,
#  'Caribbean': <gensim.models.keyedvectors.Vocab at 0x1c715d2ea90>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x1c715d2e358>,
#  'ãƒ‡ã‚': <gensim.models.keyedvectors.Vocab at 0x1c715d2e128>,
#  '«': <gensim.models.keyedvectors.Vocab at 0x1c715d2ec50>,
#  'ã‚¤ã�ªã€‚ã�§ã�‹ã�™ã�Žã‚‹ã�œã€�ãƒ™ã‚¯ãƒ†ãƒ': <gensim.models.keyedvectors.Vocab at 0x1c715d2e710>,
#  'ï¼�': <gensim.models.keyedvectors.Vocab at 0x1c715d2e4a8>,
#  'BreakingNews': <gensim.models.keyedvectors.Vocab at 0x1c715d2e390>,
#  'Caribbean-wide': <gensim.models.keyedvectors.Vocab at 0x1c715d2eba8>,
#  'Rican': <gensim.models.keyedvectors.Vocab at 0x1c715d2ea20>,
#  'quake': <gensim.models.keyedvectors.Vocab at 0x1c715d2e860>,
#  'Pacific': <gensim.models.keyedvectors.Vocab at 0x1c715d2ecc0>,
#  'Tsunami': <gensim.models.keyedvectors.Vocab at 0x1c715d2e7f0>,
#  'Warning': <gensim.models.keyedvectors.Vocab at 0x1c715d2e7b8>,
#  'Center': <gensim.models.keyedvectors.Vocab at 0x1c715d2e4e0>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1c715d2ea58>,
#  'lgf': <gensim.models.keyedvectors.Vocab at 0x1c715d2e898>,
#  'p2': <gensim.models.keyedvectors.Vocab at 0x1c715d2e748>,
#  'shake': <gensim.models.keyedvectors.Vocab at 0x1c715d2e5c0>,
#  'magnitude-5.8': <gensim.models.keyedvectors.Vocab at 0x1c715d2ec88>,
#  'More': <gensim.models.keyedvectors.Vocab at 0x1c715d2e9e8>,
#  'coastline': <gensim.models.keyedvectors.Vocab at 0x1c715d2e080>,
#  'AlertNet': <gensim.models.keyedvectors.Vocab at 0x1c715d2e1d0>,
#  'Strong': <gensim.models.keyedvectors.Vocab at 0x1c715d2e5f8>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x1c715d2e668>,
#  '``': <gensim.models.keyedvectors.Vocab at 0x1c715d2e940>,
#  'RobertaCBS5': <gensim.models.keyedvectors.Vocab at 0x1c715d2e978>,
#  'Breaking': <gensim.models.keyedvectors.Vocab at 0x1c715d2e8d0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x1c715d2e630>,
#  'Tsunmai': <gensim.models.keyedvectors.Vocab at 0x1c715d2eb70>,
#  'WARNING': <gensim.models.keyedvectors.Vocab at 0x1c715d2e160>,
#  'west': <gensim.models.keyedvectors.Vocab at 0x1c715d2e588>,
#  'Central': <gensim.models.keyedvectors.Vocab at 0x1c715d2e828>,
#  'America': <gensim.models.keyedvectors.Vocab at 0x1c715d2eac8>,
#  'magnitude': <gensim.models.keyedvectors.Vocab at 0x1c715d2e0f0>,
#  'Birth': <gensim.models.keyedvectors.Vocab at 0x1c715d2e438>,
#  'pangs': <gensim.models.keyedvectors.Vocab at 0x1c715d2e908>,
#  'NewEarthquake': <gensim.models.keyedvectors.Vocab at 0x1c715d2eb00>,
#  'Sep': <gensim.models.keyedvectors.Vocab at 0x1c711419c50>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1c711419d68>,
#  '8:42am': <gensim.models.keyedvectors.Vocab at 0x1c7114190f0>,
#  'epicenter': <gensim.models.keyedvectors.Vocab at 0x1c711419208>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x1c711419080>,
#  '6m': <gensim.models.keyedvectors.Vocab at 0x1c711419b70>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x1c711419e10>,
#  '83km': <gensim.models.keyedvectors.Vocab at 0x1c7114192b0>,
#  'S': <gensim.models.keyedvectors.Vocab at 0x1c711419e48>,
#  'Liberia': <gensim.models.keyedvectors.Vocab at 0x1c7114199e8>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x1c7114240f0>,
#  '46km': <gensim.models.keyedvectors.Vocab at 0x1c711424c88>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x1c711424278>,
#  'http': <gensim.models.keyedvectors.Vocab at 0x1c714f78710>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x1c714f78b00>,
#  'Oh': <gensim.models.keyedvectors.Vocab at 0x1c714f78470>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x1c714f78978>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x1c714f78a90>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1c714f78630>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x1c714f78a20>,
#  'Nids_ShriKant': <gensim.models.keyedvectors.Vocab at 0x1c714f78518>,
#  'Rica..': <gensim.models.keyedvectors.Vocab at 0x1c714f78748>,
#  'Now': <gensim.models.keyedvectors.Vocab at 0x1c714f785c0>,
#  'A': <gensim.models.keyedvectors.Vocab at 0x1c714f788d0>,
#  'KeepSafe': <gensim.models.keyedvectors.Vocab at 0x1c714f781d0>,
#  'GodBless': <gensim.models.keyedvectors.Vocab at 0x1c714f78278>,
#  'costa': <gensim.models.keyedvectors.Vocab at 0x1c714f78860>,
#  'rica': <gensim.models.keyedvectors.Vocab at 0x1c714f784e0>,
#  '7,9SR': <gensim.models.keyedvectors.Vocab at 0x1c714f78240>,
#  'CHILE': <gensim.models.keyedvectors.Vocab at 0x1c714f78400>,
#  "'S": <gensim.models.keyedvectors.Vocab at 0x1c714f78a58>,
#  'NAVY': <gensim.models.keyedvectors.Vocab at 0x1c714f787f0>,
#  'SAYS': <gensim.models.keyedvectors.Vocab at 0x1c714f78320>,
#  'DECLARES': <gensim.models.keyedvectors.Vocab at 0x1c714f784a8>,
#  'TSUNAMI': <gensim.models.keyedvectors.Vocab at 0x1c714f789e8>,
#  'ALERT': <gensim.models.keyedvectors.Vocab at 0x1c714f78668>,
#  'FOR': <gensim.models.keyedvectors.Vocab at 0x1c714f78550>,
#  'CHILEAN': <gensim.models.keyedvectors.Vocab at 0x1c714f780f0>,
#  'COAST': <gensim.models.keyedvectors.Vocab at 0x1c714f78b70>,
#  'FOLLOWING': <gensim.models.keyedvectors.Vocab at 0x1c714f78be0>,
#  'COSTA': <gensim.models.keyedvectors.Vocab at 0x1c714f78c50>,
#  'RICA': <gensim.models.keyedvectors.Vocab at 0x1c714f78cc0>,
#  'QUAKE': <gensim.models.keyedvectors.Vocab at 0x1c714f78d30>,
#  'CP24': <gensim.models.keyedvectors.Vocab at 0x1c714f78dd8>,
#  'BREAKING': <gensim.models.keyedvectors.Vocab at 0x1c714f78d68>,
#  'Coast': <gensim.models.keyedvectors.Vocab at 0x1c714f78e48>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x1c714f78eb8>,
#  'No': <gensim.models.keyedvectors.Vocab at 0x1c714f78f28>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x1c714f78f98>,
#  'damage/injuries': <gensim.models.keyedvectors.Vocab at 0x1c714f7da90>,
#  'TWCBreaking': <gensim.models.keyedvectors.Vocab at 0x1c714f7dc50>,
#  'Mag': <gensim.models.keyedvectors.Vocab at 0x1c714f7dba8>,
#  'Mexico': <gensim.models.keyedvectors.Vocab at 0x1c714f7d860>,
#  'C.': <gensim.models.keyedvectors.Vocab at 0x1c714f7d898>,
#  'S.': <gensim.models.keyedvectors.Vocab at 0x1c714f7d908>,
#  'â€œ': <gensim.models.keyedvectors.Vocab at 0x1c714f7d080>,
#  'USGSâ€�': <gensim.models.keyedvectors.Vocab at 0x1c714f7d0f0>,
#  'YahooNews': <gensim.models.keyedvectors.Vocab at 0x1c714f7d160>,
#  'Please': <gensim.models.keyedvectors.Vocab at 0x1c714f7d1d0>,
#  'pray': <gensim.models.keyedvectors.Vocab at 0x1c714f7d240>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x1c714f7d358>,
#  'magnitude-7.9': <gensim.models.keyedvectors.Vocab at 0x1c714f7d278>,
#  'CostaRica': <gensim.models.keyedvectors.Vocab at 0x1c714f7d390>,
#  'accord': <gensim.models.keyedvectors.Vocab at 0x1c714f7d400>,
#  'BBCWorld': <gensim.models.keyedvectors.Vocab at 0x1c714f7d470>,
#  'Details': <gensim.models.keyedvectors.Vocab at 0x1c714f7d4e0>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x1c714f7d550>,
#  'QuakeReports': <gensim.models.keyedvectors.Vocab at 0x1c714f7d588>,
#  'MEXICO': <gensim.models.keyedvectors.Vocab at 0x1c714f7d630>,
#  'CITY': <gensim.models.keyedvectors.Vocab at 0x1c714f7d6a0>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x1c714f7d710>,
#  'miles': <gensim.models.keyedvectors.Vocab at 0x1c714f7d780>,
#  'town': <gensim.models.keyedvectors.Vocab at 0x1c714f7d7f0>,
#  'northwestern': <gensim.models.keyedvectors.Vocab at 0x1c7112ce048>,
#  'Wednesday..': <gensim.models.keyedvectors.Vocab at 0x1c710b34e48>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x1c714fb7e10>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x1c714fb7c18>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x1c714fb7668>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x1c714fb7550>,
#  'okay': <gensim.models.keyedvectors.Vocab at 0x1c714fb7cf8>,
#  'fieldproducer': <gensim.models.keyedvectors.Vocab at 0x1c714fb7898>,
#  'revise': <gensim.models.keyedvectors.Vocab at 0x1c714fb7978>,
#  '7.6': <gensim.models.keyedvectors.Vocab at 0x1c714fb74a8>,
#  'detail': <gensim.models.keyedvectors.Vocab at 0x1c714fb73c8>,
#  'My': <gensim.models.keyedvectors.Vocab at 0x1c714fb72e8>,
#  'prayers': <gensim.models.keyedvectors.Vocab at 0x1c714fb7208>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1c714fb7128>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x1c714fb7048>,
#  'They': <gensim.models.keyedvectors.Vocab at 0x1c714fb7ef0>,
#  'massive': <gensim.models.keyedvectors.Vocab at 0x1c714fb7d30>,
#  'Powerful': <gensim.models.keyedvectors.Vocab at 0x1c714fb76d8>,
#  'CNBC': <gensim.models.keyedvectors.Vocab at 0x1c714fb7b70>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x1c714fb7b38>,
#  '98': <gensim.models.keyedvectors.Vocab at 0x1c714fb75f8>,
#  'San': <gensim.models.keyedvectors.Vocab at 0x1c714fb7a90>,
#  'Jose': <gensim.models.keyedvectors.Vocab at 0x1c714fb7be0>,
#  'Chile': <gensim.models.keyedvectors.Vocab at 0x1c714fb7908>,
#  "'s": <gensim.models.keyedvectors.Vocab at 0x1c714fb7588>,
#  'navy': <gensim.models.keyedvectors.Vocab at 0x1c714fb7a58>,
#  'declare': <gensim.models.keyedvectors.Vocab at 0x1c714fb7dd8>,
#  'alert': <gensim.models.keyedvectors.Vocab at 0x1c714fb7390>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x1c714fb72b0>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x1c714fb7c50>,
#  'Revised': <gensim.models.keyedvectors.Vocab at 0x1c714fb7080>,
#  '&': <gensim.models.keyedvectors.Vocab at 0x1c714fb7630>,
#  'gt': <gensim.models.keyedvectors.Vocab at 0x1c714fb7748>,
#  '24m': <gensim.models.keyedvectors.Vocab at 0x1c714fb74e0>,
#  '60km': <gensim.models.keyedvectors.Vocab at 0x1c714fb70f0>,
#  'SSE': <gensim.models.keyedvectors.Vocab at 0x1c714fb7320>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x1c711338d68>,
#  'irasuwindro': <gensim.models.keyedvectors.Vocab at 0x1c711338160>,
#  'RT_com': <gensim.models.keyedvectors.Vocab at 0x1c711338978>,
#  'Quake': <gensim.models.keyedvectors.Vocab at 0x1c711338e10>,
#  'Hits': <gensim.models.keyedvectors.Vocab at 0x1c711338940>,
#  'Damn': <gensim.models.keyedvectors.Vocab at 0x1c711338f28>,
#  'Poor': <gensim.models.keyedvectors.Vocab at 0x1c711338b00>,
#  'cnnbrk': <gensim.models.keyedvectors.Vocab at 0x1c7113389e8>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x1c711338278>,
#  'ccbp': <gensim.models.keyedvectors.Vocab at 0x1c711338470>,
#  'Big': <gensim.models.keyedvectors.Vocab at 0x1c7113384e0>,
#  'M7.9': <gensim.models.keyedvectors.Vocab at 0x1c7113389b0>,
#  'occurrred': <gensim.models.keyedvectors.Vocab at 0x1c711338cc0>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x1c711338518>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1c711338908>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1c711338ac8>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1c711338588>,
#  '7.6-magnitude': <gensim.models.keyedvectors.Vocab at 0x1c711338fd0>,
#  'weathernetwork': <gensim.models.keyedvectors.Vocab at 0x1c711338208>,
#  'Reports': <gensim.models.keyedvectors.Vocab at 0x1c711338cf8>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x1c711338c18>,
#  'collapse': <gensim.models.keyedvectors.Vocab at 0x1c711338eb8>,
#  'church': <gensim.models.keyedvectors.Vocab at 0x1c7113380f0>,
#  'tower': <gensim.models.keyedvectors.Vocab at 0x1c711338c88>,
#  'Nicoya': <gensim.models.keyedvectors.Vocab at 0x1c711338198>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1c711338ba8>,
#  'epicentre': <gensim.models.keyedvectors.Vocab at 0x1c711338240>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x1c711338898>,
#  '7.6-mag': <gensim.models.keyedvectors.Vocab at 0x1c7113385c0>,
#  'For': <gensim.models.keyedvectors.Vocab at 0x1c711338128>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x1c711338b38>,
#  'Hawaii..': <gensim.models.keyedvectors.Vocab at 0x1c7113382e8>,
#  'case..': <gensim.models.keyedvectors.Vocab at 0x1c711338c50>,
#  'mag': <gensim.models.keyedvectors.Vocab at 0x1c711338be0>,
#  'prompt': <gensim.models.keyedvectors.Vocab at 0x1c711707eb8>,
#  'karmonan': <gensim.models.keyedvectors.Vocab at 0x1c711707b70>,
#  'Radio_Riquelme': <gensim.models.keyedvectors.Vocab at 0x1c711707080>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x1c711707a90>,
#  'coastal': <gensim.models.keyedvectors.Vocab at 0x1c711707c88>,
#  'htt': <gensim.models.keyedvectors.Vocab at 0x1c711707c50>,
#  'CNN': <gensim.models.keyedvectors.Vocab at 0x1c7117074e0>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x1c711707470>,
#  'CBSNews': <gensim.models.keyedvectors.Vocab at 0x1c711707630>,
#  'LATEST': <gensim.models.keyedvectors.Vocab at 0x1c7117077b8>,
#  'DETAILS': <gensim.models.keyedvectors.Vocab at 0x1c711707828>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x1c711707dd8>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1c711707a20>,
#  'JamaicaGleaner': <gensim.models.keyedvectors.Vocab at 0x1c711707f98>,
#  'Yahoo/Space-': <gensim.models.keyedvectors.Vocab at 0x1c7117079e8>,
#  'WASHINGTON': <gensim.models.keyedvectors.Vocab at 0x1c711707cf8>,
#  'magnit': <gensim.models.keyedvectors.Vocab at 0x1c7117079b0>,
#  'Yahoo': <gensim.models.keyedvectors.Vocab at 0x1c711707358>,
#  'News': <gensim.models.keyedvectors.Vocab at 0x1c711707780>,
#  'An': <gensim.models.keyedvectors.Vocab at 0x1c7117070b8>,
#  'preliminary': <gensim.models.keyedvectors.Vocab at 0x1c711707390>,
#  'Pura': <gensim.models.keyedvectors.Vocab at 0x1c711707438>,
#  'Vida': <gensim.models.keyedvectors.Vocab at 0x1c7117074a8>,
#  'EliteDaily': <gensim.models.keyedvectors.Vocab at 0x1c711707978>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1c711707a58>,
#  'trigger': <gensim.models.keyedvectors.Vocab at 0x1c711707b00>,
#  'warning-': <gensim.models.keyedvectors.Vocab at 0x1c7117076d8>,
#  'there-just': <gensim.models.keyedvectors.Vocab at 0x1c711707898>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x1c711707ef0>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x1c711707198>,
#  'ok': <gensim.models.keyedvectors.Vocab at 0x1c7117073c8>,
#  'scary': <gensim.models.keyedvectors.Vocab at 0x1c7117075c0>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x1c711707f28>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1c711707240>,
#  'abc7newsBayArea': <gensim.models.keyedvectors.Vocab at 0x1c711707160>,
#  'abcnews': <gensim.models.keyedvectors.Vocab at 0x1c711707be0>,
#  'Magnitude-7.6': <gensim.models.keyedvectors.Vocab at 0x1c710ed1710>,
#  '_mannymeister': <gensim.models.keyedvectors.Vocab at 0x1c710ed1278>,
#  'thankyou': <gensim.models.keyedvectors.Vocab at 0x1c710ed1780>,
#  'I': <gensim.models.keyedvectors.Vocab at 0x1c710ed1550>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x1c710ed1a90>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1c710ed16d8>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1c710ed18d0>,
#  "'m": <gensim.models.keyedvectors.Vocab at 0x1c710ed1da0>,
#  'md': <gensim.models.keyedvectors.Vocab at 0x1c710ed1f60>,
#  'SonOfAKing3': <gensim.models.keyedvectors.Vocab at 0x1c710ed16a0>,
#  'UnivisionNews': <gensim.models.keyedvectors.Vocab at 0x1c710ed1240>,
#  'Northwestern': <gensim.models.keyedvectors.Vocab at 0x1c710ed1588>,
#  'Ricaâ€�': <gensim.models.keyedvectors.Vocab at 0x1c710ed19e8>,
#  '100prayingwomen': <gensim.models.keyedvectors.Vocab at 0x1c710ed1f98>,
#  'Interior': <gensim.models.keyedvectors.Vocab at 0x1c710ed1860>,
#  'Minister': <gensim.models.keyedvectors.Vocab at 0x1c710ed15f8>,
#  'Hinzpeter': <gensim.models.keyedvectors.Vocab at 0x1c710ed1518>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1c710ed14a8>,
#  'evacuation': <gensim.models.keyedvectors.Vocab at 0x1c710ed14e0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1c710ed1c88>,
#  'LisaDCNN': <gensim.models.keyedvectors.Vocab at 0x1c710ed17b8>,
#  'UPDATE': <gensim.models.keyedvectors.Vocab at 0x1c710ed1d30>,
#  'CNNweather': <gensim.models.keyedvectors.Vocab at 0x1c710ed1e80>,
#  'Warnings': <gensim.models.keyedvectors.Vocab at 0x1c710ed1d68>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x1c710ed1470>,
#  'Panama': <gensim.models.keyedvectors.Vocab at 0x1c710ed1160>,
#  'Nicaragua': <gensim.models.keyedvectors.Vocab at 0x1c710ed1c18>,
#  '7.6M': <gensim.models.keyedvectors.Vocab at 0x1c710ed1be0>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x1c710ed1cc0>,
#  'COSTARICA': <gensim.models.keyedvectors.Vocab at 0x1c710ed1a58>,
#  'ADVISORY': <gensim.models.keyedvectors.Vocab at 0x1c710ed17f0>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x1c7121dba20>,
#  'NO': <gensim.models.keyedvectors.Vocab at 0x1c7116de6d8>,
#  'WAVES': <gensim.models.keyedvectors.Vocab at 0x1c7116f3f28>,
#  'REPORTED': <gensim.models.keyedvectors.Vocab at 0x1c7116f3eb8>,
#  'YET': <gensim.models.keyedvectors.Vocab at 0x1c7116f3d30>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x1c7116f3a58>,
#  'BE': <gensim.models.keyedvectors.Vocab at 0x1c7116f3b00>,
#  'ON': <gensim.models.keyedvectors.Vocab at 0x1c7116f3b38>,
#  'PRECAUTIONARY': <gensim.models.keyedvectors.Vocab at 0x1c7116f3ba8>,
#  'EVACUATION': <gensim.models.keyedvectors.Vocab at 0x1c7116f3c18>,
#  'RECOMMENDED': <gensim.models.keyedvectors.Vocab at 0x1c7116f3c88>,
#  'PTWC': <gensim.models.keyedvectors.Vocab at 0x1c7116f3cf8>,
#  'NEWS': <gensim.models.keyedvectors.Vocab at 0x1c714b34fd0>,
#  'rock': <gensim.models.keyedvectors.Vocab at 0x1c714b34f98>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x1c714b34f60>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1c714b34f28>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x1c714b34ef0>,
#  'Reported': <gensim.models.keyedvectors.Vocab at 0x1c714b34eb8>,
#  'ABC': <gensim.models.keyedvectors.Vocab at 0x1c714b34e48>,
#  'nbcnightlynews': <gensim.models.keyedvectors.Vocab at 0x1c714b34e80>,
#  'Just': <gensim.models.keyedvectors.Vocab at 0x1c714b34e10>,
#  'Disarm': <gensim.models.keyedvectors.Vocab at 0x1c714b34dd8>,
#  'Major': <gensim.models.keyedvectors.Vocab at 0x1c714b34da0>,
#  'Reutersâ€�': <gensim.models.keyedvectors.Vocab at 0x1c714b34d30>,
#  'DanielrBarron': <gensim.models.keyedvectors.Vocab at 0x1c714b34d68>,
#  'washingtonpost': <gensim.models.keyedvectors.Vocab at 0x1c714b34cc0>,
#  'ABC7': <gensim.models.keyedvectors.Vocab at 0x1c714b34b70>,
#  'BREAKINGNEWS': <gensim.models.keyedvectors.Vocab at 0x1c714b34ba8>,
#  '7.9-mag': <gensim.models.keyedvectors.Vocab at 0x1c714b34c88>,
#  'immediate': <gensim.models.keyedvectors.Vocab at 0x1c714b34be0>,
#  'injuries': <gensim.models.keyedvectors.Vocab at 0x1c714b34c50>,
#  'TheNextCorner': <gensim.models.keyedvectors.Vocab at 0x1c714b34c18>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x1c714b34b38>,
#  'ninaism': <gensim.models.keyedvectors.Vocab at 0x1c714b34b00>,
#  'georgekourounis': <gensim.models.keyedvectors.Vocab at 0x1c714b34ac8>,
#  'landslides': <gensim.models.keyedvectors.Vocab at 0x1c714b34a90>,
#  'inland': <gensim.models.keyedvectors.Vocab at 0x1c714b34a58>,
#  'RDLKid': <gensim.models.keyedvectors.Vocab at 0x1c714b34a20>,
#  'springrose12': <gensim.models.keyedvectors.Vocab at 0x1c714b349e8>,
#  'HDNER': <gensim.models.keyedvectors.Vocab at 0x1c714b349b0>,
#  'cancel': <gensim.models.keyedvectors.Vocab at 0x1c714b34940>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1c714b34978>,
#  'Ocean': <gensim.models.keyedvectors.Vocab at 0x1c714b34908>,
#  'moanikitv': <gensim.models.keyedvectors.Vocab at 0x1c714b348d0>,
#  'threat': <gensim.models.keyedvectors.Vocab at 0x1c714b34898>,
#  'costarica': <gensim.models.keyedvectors.Vocab at 0x1c714b34828>,
#  'temblorcr': <gensim.models.keyedvectors.Vocab at 0x1c714b34860>,
#  'Is': <gensim.models.keyedvectors.Vocab at 0x1c714b347f0>,
#  'OK': <gensim.models.keyedvectors.Vocab at 0x1c714b347b8>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x1c714b34780>,
#  'RobDavis_Wx': <gensim.models.keyedvectors.Vocab at 0x1c714b34748>,
#  'LANDSLIDE': <gensim.models.keyedvectors.Vocab at 0x1c714b34710>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x1c714b346a0>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x1c714b346d8>,
#  'M7.6': <gensim.models.keyedvectors.Vocab at 0x1c714b34668>,
#  'NOSARA': <gensim.models.keyedvectors.Vocab at 0x1c714b345c0>,
#  'AP': <gensim.models.keyedvectors.Vocab at 0x1c714b34630>,
#  'â€': <gensim.models.keyedvectors.Vocab at 0x1c714b345f8>,
#  '”': <gensim.models.keyedvectors.Vocab at 0x1c714b34588>,
#  'magnitude-7': <gensim.models.keyedvectors.Vocab at 0x1c714b34550>,
#  'AustralianBuzz': <gensim.models.keyedvectors.Vocab at 0x1c714b34518>,
#  'Sth': <gensim.models.keyedvectors.Vocab at 0x1c714b344e0>,
#  'Michelle9647': <gensim.models.keyedvectors.Vocab at 0x1c714b343c8>,
#  'Red': <gensim.models.keyedvectors.Vocab at 0x1c714b34438>,
#  'Cross': <gensim.models.keyedvectors.Vocab at 0x1c714b34470>,
#  'casualties': <gensim.models.keyedvectors.Vocab at 0x1c714b344a8>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1c714b34400>,
#  'JALpalyul': <gensim.models.keyedvectors.Vocab at 0x1c714b34358>,
#  'AffiliateDesire': <gensim.models.keyedvectors.Vocab at 0x1c714b342e8>,
#  'Quality': <gensim.models.keyedvectors.Vocab at 0x1c714b341d0>,
#  'Footage': <gensim.models.keyedvectors.Vocab at 0x1c714b34390>,
#  'Sept': <gensim.models.keyedvectors.Vocab at 0x1c714b34320>,
#  '5th': <gensim.models.keyedvectors.Vocab at 0x1c714b34278>,
#  'Bummer': <gensim.models.keyedvectors.Vocab at 0x1c714b34208>,
#  'locals': <gensim.models.keyedvectors.Vocab at 0x1c714b34198>,
#  'amp': <gensim.models.keyedvectors.Vocab at 0x1c714b34160>,
#  'vacationers': <gensim.models.keyedvectors.Vocab at 0x1c714b34128>,
#  'TravelGov': <gensim.models.keyedvectors.Vocab at 0x1c714b340f0>,
#  'EmergencyMessage': <gensim.models.keyedvectors.Vocab at 0x1c714b340b8>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x1c714b34080>,
#  'ElSalvador': <gensim.models.keyedvectors.Vocab at 0x1c714b31f28>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x1c714b31d30>,
#  'ht': <gensim.models.keyedvectors.Vocab at 0x1c714b31c88>,
#  'downgrade': <gensim.models.keyedvectors.Vocab at 0x1c714b31ac8>,
#  'lift': <gensim.models.keyedvectors.Vocab at 0x1c714b31c18>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1c714b31b00>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1c714b319e8>,
#  'official': <gensim.models.keyedvectors.Vocab at 0x1c714b31978>,
#  'There': <gensim.models.keyedvectors.Vocab at 0x1c714b31908>,
#  'chaos': <gensim.models.keyedvectors.Vocab at 0x1c714b318d0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1c714b317f0>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1c714b31898>,
#  'duration': <gensim.models.keyedvectors.Vocab at 0x1c714b31860>,
#  'WorldNews': <gensim.models.keyedvectors.Vocab at 0x1c714b31748>,
#  'Some': <gensim.models.keyedvectors.Vocab at 0x1c714b317b8>,
#  'razaespn': <gensim.models.keyedvectors.Vocab at 0x1c714b31668>,
#  'Estadio': <gensim.models.keyedvectors.Vocab at 0x1c714b316d8>,
#  'Nacional': <gensim.models.keyedvectors.Vocab at 0x1c714b31320>,
#  'Issued': <gensim.models.keyedvectors.Vocab at 0x1c714b315f8>,
#  'far-Red': <gensim.models.keyedvectors.Vocab at 0x1c714b31518>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x1c714b314e0>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1c714b31400>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x1c714b31be0>,
#  'honeymoon': <gensim.models.keyedvectors.Vocab at 0x1c714b31f60>,
#  'spot': <gensim.models.keyedvectors.Vocab at 0x1c714b31390>,
#  'NBCNews': <gensim.models.keyedvectors.Vocab at 0x1c714b31da0>,
#  'That': <gensim.models.keyedvectors.Vocab at 0x1c714b31a58>,
#  'sustain': <gensim.models.keyedvectors.Vocab at 0x1c714b31358>,
#  'tens': <gensim.models.keyedvectors.Vocab at 0x1c714b31198>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x1c714b31eb8>,
#  'dollars': <gensim.models.keyedvectors.Vocab at 0x1c714b31f98>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x1c714b31ef0>,
#  'Very': <gensim.models.keyedvectors.Vocab at 0x1c714b31e80>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x1c714b31e48>,
#  'magnitude-7.6': <gensim.models.keyedvectors.Vocab at 0x1c714b31dd8>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x1c714b31e10>,
#  'swath': <gensim.models.keyedvectors.Vocab at 0x1c714b31cc0>,
#  'Wednesday': <gensim.models.keyedvectors.Vocab at 0x1c714b31d68>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x1c714b31cf8>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1c714b31c50>,
#  'tod': <gensim.models.keyedvectors.Vocab at 0x1c714b31b70>,
#  '38': <gensim.models.keyedvectors.Vocab at 0x1c714b31ba8>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x1c714b31a90>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x1c714b31b38>,
#  'fatalities': <gensim.models.keyedvectors.Vocab at 0x1c714b319b0>,
#  'Strikes': <gensim.models.keyedvectors.Vocab at 0x1c714b31940>,
#  'Off': <gensim.models.keyedvectors.Vocab at 0x1c714b31828>,
#  'measurin': <gensim.models.keyedvectors.Vocab at 0x1c714b316a0>,
#  'HuffingtonPost': <gensim.models.keyedvectors.Vocab at 0x1c714b31710>,
#  'largest': <gensim.models.keyedvectors.Vocab at 0x1c714b31780>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1c714b31630>,
#  '1991': <gensim.models.keyedvectors.Vocab at 0x1c714b31550>,
#  'LoL..WTH': <gensim.models.keyedvectors.Vocab at 0x1c714b315c0>,
#  'earthquake..': <gensim.models.keyedvectors.Vocab at 0x1c714b31588>,
#  'God': <gensim.models.keyedvectors.Vocab at 0x1c714b31438>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1c714b314a8>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1c714b31470>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1c714b312e8>,
#  'First': <gensim.models.keyedvectors.Vocab at 0x1c714b311d0>,
#  'VIDEO': <gensim.models.keyedvectors.Vocab at 0x1c714b313c8>,
#  'Independent': <gensim.models.keyedvectors.Vocab at 0x1c714b31278>,
#  '28-mile': <gensim.models.keyedvectors.Vocab at 0x1c714b31208>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x1c714b312b0>,
#  'Wednes': <gensim.models.keyedvectors.Vocab at 0x1c714b310f0>,
#  'Pray': <gensim.models.keyedvectors.Vocab at 0x1c714b31160>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x1c714b31128>,
#  'CostaRican': <gensim.models.keyedvectors.Vocab at 0x1c714b31080>,
#  'Nooo': <gensim.models.keyedvectors.Vocab at 0x1c714b310b8>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x1c714b31048>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x1c71604d940>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1c71604dcf8>,
#  'update': <gensim.models.keyedvectors.Vocab at 0x1c71604dd30>,
#  'â—¦': <gensim.models.keyedvectors.Vocab at 0x1c71604d978>,
#  'Kyodo': <gensim.models.keyedvectors.Vocab at 0x1c71604d908>,
#  'jolt': <gensim.models.keyedvectors.Vocab at 0x1c71604dda0>,
#  'regional': <gensim.models.keyedvectors.Vocab at 0x1c71604ddd8>,
#  'WilliamTeach': <gensim.models.keyedvectors.Vocab at 0x1c71604d9b0>,
#  'Which': <gensim.models.keyedvectors.Vocab at 0x1c714517f28>,
#  'Warmist': <gensim.models.keyedvectors.Vocab at 0x1c71142a2e8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1c71142a860>,
#  'blame': <gensim.models.keyedvectors.Vocab at 0x1c71142a3c8>,
#  'climate': <gensim.models.keyedvectors.Vocab at 0x1c71142aeb8>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x1c71142a0b8>,
#  '//': <gensim.models.keyedvectors.Vocab at 0x1c71142a2b0>,
#  'Dumbass': <gensim.models.keyedvectors.Vocab at 0x1c71142a898>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1c71142a6d8>,
#  'GEOLOGY..': <gensim.models.keyedvectors.Vocab at 0x1c71142ae48>,
#  'TimJohnson4': <gensim.models.keyedvectors.Vocab at 0x1c71142abe0>,
#  'prez': <gensim.models.keyedvectors.Vocab at 0x1c71142ada0>,
#  'Damage': <gensim.models.keyedvectors.Vocab at 0x1c71142afd0>,
#  'deaths': <gensim.models.keyedvectors.Vocab at 0x1c71142a978>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x1c7114192e8>,
#  'survey': <gensim.models.keyedvectors.Vocab at 0x1c711419c88>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x1c711419978>,
#  'CHICABRAVA': <gensim.models.keyedvectors.Vocab at 0x1c711419668>,
#  'stoke': <gensim.models.keyedvectors.Vocab at 0x1c711419438>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x1c711419748>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x1c711419898>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x1c711419550>,
#  'Hope': <gensim.models.keyedvectors.Vocab at 0x1c7114194a8>,
#  'TIME': <gensim.models.keyedvectors.Vocab at 0x1c714f5dd30>,
#  '|': <gensim.models.keyedvectors.Vocab at 0x1c714f5dcf8>,
#  'Holy': <gensim.models.keyedvectors.Vocab at 0x1c714f5dc18>,
#  'shit': <gensim.models.keyedvectors.Vocab at 0x1c714f5dba8>,
#  'Unbelievable..': <gensim.models.keyedvectors.Vocab at 0x1c714f5dd68>,
#  'Would': <gensim.models.keyedvectors.Vocab at 0x1c714f5dc50>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1c714f5d588>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x1c714f5d4e0>,
#  'sort': <gensim.models.keyedvectors.Vocab at 0x1c714f5d5c0>,
#  'extreme': <gensim.models.keyedvectors.Vocab at 0x1c714f5d550>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1c714af6d30>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x1c71487feb8>,
#  'region..': <gensim.models.keyedvectors.Vocab at 0x1c71487ff28>,
#  'prayers😔': <gensim.models.keyedvectors.Vocab at 0x1c71487fef0>,
#  'URGENT': <gensim.models.keyedvectors.Vocab at 0x1c71487ff60>,
#  'csmonitor': <gensim.models.keyedvectors.Vocab at 0x1c71487ffd0>,
#  '“': <gensim.models.keyedvectors.Vocab at 0x1c71592bda0>,
#  'dustinbrowning': <gensim.models.keyedvectors.Vocab at 0x1c71592be80>,
#  'SamuRojas': <gensim.models.keyedvectors.Vocab at 0x1c71592bf28>,
#  'antikCR': <gensim.models.keyedvectors.Vocab at 0x1c714cd0198>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1c714cd0780>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x1c714cd0320>,
#  'newslocker': <gensim.models.keyedvectors.Vocab at 0x1c714cd00b8>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x1c714cd01d0>,
#  'Ca': <gensim.models.keyedvectors.Vocab at 0x1c714cd0278>,
#  "n't": <gensim.models.keyedvectors.Vocab at 0x1c714cd02e8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x1c714cd0f60>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x1c714cd0b70>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1c714cd0be0>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x1c714cd0ba8>,
#  'DICE': <gensim.models.keyedvectors.Vocab at 0x1c714cd0080>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1c714cd0d68>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x1c714cd0748>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1c714cd06a0>,
#  'fatality': <gensim.models.keyedvectors.Vocab at 0x1c714cd07f0>,
#  'resu': <gensim.models.keyedvectors.Vocab at 0x1c714cd0c18>,
#  'Update': <gensim.models.keyedvectors.Vocab at 0x1c714cd0358>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1c714cd03c8>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x1c714cd0390>,
#  'CPPGeophysics': <gensim.models.keyedvectors.Vocab at 0x1c714cd00f0>,
#  'Nice': <gensim.models.keyedvectors.Vocab at 0x1c714cd0828>,
#  'visualization': <gensim.models.keyedvectors.Vocab at 0x1c714cd09b0>,
#  'seismic': <gensim.models.keyedvectors.Vocab at 0x1c714cd0898>,
#  'wave': <gensim.models.keyedvectors.Vocab at 0x1c714cd0c88>,
#  'propagate': <gensim.models.keyedvectors.Vocab at 0x1c714cd04e0>,
#  'USArray': <gensim.models.keyedvectors.Vocab at 0x1c714cd02b0>,
#  'EarthScopeInfo': <gensim.models.keyedvectors.Vocab at 0x1c714cd05f8>,
#  'DarinRMcClure': <gensim.models.keyedvectors.Vocab at 0x1c714cd0668>,
#  'Praying': <gensim.models.keyedvectors.Vocab at 0x1c714cd0588>,
#  'YourAnonNews': <gensim.models.keyedvectors.Vocab at 0x1c714cd0470>,
#  'YAN': <gensim.models.keyedvectors.Vocab at 0x1c714cd0940>,
#  'Bad': <gensim.models.keyedvectors.Vocab at 0x1c714cd0ac8>,
#  'Know': <gensim.models.keyedvectors.Vocab at 0x1c714cd0a90>,
#  'Pac': <gensim.models.keyedvectors.Vocab at 0x1c714cd0a20>,
#  'NWers': <gensim.models.keyedvectors.Vocab at 0x1c714cd0ef0>,
#  'Pls': <gensim.models.keyedvectors.Vocab at 0x1c714cd0e80>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x1c714cd0dd8>,
#  'NW': <gensim.models.keyedvectors.Vocab at 0x1c714cd0f98>,
#  'NPR': <gensim.models.keyedvectors.Vocab at 0x1c711422b38>,
#  'tombanse': <gensim.models.keyedvectors.Vocab at 0x1c711422e80>,
#  'worldnews': <gensim.models.keyedvectors.Vocab at 0x1c7114220f0>,
#  'Canceled': <gensim.models.keyedvectors.Vocab at 0x1c711422400>,
#  'After': <gensim.models.keyedvectors.Vocab at 0x1c7114225f8>,
#  'In': <gensim.models.keyedvectors.Vocab at 0x1c711422ac8>,
#  'The': <gensim.models.keyedvectors.Vocab at 0x1c711422198>,
#  'Two-Way': <gensim.models.keyedvectors.Vocab at 0x1c711422780>,
#  'Earth': <gensim.models.keyedvectors.Vocab at 0x1c711422908>,
#  'Matias': <gensim.models.keyedvectors.Vocab at 0x1c711422f28>,
#  'Doing': <gensim.models.keyedvectors.Vocab at 0x1c711422c18>,
#  'Good': <gensim.models.keyedvectors.Vocab at 0x1c7114226d8>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x1c7114227b8>,
#  'Gon': <gensim.models.keyedvectors.Vocab at 0x1c711422048>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x1c711422080>,
#  'Try': <gensim.models.keyedvectors.Vocab at 0x1c711319128>,
#  'Calling': <gensim.models.keyedvectors.Vocab at 0x1c711319048>,
#  'His': <gensim.models.keyedvectors.Vocab at 0x1c711424320>,
#  'Momma': <gensim.models.keyedvectors.Vocab at 0x1c7114242b0>,
#  'Later': <gensim.models.keyedvectors.Vocab at 0x1c711424e10>,
#  'fo': <gensim.models.keyedvectors.Vocab at 0x1c711424588>,
#  'Angie': <gensim.models.keyedvectors.Vocab at 0x1c711424eb8>,
#  'Thompson': <gensim.models.keyedvectors.Vocab at 0x1c711424978>,
#  'Messerschmidt': <gensim.models.keyedvectors.Vocab at 0x1c711424d30>,
#  'Claryssa-Faye': <gensim.models.keyedvectors.Vocab at 0x1c711424b00>,
#  'Skie': <gensim.models.keyedvectors.Vocab at 0x1c711424630>,
#  'Did': <gensim.models.keyedvectors.Vocab at 0x1c711424f60>,
#  '14:42:10': <gensim.models.keyedvectors.Vocab at 0x1c711424fd0>,
#  'India': <gensim.models.keyedvectors.Vocab at 0x1c711424748>,
#  'IBNLive.comPowerful': <gensim.models.keyedvectors.Vocab at 0x1c7114246a0>,
#  'deadReu': <gensim.models.keyedvectors.Vocab at 0x1c711424780>,
#  'Two': <gensim.models.keyedvectors.Vocab at 0x1c711424358>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x1c711424860>,
#  'injure': <gensim.models.keyedvectors.Vocab at 0x1c7114244e0>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x1c711424518>,
#  'Piedras': <gensim.models.keyedvectors.Vocab at 0x1c711424e48>,
#  'homestay': <gensim.models.keyedvectors.Vocab at 0x1c711424f98>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x1c711424ef0>,
#  'Isidro': <gensim.models.keyedvectors.Vocab at 0x1c711424e80>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x1c711424da0>,
#  'Heredia': <gensim.models.keyedvectors.Vocab at 0x1c711424cf8>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x1c711424be0>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x1c711424b70>,
#  'MrVop': <gensim.models.keyedvectors.Vocab at 0x1c711424ac8>,
#  'RandyDorfman': <gensim.models.keyedvectors.Vocab at 0x1c7114249e8>,
#  'WCOOP': <gensim.models.keyedvectors.Vocab at 0x1c711424908>,
#  'players': <gensim.models.keyedvectors.Vocab at 0x1c711424898>,
#  'USA': <gensim.models.keyedvectors.Vocab at 0x1c7114247b8>,
#  'TODAY7.6-magnitude': <gensim.models.keyedvectors.Vocab at 0x1c7114247f0>,
#  'coastCNN': <gensim.models.keyedvectors.Vocab at 0x1c7114246d8>,
#  'Online': <gensim.models.keyedvectors.Vocab at 0x1c711424668>,
#  'NewsMagnitude': <gensim.models.keyedvectors.Vocab at 0x1c7114245c0>,
#  'RicaABC': <gensim.models.keyedvectors.Vocab at 0x1c711424550>,
#  'OnlineA': <gensim.models.keyedvectors.Vocab at 0x1c711424400>,
#  'pow': <gensim.models.keyedvectors.Vocab at 0x1c711424390>,
#  'Our': <gensim.models.keyedvectors.Vocab at 0x1c711424f28>,
#  'hearts': <gensim.models.keyedvectors.Vocab at 0x1c711424dd8>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x1c711424c18>,
#  'Covering': <gensim.models.keyedvectors.Vocab at 0x1c711424ba8>,
#  'TheAngieShow': <gensim.models.keyedvectors.Vocab at 0x1c711424c50>,
#  'Associated': <gensim.models.keyedvectors.Vocab at 0x1c711424a90>,
#  'Press': <gensim.models.keyedvectors.Vocab at 0x1c711424a58>,
#  'ar': <gensim.models.keyedvectors.Vocab at 0x1c711424710>,
#  'Fox': <gensim.models.keyedvectors.Vocab at 0x1c711424828>,
#  'SAN': <gensim.models.keyedvectors.Vocab at 0x1c7114245f8>,
#  'JOSE': <gensim.models.keyedvectors.Vocab at 0x1c7114243c8>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x1c711424470>,
#  'trend': <gensim.models.keyedvectors.Vocab at 0x1c711424438>,
#  'Viva': <gensim.models.keyedvectors.Vocab at 0x1c7159a27b8>,
#  'bitch': <gensim.models.keyedvectors.Vocab at 0x1c7159a2a20>,
#  'CostaRicaEarthquake': <gensim.models.keyedvectors.Vocab at 0x1c7159a2f98>,
#  'REN': <gensim.models.keyedvectors.Vocab at 0x1c7159a2898>,
#  'Federation': <gensim.models.keyedvectors.Vocab at 0x1c7159a2e48>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x1c7159a2978>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x1c7159a2908>,
#  '4:11pm': <gensim.models.keyedvectors.Vocab at 0x1c7159a29b0>,
#  '15m': <gensim.models.keyedvectors.Vocab at 0x1c7159a2c18>,
#  '71km': <gensim.models.keyedvectors.Vocab at 0x1c7159a2eb8>,
#  '35km': <gensim.models.keyedvectors.Vocab at 0x1c7159a2860>,
#  'We': <gensim.models.keyedvectors.Vocab at 0x1c7159a28d0>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x1c7159a2b38>,
#  '20km': <gensim.models.keyedvectors.Vocab at 0x1c7159a2ef0>,
#  'Guanacaste': <gensim.models.keyedvectors.Vocab at 0x1c7159a2da0>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x1c7159a2e10>,
#  'Nosara': <gensim.models.keyedvectors.Vocab at 0x1c7159a2a58>,
#  'panic': <gensim.models.keyedvectors.Vocab at 0x1c7159a2dd8>,
#  'minor': <gensim.models.keyedvectors.Vocab at 0x1c715d2cc50>,
#  'IBNLive.comStrong': <gensim.models.keyedvectors.Vocab at 0x1c715d2c470>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x1c715d2c5c0>,
#  'Living': <gensim.models.keyedvectors.Vocab at 0x1c715d2c160>,
#  'Social': <gensim.models.keyedvectors.Vocab at 0x1c715d2ca20>,
#  'Andy': <gensim.models.keyedvectors.Vocab at 0x1c715d2c550>,
#  'Roddick': <gensim.models.keyedvectors.Vocab at 0x1c715d2c0f0>,
#  'onedirection': <gensim.models.keyedvectors.Vocab at 0x1c715d2c6d8>,
#  '=/': <gensim.models.keyedvectors.Vocab at 0x1c715d2c5f8>,
#  'https': <gensim.models.keyedvectors.Vocab at 0x1c715d2c3c8>,
#  '//t.co/Ef5TdX9M': <gensim.models.keyedvectors.Vocab at 0x1c715d2c940>,
#  'EarthquakeCalifornia': <gensim.models.keyedvectors.Vocab at 0x1c715d2c828>,
#  'delay': <gensim.models.keyedvectors.Vocab at 0x1c715d2c390>,
#  'World': <gensim.models.keyedvectors.Vocab at 0x1c715d2c278>,
#  'Cup': <gensim.models.keyedvectors.Vocab at 0x1c715d2c400>,
#  'qualifier': <gensim.models.keyedvectors.Vocab at 0x1c715d2c080>,
#  'Mexican': <gensim.models.keyedvectors.Vocab at 0x1c715d2c7b8>,
#  'Buildings': <gensim.models.keyedvectors.Vocab at 0x1c715d2ce10>,
#  'sway': <gensim.models.keyedvectors.Vocab at 0x1c715d2c518>,
#  'residents': <gensim.models.keyedvectors.Vocab at 0x1c715d2c710>,
#  'rush': <gensim.models.keyedvectors.Vocab at 0x1c715d2c4e0>,
#  'streets': <gensim.models.keyedvectors.Vocab at 0x1c715d2c7f0>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x1c715d2c908>,
#  'Geologyupdate': <gensim.models.keyedvectors.Vocab at 0x1c715d48dd8>,
#  'Seattle': <gensim.models.keyedvectors.Vocab at 0x1c715d481d0>,
#  'Times': <gensim.models.keyedvectors.Vocab at 0x1c715d48208>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x1c715d48b38>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1c715d48780>,
#  'Washington': <gensim.models.keyedvectors.Vocab at 0x1c715d48320>,
#  'Post': <gensim.models.keyedvectors.Vocab at 0x1c715d48048>,
#  'CBC.caPowerf': <gensim.models.keyedvectors.Vocab at 0x1c715d48860>,
#  'Three': <gensim.models.keyedvectors.Vocab at 0x1c715d48438>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x1c715d48550>,
#  'Xinhua': <gensim.models.keyedvectors.Vocab at 0x1c715d48ac8>,
#  'NationThree': <gensim.models.keyedvectors.Vocab at 0x1c715d48cf8>,
#  'quak': <gensim.models.keyedvectors.Vocab at 0x1c715d48a20>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1c715d484a8>,
#  'resistant': <gensim.models.keyedvectors.Vocab at 0x1c715d48128>,
#  'construction': <gensim.models.keyedvectors.Vocab at 0x1c715d48080>,
#  'Cangrejal': <gensim.models.keyedvectors.Vocab at 0x1c715d48be0>,
#  'sho': <gensim.models.keyedvectors.Vocab at 0x1c715d48e10>,
#  'Rocked': <gensim.models.keyedvectors.Vocab at 0x1c7116f3588>,
#  '1.0': <gensim.models.keyedvectors.Vocab at 0x1c7116f3ac8>,
#  'Southern': <gensim.models.keyedvectors.Vocab at 0x1c7116f34e0>,
#  'California': <gensim.models.keyedvectors.Vocab at 0x1c7116f3a90>,
#  'escape': <gensim.models.keyedvectors.Vocab at 0x1c7116f3400>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1c7116f35f8>,
#  'bulletin': <gensim.models.keyedvectors.Vocab at 0x1c7116f3e80>,
#  'terrify': <gensim.models.keyedvectors.Vocab at 0x1c7116f3da0>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x1c7116f3198>,
#  'QuakeÂ': <gensim.models.keyedvectors.Vocab at 0x1c7116f31d0>,
#  'Ready': <gensim.models.keyedvectors.Vocab at 0x1c7116f3358>,
#  'Action': <gensim.models.keyedvectors.Vocab at 0x1c7116f3208>,
#  'Source': <gensim.models.keyedvectors.Vocab at 0x1c7116f3048>,
#  'Â': <gensim.models.keyedvectors.Vocab at 0x1c7116f3780>,
#  'Irish': <gensim.models.keyedvectors.Vocab at 0x1c7116f36a0>,
#  'Cro': <gensim.models.keyedvectors.Vocab at 0x1c7116f3ef0>,
#  'It': <gensim.models.keyedvectors.Vocab at 0x1c7116f3668>,
#  'appear': <gensim.models.keyedvectors.Vocab at 0x1c7116f3f60>,
#  'Thursday': <gensim.models.keyedvectors.Vocab at 0x1c7116f3550>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x1c7116f3b70>,
#  'unsc': <gensim.models.keyedvectors.Vocab at 0x1c7116f38d0>,
#  'Terror': <gensim.models.keyedvectors.Vocab at 0x1c7116f3860>,
#  'casino': <gensim.models.keyedvectors.Vocab at 0x1c7116f30f0>,
#  'Capital': <gensim.models.keyedvectors.Vocab at 0x1c7116f3710>,
#  'Videos': <gensim.models.keyedvectors.Vocab at 0x1c710ff2978>,
#  'Surface': <gensim.models.keyedvectors.Vocab at 0x1c710ff2048>,
#  'Video': <gensim.models.keyedvectors.Vocab at 0x1c710ff2710>,
#  '1.8': <gensim.models.keyedvectors.Vocab at 0x1c710ff20b8>,
#  'Island': <gensim.models.keyedvectors.Vocab at 0x1c710ff2ba8>,
#  'Environment': <gensim.models.keyedvectors.Vocab at 0x1c710ff2780>,
#  'Planet': <gensim.models.keyedvectors.Vocab at 0x1c710ff2d68>,
#  'Ark': <gensim.models.keyedvectors.Vocab at 0x1c710ff2b70>,
#  'EARTHQUAKE': <gensim.models.keyedvectors.Vocab at 0x1c710ff29b0>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x1c710ff2518>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x1c710ff2898>,
#  'Another': <gensim.models.keyedvectors.Vocab at 0x1c710ff2860>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1c710ff2128>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x1c710ff2748>,
#  'awake': <gensim.models.keyedvectors.Vocab at 0x1c710ff2160>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1c710ff2470>,
#  'Dang': <gensim.models.keyedvectors.Vocab at 0x1c710ff2fd0>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x1c710ff26a0>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x1c710ff2cf8>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1c710ff2c50>,
#  '3.5': <gensim.models.keyedvectors.Vocab at 0x1c710ff2400>,
#  'Beverly': <gensim.models.keyedvectors.Vocab at 0x1c710ff2908>,
#  'Hills': <gensim.models.keyedvectors.Vocab at 0x1c710ff2b00>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x1c710ff2390>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1c710ff2588>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x1c710ff2e48>,
#  'zomanno': <gensim.models.keyedvectors.Vocab at 0x1c710ff2c88>,
#  'EARTHQUAKEEE': <gensim.models.keyedvectors.Vocab at 0x1c710ff24a8>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1c710ff2320>,
#  'coincidence': <gensim.models.keyedvectors.Vocab at 0x1c710ff2278>,
#  'episode': <gensim.models.keyedvectors.Vocab at 0x1c710ff2a90>,
#  'HoneyBooBoo': <gensim.models.keyedvectors.Vocab at 0x1c710ff2208>,
#  '9021uh-0': <gensim.models.keyedvectors.Vocab at 0x1c710ff2f98>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1c710ff25f8>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1c710ff27b8>,
#  'westside': <gensim.models.keyedvectors.Vocab at 0x1c7112c4550>,
#  'eastern': <gensim.models.keyedvectors.Vocab at 0x1c7112c44a8>,
#  'SFV': <gensim.models.keyedvectors.Vocab at 0x1c7112c4ba8>,
#  'TheLAScene': <gensim.models.keyedvectors.Vocab at 0x1c7112c4fd0>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1c7112c4b70>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1c7112c4e48>,
#  'BeverlyHills': <gensim.models.keyedvectors.Vocab at 0x1c7112c4eb8>,
#  'upgrade': <gensim.models.keyedvectors.Vocab at 0x1c7112c49e8>,
#  'ArianaGrande': <gensim.models.keyedvectors.Vocab at 0x1c7112c4940>,
#  'Hi': <gensim.models.keyedvectors.Vocab at 0x1c7112c4390>,
#  'IÂ´m': <gensim.models.keyedvectors.Vocab at 0x1c7112c47f0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x1c7112c4da0>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x1c7112c4710>,
#  'again..': <gensim.models.keyedvectors.Vocab at 0x1c7112c4a58>,
#  'seriously..': <gensim.models.keyedvectors.Vocab at 0x1c7112c46d8>,
#  'Tell': <gensim.models.keyedvectors.Vocab at 0x1c7112c4f98>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1c7112c4470>,
#  'bout': <gensim.models.keyedvectors.Vocab at 0x1c7112c40b8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1c7112c4cf8>,
#  'Bobak9': <gensim.models.keyedvectors.Vocab at 0x1c7112c44e0>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x1c7112c4f60>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x1c7112c4630>,
#  'UsainBolt': <gensim.models.keyedvectors.Vocab at 0x1c7112c4128>,
#  'Never': <gensim.models.keyedvectors.Vocab at 0x1c7112c4278>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1c7112c4588>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1c7112c4208>,
#  'SO': <gensim.models.keyedvectors.Vocab at 0x1c7112c4cc0>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x1c7112c4978>,
#  'Lol': <gensim.models.keyedvectors.Vocab at 0x1c7112c4dd8>,
#  'DNC2012': <gensim.models.keyedvectors.Vocab at 0x1c7112c4198>,
#  'Was': <gensim.models.keyedvectors.Vocab at 0x1c7112c4748>,
# ...
#  'side': <gensim.models.keyedvectors.Vocab at 0x1c714f71c88>,
#  'LAFD': <gensim.models.keyedvectors.Vocab at 0x1c714f71048>,
#  'LAquake': <gensim.models.keyedvectors.Vocab at 0x1c714f71e48>,
#  'Emergency': <gensim.models.keyedvectors.Vocab at 0x1c714f71be0>,
#  'Mode': <gensim.models.keyedvectors.Vocab at 0x1c714f715f8>,
#  'discontinue': <gensim.models.keyedvectors.Vocab at 0x1c714f71e80>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x1c714f71f60>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x1c714f71208>,
#  'normalâ€¦': <gensim.models.keyedvectors.Vocab at 0x1c714f71dd8>,
#  'Quakes': <gensim.models.keyedvectors.Vocab at 0x1c714f71780>,
#  'southwest': <gensim.models.keyedvectors.Vocab at 0x1c714f71d30>,
#  'China': <gensim.models.keyedvectors.Vocab at 0x1c714f716a0>,
#  'dozens': <gensim.models.keyedvectors.Vocab at 0x1c714f71b70>,
#  '20,000': <gensim.models.keyedvectors.Vocab at 0x1c714f71ba8>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x1c714f71898>,
#  'Earthquakes': <gensim.models.keyedvectors.Vocab at 0x1c714f71b00>,
#  'alertã€': <gensim.models.keyedvectors.Vocab at 0x1c714f719e8>,
#  '2.1': <gensim.models.keyedvectors.Vocab at 0x1c714f71860>,
#  '07': <gensim.models.keyedvectors.Vocab at 0x1c714f714e0>,
#  '15:33:36': <gensim.models.keyedvectors.Vocab at 0x1c714f71128>,
#  'Dear': <gensim.models.keyedvectors.Vocab at 0x1c714f71550>,
#  '2x': <gensim.models.keyedvectors.Vocab at 0x1c714f71358>,
#  "'ve": <gensim.models.keyedvectors.Vocab at 0x1c714f71cc0>,
#  '1/2': <gensim.models.keyedvectors.Vocab at 0x1c714f710b8>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x1c714f71d68>,
#  'away-Results': <gensim.models.keyedvectors.Vocab at 0x1c714f716d8>,
#  'crappy': <gensim.models.keyedvectors.Vocab at 0x1c714f71710>,
#  'workout': <gensim.models.keyedvectors.Vocab at 0x1c714f71438>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1c714f71978>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1c714f71198>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x1c714f713c8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1c714f712e8>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x1c714f71f28>,
#  'Shakes': <gensim.models.keyedvectors.Vocab at 0x1c714f717b8>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x1c714f71b38>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x1c714f71240>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1c714f71ef0>,
#  'Yea': <gensim.models.keyedvectors.Vocab at 0x1c714f71748>,
#  'figure': <gensim.models.keyedvectors.Vocab at 0x1c714f71080>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x1c714f71c50>,
#  'uselessinfo': <gensim.models.keyedvectors.Vocab at 0x1c714f71518>,
#  'Watchers': <gensim.models.keyedvectors.Vocab at 0x1c714f71eb8>,
#  'Massive': <gensim.models.keyedvectors.Vocab at 0x1c714f71470>,
#  'awaken': <gensim.models.keyedvectors.Vocab at 0x1c714f718d0>,
#  'Nicaraguan': <gensim.models.keyedvectors.Vocab at 0x1c714f71a90>,
#  'Apoyeque': <gensim.models.keyedvectors.Vocab at 0x1c714f71da0>,
#  'volcano': <gensim.models.keyedvectors.Vocab at 0x1c714f711d0>,
#  'At': <gensim.models.keyedvectors.Vocab at 0x1c714f71cf8>,
#  '12:35': <gensim.models.keyedvectors.Vocab at 0x1c714f71908>,
#  'PM': <gensim.models.keyedvectors.Vocab at 0x1c714f717f0>,
#  'UTC': <gensim.models.keyedvectors.Vocab at 0x1c714f71400>,
#  'Minahasa': <gensim.models.keyedvectors.Vocab at 0x1c714f71a20>,
#  'M4.7': <gensim.models.keyedvectors.Vocab at 0x1c714f71fd0>,
#  '35.70km': <gensim.models.keyedvectors.Vocab at 0x1c714f719b0>,
#  'Stay': <gensim.models.keyedvectors.Vocab at 0x1c714f71278>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x1c714f71320>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x1c714f71390>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x1c714f71a58>,
#  'BECOME': <gensim.models.keyedvectors.Vocab at 0x1c714f71ac8>,
#  'ASEXUAL': <gensim.models.keyedvectors.Vocab at 0x1c714f71c18>,
#  'NOW': <gensim.models.keyedvectors.Vocab at 0x1c714f715c0>,
#  '5.6': <gensim.models.keyedvectors.Vocab at 0x1c714f710f0>,
#  'earthqu': <gensim.models.keyedvectors.Vocab at 0x1c714f714a8>,
#  'Felt': <gensim.models.keyedvectors.Vocab at 0x1c714f71630>,
#  'South': <gensim.models.keyedvectors.Vocab at 0x1c714f71828>,
#  'tremor': <gensim.models.keyedvectors.Vocab at 0x1c714f71668>,
#  'TrafficSA': <gensim.models.keyedvectors.Vocab at 0x1c71075d400>,
#  'offtraffic': <gensim.models.keyedvectors.Vocab at 0x1c71075d470>,
#  'East': <gensim.models.keyedvectors.Vocab at 0x1c71075d080>,
#  'Rand': <gensim.models.keyedvectors.Vocab at 0x1c71075d518>,
#  'Otro': <gensim.models.keyedvectors.Vocab at 0x1c71075d550>,
#  'temblor': <gensim.models.keyedvectors.Vocab at 0x1c71075d5c0>,
#  'en': <gensim.models.keyedvectors.Vocab at 0x1c71075d588>,
#  'Sat': <gensim.models.keyedvectors.Vocab at 0x1c71075d5f8>,
#  '08': <gensim.models.keyedvectors.Vocab at 0x1c71075d668>,
#  '16:29:32': <gensim.models.keyedvectors.Vocab at 0x1c71075d6d8>,
#  'AMT': <gensim.models.keyedvectors.Vocab at 0x1c71075d6a0>,
#  'Interesting': <gensim.models.keyedvectors.Vocab at 0x1c71075d630>,
#  'Hojancha': <gensim.models.keyedvectors.Vocab at 0x1c71075d9e8>,
#  'REPORTS': <gensim.models.keyedvectors.Vocab at 0x1c71075db00>,
#  'â€¢': <gensim.models.keyedvectors.Vocab at 0x1c71075dbe0>,
#  'ENE': <gensim.models.keyedvectors.Vocab at 0x1c71075dac8>,
#  'OF': <gensim.models.keyedvectors.Vocab at 0x1c71075da58>,
#  'HOJANCHA': <gensim.models.keyedvectors.Vocab at 0x1c71075dba8>,
#  'M5.6': <gensim.models.keyedvectors.Vocab at 0x1c71075d898>,
#  '11km': <gensim.models.keyedvectors.Vocab at 0x1c71075db38>,
#  '2012-09-08': <gensim.models.keyedvectors.Vocab at 0x1c71075dc50>,
#  'USGSBigQuakes': <gensim.models.keyedvectors.Vocab at 0x1c71075dcc0>,
#  'Sep-8': <gensim.models.keyedvectors.Vocab at 0x1c71075dd30>,
#  '20:29': <gensim.models.keyedvectors.Vocab at 0x1c71075dd68>,
#  'YouTube': <gensim.models.keyedvectors.Vocab at 0x1c71075dda0>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x1c71075deb8>,
#  '4.1': <gensim.models.keyedvectors.Vocab at 0x1c71075de10>,
#  'Islands': <gensim.models.keyedvectors.Vocab at 0x1c71075df60>,
#  'Aleutian': <gensim.models.keyedvectors.Vocab at 0x1c71075dfd0>,
#  'nswia_weather': <gensim.models.keyedvectors.Vocab at 0x1c71075d048>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1c71075d320>,
#  'Woy': <gensim.models.keyedvectors.Vocab at 0x1c71075d4e0>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x1c71075d2e8>,
#  '16:23:51': <gensim.models.keyedvectors.Vocab at 0x1c71075d1d0>,
#  'AEST': <gensim.models.keyedvectors.Vocab at 0x1c71075ddd8>,
#  'Andaman': <gensim.models.keyedvectors.Vocab at 0x1c71075d2b0>,
#  'Region': <gensim.models.keyedvectors.Vocab at 0x1c71075d208>,
#  'relieve': <gensim.models.keyedvectors.Vocab at 0x1c71075d438>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x1c71075d780>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1c71075d7b8>,
#  'equal': <gensim.models.keyedvectors.Vocab at 0x1c71075d4a8>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x1c71075d7f0>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x1c71075d8d0>,
#  '4.6': <gensim.models.keyedvectors.Vocab at 0x1c71075d978>,
#  '5km': <gensim.models.keyedvectors.Vocab at 0x1c71075d908>,
#  'NNE': <gensim.models.keyedvectors.Vocab at 0x1c71075dc18>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x1c71075dc88>,
#  '20:13': <gensim.models.keyedvectors.Vocab at 0x1c71075df98>,
#  '21m': <gensim.models.keyedvectors.Vocab at 0x1c71075de80>,
#  '37km': <gensim.models.keyedvectors.Vocab at 0x1c71075da90>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x1c71075df28>,
#  '06:29:35': <gensim.models.keyedvectors.Vocab at 0x1c71075da20>,
#  'quakemonitor': <gensim.models.keyedvectors.Vocab at 0x1c71075d0f0>,
#  'Depth': <gensim.models.keyedvectors.Vocab at 0x1c71075d198>,
#  '35.00': <gensim.models.keyedvectors.Vocab at 0x1c71075d3c8>,
#  'km': <gensim.models.keyedvectors.Vocab at 0x1c71075d940>,
#  '7:29:35': <gensim.models.keyedvectors.Vocab at 0x1c71075d9b0>,
#  'BST': <gensim.models.keyedvectors.Vocab at 0x1c71075db70>,
#  '42km': <gensim.models.keyedvectors.Vocab at 0x1c71075de48>,
#  'SW': <gensim.models.keyedvectors.Vocab at 0x1c71075def0>,
#  'Paquera': <gensim.models.keyedvectors.Vocab at 0x1c71075d390>,
#  '00:29': <gensim.models.keyedvectors.Vocab at 0x1c71075d160>,
#  '10:05:02': <gensim.models.keyedvectors.Vocab at 0x1c71075d710>,
#  'Sott': <gensim.models.keyedvectors.Vocab at 0x1c71075d748>,
#  'Officials': <gensim.models.keyedvectors.Vocab at 0x1c71075dcf8>,
#  'Could': <gensim.models.keyedvectors.Vocab at 0x1c7116fa4e0>,
#  'Still': <gensim.models.keyedvectors.Vocab at 0x1c7116fa128>,
#  'Occur': <gensim.models.keyedvectors.Vocab at 0x1c7116faf98>,
#  'fondalo': <gensim.models.keyedvectors.Vocab at 0x1c7116fa9b0>,
#  'socialmedia': <gensim.models.keyedvectors.Vocab at 0x1c7116fa9e8>,
#  'Exchange': <gensim.models.keyedvectors.Vocab at 0x1c7116fafd0>,
#  'Site': <gensim.models.keyedvectors.Vocab at 0x1c7116fae10>,
#  'Reaffirms': <gensim.models.keyedvectors.Vocab at 0x1c7116faeb8>,
#  'terremoto': <gensim.models.keyedvectors.Vocab at 0x1c7116faef0>,
#  '5.1': <gensim.models.keyedvectors.Vocab at 0x1c7116fa7b8>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x1c7116fa588>,
#  'Mid-Atlantic': <gensim.models.keyedvectors.Vocab at 0x1c7116fa5f8>,
#  'Ridge': <gensim.models.keyedvectors.Vocab at 0x1c7116fa160>,
#  '3.2': <gensim.models.keyedvectors.Vocab at 0x1c7116fa470>,
#  'Northern': <gensim.models.keyedvectors.Vocab at 0x1c7116fa208>,
#  'Dispatch': <gensim.models.keyedvectors.Vocab at 0x1c7116fa278>,
#  '5.2': <gensim.models.keyedvectors.Vocab at 0x1c7116fa2e8>,
#  '8km': <gensim.models.keyedvectors.Vocab at 0x1c7116fa0b8>,
#  'W': <gensim.models.keyedvectors.Vocab at 0x1c7116fa080>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x1c7116fa320>,
#  '23:51': <gensim.models.keyedvectors.Vocab at 0x1c7116fa358>,
#  '24km': <gensim.models.keyedvectors.Vocab at 0x1c7116fa390>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x1c7116fa668>,
#  '05:51:09': <gensim.models.keyedvectors.Vocab at 0x1c7116fa6a0>,
#  '10km': <gensim.models.keyedvectors.Vocab at 0x1c7116fa7f0>,
#  'Samara': <gensim.models.keyedvectors.Vocab at 0x1c7116fa748>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x1c7116fab00>,
#  '13:10': <gensim.models.keyedvectors.Vocab at 0x1c7116fab70>,
#  '57m': <gensim.models.keyedvectors.Vocab at 0x1c7116fabe0>,
#  '44km': <gensim.models.keyedvectors.Vocab at 0x1c7116fa8d0>,
#  'ChileEarthquake': <gensim.models.keyedvectors.Vocab at 0x1c7116fa908>,
#  'Chilean': <gensim.models.keyedvectors.Vocab at 0x1c7116fa940>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x1c7116fa978>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1c7116fa198>,
#  'emergency': <gensim.models.keyedvectors.Vocab at 0x1c7116fac88>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1c7116faf60>,
#  '-via': <gensim.models.keyedvectors.Vocab at 0x1c7116fae80>,
#  'AFP': <gensim.models.keyedvectors.Vocab at 0x1c7116fadd8>,
#  'PrayForChile': <gensim.models.keyedvectors.Vocab at 0x1c7116fa5c0>,
#  'Five': <gensim.models.keyedvectors.Vocab at 0x1c7116fa4a8>,
#  '8.2': <gensim.models.keyedvectors.Vocab at 0x1c7116fa240>,
#  'aftermath': <gensim.models.keyedvectors.Vocab at 0x1c7116fa0f0>,
#  'FOX8NOLA': <gensim.models.keyedvectors.Vocab at 0x1c7116fa3c8>,
#  'unbelievable': <gensim.models.keyedvectors.Vocab at 0x1c7116fa438>,
#  'img': <gensim.models.keyedvectors.Vocab at 0x1c7116fa710>,
#  'Larryferlazzo': <gensim.models.keyedvectors.Vocab at 0x1c7116fa780>,
#  'stevesilberman': <gensim.models.keyedvectors.Vocab at 0x1c7116fa828>,
#  'Evacuation': <gensim.models.keyedvectors.Vocab at 0x1c7116fa898>,
#  'progress': <gensim.models.keyedvectors.Vocab at 0x1c7116faba8>,
#  'Iquique': <gensim.models.keyedvectors.Vocab at 0x1c7116fac50>,
#  'googlenews': <gensim.models.keyedvectors.Vocab at 0x1c7116faa20>,
#  'Least': <gensim.models.keyedvectors.Vocab at 0x1c7116fa048>,
#  'Dead': <gensim.models.keyedvectors.Vocab at 0x1c7116fa6d8>,
#  'Near': <gensim.models.keyedvectors.Vocab at 0x1c7116fad30>,
#  'Wall': <gensim.models.keyedvectors.Vocab at 0x1c7116faf28>,
#  'Street': <gensim.models.keyedvectors.Vocab at 0x1c7116faa90>,
#  'Journal': <gensim.models.keyedvectors.Vocab at 0x1c7116fada0>,
#  'Montreal': <gensim.models.keyedvectors.Vocab at 0x1c7116fa630>,
#  'Gazet': <gensim.models.keyedvectors.Vocab at 0x1c7116faa58>,
#  'spark': <gensim.models.keyedvectors.Vocab at 0x1c7116fad68>,
#  'tsunamiwarning': <gensim.models.keyedvectors.Vocab at 0x1c7116fa400>,
#  'thousands': <gensim.models.keyedvectors.Vocab at 0x1c7116fa1d0>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x1c7116facc0>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x1c7116fac18>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x1c7116fa518>,
#  'vessels': <gensim.models.keyedvectors.Vocab at 0x1c7116fab38>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x1c7116fa2b0>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x1c7116fae48>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x1c714899048>,
#  'remarkable': <gensim.models.keyedvectors.Vocab at 0x1c714899080>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x1c7148990b8>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x1c7148990f0>,
#  'Tweeted': <gensim.models.keyedvectors.Vocab at 0x1c714899160>,
#  'Top': <gensim.models.keyedvectors.Vocab at 0x1c714899198>,
#  'CNN.â€¦': <gensim.models.keyedvectors.Vocab at 0x1c714899128>,
#  'Incredible': <gensim.models.keyedvectors.Vocab at 0x1c7148991d0>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1c714899208>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x1c714899240>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x1c714899278>,
#  'ocean': <gensim.models.keyedvectors.Vocab at 0x1c7148992b0>,
#  'People': <gensim.models.keyedvectors.Vocab at 0x1c714899320>,
#  'flee': <gensim.models.keyedvectors.Vocab at 0x1c7148992e8>,
#  'Way': <gensim.models.keyedvectors.Vocab at 0x1c714899390>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1c7148993c8>,
#  'May': <gensim.models.keyedvectors.Vocab at 0x1c714899400>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x1c714899438>,
#  'Deadly': <gensim.models.keyedvectors.Vocab at 0x1c7148994e0>,
#  'Magnitude-8.2': <gensim.models.keyedvectors.Vocab at 0x1c7148994a8>,
#  'Temblor': <gensim.models.keyedvectors.Vocab at 0x1c714899518>,
#  'Rocks': <gensim.models.keyedvectors.Vocab at 0x1c714899550>,
#  '5.5': <gensim.models.keyedvectors.Vocab at 0x1c714899588>,
#  '2014-04-02': <gensim.models.keyedvectors.Vocab at 0x1c7148995c0>,
#  '11:07:31': <gensim.models.keyedvectors.Vocab at 0x1c7148995f8>,
#  '-19.99': <gensim.models.keyedvectors.Vocab at 0x1c714899630>,
#  '-70.92': <gensim.models.keyedvectors.Vocab at 0x1c7148996a0>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x1c714899668>,
#  'ANEWS': <gensim.models.keyedvectors.Vocab at 0x1c7148996d8>,
#  'interior': <gensim.models.keyedvectors.Vocab at 0x1c714899710>,
#  'minister': <gensim.models.keyedvectors.Vocab at 0x1c714899748>,
#  'Tsunami-triggering': <gensim.models.keyedvectors.Vocab at 0x1c714899780>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x1c7148997b8>,
#  '300Â': <gensim.models.keyedvectors.Vocab at 0x1c714899828>,
#  'prisoners': <gensim.models.keyedvectors.Vocab at 0x1c7148997f0>,
#  'aftershocks': <gensim.models.keyedvectors.Vocab at 0x1c714899860>,
#  'Read': <gensim.models.keyedvectors.Vocab at 0x1c714899898>,
#  'Peru': <gensim.models.keyedvectors.Vocab at 0x1c714899908>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x1c714899940>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x1c714899978>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x1c7148999b0>,
#  'inmates': <gensim.models.keyedvectors.Vocab at 0x1c7148999e8>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x1c714899a20>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x1c714899a58>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x1c714899ac8>,
#  'Arica': <gensim.models.keyedvectors.Vocab at 0x1c714899b38>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x1c714899b70>,
#  'TRENDING': <gensim.models.keyedvectors.Vocab at 0x1c714899be0>,
#  'TODAY': <gensim.models.keyedvectors.Vocab at 0x1c714899ba8>,
#  'Tuesday': <gensim.models.keyedvectors.Vocab at 0x1c714899c18>,
#  'Via': <gensim.models.keyedvectors.Vocab at 0x1c714899c50>,
#  ...}

# %%
w2v_quake.train(list_of_words_quake, total_examples=w2v_quake.corpus_count, epochs=30, report_delay=1)
w2v_flood.train(list_of_words_flood, total_examples=w2v_quake.corpus_count, epochs=30, report_delay=1)
# Out:
# INFO - 14:01:11: training model with 3 workers on 12305 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=4
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:11: EPOCH - 1 : training on 64955 raw words (31026 effective words) took 0.1s, 220733 effective words/s
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:11: EPOCH - 2 : training on 64955 raw words (31021 effective words) took 0.1s, 381303 effective words/s
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:11: EPOCH - 3 : training on 64955 raw words (31040 effective words) took 0.1s, 470901 effective words/s
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:11: EPOCH - 4 : training on 64955 raw words (31028 effective words) took 0.1s, 459473 effective words/s
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:11: EPOCH - 5 : training on 64955 raw words (30971 effective words) took 0.1s, 403388 effective words/s
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:11: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:11: EPOCH - 6 : training on 64955 raw words (30919 effective words) took 0.1s, 415903 effective words/s
# INFO - 14:01:11: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 7 : training on 64955 raw words (31083 effective words) took 0.1s, 374775 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 8 : training on 64955 raw words (30964 effective words) took 0.1s, 388412 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 9 : training on 64955 raw words (31063 effective words) took 0.1s, 464585 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 10 : training on 64955 raw words (31062 effective words) took 0.1s, 439463 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 11 : training on 64955 raw words (31074 effective words) took 0.1s, 422327 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 12 : training on 64955 raw words (31000 effective words) took 0.1s, 295957 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 13 : training on 64955 raw words (31050 effective words) took 0.1s, 435615 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 14 : training on 64955 raw words (30901 effective words) took 0.1s, 361536 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 15 : training on 64955 raw words (31099 effective words) took 0.1s, 334433 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 16 : training on 64955 raw words (31006 effective words) took 0.1s, 306595 effective words/s
# INFO - 14:01:12: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:12: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:12: EPOCH - 17 : training on 64955 raw words (31037 effective words) took 0.1s, 365835 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 18 : training on 64955 raw words (30940 effective words) took 0.1s, 414746 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 19 : training on 64955 raw words (31007 effective words) took 0.1s, 394166 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 20 : training on 64955 raw words (31122 effective words) took 0.1s, 421251 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 21 : training on 64955 raw words (31054 effective words) took 0.1s, 393735 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 22 : training on 64955 raw words (31009 effective words) took 0.1s, 379880 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 23 : training on 64955 raw words (31021 effective words) took 0.1s, 333439 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 24 : training on 64955 raw words (31122 effective words) took 0.1s, 418902 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 25 : training on 64955 raw words (31043 effective words) took 0.1s, 374018 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 26 : training on 64955 raw words (30973 effective words) took 0.1s, 383275 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 27 : training on 64955 raw words (31121 effective words) took 0.1s, 332139 effective words/s
# INFO - 14:01:13: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:13: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:13: EPOCH - 28 : training on 64955 raw words (31007 effective words) took 0.1s, 320095 effective words/s
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 29 : training on 64955 raw words (31074 effective words) took 0.1s, 443434 effective words/s
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 30 : training on 64955 raw words (31049 effective words) took 0.1s, 466442 effective words/s
# INFO - 14:01:14: training on a 1948650 raw words (930886 effective words) took 2.8s, 336089 effective words/s
# INFO - 14:01:14: training model with 3 workers on 8305 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=4
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 1 : training on 43113 raw words (19959 effective words) took 0.1s, 377238 effective words/s
# WARNING - 14:01:14: EPOCH - 1 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 2 : training on 43113 raw words (20027 effective words) took 0.1s, 333821 effective words/s
# WARNING - 14:01:14: EPOCH - 2 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 3 : training on 43113 raw words (19997 effective words) took 0.1s, 390619 effective words/s
# WARNING - 14:01:14: EPOCH - 3 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 4 : training on 43113 raw words (20033 effective words) took 0.1s, 332061 effective words/s
# WARNING - 14:01:14: EPOCH - 4 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 5 : training on 43113 raw words (19979 effective words) took 0.1s, 344378 effective words/s
# WARNING - 14:01:14: EPOCH - 5 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 6 : training on 43113 raw words (20136 effective words) took 0.1s, 322442 effective words/s
# WARNING - 14:01:14: EPOCH - 6 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 7 : training on 43113 raw words (19969 effective words) took 0.1s, 303568 effective words/s
# WARNING - 14:01:14: EPOCH - 7 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 8 : training on 43113 raw words (19932 effective words) took 0.1s, 302411 effective words/s
# WARNING - 14:01:14: EPOCH - 8 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 9 : training on 43113 raw words (20020 effective words) took 0.1s, 324099 effective words/s
# WARNING - 14:01:14: EPOCH - 9 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 10 : training on 43113 raw words (20078 effective words) took 0.1s, 365729 effective words/s
# WARNING - 14:01:14: EPOCH - 10 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 11 : training on 43113 raw words (19968 effective words) took 0.1s, 351215 effective words/s
# WARNING - 14:01:14: EPOCH - 11 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 12 : training on 43113 raw words (19946 effective words) took 0.1s, 355962 effective words/s
# WARNING - 14:01:14: EPOCH - 12 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:14: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:14: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:14: EPOCH - 13 : training on 43113 raw words (19878 effective words) took 0.1s, 339626 effective words/s
# WARNING - 14:01:14: EPOCH - 13 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 14 : training on 43113 raw words (19899 effective words) took 0.1s, 394685 effective words/s
# WARNING - 14:01:15: EPOCH - 14 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 15 : training on 43113 raw words (19906 effective words) took 0.1s, 363280 effective words/s
# WARNING - 14:01:15: EPOCH - 15 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 16 : training on 43113 raw words (19968 effective words) took 0.0s, 440444 effective words/s
# WARNING - 14:01:15: EPOCH - 16 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 17 : training on 43113 raw words (20084 effective words) took 0.1s, 360805 effective words/s
# WARNING - 14:01:15: EPOCH - 17 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 18 : training on 43113 raw words (20022 effective words) took 0.1s, 344596 effective words/s
# WARNING - 14:01:15: EPOCH - 18 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 19 : training on 43113 raw words (19905 effective words) took 0.1s, 358932 effective words/s
# WARNING - 14:01:15: EPOCH - 19 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 20 : training on 43113 raw words (20029 effective words) took 0.1s, 349858 effective words/s
# WARNING - 14:01:15: EPOCH - 20 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 21 : training on 43113 raw words (20080 effective words) took 0.1s, 368869 effective words/s
# WARNING - 14:01:15: EPOCH - 21 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 22 : training on 43113 raw words (20058 effective words) took 0.1s, 325044 effective words/s
# WARNING - 14:01:15: EPOCH - 22 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 23 : training on 43113 raw words (20091 effective words) took 0.1s, 311046 effective words/s
# WARNING - 14:01:15: EPOCH - 23 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 24 : training on 43113 raw words (20084 effective words) took 0.1s, 387580 effective words/s
# WARNING - 14:01:15: EPOCH - 24 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 25 : training on 43113 raw words (20050 effective words) took 0.1s, 354654 effective words/s
# WARNING - 14:01:15: EPOCH - 25 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 26 : training on 43113 raw words (20012 effective words) took 0.1s, 380470 effective words/s
# WARNING - 14:01:15: EPOCH - 26 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 27 : training on 43113 raw words (19897 effective words) took 0.1s, 333161 effective words/s
# WARNING - 14:01:15: EPOCH - 27 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:15: EPOCH - 28 : training on 43113 raw words (19957 effective words) took 0.1s, 329735 effective words/s
# WARNING - 14:01:15: EPOCH - 28 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:15: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:15: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:16: EPOCH - 29 : training on 43113 raw words (20025 effective words) took 0.1s, 350005 effective words/s
# WARNING - 14:01:16: EPOCH - 29 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:16: worker thread finished; awaiting finish of 2 more threads
# INFO - 14:01:16: worker thread finished; awaiting finish of 1 more threads
# INFO - 14:01:16: worker thread finished; awaiting finish of 0 more threads
# INFO - 14:01:16: EPOCH - 30 : training on 43113 raw words (19981 effective words) took 0.1s, 340393 effective words/s
# WARNING - 14:01:16: EPOCH - 30 : supplied example count (2518) did not equal expected count (5140)
# INFO - 14:01:16: training on a 1293390 raw words (599970 effective words) took 1.9s, 309301 effective words/s
# (599970, 1293390)

# %% [markdown]
# The following code allows us to see words closely related (positively or negatively) with any other word. In this case we put in the word 'help'.

# %%
w2v_quake.wv.most_similar(positive=["dead"])
# Out:
# INFO - 14:01:20: precomputing L2-norms of word weight vectors
# [('northern', 0.9993839263916016),
#  ('rock', 0.9992939233779907),
#  ('kill', 0.9991955757141113),
#  ('A', 0.9991101026535034),
#  ('7.9', 0.9990882873535156),
#  ('Strong', 0.9990764260292053),
#  ('Italy', 0.9990614652633667),
#  ('Magnitude', 0.9990595579147339),
#  ('Powerful', 0.9990211725234985),
#  ('cnnbrk', 0.9990118741989136)]

# %% [markdown]
# We will now convert these word2vec embeddings into a pandas dataframe. This can be converted into a csv for use later in maybe R. We will also explore ways to use this in an SVM model to classify our tweets.

# %%
word_list_quake = []
vector_list_quake = []
for word in w2v_quake.wv.vocab:
    word_list_quake.append(word)
    vector_list_quake.append(w2v_quake.wv.get_vector(word))
    
word_list_flood = []
vector_list_flood = []
for word in w2v_flood.wv.vocab:
    word_list_flood.append(word)
    vector_list_flood.append(w2v_flood.wv.get_vector(word))

# %%
quake_embeddings = pd.DataFrame()
quake_embeddings['Word'] = word_list_quake
quake_embeddings['Vector'] = vector_list_quake

# %%
flood_embeddings = pd.DataFrame()
flood_embeddings['Word'] = word_list_flood
flood_embeddings['Vector'] = vector_list_flood

# %%
#quake_embeddings.to_csv('Word2Vec_Earthquake.csv')
#flood_embeddings.to_csv('Word2Vec_Flood.csv')

# %% [markdown]
# ## SVM Classifer
