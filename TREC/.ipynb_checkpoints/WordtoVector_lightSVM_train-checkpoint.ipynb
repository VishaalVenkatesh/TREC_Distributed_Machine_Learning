# %%
import csv
import collections
import itertools
import numpy as np
import pandas as pd
import string
import re
import os
from sklearn.model_selection import train_test_split

# %%
allevents = os.listdir('Stats/csv')

# %%
for eachevent in allevents:
    print("Reading:", eachevent)
    df = pd.read_csv('Stats/csv/'+eachevent)
    df['difference'] = abs(df['Negative(0) class'] - df['Positive(1) class'])
    df['total'] = abs(df['Negative(0) class'] + df['Positive(1) class'])
    print(df.iloc[df['difference'].idxmin()])
    print("------------------------------------------------------------------")
# Out:
# Reading: chileEarthquake2014.csv
# Class Name           ThirdPartyObservation
# Negative(0) class                      157
# Positive(1) class                      154
# difference                               3
# total                                  311
# Name: 1, dtype: object
# ------------------------------------------------------------------
# Reading: typhoonYolanda2013.csv
# Class Name           Hashtags
# Negative(0) class         261
# Positive(1) class         303
# difference                 42
# total                     564
# Name: 13, dtype: object
# ------------------------------------------------------------------
# Reading: manilaFloods2013.csv
# Class Name           Irrelevant
# Negative(0) class           260
# Positive(1) class           151
# difference                  109
# total                       411
# Name: 6, dtype: object
# ------------------------------------------------------------------
# Reading: albertaFloods2013.csv
# Class Name           ContinuingNews
# Negative(0) class               369
# Positive(1) class               353
# difference                       16
# total                           722
# Name: 2, dtype: object
# ------------------------------------------------------------------
# Reading: joplinTornado2011.csv
# Class Name           ContinuingNews
# Negative(0) class                38
# Positive(1) class                58
# difference                       20
# total                            96
# Name: 3, dtype: object
# ------------------------------------------------------------------
# Reading: flSchoolShooting2018.csv
# Class Name           MultimediaShare
# Negative(0) class                568
# Positive(1) class                550
# difference                        18
# total                           1118
# Name: 0, dtype: object
# ------------------------------------------------------------------
# Reading: italyEarthquakes2012.csv
# Class Name           Irrelevant
# Negative(0) class            50
# Positive(1) class            53
# difference                    3
# total                       103
# Name: 0, dtype: object
# ------------------------------------------------------------------
# Reading: typhoonHagupit2014.csv
# Class Name           ThirdPartyObservation
# Negative(0) class                     2250
# Positive(1) class                     1691
# difference                             559
# total                                 3941
# Name: 0, dtype: object
# ------------------------------------------------------------------
# Reading: nepalEarthquake2015.csv
# Class Name           Sentiment
# Negative(0) class         3268
# Positive(1) class         2595
# difference                 673
# total                     5863
# Name: 4, dtype: object
# ------------------------------------------------------------------
# Reading: guatemalaEarthquake2012.csv
# Class Name           KnownAlready
# Negative(0) class              88
# Positive(1) class              66
# difference                     22
# total                         154
# Name: 8, dtype: object
# ------------------------------------------------------------------
# Reading: bostonBombings2013.csv
# Class Name           PastNews
# Negative(0) class         280
# Positive(1) class         255
# difference                 25
# total                     535
# Name: 0, dtype: object
# ------------------------------------------------------------------
# Reading: parisAttacks2015.csv
# Class Name           Sentiment
# Negative(0) class         1277
# Positive(1) class          789
# difference                 488
# total                     2066
# Name: 13, dtype: object
# ------------------------------------------------------------------
# Reading: australiaBushfire2013.csv
# Class Name           ContinuingNews
# Negative(0) class               242
# Positive(1) class               435
# difference                      193
# total                           677
# Name: 2, dtype: object
# ------------------------------------------------------------------
# Reading: queenslandFloods2013.csv
# Class Name           ContinuingNews
# Negative(0) class               349
# Positive(1) class               364
# difference                       15
# total                           713
# Name: 2, dtype: object
# ------------------------------------------------------------------
# Reading: philipinnesFloods2012.csv
# Class Name           FirstPartyObservation
# Negative(0) class                      201
# Positive(1) class                      236
# difference                              35
# total                                  437
# Name: 10, dtype: object
# ------------------------------------------------------------------

# %% [markdown]
# ### Unpack GloVe

# %%
filename = 'glove.twitter.27B/glove.twitter.27B.100d.txt'

# %%
def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    f = open(gloveFile,'r')
    model = {}
    for line in f:
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print("Done.",len(model)," words loaded!")
    return model

# %%
twittervocab = loadGloveModel(filename)
# Out:
# Loading Glove Model
# Done. 1193515  words loaded!

# %%
np.random.seed(120)
randvec = np.random.rand(100)

# %% [markdown]
# ## Get features

# %%
def ptext(text): return re.findall("[a-zA-Z']+", text.lower())

def getwordvec(dataset, maximum_len):
    data = []
    for eachsent in dataset:
        sentence = [twittervocab[word] if word in twittervocab.keys() else randvec for word in eachsent]
        if len(sentence) < maximum_len:
            sentence.extend([[0]*100 for _ in range(maximum_len-len(sentence))])
        data.append(sentence)
    return np.array(data)

def process(filename):
    df = pd.read_csv('Features/'+filename).drop('Unnamed: 0', axis=1)
    common = ['tweetids', 'topics', 'alltopics', 'categories','cleanedtweets']
    columns = [name for name in list(df.columns) if name not in common]
    tweetsdata = df['cleanedtweets'].tolist()
    tweetdata = [ptext(eachtweet) for eachtweet in tweetsdata]
    folder = filename.split('.')[0]
    print("Reading each labels from file: ", filename)
    print("--------------------------------------------------------------")
    os.mkdir('datasets/'+folder)
    
    maximum_len = max([len(i) for i in tweetdata])
    minimum_len = min([len(i) for i in tweetdata])
    print("Maximum length: ", maximum_len)
    print("--------------------------------------------------------------")
    for each_label in columns:
        labels = df[each_label]
        X_train, X_test, y_train, y_test = train_test_split(tweetdata, labels, test_size = 0.20)  
        # train
        x_train = getwordvec(X_train, maximum_len)
        
        new_x_train = np.reshape(x_train, (-1, x_train.shape[1]*x_train.shape[2]))
        # test
        x_test = getwordvec(X_test, maximum_len)

        new_x_test = np.reshape(x_test,(-1, x_test.shape[1]*x_test.shape[2]))
        
        with open('datasets/'+folder+'/'+each_label+'_train_'+str(maximum_len)+'00.txt','w') as fp:
            for left, right in zip(y_train, new_x_train):
                new_right = ' '.join([str(index+1)+':'+str(value) for index, value in enumerate(right)])
                left = -1 if left == 0 else left
                feat = str(left)+' '+str(new_right)
                fp.write("%s\n" %(feat))
                
        with open('datasets/'+folder+'/'+each_label+'_test_'+str(maximum_len)+'00.txt','w') as fp:
            for left, right in zip(y_test, new_x_test):
                new_right = ' '.join([str(index+1)+':'+str(value) for index, value in enumerate(right)])
                left = -1 if left == 0 else left
                feat = str(left)+' '+str(new_right)
                fp.write("%s\n" %(feat))
        print("Finished processing label: ", each_label)
        print("--------------------------------------------------------------")

# %%
files = os.listdir('Features/')

# %%
for file in files: 
    process(file)
    print("********************************************************************")
# Out:
# Reading each labels from file:  Shooting_features.csv
# --------------------------------------------------------------
# Maximum length:  29
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  chileEarthquake2014.csv
# --------------------------------------------------------------
# Maximum length:  26
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  typhoonYolanda2013.csv
# --------------------------------------------------------------
# Maximum length:  27
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  Attacks_features.csv
# --------------------------------------------------------------
# Maximum length:  28
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  manilaFloods2013.csv
# --------------------------------------------------------------
# Maximum length:  26
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  albertaFloods2013.csv
# --------------------------------------------------------------
# Maximum length:  27
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  fire_features.csv
# --------------------------------------------------------------
# Maximum length:  27
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  italyEarthquakes2012.csv
# --------------------------------------------------------------
# Maximum length:  25
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  Bombing_features.csv
# --------------------------------------------------------------
# Maximum length:  28
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  typhoonHagupit2014.csv
# --------------------------------------------------------------
# Maximum length:  31
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  nepalEarthquake2015.csv
# --------------------------------------------------------------
# Maximum length:  32
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  guatemalaEarthquake2012.csv
# --------------------------------------------------------------
# Maximum length:  26
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  queenslandFloods2013.csv
# --------------------------------------------------------------
# Maximum length:  27
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  Tornado_features.csv
# --------------------------------------------------------------
# Maximum length:  25
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# ********************************************************************
# Reading each labels from file:  philipinnesFloods2012.csv
# --------------------------------------------------------------
# Maximum length:  27
# --------------------------------------------------------------
# Finished processing label:  ThirdPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Factoid
# --------------------------------------------------------------
# Finished processing label:  ContinuingNews
# --------------------------------------------------------------
# Finished processing label:  EmergingThreats
# --------------------------------------------------------------
# Finished processing label:  Advice
# --------------------------------------------------------------
# Finished processing label:  PastNews
# --------------------------------------------------------------
# Finished processing label:  Irrelevant
# --------------------------------------------------------------
# Finished processing label:  Sentiment
# --------------------------------------------------------------
# Finished processing label:  Discussion
# --------------------------------------------------------------
# Finished processing label:  SearchAndRescue
# --------------------------------------------------------------
# Finished processing label:  FirstPartyObservation
# --------------------------------------------------------------
# Finished processing label:  Donations
# --------------------------------------------------------------
# Finished processing label:  MultimediaShare
# --------------------------------------------------------------
# Finished processing label:  Volunteer
# --------------------------------------------------------------
# Finished processing label:  GoodsServices
# --------------------------------------------------------------
# Finished processing label:  MovePeople
# --------------------------------------------------------------
# Finished processing label:  Official
# --------------------------------------------------------------
# Finished processing label:  ServiceAvailable
# --------------------------------------------------------------
# Finished processing label:  CleanUp
# --------------------------------------------------------------
# Finished processing label:  InformationWanted
# --------------------------------------------------------------
# Finished processing label:  SignificantEventChange
# --------------------------------------------------------------
# Finished processing label:  KnownAlready
# --------------------------------------------------------------
# Finished processing label:  Weather
# --------------------------------------------------------------
# Finished processing label:  Hashtags
# --------------------------------------------------------------
# Finished processing label:  Unknown
# --------------------------------------------------------------
# ********************************************************************

# %% [markdown]
# ### Seperating events

# %%
featuredata_name = ['Earthquake_features.csv', 'typhoon_features.csv', 'Floods_features.csv']

# %%
for f in featuredata_name:
    df = pd.read_csv('Features/'+f).drop('Unnamed: 0', axis=1)
    topics = list(set(df['topics']))
    for i in range(len(topics)):
        print("Reading topic: ", topics[i])
        df[df['topics'] == topics[i]].to_csv('Features/'+topics[i]+'.csv')
    print("-----------------------------------------------------------------------")
# Out:
# Reading topic:  guatemalaEarthquake2012
# Reading topic:  chileEarthquake2014
# Reading topic:  nepalEarthquake2015
# Reading topic:  italyEarthquakes2012
# -----------------------------------------------------------------------
# Reading topic:  typhoonYolanda2013
# Reading topic:  typhoonHagupit2014
# -----------------------------------------------------------------------
# Reading topic:  queenslandFloods2013
# Reading topic:  philipinnesFloods2012
# Reading topic:  albertaFloods2013
# Reading topic:  manilaFloods2013
# -----------------------------------------------------------------------

# %%
topics = list(set(df['topics']))

# %% [markdown]
# #### LIBSVM

# %%
from collections import Counter

# %%
with open('GADGET/GADGET/data/mnist/mnist.scale.t','r') as fp:
    newcontent = fp.read().splitlines()

# %%
newcontent = [content[i] for i in range(len(content)) if int(content[i][0]) < 2]

# %%
len(newcontent)
# Out:
# 2115

# %%
newcontent = ['-1'+each[1:] if int(each[0]) < 5 else '1'+each[1:]  for each in newcontent]

# %%
with open('GADGET/GADGET/data/mnist/testdata.txt','w') as fp:
    for each in newcontent:
        fp.write("%s\n" %each)

# %%
Counter([each.split()[0] for each in newcontent])
# Out:
# Counter({'1': 4861, '-1': 5139})

# %%
type(newcontent[10])
# Out:
# str

# %%
newcontent[:10]
# Out:
# ['1 129:0.14902 130:0.996078 131:0.427451 157:0.341176 158:0.988235 159:0.321569 185:0.529412 186:0.945098 212:0.176471 213:0.956863 214:0.588235 240:0.329412 241:0.996078 242:0.247059 268:0.792157 269:0.87451 270:0.0431373 295:0.12549 296:0.996078 297:0.847059 323:0.372549 324:0.996078 325:0.764706 351:0.54902 352:0.996078 353:0.301961 378:0.223529 379:0.929412 380:0.803922 381:0.0313725 406:0.486275 407:1 408:0.647059 434:0.670588 435:0.996078 436:0.317647 461:0.0941176 462:0.909804 463:0.843137 489:0.470588 490:0.996078 491:0.623529 517:0.592157 518:0.996078 519:0.556863 545:0.894118 546:0.996078 547:0.258824 572:0.239216 573:0.984314 574:0.996078 575:0.258824 600:0.552941 601:0.996078 602:0.803922 603:0.0117647 627:0.0392157 628:0.843137 629:0.996078 630:0.47451 655:0.0196078 656:0.776471 657:0.690196 658:0.0392157 ',
#  '0 125:0.0431373 126:0.588235 127:0.992157 128:0.792157 129:0.121569 153:0.145098 154:0.984314 155:0.984314 156:0.992157 157:0.419608 180:0.0823529 181:0.772549 182:0.984314 183:0.984314 184:0.992157 185:0.419608 207:0.431373 208:0.745098 209:0.984314 210:0.984314 211:0.984314 212:0.992157 213:0.662745 214:0.427451 215:0.243137 235:0.992157 236:0.984314 237:0.984314 238:0.984314 239:0.984314 240:0.992157 241:0.984314 242:0.984314 243:0.862745 244:0.2 262:0.713725 263:1 264:0.992157 265:0.992157 266:0.992157 267:0.992157 268:0.917647 269:0.870588 270:0.992157 271:0.992157 272:0.992157 289:0.247059 290:0.866667 291:0.992157 292:0.984314 293:0.984314 294:0.984314 295:0.576471 296:0.301961 297:0.243137 298:0.501961 299:0.984314 300:0.984314 301:0.411765 316:0.12549 317:0.905882 318:0.984314 319:0.992157 320:0.984314 321:0.862745 322:0.537255 323:0.0392157 326:0.121569 327:0.901961 328:0.984314 329:0.952941 330:0.443137 331:0.0196078 344:0.145098 345:0.984314 346:0.984314 347:0.992157 348:0.737255 349:0.0784314 355:0.427451 356:0.984314 357:0.992157 358:0.984314 359:0.137255 372:0.145098 373:0.984314 374:0.984314 375:0.788235 376:0.117647 383:0.121569 384:0.784314 385:0.992157 386:0.984314 387:0.137255 400:0.145098 401:0.992157 402:0.992157 411:0.12549 412:0.792157 413:1 414:0.992157 415:0.643137 428:0.54902 429:0.984314 430:0.984314 439:0.427451 440:0.984314 441:0.992157 442:0.984314 443:0.137255 456:0.85098 457:0.984314 458:0.984314 465:0.0823529 466:0.247059 467:0.905882 468:0.984314 469:0.992157 470:0.901961 471:0.117647 484:0.85098 485:0.984314 486:0.984314 493:0.564706 494:0.984314 495:0.984314 496:0.984314 497:0.866667 498:0.239216 512:0.85098 513:0.984314 514:0.984314 520:0.713725 521:0.866667 522:0.984314 523:0.984314 524:0.984314 525:0.705882 540:0.854902 541:0.992157 542:0.992157 543:0.286275 544:0.286275 545:0.894118 546:0.992157 547:0.992157 548:1 549:0.992157 550:0.992157 551:0.992157 552:0.992157 568:0.443137 569:0.984314 570:0.984314 571:0.992157 572:0.984314 573:0.984314 574:0.984314 575:0.984314 576:0.992157 577:0.984314 578:0.984314 579:0.984314 580:0.576471 596:0.121569 597:0.901961 598:0.984314 599:0.992157 600:0.984314 601:0.984314 602:0.984314 603:0.984314 604:0.992157 605:0.901961 606:0.741176 607:0.137255 608:0.0392157 625:0.243137 626:0.556863 627:0.992157 628:0.984314 629:0.984314 630:0.984314 631:0.984314 632:0.992157 633:0.419608 655:0.282353 656:0.682353 657:0.984314 658:0.678431 659:0.278431 660:0.282353 661:0.117647 ',
#  '1 157:0.301961 158:0.996078 159:0.419608 160:0.0117647 184:0.0745098 185:0.890196 186:0.996078 187:0.996078 188:0.0352941 212:0.317647 213:0.996078 214:0.996078 215:0.647059 216:0.00392157 239:0.027451 240:0.796078 241:0.996078 242:0.996078 243:0.286275 267:0.207843 268:0.996078 269:0.996078 270:0.980392 295:0.52549 296:0.996078 297:0.996078 298:0.705882 323:0.768627 324:0.996078 325:0.972549 326:0.188235 350:0.227451 351:0.996078 352:0.996078 353:0.929412 378:0.435294 379:0.996078 380:0.996078 381:0.517647 406:0.639216 407:0.996078 408:0.933333 409:0.109804 433:0.235294 434:0.988235 435:0.996078 436:0.87451 461:0.309804 462:0.996078 463:0.996078 464:0.603922 489:0.639216 490:0.996078 491:0.933333 492:0.207843 516:0.109804 517:0.988235 518:0.996078 519:0.823529 544:0.337255 545:0.996078 546:0.996078 547:0.513725 572:0.411765 573:0.996078 574:0.917647 575:0.0784314 600:0.686275 601:0.996078 602:0.8 603:0.0196078 627:0.0196078 628:0.827451 629:0.996078 630:0.768627 655:0.0117647 656:0.619608 657:0.996078 658:0.627451 684:0.101961 685:0.615686 686:0.419608 ',
#  '0 124:0.239216 125:0.0117647 126:0.164706 127:0.462745 128:0.756863 129:0.462745 130:0.462745 131:0.239216 150:0.054902 151:0.701961 152:0.960784 153:0.92549 154:0.94902 155:0.996078 156:0.996078 157:0.996078 158:0.996078 159:0.960784 160:0.921569 161:0.329412 178:0.592157 179:0.996078 180:0.996078 181:0.996078 182:0.835294 183:0.752941 184:0.698039 185:0.698039 186:0.705882 187:0.996078 188:0.996078 189:0.945098 190:0.180392 205:0.168627 206:0.921569 207:0.996078 208:0.886275 209:0.25098 210:0.109804 211:0.0470588 214:0.00784314 215:0.501961 216:0.988235 217:1 218:0.678431 219:0.0666667 233:0.219608 234:0.996078 235:0.992157 236:0.419608 244:0.52549 245:0.980392 246:0.996078 247:0.294118 261:0.247059 262:0.996078 263:0.619608 273:0.866667 274:0.996078 275:0.615686 289:0.760784 290:0.996078 291:0.403922 301:0.588235 302:0.996078 303:0.835294 316:0.133333 317:0.862745 318:0.937255 319:0.227451 329:0.329412 330:0.996078 331:0.835294 344:0.494118 345:0.996078 346:0.670588 357:0.329412 358:0.996078 359:0.835294 372:0.839216 373:0.937255 374:0.235294 385:0.329412 386:0.996078 387:0.835294 400:0.839216 401:0.780392 413:0.329412 414:0.996078 415:0.835294 427:0.0431373 428:0.858824 429:0.780392 441:0.329412 442:0.996078 443:0.835294 455:0.384314 456:0.996078 457:0.780392 469:0.635294 470:0.996078 471:0.819608 483:0.384314 484:0.996078 485:0.780392 496:0.2 497:0.933333 498:0.996078 499:0.294118 511:0.384314 512:0.996078 513:0.780392 523:0.2 524:0.647059 525:0.996078 526:0.764706 527:0.0156863 539:0.258824 540:0.945098 541:0.780392 550:0.0117647 551:0.654902 552:0.996078 553:0.890196 554:0.215686 568:0.839216 569:0.835294 570:0.0784314 576:0.180392 577:0.596078 578:0.792157 579:0.996078 580:0.996078 581:0.247059 596:0.839216 597:0.996078 598:0.8 599:0.705882 600:0.705882 601:0.705882 602:0.705882 603:0.705882 604:0.921569 605:0.996078 606:0.996078 607:0.917647 608:0.611765 609:0.0392157 624:0.317647 625:0.803922 626:0.996078 627:0.996078 628:0.996078 629:0.996078 630:0.996078 631:0.996078 632:0.996078 633:0.988235 634:0.917647 635:0.470588 653:0.101961 654:0.823529 655:0.996078 656:0.996078 657:0.996078 658:0.996078 659:0.996078 660:0.6 661:0.407843 ',
#  '0 153:0.0666667 154:0.258824 155:0.541176 156:1 157:0.992157 158:0.662745 159:0.541176 160:0.0901961 179:0.0196078 180:0.470588 181:0.894118 182:0.988235 183:0.988235 184:0.992157 185:0.988235 186:0.988235 187:0.988235 188:0.619608 207:0.423529 208:0.988235 209:0.988235 210:0.988235 211:0.988235 212:0.745098 213:0.988235 214:0.988235 215:0.988235 216:0.988235 234:0.168627 235:0.913725 236:0.988235 237:0.988235 238:0.988235 239:0.454902 240:0.0196078 241:0.529412 242:0.988235 243:0.988235 244:0.988235 261:0.168627 262:0.698039 263:0.992157 264:0.988235 265:0.866667 266:0.168627 267:0.00784314 269:0.0196078 270:0.211765 271:0.909804 272:0.988235 273:0.823529 289:0.364706 290:0.992157 291:1 292:0.976471 293:0.45098 299:0.533333 300:0.984314 301:1 302:0.603922 317:0.65098 318:0.988235 319:0.992157 320:0.72549 328:0.819608 329:0.992157 330:0.807843 344:0.0745098 345:0.862745 346:0.988235 347:0.992157 348:0.360784 356:0.454902 357:0.992157 358:0.807843 372:0.27451 373:0.988235 374:0.988235 375:0.752941 376:0.0666667 384:0.454902 385:0.992157 386:0.87451 387:0.0980392 400:0.478431 401:0.988235 402:0.988235 403:0.247059 412:0.454902 413:0.992157 414:0.988235 415:0.270588 428:0.517647 429:0.992157 430:0.992157 440:0.454902 441:1 442:0.992157 443:0.270588 456:0.721569 457:0.988235 458:0.988235 468:0.454902 469:0.992157 470:0.988235 471:0.270588 484:0.721569 485:0.988235 486:0.988235 496:0.454902 497:0.992157 498:0.941176 499:0.196078 512:0.721569 513:0.988235 514:0.988235 524:0.823529 525:0.992157 526:0.439216 540:0.188235 541:0.909804 542:0.988235 543:0.619608 552:0.901961 553:0.909804 554:0.0313725 569:0.364706 570:0.992157 571:0.956863 572:0.196078 579:0.607843 580:0.992157 581:0.658824 597:0.133333 598:0.643137 599:0.992157 600:0.443137 606:0.258824 607:0.92549 608:0.905882 609:0.164706 626:0.12549 627:0.870588 628:0.941176 629:0.52549 632:0.14902 633:0.356863 634:0.917647 635:0.988235 636:0.537255 655:0.0980392 656:0.694118 657:0.941176 658:0.811765 659:0.403922 660:0.913725 661:0.988235 662:0.988235 663:0.690196 664:0.137255 684:0.0588235 685:0.211765 686:0.701961 687:0.988235 688:0.537255 689:0.537255 690:0.211765 691:0.0156863 ',
#  '1 126:0.501961 127:1 128:0.74902 154:0.74902 155:1 156:1 157:0.25098 182:1 183:1 184:1 185:0.501961 210:1 211:1 212:1 238:1 239:1 240:1 266:0.501961 267:1 268:1 269:0.501961 294:1 295:1 296:1 297:0.501961 322:1 323:1 324:1 325:0.501961 350:1 351:1 352:1 353:0.501961 378:1 379:1 380:1 381:0.501961 406:1 407:1 408:1 434:1 435:1 436:1 462:1 463:1 464:1 490:1 491:1 492:1 518:0.74902 519:1 520:1 521:0.501961 546:0.74902 547:1 548:1 549:0.501961 573:0.25098 574:1 575:1 576:1 577:0.501961 601:0.74902 602:1 603:1 604:1 605:0.501961 628:0.25098 629:1 630:1 631:1 632:0.25098 656:0.25098 657:1 658:0.501961 ',
#  '0 126:0.0117647 127:0.313725 128:0.764706 129:0.333333 130:0.313725 131:0.313725 132:0.313725 133:0.054902 154:0.0352941 155:0.992157 156:0.992157 157:0.992157 158:0.992157 159:0.992157 160:0.992157 161:0.596078 178:0.0431373 179:0.243137 180:0.219608 182:0.0352941 183:0.992157 184:0.992157 185:0.992157 186:0.992157 187:0.992157 188:0.992157 189:0.984314 190:0.929412 191:0.223529 206:0.552941 207:0.992157 208:0.945098 209:0.32549 210:0.0156863 211:0.631373 212:0.992157 213:0.992157 214:0.992157 215:0.992157 216:0.992157 217:0.992157 218:0.992157 219:0.235294 232:0.0431373 233:0.552941 234:0.972549 235:0.992157 236:0.992157 237:0.576471 239:0.286275 240:0.819608 241:0.988235 242:0.992157 243:0.992157 244:0.992157 245:0.992157 246:0.992157 247:0.831373 260:0.576471 261:0.992157 262:0.992157 263:0.992157 264:0.992157 265:0.780392 266:0.133333 269:0.627451 270:0.992157 271:0.556863 272:0.760784 273:0.992157 274:0.992157 275:0.956863 276:0.301961 286:0.0352941 287:0.533333 288:0.980392 289:0.992157 290:0.992157 291:0.992157 292:0.992157 293:0.992157 294:0.270588 297:0.0588235 298:0.203922 299:0.0196078 300:0.105882 301:0.788235 302:0.992157 303:0.992157 304:0.611765 314:0.313725 315:0.992157 316:0.992157 317:0.992157 318:0.992157 319:0.992157 320:0.992157 321:0.819608 322:0.160784 329:0.141176 330:0.992157 331:0.992157 332:0.768627 333:0.129412 342:0.337255 343:0.992157 344:0.992157 345:0.992157 346:0.992157 347:0.992157 348:0.917647 349:0.160784 357:0.164706 358:0.992157 359:0.992157 360:0.992157 361:0.305882 370:0.996078 371:0.992157 372:0.992157 373:0.992157 374:0.992157 375:0.992157 376:0.647059 385:0.827451 386:0.992157 387:0.992157 388:0.992157 389:0.305882 398:0.996078 399:0.992157 400:0.992157 401:0.992157 402:0.992157 403:0.67451 404:0.0705882 413:0.827451 414:0.992157 415:0.992157 416:0.992157 417:0.305882 426:0.996078 427:0.992157 428:0.992157 429:0.992157 430:0.823529 431:0.0156863 438:0.164706 439:0.898039 440:0.964706 441:0.988235 442:0.992157 443:0.992157 444:0.623529 445:0.0117647 454:0.996078 455:0.992157 456:0.992157 457:0.992157 458:0.819608 464:0.388235 465:0.584314 466:0.823529 467:0.992157 468:0.992157 469:0.992157 470:0.992157 471:0.94902 472:0.254902 482:1 483:0.992157 484:0.992157 485:0.992157 486:0.854902 487:0.207843 488:0.207843 489:0.207843 490:0.705882 491:0.894118 492:0.956863 493:0.992157 494:0.992157 495:0.992157 496:0.992157 497:0.992157 498:0.992157 499:0.301961 510:0.639216 511:0.992157 512:0.992157 513:0.992157 514:0.992157 515:0.992157 516:0.992157 517:0.992157 518:0.992157 519:0.992157 520:0.992157 521:0.992157 522:0.992157 523:0.992157 524:0.992157 525:0.992157 526:0.756863 527:0.113725 538:0.313725 539:0.992157 540:0.992157 541:0.992157 542:0.992157 543:0.992157 544:0.992157 545:0.992157 546:0.992157 547:0.992157 548:0.992157 549:0.992157 550:0.992157 551:0.992157 552:0.917647 553:0.756863 554:0.0941176 566:0.172549 567:0.823529 568:0.992157 569:0.992157 570:0.992157 571:0.992157 572:0.992157 573:0.992157 574:0.992157 575:0.992157 576:0.992157 577:0.992157 578:0.992157 579:0.898039 580:0.262745 595:0.14902 596:0.894118 597:0.992157 598:0.992157 599:0.992157 600:0.992157 601:0.992157 602:0.992157 603:0.992157 604:0.992157 605:0.972549 606:0.921569 607:0.254902 624:0.152941 625:0.823529 626:0.992157 627:0.992157 628:0.992157 629:0.992157 630:0.992157 631:0.992157 632:0.741176 633:0.447059 653:0.168627 654:0.423529 655:0.992157 656:0.992157 657:0.701961 658:0.305882 659:0.305882 660:0.105882 ',
#  '0 150:0.12549 151:1 152:0.996078 153:1 154:0.996078 155:0.996078 156:0.996078 157:0.615686 158:0.509804 159:0.345098 160:0.00392157 178:0.12549 179:0.992157 180:0.992157 181:0.992157 182:0.992157 183:0.992157 184:0.992157 185:0.992157 186:0.992157 187:0.992157 188:0.423529 189:0.00784314 206:0.054902 207:0.505882 208:0.933333 209:0.992157 210:0.992157 211:0.992157 212:0.992157 213:0.992157 214:0.992157 215:0.992157 216:0.992157 217:0.117647 236:0.219608 237:0.992157 238:0.972549 239:0.654902 240:0.921569 241:0.992157 242:0.992157 243:0.992157 244:0.992157 245:0.407843 263:0.0196078 264:0.698039 265:0.992157 266:0.713725 268:0.105882 269:0.52549 270:0.968627 271:0.992157 272:0.992157 273:0.843137 274:0.0588235 290:0.0196078 291:0.509804 292:0.992157 293:0.870588 294:0.105882 298:0.729412 299:0.992157 300:0.992157 301:0.992157 302:0.0941176 318:0.12549 319:0.992157 320:0.992157 321:0.478431 326:0.262745 327:0.964706 328:0.992157 329:0.992157 330:0.415686 346:0.458824 347:0.992157 348:0.780392 349:0.0980392 355:0.733333 356:0.992157 357:0.992157 358:0.580392 373:0.180392 374:0.882353 375:0.960784 376:0.262745 383:0.345098 384:0.992157 385:0.992157 386:0.580392 401:0.584314 402:0.992157 403:0.72549 411:0.345098 412:0.992157 413:0.992157 414:0.580392 428:0.0588235 429:0.894118 430:0.992157 431:0.364706 439:0.345098 440:0.992157 441:0.992157 442:0.580392 456:0.0745098 457:0.992157 458:0.992157 459:0.364706 467:0.345098 468:0.992157 469:0.992157 470:0.580392 484:0.0745098 485:0.992157 486:0.992157 487:0.364706 495:0.345098 496:0.992157 497:0.992157 498:0.427451 512:0.0745098 513:0.992157 514:0.992157 515:0.52549 523:0.345098 524:0.992157 525:0.858824 526:0.0627451 540:0.0745098 541:0.992157 542:0.992157 543:0.901961 544:0.12549 551:0.517647 552:0.992157 553:0.603922 568:0.0745098 569:0.992157 570:0.992157 571:0.992157 572:0.913725 573:0.470588 575:0.290196 576:0.392157 577:0.392157 578:0.784314 579:0.972549 580:0.85098 581:0.129412 596:0.00784314 597:0.623529 598:0.992157 599:0.992157 600:0.992157 601:0.976471 602:0.901961 603:0.968627 604:0.992157 605:0.992157 606:0.992157 607:0.992157 608:0.427451 625:0.372549 626:0.992157 627:0.992157 628:0.992157 629:0.992157 630:0.992157 631:0.992157 632:0.992157 633:0.992157 634:0.992157 635:0.462745 636:0.0117647 653:0.00784314 654:0.160784 655:0.992157 656:0.992157 657:0.992157 658:0.992157 659:0.992157 660:0.992157 661:0.992157 662:0.466667 663:0.00784314 682:0.0627451 683:0.2 684:0.345098 685:0.839216 686:0.647059 687:0.388235 688:0.0196078 689:0.0196078 690:0.00392157 ',
#  '1 124:0.854902 125:0.992157 126:0.0431373 152:0.85098 153:0.988235 154:0.360784 180:0.784314 181:0.988235 182:0.988235 208:0.309804 209:0.8 210:0.980392 211:0.0941176 237:0.309804 238:0.976471 239:0.584314 265:0.427451 266:0.988235 267:0.945098 293:0.811765 294:0.988235 295:0.945098 321:0.494118 322:0.988235 323:0.945098 349:0.627451 350:0.988235 351:0.945098 377:0.898039 378:0.988235 379:0.992157 380:0.403922 405:0.207843 406:0.721569 407:1 408:0.670588 434:0.47451 435:0.992157 436:0.894118 462:0.47451 463:0.992157 464:0.894118 490:0.47451 491:0.992157 492:0.894118 518:0.47451 519:0.992157 520:0.894118 546:0.835294 547:0.992157 548:0.921569 549:0.109804 574:0.788235 575:0.992157 576:0.988235 577:0.376471 602:0.47451 603:0.992157 604:0.988235 605:0.376471 630:0.47451 631:0.992157 632:0.988235 633:0.376471 658:0.25098 659:0.764706 660:0.945098 661:0.196078 ',
#  '1 153:0.796078 154:0.756863 155:0.117647 181:0.796078 182:0.992157 183:0.513725 209:0.4 210:0.996078 211:0.592157 237:0.4 238:0.992157 239:0.592157 265:0.160784 266:0.996078 267:0.992157 294:0.992157 295:0.988235 296:0.321569 322:0.596078 323:0.992157 324:0.796078 350:0.596078 351:0.988235 352:0.796078 378:0.360784 379:0.992157 380:0.839216 381:0.0392157 406:0.0392157 407:0.831373 408:0.992157 409:0.196078 435:0.796078 436:0.996078 437:0.439216 463:0.635294 464:0.992157 465:0.592157 491:0.4 492:0.996078 493:0.592157 519:0.4 520:0.992157 521:0.752941 547:0.4 548:0.996078 549:0.992157 575:0.4 576:0.992157 577:0.988235 603:0.160784 604:1 605:0.992157 632:0.992157 633:0.988235 660:0.678431 661:0.992157 662:0.243137 688:0.2 689:0.988235 690:0.4 ']
