# %%
'''
    Importing Modules
'''
import csv, os, collections, json
import numpy as np
import pandas as pd
import collections
import preprocessor as p
import itertools
import json
from pprint import pprint

# %%
'''
    Set working directory
'''
filen = 'trecis2018-train/'
files = os.listdir(filen)

# %%
'''
    Function to get event details from json file
'''
def getevents(filename):
    with open(filename, 'r', encoding = 'utf-8' ) as fp:
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
        
    allevents = []
    for eachevent in range(len(data)):
        allevents.append(data[i]['topic'])
    return allevents

# %%
'''
    Function to open each json file about a specific event and obtian info on the tweets
'''

def gettweets(filename):
                
    with open(filename, 'r' ,encoding = 'utf-8' ) as fp:     
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
    
    #print(data[0].keys())
    #print(data[0]['allProperties'].keys())
    #print(data[0])
    #print(data[1]['allProperties']['source'])
    #print(data[1]['allProperties']['text'])
    alltwts = []
    allid = []
    alltopics = []
    retweet = []
    follower_count = []
    source = []
    user_created_at = []
    tweet_created_at = []
    user_lang = []
    user_screen_name = []
    user_location = []
    for i in range (len(data)):
        
        alltwts.append(data[i]['allProperties']['text'])
        allid.append(data[i]['allProperties']['id'])
        alltopics.append(data[i]['topic'])
        retweet.append(data[i]['allProperties']['retweet_count'])
        follower_count.append(data[i]['allProperties']['user.followers_count'])
        source.append(data[i]['allProperties']['source'])
        user_created_at.append(data[i]['allProperties']['user.created_at'])
        tweet_created_at.append(data[i]['allProperties']['created_at'])
        user_lang.append(data[i]['allProperties']['user.lang'])
        user_screen_name.append(data[i]['allProperties']['user.screen_name'])
        user_location.append(data[i]['allProperties']['user.location'])
    return (allid, alltwts, alltopics, retweet, follower_count, source, user_created_at, tweet_created_at, user_lang, user_screen_name, user_location)

# %%
'''
    Appending returned info about the tweets into lists to later create pandas df
'''
ids = []
tweet = []
topic = []
retweet = []
follower_count = []
source = []
user_created_at = []
tweet_created_at = []
user_lang = []
user_screen_name = []
user_location = []
for each in files:
    a, b, c, d, e, f, g, h, i, j, k = gettweets(filen+each)
    ids.extend(a)
    tweet.extend(b)
    topic.extend(c)
    retweet.extend(d)
    follower_count.extend(e)
    source.extend(f)
    user_created_at.extend(g)
    tweet_created_at.extend(h)
    user_lang.extend(i)
    user_screen_name.extend(j)
    user_location.extend(k)
# Out:
# dict_keys(['user.verified', 'user.listed_count', 'in_reply_to_status_id', 'user.profile_background_tile', 'entities.urls', 'in_reply_to_user_id_str', 'source', 'user.profile_sidebar_border_color', 'user.utc_offset', 'user.translator_type', 'entities.hashtags', 'entities.symbols', 'retweet_count', 'user.profile_use_background_image', 'user.id_str', 'is_quote_status', 'user.profile_banner_url', 'in_reply_to_user_id', 'text', 'id', 'user.created_at', 'user.profile_image_url_https', 'user.follow_request_sent', 'user.profile_background_image_url', 'entities.user_mentions', 'user.id', 'user.default_profile_image', 'user.statuses_count', 'user.profile_text_color', 'user.following', 'user.is_translator', 'user.profile_background_image_url_https', 'user.lang', 'user.screen_name', 'user.entities.description.urls', 'user.entities.url.urls', 'user.friends_count', 'user.is_translation_enabled', 'user.has_extended_profile', 'user.followers_count', 'user.url', 'user.location', 'in_reply_to_status_id_str', 'user.contributors_enabled', 'created_at', 'user.name', 'docno', 'user.default_profile', 'content', 'retweeted', 'geo', 'in_reply_to_screen_name', 'srcjson', 'id_str', 'user.protected', 'user.profile_sidebar_fill_color', 'favorite_count', 'place', 'lang', 'favorited', 'user.profile_link_color', 'timestamp', 'user.profile_background_color', 'user.notifications', 'coordinates', 'truncated', 'user.description', 'user.favourites_count', 'user.time_zone', 'user.profile_image_url', 'user.geo_enabled', 'contributors'])
# dict_keys(['user.verified', 'user.listed_count', 'in_reply_to_status_id', 'user.profile_background_tile', 'entities.urls', 'in_reply_to_user_id_str', 'source', 'user.profile_sidebar_border_color', 'user.utc_offset', 'user.translator_type', 'entities.hashtags', 'entities.symbols', 'retweet_count', 'user.profile_use_background_image', 'user.id_str', 'is_quote_status', 'user.profile_banner_url', 'in_reply_to_user_id', 'text', 'id', 'user.created_at', 'user.profile_image_url_https', 'user.follow_request_sent', 'user.profile_background_image_url', 'entities.user_mentions', 'user.id', 'user.default_profile_image', 'user.statuses_count', 'user.profile_text_color', 'user.following', 'user.is_translator', 'user.profile_background_image_url_https', 'user.lang', 'user.screen_name', 'user.entities.description.urls', 'user.entities.url.urls', 'user.friends_count', 'user.is_translation_enabled', 'user.has_extended_profile', 'user.followers_count', 'user.url', 'user.location', 'in_reply_to_status_id_str', 'user.contributors_enabled', 'created_at', 'user.name', 'docno', 'user.default_profile', 'content', 'retweeted', 'geo', 'in_reply_to_screen_name', 'srcjson', 'id_str', 'user.protected', 'user.profile_sidebar_fill_color', 'favorite_count', 'place', 'lang', 'favorited', 'user.profile_link_color', 'timestamp', 'possibly_sensitive', 'user.profile_background_color', 'user.notifications', 'coordinates', 'truncated', 'user.description', 'user.favourites_count', 'user.time_zone', 'user.profile_image_url', 'user.geo_enabled', 'contributors'])
# dict_keys(['user.listed_count', 'user.verified', 'in_reply_to_status_id', 'user.profile_background_tile', 'entities.urls', 'in_reply_to_user_id_str', 'source', 'user.profile_sidebar_border_color', 'user.utc_offset', 'user.translator_type', 'entities.hashtags', 'retweet_count', 'entities.symbols', 'user.profile_use_background_image', 'user.id_str', 'is_quote_status', 'user.profile_banner_url', 'in_reply_to_user_id', 'id', 'text', 'metadata.result_type', 'user.created_at', 'user.profile_image_url_https', 'user.follow_request_sent', 'user.profile_background_image_url', 'entities.user_mentions', 'user.id', 'user.default_profile_image', 'user.statuses_count', 'user.profile_text_color', 'user.following', 'user.is_translator', 'user.profile_background_image_url_https', 'user.screen_name', 'user.lang', 'user.friends_count', 'user.entities.description.urls', 'user.entities.url.urls', 'user.is_translation_enabled', 'user.has_extended_profile', 'user.followers_count', 'user.url', 'user.location', 'in_reply_to_status_id_str', 'user.contributors_enabled', 'created_at', 'user.name', 'docno', 'user.default_profile', 'content', 'retweeted', 'geo', 'in_reply_to_screen_name', 'srcjson', 'metadata.iso_language_code', 'id_str', 'user.protected', 'user.profile_sidebar_fill_color', 'favorite_count', 'place', 'lang', 'favorited', 'user.profile_link_color', 'timestamp', 'possibly_sensitive', 'user.profile_background_color', 'coordinates', 'user.notifications', 'truncated', 'user.description', 'user.favourites_count', 'user.time_zone', 'user.profile_image_url', 'user.geo_enabled', 'contributors'])
# dict_keys(['user.listed_count', 'user.verified', 'in_reply_to_status_id', 'user.profile_background_tile', 'entities.urls', 'in_reply_to_user_id_str', 'source', 'user.profile_sidebar_border_color', 'user.utc_offset', 'user.translator_type', 'entities.hashtags', 'entities.symbols', 'retweet_count', 'user.profile_use_background_image', 'user.id_str', 'entities.media', 'is_quote_status', 'in_reply_to_user_id', 'id', 'text', 'user.created_at', 'user.profile_image_url_https', 'user.follow_request_sent', 'user.profile_background_image_url', 'entities.user_mentions', 'user.id', 'user.default_profile_image', 'user.statuses_count', 'user.profile_text_color', 'user.following', 'user.is_translator', 'user.profile_background_image_url_https', 'user.screen_name', 'user.lang', 'display_text_range', 'user.entities.description.urls', 'user.friends_count', 'user.is_translation_enabled', 'user.has_extended_profile', 'user.followers_count', 'user.url', 'user.location', 'in_reply_to_status_id_str', 'user.contributors_enabled', 'created_at', 'user.name', 'docno', 'user.default_profile', 'content', 'retweeted', 'geo', 'in_reply_to_screen_name', 'full_text', 'extended_entities.media', 'srcjson', 'id_str', 'user.protected', 'user.profile_sidebar_fill_color', 'favorite_count', 'place', 'lang', 'user.profile_link_color', 'favorited', 'timestamp', 'user.profile_background_color', 'possibly_sensitive', 'user.notifications', 'coordinates', 'truncated', 'user.description', 'user.favourites_count', 'user.time_zone', 'user.profile_image_url', 'user.geo_enabled', 'contributors'])
# dict_keys(['user.listed_count', 'retweeted_status.user.url', 'retweeted_status.user.profile_sidebar_fill_color', 'user.profile_background_tile', 'entities.urls', 'retweeted_status.user.geo_enabled', 'in_reply_to_user_id_str', 'retweeted_status.user.profile_background_image_url', 'retweeted_status.user.created_at', 'entities.hashtags', 'entities.symbols', 'retweeted_status.user.screen_name', 'retweeted_status.user.friends_count', 'retweeted_status.user.profile_text_color', 'is_quote_status', 'retweeted_status.user.id', 'id', 'text', 'retweeted_status.user.profile_background_image_url_https', 'retweeted_status.truncated', 'metadata.result_type', 'retweeted_status.place.bounding_box.coordinates', 'retweeted_status.user.profile_image_url', 'entities.user_mentions', 'user.id', 'user.profile_text_color', 'user.following', 'retweeted_status.in_reply_to_user_id_str', 'user.profile_background_image_url_https', 'retweeted_status.geo', 'retweeted_status.retweeted', 'retweeted_status.user.profile_link_color', 'retweeted_status.user.profile_sidebar_border_color', 'user.entities.description.urls', 'retweeted_status.coordinates', 'retweeted_status.user.id_str', 'retweeted_status.user.utc_offset', 'user.followers_count', 'user.location', 'retweeted_status.user.time_zone', 'retweeted_status.metadata.result_type', 'in_reply_to_status_id_str', 'retweeted_status.user.is_translation_enabled', 'created_at', 'user.name', 'retweeted_status.user.profile_background_tile', 'retweeted_status.retweet_count', 'docno', 'retweeted_status.source', 'retweeted_status.place.url', 'retweeted', 'geo', 'retweeted_status.entities.symbols', 'retweeted_status.place.country_code', 'srcjson', 'metadata.iso_language_code', 'retweeted_status.favorited', 'user.protected', 'place', 'timestamp', 'retweeted_status.user.has_extended_profile', 'retweeted_status.text', 'retweeted_status.user.location', 'user.profile_background_color', 'retweeted_status.contributors', 'coordinates', 'truncated', 'retweeted_status.entities.hashtags', 'user.description', 'retweeted_status.place.full_name', 'retweeted_status.user.followers_count', 'retweeted_status.user.contributors_enabled', 'retweeted_status.in_reply_to_status_id_str', 'retweeted_status.in_reply_to_screen_name', 'retweeted_status.entities.user_mentions', 'retweeted_status.user.is_translator', 'retweeted_status.user.translator_type', 'user.profile_image_url', 'retweeted_status.place.place_type', 'retweeted_status.user.verified', 'user.verified', 'retweeted_status.user.following', 'retweeted_status.favorite_count', 'retweeted_status.user.profile_banner_url', 'in_reply_to_status_id', 'retweeted_status.user.favourites_count', 'source', 'retweeted_status.in_reply_to_status_id', 'retweeted_status.place.country', 'user.profile_sidebar_border_color', 'user.utc_offset', 'user.translator_type', 'retweet_count', 'user.profile_use_background_image', 'user.id_str', 'retweeted_status.user.default_profile', 'user.profile_banner_url', 'in_reply_to_user_id', 'user.created_at', 'user.profile_image_url_https', 'user.follow_request_sent', 'user.profile_background_image_url', 'retweeted_status.entities.urls', 'retweeted_status.user.entities.description.urls', 'retweeted_status.id_str', 'user.default_profile_image', 'user.statuses_count', 'retweeted_status.metadata.iso_language_code', 'retweeted_status.user.default_profile_image', 'retweeted_status.user.statuses_count', 'user.is_translator', 'user.screen_name', 'user.lang', 'retweeted_status.user.listed_count', 'user.friends_count', 'retweeted_status.is_quote_status', 'user.is_translation_enabled', 'user.has_extended_profile', 'retweeted_status.user.lang', 'user.url', 'user.contributors_enabled', 'retweeted_status.place.contained_within', 'retweeted_status.place.bounding_box.type', 'retweeted_status.user.profile_use_background_image', 'user.default_profile', 'content', 'in_reply_to_screen_name', 'retweeted_status.in_reply_to_user_id', 'retweeted_status.lang', 'id_str', 'retweeted_status.place.id', 'use ...
# dict_keys(['user.showAllInlineMedia', 'inReplyToUserId', 'user.profileBannerImageUrl', 'source', 'user.profileImageUrlHttps', 'user.profileImageUrl', 'user.listedCount', 'createdAt', 'hashtagEntities', 'user.profileSidebarFillColor', 'mediaEntities', 'isPossiblySensitive', 'user.isDefaultProfileImage', 'id', 'text', 'isRetweeted', 'place.placeType', 'isTruncated', 'user.isFollowRequestSent', 'user.id', 'user.friendsCount', 'user.statusesCount', 'user.profileBackgroundImageUrlHttps', 'quotedStatusId', 'place.id', 'user.profileSidebarBorderColor', 'user.isVerified', 'user.profileBackgroundColor', 'user.favouritesCount', 'user.translator', 'user.lang', 'user.utcOffset', 'user.isContributorsEnabled', 'place.boundingBoxType', 'user.profileLinkColor', 'user.url', 'user.profileUseBackgroundImage', 'user.profileTextColor', 'user.profileBackgroundTiled', 'userMentionEntities', 'place.url', 'user.name', 'user.isDefaultProfile', 'docno', 'content', 'place.country', 'currentUserRetweetId', 'inReplyToStatusId', 'srcjson', 'user.isGeoEnabled', 'contributorsIDs', 'user.createdAt', 'lang', 'timestamp', 'displayTextRangeEnd', 'place.name', 'user.descriptionURLEntities', 'place.countryCode', 'place.fullName', 'isFavorited', 'displayTextRangeStart', 'user.description', 'user.profileBackgroundImageUrl', 'user.screenName', 'user.followersCount', 'user.isProtected', 'urlEntities', 'place.boundingBoxCoordinates', 'symbolEntities', 'retweetCount', 'favoriteCount'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-6ac7d8cab7bc> in <module>
#      14 user_location = []
#      15 for each in files:
# ---> 16     a, b, c, d, f, i = gettweets(filen+each)
#      17     ids.extend(a)
#      18     tweet.extend(b)
#
# <ipython-input-99-37d6da8f637c> in gettweets(filename)
#      29         allid.append(data[i]['allProperties']['id'])
#      30         alltopics.append(data[i]['topic'])
# ---> 31         retweet.append(data[i]['allProperties']['retweet_count'])
#      32         #follower_count.append(data[i]['allProperties']['user.followers_count'])
#      33         source.append(data[i]['allProperties']['source'])
#
# KeyError: 'retweet_count'

# %%
tweetdf = pd.DataFrame([ids, tweet, topic, source, user_created_at, tweet_created_at, user_lang, user_screen_name, user_location]).T

# %%
tweetdf.columns = ['ID', 'Tweet', 'Event', 'Retweet_Count', 'Follower_Count', 'Source', 'User_Created_at', 'Tweet_Created_at', 'User_Language', 'User_Screen_Name', 'User_Location']

# %%
tweetdf.head(100)
# Out:
#                     ID                                              Tweet  \
# 0   389908166353231872  Earthquake in Iloilo, Philippines! My head's a...
# 1   389909609190006784  RT @LastQuake: NEW: Felt #earthquake M7.0 - Bo...
# 2   389910137676107776  RT @NewEarthquake: 7.2 earthquake, 2km S of Nu...
# 3   389910670361100288  RT @gmanews: JUST IN: Magnitude 7.2 earthquake...
# 4   389911173665001472  RT @NewEarthquake: 7.2 earthquake, 2km S of Nu...
# 5   389911358214393856  RT @gmanews: JUST IN: Magnitude 7.2 earthquake...
# 6   389911794442964992  RT @BreakingNews: 7.2 earthquake recorded in t...
# 7   389911937040932864  RT @NewEarthquake: 7.2 earthquake, 2km S of Nu...
# 8   389911949644808193  RT @NewEarthquake: 7.2 earthquake, 2km S of Nu...
# 9   389912650068402177  Southern Philippines hit by 7.4 magnitude eart...
# 10  389913589596704768  RT @LanceUlanoff: 7.2 Earthquake in Philippine...
# 11  389913644131045376  RT @ABC7: #EARTHQUAKE Quake with prelim mag of...
# 12  389913971287154688  RT @RT_com: #BREAKING: 7.2 quake hits southern...
# 13  389914239730610176  Magnitude 7.4 quake hits Philippines, no tsuna...
# 14  389915464446795776  RT @NWS_PTWC: NO widespread tsunami hazard for...
# 15  389917091823763456  USGS M 7.2, 5km E of Balilihan, Philippines: T...
# 16  389917750363029504  #Temblorâ™¨ M 5.4, 6km NNE of Nueva Fuerza, Ph...
# 17  389918857642536960  RT @Tweetbrk: NEW: Significant preliminary 7.2...
# 18  389919981720195073  RT @hamburqa: there was a 7.2 magnitude earthq...
# 19  389920120119635969  National Disaster Agency: 4 people killed in b...
# 20  389920547934449664  A 7.4 magnitude #earthquake has hit the southe...
# 21  389922229871321088  RT @BreakingNews: 4 people killed in building ...
# 22  389922594788364288  7.4 quake strikes Philippines http://t.co/CYFz...
# 23  389922607333515264  RT @BreakingNews: 4 people killed in building ...
# 24  389923207127392256  RT @YahooNews: Magnitude 7.4 quake hits Philip...
# 25  389923253285707776  RT @ilovejamich: Magnitude 7.2 #earthquake in ...
# 26  389924079555207168  RT @cnni: A 7.2-magnitude earthquake has struc...
# 27  389924092130107392  #earthquake M7.2: Bohol, Philippines http://t....
# 28  389924213751963649  Lord God, keep the people safe in the Philippi...
# 29  389924276666523650  RT @abcnews: #Breaking: #Earthquake measuring ...
# ..                 ...                                                ...
# 70  389939543966613504  RT @alliharvard: i just heard about the earthq...
# 71  389940768703406081              Before anything else, #PrayforVisayas
# 72  389941125185687552  RT @enzodeocales: 411 Year old Loboc Church in...
# 73  389941297169321985  At least 4 people killed after 7.2 #earthquake...
# 74  389941557203185665  "A 7.2-magnitude earthquake struck in southeas...
# 75  389941670466166784  Mayor Rama announced no classes for both priva...
# 76  389942765183696897  RT @BILLYversCebu: Earthquake!!! First time I ...
# 77  389942966506500096  Magnitude 7.1 earthquake hits the Philippines!...
# 78  389943318836047872  RT @QueenPetraK: 1 Retweet = 1 Prayer\n\n#Pray...
# 79  389943503364849665  RT @FeedTheChildren: Please pray for the peopl...
# 80  389943947956862976  Bible Prophecy, Rapture, 7.2 Earthquake Philip...
# 81  389944447108014080  Magnitude-7.1 earthquake hits the Philippines:...
# 82  389944585511641088  RT @QueenPetraK: 1 Retweet = 1 Prayer\n\n#Pray...
# 83  389946850444185601    Sad,sad,sad news...🙏🙏#PrayForBohol #PrayForCebu
# 84  389947278230052864  Major earthquake hits the Philippines - http:/...
# 85  389947676717875200                    Lord,help us... #PrayForVisayas
# 86  389947907412996096  RT @inquirerdotnet: INFOGRAPHIC: Map locating ...
# 87  389948112904544256  RT @NewEarthquake: 5.0 earthquake, 2km SSE of ...
# 88  389948574282158081  RT @GandangGabiVice: This is really heartbreak...
# 89  389948620432101376  RT @BILLYversCebu: So this is what happened to...
# 90  389948880474763264  RT @GandangGabiVice: This is really heartbreak...
# 91  389948922413592576  Emang di pilipina ada apaan min ?"@Update_Tran...
# 92  389949027283775488  Let's say our prayers for those affected by th...
# 93  389949367009808384  @G2BArmyCebu Keepsafe ! #PrayForVisayas #PrayF...
# 94  389949492839342080  RT @NewEarthquake: 7.2 earthquake, 2km S of Nu...
# 95  389950365258350592  @tomlinsondisney yep. search for #PrayForVisay...
# 96  389950730175389696  RT @GandangGabiVice: This is really heartbreak...
# 97  389950767898951681  RT @SaklapFriend: God is good all the time. #P...
# 98  389950814061486080  #PrayForVisayas Earthquake go away don't come ...
# 99  389950969225568257             #PrayForVisayas Keep safe everyone! :(
#
#                   Event                                             Source  \
# 0   earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 1   earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 2   earthquakeBohol2013  <a href="http://twitter.com/download/iphone" r...
# 3   earthquakeBohol2013  <a href="http://stone.com/Twittelator" rel="no...
# 4   earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 5   earthquakeBohol2013  <a href="http://blackberry.com/twitter" rel="n...
# 6   earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 7   earthquakeBohol2013  <a href="http://twitter.com/download/iphone" r...
# 8   earthquakeBohol2013  <a href="http://twitter.com/#!/download/ipad" ...
# 9   earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 10  earthquakeBohol2013  <a href="http://twitter.com/download/iphone" r...
# 11  earthquakeBohol2013  <a href="http://www.myplume.com/" rel="nofollo...
# 12  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 13  earthquakeBohol2013  <a href="http://twitterfeed.com" rel="nofollow...
# 14  earthquakeBohol2013  <a href="http://twitter.com/#!/download/ipad" ...
# 15  earthquakeBohol2013  <a href="http://twitterfeed.com" rel="nofollow...
# 16  earthquakeBohol2013  <a href="https://dlvrit.com/" rel="nofollow">d...
# 17  earthquakeBohol2013  <a href="http://twitter.com/download/iphone" r...
# 18  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 19  earthquakeBohol2013  <a href="http://www.socialflow.com" rel="nofol...
# 20  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 21  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 22  earthquakeBohol2013  <a href="https://dlvrit.com/" rel="nofollow">d...
# 23  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 24  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 25  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 26  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 27  earthquakeBohol2013  <a href="http://www.hootsuite.com" rel="nofoll...
# 28  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 29  earthquakeBohol2013  <a href="http://twitter.com/#!/download/ipad" ...
# ..                  ...                                                ...
# 70  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 71  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 72  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 73  earthquakeBohol2013  <a href="http://www.GlobalSunTimes.com" rel="n...
# 74  earthquakeBohol2013  <a href="https://itunes.apple.com/us/app/cnn-a...
# 75  earthquakeBohol2013  <a href="https://about.twitter.com/products/tw...
# 76  earthquakeBohol2013  <a href="http://twitter.com/#!/download/ipad" ...
# 77  earthquakeBohol2013  <a href="https://mobile.twitter.com" rel="nofo...
# 78  earthquakeBohol2013  <a href="https://about.twitter.com/products/tw...
# 79  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 80  earthquakeBohol2013  <a href="https://ifttt.com" rel="nofollow">IFT...
# 81  earthquakeBohol2013  <a href="http://twitterfeed.com" rel="nofollow...
# 82  earthquakeBohol2013  <a href="https://about.twitter.com/products/tw...
# 83  earthquakeBohol2013  <a href="http://twitter.com/download/iphone" r...
# 84  earthquakeBohol2013  <a href="http://www.twistools.com" rel="nofoll...
# 85  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 86  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 87  earthquakeBohol2013  <a href="http://www.twitter.com" rel="nofollow...
# 88  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 89  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 90  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 91  earthquakeBohol2013  <a href="http://blackberry.com/twitter" rel="n...
# 92  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 93  earthquakeBohol2013  <a href="https://about.twitter.com/products/tw...
# 94  earthquakeBohol2013  <a href="https://mobile.twitter.com" rel="nofo...
# 95  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 96  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 97  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 98  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 99  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
#
#    User_Language
# 0             en
# 1             es
# 2             es
# 3             en
# 4             en
# 5             en
# 6             en
# 7             es
# 8             en
# 9             en
# 10            en
# 11            en
# 12            en
# 13            en
# 14            es
# 15            en
# 16            en
# 17            en
# 18            en
# 19            en
# 20            en
# 21            en
# 22            en
# 23            en
# 24            en
# 25            en
# 26            en
# 27            nl
# 28            en
# 29            en
# ..           ...
# 70            en
# 71            en
# 72            en
# 73            en
# 74            en
# 75            en
# 76            en
# 77            en
# 78            en
# 79            en
# 80            en
# 81            en
# 82            en
# 83            en
# 84            fr
# 85            en
# 86            en
# 87            ja
# 88            en
# 89            en
# 90            en
# 91            id
# 92            en
# 93            en
# 94            en
# 95            en
# 96            en
# 97            en
# 98            en
# 99            en
#
# [100 rows x 5 columns]

# %%
'''
    Opening a json contianing descriptions about the events on which the tweets are about
'''
with open('TRECIS_2018_2019-labels/TRECIS_2018_2019-labels.json', 'r', encoding = 'utf-8' ) as fp:
        data = json.loads("[" + fp.read().replace("}\n{", "},\n{") + "]")
        tweetid = []
        event_desc = []
        cat = []
        priority = []
        
        for i in range (len(data[0])):
            tweetid.append(data[0][i]['postID'])
            event_desc.append(data[0][i]['eventDescription'])
            cat.append(data[0][i]['postCategories'])
            priority.append(data[0][i]['postPriority'])

# %%
len(tweetid), len(event_desc), len(cat), len(priority)
# Out:
# (38478, 38478, 38478, 38478)

# %%
labeldf = pd.DataFrame([tweetid, event_desc, cat, priority]).T

# %%
labeldf.columns = ['ID', 'Event_Decrption', 'Categories', 'Priority']

# %%
labeldf.tail(10)
# Out:
#                         ID                                    Event_Decrption  \
# 38468  1135532790601068546  The 2019 Alberta wildfires were described by N...
# 38469  1135535392818679808  The 2019 Alberta wildfires were described by N...
# 38470  1135535540051353602  The 2019 Alberta wildfires were described by N...
# 38471  1135551329705873409  The 2019 Alberta wildfires were described by N...
# 38472  1135552993254920194  The 2019 Alberta wildfires were described by N...
# 38473  1135557504484687872  The 2019 Alberta wildfires were described by N...
# 38474  1135560375074603008  The 2019 Alberta wildfires were described by N...
# 38475  1135560828298510336  The 2019 Alberta wildfires were described by N...
# 38476  1135561309573902336  The 2019 Alberta wildfires were described by N...
# 38477  1135561310513451008  The 2019 Alberta wildfires were described by N...
#
#                                               Categories Priority
# 38468  [FirstPartyObservation, Location, MultimediaSh...      Low
# 38469  [Location, MultimediaShare, Factoid, Hashtags,...      Low
# 38470                  [Location, MultimediaShare, News]      Low
# 38471                                         [Location]   Medium
# 38472  [Location, MultimediaShare, Official, Hashtags...      Low
# 38473  [Weather, Location, MultimediaShare, Hashtags,...      Low
# 38474  [Location, MultimediaShare, Official, Hashtags...      Low
# 38475         [Location, Factoid, ContextualInformation]      Low
# 38476        [Location, MultimediaShare, Hashtags, News]      Low
# 38477                [Location, Factoid, Hashtags, News]   Medium

# %%
'''
    Inner join on the tweets and label df to arrive at a comprehensive df
'''

joindf = pd.merge(tweetdf,labeldf,on='ID')

# %%
joindf.head()
# Out:
#                    ID                                              Tweet  \
# 0  389908166353231872  Earthquake in Iloilo, Philippines! My head's a...
# 1  389909609190006784  RT @LastQuake: NEW: Felt #earthquake M7.0 - Bo...
# 2  389910670361100288  RT @gmanews: JUST IN: Magnitude 7.2 earthquake...
# 3  389912650068402177  Southern Philippines hit by 7.4 magnitude eart...
# 4  389913589596704768  RT @LanceUlanoff: 7.2 Earthquake in Philippine...
#
#                  Event                                             Source  \
# 0  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  earthquakeBohol2013  <a href="http://twitter.com/download/android" ...
# 2  earthquakeBohol2013  <a href="http://stone.com/Twittelator" rel="no...
# 3  earthquakeBohol2013  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  earthquakeBohol2013  <a href="http://twitter.com/download/iphone" r...
#
#   User_Language                                    Event_Decrption  \
# 0            en  The 2013 Bohol earthquake occurred on October ...
# 1            es  The 2013 Bohol earthquake occurred on October ...
# 2            en  The 2013 Bohol earthquake occurred on October ...
# 3            en  The 2013 Bohol earthquake occurred on October ...
# 4            en  The 2013 Bohol earthquake occurred on October ...
#
#                                    Categories Priority
# 0                                [Irrelevant]      Low
# 1                 [MultimediaShare, Hashtags]      Low
# 2  [Location, MultimediaShare, Factoid, News]      Low
# 3                            [Location, News]      Low
# 4                  [MultimediaShare, Factoid]      Low

# %%
joindf.to_csv('Ultimate Dataframe.csv')
